# %%
import os
import pymorphy2
import re
import string

# %%
#Парсинг датасета

# %%
dataset = 'devset'

# %%
factrueval_dev_tokens = dict()
factrueval_dev_tokens_list = []
factrueval_dev_spans = dict()
factrueval_dev_objects = dict()

# %%
#Проходимся по всем файлам в папке
for file in os.listdir('./'+ dataset + '/'):
    if file.endswith('tokens'):
        with open('./' + dataset + '/' + file, 'r+', encoding='utf-8') as file_obj: 
            for line in file_obj.readlines():
                token = line.split()
                if token != []:
                     factrueval_dev_tokens[int(token[0])] = token[1:]
                factrueval_dev_tokens_list.append(token)
                
    if file.endswith('spans'):
        with open('./' + dataset + '/' + file, 'r+', encoding='utf-8') as file_obj:
            for line in file_obj.readlines():
                span = line.split()
                if span != []:
                    factrueval_dev_spans[span[0]] = span[1:]
    
    if file.endswith('objects'):
        with open('./' + dataset + '/' + file, 'r+', encoding='utf-8') as file_obj:
            for line in file_obj.readlines():
                object = line.split('#')[0].split()
                if object != []:
                    factrueval_dev_objects[object[0]] = object[1:]

# %%
factrueval_dev_tokens
# Out:
# {143783: ['0', '1', 'В'],
#  143784: ['2', '11', 'понедельник'],
#  143785: ['14', '2', '28'],
#  143786: ['17', '4', 'июня'],
#  143787: ['22', '1', 'у'],
#  143788: ['24', '6', 'здания'],
#  143789: ['31', '5', 'мэрии'],
#  143790: ['37', '6', 'Москвы'],
#  143791: ['44', '2', 'на'],
#  143792: ['47', '8', 'Тверской'],
#  143793: ['56', '7', 'площади'],
#  143794: ['64', '10', 'состоялась'],
#  143795: ['75', '9', 'очередная'],
#  143796: ['85', '19', 'несанкционированная'],
#  143797: ['105', '5', 'акция'],
#  143798: ['111', '8', 'протеста'],
#  143799: ['120', '1', '«'],
#  143800: ['121', '4', 'День'],
#  143801: ['126', '5', 'гнева'],
#  143802: ['131', '1', '»'],
#  143803: ['132', '1', ','],
#  143804: ['134', '1', 'в'],
#  143805: ['136', '4', 'этот'],
#  143806: ['141', '3', 'раз'],
#  143807: ['145', '12', 'направленная'],
#  143808: ['157', '1', ','],
#  143809: ['159', '7', 'главным'],
#  143810: ['167', '7', 'образом'],
#  143811: ['174', '1', ','],
#  143812: ['176', '6', 'против'],
#  143813: ['183', '8', 'политики'],
#  143814: ['192', '10', 'московских'],
#  143815: ['203', '1', 'и'],
#  143816: ['205', '12', 'подмосковных'],
#  143817: ['218', '7', 'властей'],
#  143818: ['225', '1', '.'],
#  143819: ['227', '5', 'Среди'],
#  143820: ['233', '10', 'требований'],
#  143821: ['243', '1', ','],
#  143822: ['245', '11', 'выдвигаемых'],
#  143823: ['257', '14', 'организаторами'],
#  143824: ['272', '5', 'акции'],
#  143825: ['277', '1', ':'],
#  143826: ['279', '1', '«'],
#  143827: ['280', '11', 'немедленная'],
#  143828: ['292', '8', 'отставка'],
#  143829: ['301', '4', 'мэра'],
#  143830: ['306', '6', 'Москвы'],
#  143831: ['313', '4', 'Юрия'],
#  143832: ['318', '7', 'Лужкова'],
#  143833: ['325', '1', ','],
#  143834: ['327', '13', 'расследование'],
#  143835: ['341', '6', 'итогов'],
#  143836: ['348', '3', 'его'],
#  143837: ['352', '12', 'деятельности'],
#  143838: ['364', '1', '»'],
#  143839: ['365', '1', ','],
#  143840: ['367', '1', '«'],
#  143841: ['368', '5', 'созыв'],
#  143842: ['374', '11', 'московского'],
#  143843: ['386', '13', 'общественного'],
#  143844: ['400', '6', 'форума'],
#  143845: ['407', '3', 'для'],
#  143846: ['411', '10', 'обсуждения'],
#  143847: ['422', '5', 'путей'],
#  143848: ['428', '14', 'реформирования'],
#  143849: ['443', '8', 'основных'],
#  143850: ['452', '4', 'сфер'],
#  143851: ['457', '17', 'жизнедеятельности'],
#  143852: ['475', '1', 'в'],
#  143853: ['477', '6', 'Москве'],
#  143854: ['483', '1', '»'],
#  143855: ['484', '1', ','],
#  143856: ['486', '1', '«'],
#  143857: ['487', '14', 'восстановление'],
#  143858: ['502', '6', 'прямых'],
#  143859: ['509', '7', 'выборов'],
#  143860: ['517', '4', 'глав'],
#  143861: ['522', '8', 'регионов'],
#  143862: ['531', '6', 'России'],
#  143863: ['537', '1', '»'],
#  143864: ['538', '1', ','],
#  143865: ['540', '1', '«'],
#  143866: ['541', '7', 'роспуск'],
#  143867: ['549', '12', 'нелегитимной'],
#  143868: ['562', '10', 'Мосгордумы'],
#  143869: ['572', '1', '»'],
#  143870: ['573', '1', ','],
#  143871: ['575', '8', 'отставка'],
#  143872: ['584', '13', 'подмосковного'],
#  143873: ['598', '11', 'губернатора'],
#  143874: ['610', '6', 'Бориса'],
#  143875: ['617', '7', 'Громова'],
#  143876: ['625', '1', 'и'],
#  143877: ['627', '2', 'др'],
#  143878: ['629', '1', '.'],
#  143879: ['631', '10', 'Участникам'],
#  143880: ['642', '5', 'акции'],
#  143881: ['648', '12', 'предлагалось'],
#  143882: ['661', '8', 'принести'],
#  143883: ['670', '1', 'с'],
#  143884: ['672', '5', 'собой'],
#  143885: ['678', '4', 'лист'],
#  143886: ['683', '6', 'бумаги'],
#  143887: ['690', '3', 'или'],
#  143888: ['694', '5', 'кусок'],
#  143889: ['700', '5', 'ткани'],
#  143890: ['706', '7', 'чёрного'],
#  143891: ['714', '5', 'цвета'],
#  143892: ['719', '1', ','],
#  143893: ['721', '15', 'символизирующие'],
#  143894: ['737', '1', '«'],
#  143895: ['738', '6', 'чёрную'],
#  143896: ['745', '5', 'метку'],
#  143897: ['750', '1', '»'],
#  143898: ['752', '3', 'для'],
#  143899: ['756', '4', 'Юрия'],
#  143900: ['761', '7', 'Лужкова'],
#  143901: ['768', '1', '.'],
#  143902: ['771', '6', 'Начало'],
#  143903: ['778', '5', 'акции'],
#  143904: ['784', '4', 'было'],
#  143905: ['789', '8', 'намечено'],
#  143906: ['798', '2', 'на'],
#  143907: ['801', '2', '19'],
#  143908: ['804', '5', 'часов'],
#  143909: ['809', '1', ';'],
#  143910: ['811', '14', 'подчёркивалось'],
#  143911: ['825', '1', ','],
#  143912: ['827', '3', 'что'],
#  143913: ['831', '3', 'она'],
#  143914: ['835', '9', 'состоится'],
#  143915: ['845', '8', 'несмотря'],
#  143916: ['854', '2', 'на'],
#  143917: ['857', '6', 'запрет'],
#  143918: ['864', '7', 'властей'],
#  143919: ['871', '1', '.'],
#  143920: ['873', '10', 'Освещающие'],
#  143921: ['884', '5', 'акцию'],
#  143922: ['890', '8', 'блоггеры'],
#  143923: ['899', '8', 'сообщили'],
#  143924: ['907', '1', ','],
#  143925: ['909', '3', 'что'],
#  143926: ['913', '8', 'автобусы'],
#  143927: ['922', '1', 'с'],
#  143928: ['924', '8', 'милицией'],
#  143929: ['933', '5', 'стали'],
#  143930: ['939', '8', 'занимать'],
#  143931: ['948', '7', 'площадь'],
#  143932: ['956', '1', 'у'],
#  143933: ['958', '9', 'памятника'],
#  143934: ['968', '4', 'Юрию'],
#  143935: ['973', '11', 'Долгорукому'],
#  143936: ['985', '3', 'ещё'],
#  143937: ['989', '1', 'с'],
#  143938: ['991', '2', '15'],
#  143939: ['994', '5', 'часов'],
#  143940: ['1000', '3', 'дня'],
#  143941: ['1003', '1', ','],
#  143942: ['1005', '11', 'центральная'],
#  143943: ['1017', '5', 'часть'],
#  143944: ['1023', '7', 'площади'],
#  143945: ['1031', '4', 'была'],
#  143946: ['1036', '9', 'огорожена'],
#  143947: ['1045', '1', '.'],
#  143948: ['1047', '2', 'Ко'],
#  143949: ['1050', '7', 'времени'],
#  143950: ['1058', '6', 'начала'],
#  143951: ['1065', '5', 'акции'],
#  143952: ['1071', '6', 'вокруг'],
#  143953: ['1078', '11', 'огороженной'],
#  143954: ['1090', '10', 'территории'],
#  143955: ['1101', '9', 'собралось'],
#  143956: ['1111', '9', 'множество'],
#  143957: ['1121', '11', 'журналистов'],
#  143958: ['1133', '1', 'и'],
#  143959: ['1135', '8', 'прохожих'],
#  143960: ['1143', '1', ','],
#  143961: ['1145', '2', 'по'],
#  143962: ['1148', '4', 'мере'],
#  143963: ['1153', '8', 'прибытия'],
#  143964: ['1162', '5', 'самих'],
#  143965: ['1168', '10', 'участников'],
#  143966: ['1179', '5', 'акции'],
#  143967: ['1185', '7', 'милиция'],
#  143968: ['1193', '6', 'начала'],
#  143969: ['1200', '10', 'планомерно'],
#  143970: ['1211', '2', 'их'],
#  143971: ['1214', '11', 'задерживать'],
#  143972: ['1226', '1', 'и'],
#  143973: ['1228', '11', 'заталкивать'],
#  143974: ['1240', '1', 'в'],
#  143975: ['1242', '8', 'автобусы'],
#  143976: ['1250', '1', '.'],
#  143977: ['1253', '5', 'Всего'],
#  143978: ['1258', '1', ','],
#  143979: ['1260', '2', 'по'],
#  143980: ['1263', '10', 'сообщениям'],
#  143981: ['1274', '9', 'блоггеров'],
#  143982: ['1284', '1', 'и'],
#  143983: ['1286', '3', 'СМИ'],
#  143984: ['1289', '1', ','],
#  143985: ['1291', '4', 'было'],
#  143986: ['1296', '9', 'задержано'],
#  143987: ['1306', '5', 'более'],
#  143988: ['1312', '2', '30'],
#  143989: ['1315', '7', 'человек'],
#  143990: ['1322', '1', '.'],
#  143991: ['1324', '12', 'Пользователь'],
#  143992: ['1337', '2', 'ЖЖ'],
#  143993: ['1340', '5', 'zyalt'],
#  143994: ['1346', '8', 'сообщает'],
#  143995: ['1354', '1', ','],
#  143996: ['1356', '3', 'что'],
#  143997: ['1360', '5', 'среди'],
#  143998: ['1366', '11', 'задержанных'],
#  143999: ['1378', '8', 'оказался'],
#  144000: ['1387', '7', 'депутат'],
#  144001: ['1395', '14', 'муниципального'],
#  144002: ['1410', '8', 'собрания'],
#  144003: ['1419', '6', 'района'],
#  144004: ['1426', '8', 'Отрадное'],
#  144005: ['1434', '1', ','],
#  144006: ['1436', '14', 'сопредседатель'],
#  144007: ['1451', '11', 'московского'],
#  144008: ['1463', '9', 'отделения'],
#  144009: ['1473', '8', 'движения'],
#  144010: ['1482', '1', '«'],
#  144011: ['1483', '12', 'Солидарность'],
#  144012: ['1495', '1', '»'],
#  144013: ['1497', '6', 'Михаил'],
#  144014: ['1504', '9', 'Вельмакин'],
#  144015: ['1513', '1', ','],
#  144016: ['1515', '9', 'известный'],
#  144017: ['1525', '13', 'правозащитник'],
#  144018: ['1539', '3', 'Лев'],
#  144019: ['1543', '9', 'Пономарев'],
#  144020: ['1552', '1', ','],
#  144021: ['1554', '11', 'координатор'],
#  144022: ['1566', '8', 'движения'],
#  144023: ['1575', '1', '«'],
#  144024: ['1576', '5', 'Левый'],
#  144025: ['1582', '5', 'фронт'],
#  144026: ['1587', '1', '»'],
#  144027: ['1589', '6', 'Сергей'],
#  144028: ['1596', '8', 'Удальцов'],
#  144029: ['1604', '1', '.'],
#  144030: ['1607', '14', 'Организаторами'],
#  144031: ['1622', '5', 'акции'],
#  144032: ['1628', '9', 'выступили'],
#  144033: ['1638', '8', 'движение'],
#  144034: ['1647', '1', '«'],
#  144035: ['1648', '2', 'За'],
#  144036: ['1651', '5', 'права'],
#  144037: ['1657', '8', 'человека'],
#  144038: ['1665', '1', '»'],
#  144039: ['1666', '1', ','],
#  144040: ['1668', '4', 'Союз'],
#  144041: ['1673', '15', 'координационных'],
#  144042: ['1689', '7', 'советов'],
#  144043: ['1697', '1', '('],
#  144044: ['1698', '3', 'СКС'],
#  144045: ['1701', '1', ')'],
#  144046: ['1702', '1', ','],
#  144047: ['1704', '8', 'институт'],
#  144048: ['1713', '1', '«'],
#  144049: ['1714', '12', 'Коллективное'],
#  144050: ['1727', '8', 'действие'],
#  144051: ['1735', '1', '»'],
#  144052: ['1736', '1', ','],
#  144053: ['1738', '1', '«'],
#  144054: ['1739', '8', 'Жилищная'],
#  144055: ['1748', '12', 'солидарность'],
#  144056: ['1760', '1', '»'],
#  144057: ['1761', '1', ','],
#  144058: ['1763', '8', 'Движение'],
#  144059: ['1772', '9', 'общежитий'],
#  144060: ['1782', '6', 'Москвы'],
#  144061: ['1788', '1', ','],
#  144062: ['1790', '8', 'Движение'],
#  144063: ['1799', '1', 'в'],
#  144064: ['1801', '6', 'защиту'],
#  144065: ['1808', '11', 'Химкинского'],
#  144066: ['1820', '4', 'леса'],
#  144067: ['1824', '1', ','],
#  144068: ['1826', '8', 'движение'],
#  144069: ['1835', '1', '«'],
#  144070: ['1836', '10', 'Московский'],
#  144071: ['1847', '5', 'совет'],
#  144072: ['1852', '1', '»'],
#  144073: ['1853', '1', ','],
#  144074: ['1855', '1', '«'],
#  144075: ['1856', '15', 'Координационный'],
#  144076: ['1872', '5', 'совет'],
#  144077: ['1878', '12', 'пострадавших'],
#  144078: ['1891', '12', 'соинвесторов'],
#  144079: ['1903', '1', '»'],
#  144080: ['1904', '1', '.'],
#  149382: ['0', '5', 'Конец'],
#  149383: ['6', '5', 'света'],
#  149384: ['11', '1', ','],
#  149385: ['13', '7', 'который'],
#  149386: ['21', '9', 'предрекал'],
#  149387: ['31', '11', 'проповедник'],
#  149388: ['42', '1', '-'],
#  149389: ['43', '10', 'евангелист'],
#  149390: ['54', '7', 'Герольд'],
#  149391: ['62', '7', 'Кемпинг'],
#  149392: ['70', '5', 'утром'],
#  149393: ['76', '1', 'в'],
#  149394: ['78', '5', '06.00'],
#  149395: ['84', '2', 'по'],
#  149396: ['87', '11', 'московскому'],
#  149397: ['99', '7', 'времени'],
#  149398: ['107', '2', '21'],
#  149399: ['110', '3', 'мая'],
#  149400: ['114', '4', '2011'],
#  149401: ['119', '4', 'года'],
#  149402: ['124', '3', 'так'],
#  149403: ['128', '1', 'и'],
#  149404: ['130', '2', 'не'],
#  149405: ['133', '8', 'наступил'],
#  149406: ['141', '1', '.'],
#  149407: ['144', '3', 'Это'],
#  149408: ['148', '6', 'далеко'],
#  149409: ['155', '2', 'не'],
#  149410: ['158', '6', 'первое'],
#  149411: ['165', '11', 'несбывшееся'],
#  149412: ['177', '12', 'предсказание'],
#  149413: ['190', '12', 'апокалипсиса'],
#  149414: ['202', '1', '.'],
#  149415: ['204', '8', 'Поначалу'],
#  149416: ['213', '2', 'на'],
#  149417: ['216', '4', 'него'],
#  149418: ['221', '11', 'практически'],
#  149419: ['233', '2', 'не'],
#  149420: ['236', '8', 'обратили'],
#  149421: ['245', '8', 'внимания'],
#  149422: ['253', '1', ','],
#  149423: ['255', '6', 'однако'],
#  149424: ['261', '1', ','],
#  149425: ['263', '1', 'с'],
#  149426: ['265', '12', 'приближением'],
#  149427: ['278', '4', 'этой'],
#  149428: ['283', '4', 'даты'],
#  149429: ['287', '1', ','],
#  149430: ['289', '6', 'немало'],
#  149431: ['296', '3', 'СМИ'],
#  149432: ['300', '1', 'в'],
#  149433: ['302', '7', 'поисках'],
#  149434: ['310', '6', 'сюжета'],
#  149435: ['316', '1', ','],
#  149436: ['318', '15', 'останавливались'],
#  149437: ['334', '2', 'на'],
#  149438: ['337', '4', 'этом'],
#  149439: ['341', '1', ','],
#  149440: ['343', '8', 'создавая'],
#  149441: ['352', '10', 'прекрасную'],
#  149442: ['363', '10', 'бесплатную'],
#  149443: ['374', '11', 'PR-компанию'],
#  149444: ['386', '3', 'для'],
#  149445: ['390', '12', 'горе-пророка'],
#  149446: ['402', '1', '.'],
#  149447: ['404', '6', 'Вполне'],
#  149448: ['411', '8', 'вероятно'],
#  149449: ['419', '1', ','],
#  149450: ['421', '3', 'что'],
#  149451: ['425', '7', 'Герольд'],
#  149452: ['433', '7', 'Кемпинг'],
#  149453: ['441', '8', 'объяснит'],
#  149454: ['450', '3', 'это'],
#  149455: ['454', '10', 'какой-либо'],
#  149456: ['465', '11', 'неточностью'],
#  149457: ['477', '1', 'и'],
#  149458: ['479', '9', 'перенесет'],
#  149459: ['489', '10', 'катастрофу'],
#  149460: ['500', '2', 'на'],
#  149461: ['503', '9', 'некоторое'],
#  149462: ['513', '5', 'время'],
#  149463: ['519', '6', 'вперёд'],
#  149464: ['525', '1', ','],
#  149465: ['527', '1', 'и'],
#  149466: ['529', '2', 'по'],
#  149467: ['532', '8', 'прежнему'],
#  149468: ['541', '5', 'будет'],
#  149469: ['547', '10', 'оставаться'],
#  149470: ['558', '1', 'в'],
#  149471: ['560', '6', 'центре'],
#  149472: ['567', '8', 'внимания'],
#  149473: ['575', '1', '.'],
#  149474: ['577', '3', 'Так'],
#  149475: ['580', '1', ','],
#  149476: ['582', '8', 'согласно'],
#  149477: ['591', '3', 'его'],
#  149478: ['595', '12', 'пророчествам'],
#  149479: ['607', '1', ','],
#  149480: ['609', '1', '6'],
#  149481: ['611', '8', 'сентября'],
#  149482: ['620', '4', '1994'],
#  149483: ['625', '4', 'года'],
#  149484: ['630', '2', 'на'],
#  149485: ['633', '5', 'Землю'],
#  149486: ['639', '6', 'должен'],
#  149487: ['646', '3', 'был'],
#  149488: ['650', '10', 'опуститься'],
#  149489: ['661', '5', 'Иисус'],
#  149490: ['667', '7', 'Христос'],
#  149491: ['674', '1', '.'],
#  149492: ['677', '9', 'Следующее'],
#  149493: ['687', '8', 'подобное'],
#  149494: ['696', '11', 'мероприятие'],
#  149495: ['707', '1', ','],
#  149496: ['709', '2', 'по'],
#  149497: ['712', '9', 'прогнозам'],
#  149498: ['722', '4', 'майя'],
#  149499: ['726', '1', ','],
#  149500: ['728', '9', 'ожидается'],
#  149501: ['738', '2', '21'],
#  149502: ['741', '7', 'декабря'],
#  149503: ['749', '4', '2012'],
#  149504: ['754', '4', 'года'],
#  149505: ['758', '1', ','],
#  149506: ['760', '6', 'однако'],
#  149507: ['767', '2', 'не'],
#  149508: ['770', '7', 'следует'],
#  149509: ['778', '8', 'забывать'],
#  149510: ['786', '1', ','],
#  149511: ['788', '3', 'что'],
#  149512: ['792', '5', 'конец'],
#  149513: ['798', '4', 'этой'],
#  149514: ['803', '11', 'цивилизации'],
#  149515: ['815', '8', 'наступил'],
#  149516: ['824', '11', 'значительно'],
#  149517: ['836', '6', 'раньше'],
#  149518: ['842', '1', ','],
#  149519: ['844', '1', 'и'],
#  149520: ['846', '3', 'это'],
#  149521: ['850', '9', 'отчего-то'],
#  149522: ['860', '2', 'не'],
#  149523: ['863', '10', 'отображено'],
#  149524: ['874', '1', 'в'],
#  149525: ['876', '2', 'их'],
#  149526: ['879', '8', 'наследии'],
#  149527: ['887', '1', ','],
#  149528: ['889', '7', 'поэтому'],
#  149529: ['897', '1', 'и'],
#  149530: ['899', '13', 'достоверность'],
#  149531: ['913', '9', 'подобного'],
#  149532: ['923', '10', 'прорицания'],
#  149533: ['934', '6', 'далеко'],
#  149534: ['941', '2', 'не'],
#  149535: ['944', '8', 'очевидна'],
#  149536: ['952', '1', '.'],
#  149537: ['955', '4', 'Если'],
#  149538: ['959', '1', '-'],
#  149539: ['960', '2', 'же'],
#  149540: ['963', '1', 'и'],
#  149541: ['965', '4', 'майя'],
#  149542: ['970', '8', 'ошиблись'],
#  149543: ['978', '1', ','],
#  149544: ['980', '2', 'то'],
#  149545: ['983', '13', 'расслабляться'],
#  149546: ['997', '9', 'всё-равно'],
#  149547: ['1007', '2', 'не'],
#  149548: ['1010', '5', 'стоит'],
#  149549: ['1015', '1', '.'],
#  149550: ['1017', '16', 'Апокалиптических'],
#  149551: ['1034', '6', 'теорий'],
#  149552: ['1041', '3', 'ещё'],
#  149553: ['1045', '10', 'достаточно'],
#  149554: ['1055', '1', ':'],
#  149555: ['1058', '1', '*'],
#  149556: ['1060', '4', '2021'],
#  149557: ['1065', '3', 'год'],
#  149558: ['1069', '1', '—'],
#  149559: ['1071', '8', 'инверсия'],
#  149560: ['1080', '10', 'магнитного'],
#  149561: ['1091', '4', 'поля'],
#  149562: ['1096', '5', 'Земли'],
#  149563: ['1102', '9', 'уничтожит'],
#  149564: ['1112', '5', 'часть'],
#  149565: ['1118', '12', 'человечества'],
#  149566: ['1130', '1', '.'],
#  149567: ['1132', '1', '*'],
#  149568: ['1134', '4', '2060'],
#  149569: ['1139', '3', 'год'],
#  149570: ['1143', '1', '—'],
#  149571: ['1145', '8', 'Согласно'],
#  149572: ['1154', '8', 'расчётам'],
#  149573: ['1163', '6', 'Исаака'],
#  149574: ['1170', '7', 'Ньютона'],
#  149575: ['1177', '1', ','],
#  149576: ['1179', '9', 'сделанным'],
#  149577: ['1189', '1', 'в'],
#  149578: ['1191', '4', '1704'],
#  149579: ['1196', '4', 'году'],
#  149580: ['1201', '2', 'по'],
#  149581: ['1204', '10', 'библейской'],
#  149582: ['1215', '5', 'книге'],
#  149583: ['1221', '7', 'Даниила'],
#  149584: ['1229', '6', 'станет'],
#  149585: ['1236', '9', 'последним'],
#  149586: ['1246', '3', 'для'],
#  149587: ['1250', '5', 'людей'],
#  149588: ['1255', '1', '.'],
#  149589: ['1257', '1', '*'],
#  149590: ['1259', '4', '2242'],
#  149591: ['1264', '3', 'год'],
#  149592: ['1268', '1', '—'],
#  149593: ['1270', '5', 'конец'],
#  149594: ['1276', '5', 'эпохи'],
#  149595: ['1282', '6', 'Солнца'],
#  149596: ['1289', '8', 'согласно'],
#  149597: ['1298', '6', 'теории'],
#  149598: ['1305', '5', 'смены'],
#  149599: ['1311', '9', 'планетных'],
#  149600: ['1321', '4', 'эпох'],
#  149601: ['1325', '1', ','],
#  149602: ['1327', '7', 'которая'],
#  149603: ['1335', '4', 'была'],
#  149604: ['1340', '8', 'изложена'],
#  149605: ['1349', '1', 'в'],
#  149606: ['1351', '7', 'работах'],
#  149607: ['1359', '3', 'ибн'],
#  149608: ['1363', '4', 'Эзра'],
#  149609: ['1367', '1', ','],
#  149610: ['1369', '7', 'Авраама'],
#  149611: ['1377', '1', 'и'],
#  149612: ['1379', '3', 'Абу'],
#  149613: ['1383', '6', 'Машара'],
#  149614: ['1389', '1', '.'],
#  149615: ['1391', '1', '*'],
#  149616: ['1393', '4', '2892'],
#  149617: ['1398', '3', 'год'],
#  149618: ['1402', '1', '—'],
#  149619: ['1404', '11', 'апокалипсис'],
#  149620: ['1416', '9', 'обещанный'],
#  149621: ['1426', '6', 'Авелем'],
#  149622: ['1432', '1', '.'],
#  149623: ['1434', '1', '*'],
#  149624: ['1436', '4', '3797'],
#  149625: ['1441', '3', 'год'],
#  149626: ['1445', '1', '—'],
#  149627: ['1447', '7', 'кончину'],
#  149628: ['1455', '4', 'миру'],
#  149629: ['1460', '7', 'предрёк'],
#  149630: ['1468', '3', 'сам'],
#  149631: ['1472', '11', 'Нострадамус'],
#  149632: ['1483', '1', '.'],
#  149633: ['1485', '1', '*'],
#  149634: ['1487', '4', '5079'],
#  149635: ['1492', '3', 'год'],
#  149636: ['1496', '1', '—'],
#  149637: ['1498', '5', 'сочла'],
#  149638: ['1504', '9', 'последним'],
#  149639: ['1514', '8', 'всемирно'],
#  149640: ['1523', '9', 'известная'],
#  149641: ['1533', '5', 'Ванга'],
#  149642: ['1539', '1', '…'],
#  155118: ['0', '12', 'Промышленный'],
#  155119: ['13', '1', 'и'],
#  155120: ['15', '12', 'коммерческий'],
#  155121: ['28', '4', 'банк'],
#  155122: ['33', '5', 'Китая'],
#  155123: ['39', '1', '('],
#  155124: ['40', '10', 'Industrial'],
#  155125: ['51', '3', 'and'],
#  155126: ['55', '10', 'Commercial'],
#  155127: ['66', '4', 'Bank'],
#  155128: ['71', '2', 'of'],
#  155129: ['74', '5', 'China'],
#  155130: ['79', '1', ')'],
#  155131: ['80', '1', ','],
#  155132: ['82', '2', 'по'],
#  155133: ['85', '9', 'некоторым'],
#  155134: ['95', '11', 'показателям'],
#  155135: ['107', '1', '—'],
#  155136: ['109', '10', 'крупнейший'],
#  155137: ['120', '4', 'банк'],
#  155138: ['125', '4', 'мира'],
#  155139: ['129', '1', ','],
#  155140: ['131', '8', 'подписал'],
#  155141: ['140', '10', 'соглашение'],
#  155142: ['151', '1', 'о'],
#  155143: ['153', '7', 'покупке'],
#  155144: ['161', '11', 'контрольной'],
#  155145: ['173', '4', 'доли'],
#  155146: ['178', '1', 'в'],
#  155147: ['180', '12', 'американском'],
#  155148: ['193', '9', 'отделении'],
#  155149: ['203', '4', 'Bank'],
#  155150: ['208', '2', 'of'],
#  155151: ['211', '4', 'East'],
#  155152: ['216', '4', 'Asia'],
#  155153: ['220', '1', ','],
#  155154: ['222', '11', 'управляющим'],
#  155155: ['234', '4', '13-ю'],
#  155156: ['239', '9', 'филиалами'],
#  155157: ['249', '1', 'в'],
#  155158: ['251', '10', 'Калифорнии'],
#  155159: ['262', '1', 'и'],
#  155160: ['264', '9', 'Нью-Йорке'],
#  155161: ['273', '1', '.'],
#  155162: ['275', '2', 'За'],
#  155163: ['278', '2', '80'],
#  155164: ['281', '9', 'процентов'],
#  155165: ['291', '5', 'акций'],
#  155166: ['297', '4', 'этой'],
#  155167: ['302', '10', 'финансовой'],
#  155168: ['313', '9', 'структуры'],
#  155169: ['322', '1', ','],
#  155170: ['324', '14', 'подконтрольный'],
#  155171: ['339', '10', 'китайскому'],
#  155172: ['350', '13', 'правительству'],
#  155173: ['364', '4', 'банк'],
#  155174: ['369', '8', 'заплатит'],
#  155175: ['378', '5', 'около'],
#  155176: ['384', '3', '100'],
#  155177: ['388', '3', 'млн'],
#  155178: ['392', '8', 'долларов'],
#  155179: ['400', '1', '.'],
#  155180: ['403', '10', 'Соглашение'],
#  155181: ['414', '4', 'было'],
#  155182: ['419', '9', 'подписано'],
#  155183: ['429', '1', 'в'],
#  155184: ['431', '8', 'минувшую'],
#  155185: ['440', '7', 'пятницу'],
#  155186: ['448', '1', 'в'],
#  155187: ['450', '6', 'Чикаго'],
#  155188: ['456', '1', ','],
#  155189: ['458', '1', 'в'],
#  155190: ['460', '9', 'последний'],
#  155191: ['470', '4', 'день'],
#  155192: ['475', '6', 'визита'],
#  155193: ['482', '12', 'председателя'],
#  155194: ['495', '3', 'КНР'],
#  155195: ['499', '2', 'Ху'],
#  155196: ['502', '8', 'Цзиньтао'],
#  155197: ['511', '1', 'в'],
#  155198: ['513', '3', 'США'],
#  155199: ['516', '1', '.'],
#  155200: ['518', '6', 'Сделка'],
#  155201: ['525', '7', 'ожидает'],
#  155202: ['533', '11', 'утверждения'],
#  155203: ['545', '13', 'американскими'],
#  155204: ['559', '13', 'регулирующими'],
#  155205: ['573', '8', 'органами'],
#  155206: ['581', '1', ','],
#  155207: ['583', '3', 'что'],
#  155208: ['587', '5', 'может'],
#  155209: ['593', '9', 'задержать'],
#  155210: ['603', '2', 'ее'],
#  155211: ['606', '10', 'завершение'],
#  155212: ['617', '2', 'до'],
#  155213: ['620', '5', 'конца'],
#  155214: ['626', '5', 'этого'],
#  155215: ['632', '4', 'года'],
#  155216: ['636', '1', '.'],
#  155217: ['639', '4', 'Доля'],
#  155218: ['644', '13', 'правительства'],
#  155219: ['658', '5', 'Китая'],
#  155220: ['664', '1', 'в'],
#  155221: ['666', '10', 'Industrial'],
#  155222: ['677', '3', 'and'],
#  155223: ['681', '10', 'Commercial'],
#  155224: ['692', '4', 'Bank'],
#  155225: ['697', '2', 'of'],
#  155226: ['700', '5', 'China'],
#  155227: ['706', '10', 'составляет'],
#  155228: ['717', '2', '70'],
#  155229: ['720', '9', 'процентов'],
#  155230: ['729', '1', '.'],
#  155231: ['731', '4', 'Если'],
#  155232: ['736', '6', 'сделка'],
#  155233: ['743', '5', 'будет'],
#  155234: ['749', '10', 'утверждена'],
#  155235: ['759', '1', ','],
#  155236: ['761', '2', 'то'],
#  155237: ['764', '15', 'государственный'],
#  155238: ['780', '9', 'китайский'],
#  155239: ['790', '4', 'банк'],
#  155240: ['795', '7', 'впервые'],
#  155241: ['803', '1', 'в'],
#  155242: ['805', '7', 'истории'],
#  155243: ['813', '7', 'получит'],
#  155244: ['821', '8', 'контроль'],
#  155245: ['830', '3', 'над'],
#  155246: ['834', '12', 'американским'],
#  155247: ['847', '10', 'финансовым'],
#  155248: ['858', '11', 'учреждением'],
#  155249: ['869', '1', '.'],
#  155250: ['871', '10', 'Американцы'],
#  155251: ['882', '6', 'смогут'],
#  155252: ['889', '6', 'делать'],
#  155253: ['896', '6', 'вклады'],
#  155254: ['903', '1', 'в'],
#  155255: ['905', '3', 'его'],
#  155256: ['909', '8', 'филиалах'],
#  155257: ['917', '1', ','],
#  155258: ['919', '1', 'а'],
#  155259: ['921', '9', 'инвесторы'],
#  155260: ['931', '6', 'смогут'],
#  155261: ['938', '9', 'открывать'],
#  155262: ['948', '5', 'счета'],
#  155263: ['954', '1', 'и'],
#  155264: ['956', '6', 'играть'],
#  155265: ['963', '2', 'на'],
#  155266: ['966', '5', 'курсе'],
#  155267: ['972', '4', 'юаня'],
#  155268: ['976', '1', '.'],
#  155269: ['979', '2', 'За'],
#  155270: ['982', '9', 'последние'],
#  155271: ['992', '4', 'годы'],
#  155272: ['997', '7', 'размеры'],
#  155273: ['1005', '11', 'иностранных'],
#  155274: ['1017', '10', 'инвестиций'],
#  155275: ['1028', '5', 'Китая'],
#  155276: ['1034', '5', 'резко'],
#  155277: ['1040', '11', 'увеличились'],
#  155278: ['1051', '1', ','],
#  155279: ['1053', '6', 'однако'],
#  155280: ['1060', '10', 'расширение'],
#  155281: ['1071', '9', 'китайских'],
#  155282: ['1081', '10', 'финансовых'],
#  155283: ['1092', '10', 'учреждений'],
#  155284: ['1103', '9', 'проходило'],
#  155285: ['1113', '7', 'гораздо'],
#  155286: ['1121', '9', 'медленнее'],
#  155287: ['1130', '1', '.'],
#  155288: ['1132', '3', 'При'],
#  155289: ['1136', '10', 'подписании'],
#  155290: ['1147', '6', 'нового'],
#  155291: ['1154', '10', 'соглашения'],
#  155292: ['1165', '7', 'министр'],
#  155293: ['1173', '8', 'торговли'],
#  155294: ['1182', '5', 'Китая'],
#  155295: ['1188', '4', 'Чэнь'],
#  155296: ['1193', '5', 'Дэмин'],
#  155297: ['1199', '6', 'заявил'],
#  155298: ['1205', '1', ','],
#  155299: ['1207', '3', 'что'],
#  155300: ['1211', '5', 'одним'],
#  155301: ['1217', '2', 'из'],
#  155302: ['1220', '11', 'приоритетов'],
#  155303: ['1232', '8', 'является'],
#  155304: ['1241', '7', 'перевод'],
#  155305: ['1249', '8', 'огромных'],
#  155306: ['1258', '8', 'резервов'],
#  155307: ['1267', '11', 'иностранной'],
#  155308: ['1279', '6', 'валюты'],
#  155309: ['1286', '1', 'в'],
#  155310: ['1288', '10', 'зарубежные'],
#  155311: ['1299', '6', 'активы'],
#  155312: ['1305', '1', '.'],
#  155313: ['0', '5', 'Барак'],
#  155314: ['6', '5', 'Обама'],
#  155315: ['12', '9', 'принимает'],
#  155316: ['22', '1', 'в'],
#  155317: ['24', '5', 'Белом'],
#  155318: ['30', '4', 'доме'],
#  155319: ['35', '6', 'своего'],
#  155320: ['42', '12', 'французского'],
#  155321: ['55', '7', 'коллегу'],
#  155322: ['63', '6', 'Николя'],
#  155323: ['70', '7', 'Саркози'],
#  155324: ['77', '1', '.'],
#  155325: ['79', '3', 'Как'],
#  155326: ['83', '4', 'было'],
#  155327: ['88', '9', 'объявлено'],
#  155328: ['97', '1', ','],
#  155329: ['99', '9', 'президент'],
#  155330: ['109', '7', 'Франции'],
#  155331: ['117', '6', 'прибыл'],
#  155332: ['124', '1', 'в'],
#  155333: ['126', '9', 'Вашингтон'],
#  155334: ['135', '1', ','],
#  155335: ['137', '5', 'чтобы'],
#  155336: ['143', '8', 'обсудить'],
#  155337: ['152', '1', 'с'],
#  155338: ['154', '6', 'главой'],
#  155339: ['161', '13', 'администрации'],
#  155340: ['175', '3', 'США'],
#  155341: ['179', '3', 'ряд'],
#  155342: ['183', '8', 'насущных'],
#  155343: ['192', '7', 'проблем'],
#  155344: ['199', '1', ','],
#  155345: ['201', '7', 'главное'],
#  155346: ['209', '5', 'место'],
#  155347: ['215', '5', 'среди'],
#  155348: ['221', '7', 'которых'],
#  155349: ['229', '8', 'занимает'],
#  155350: ['238', '9', 'состояние'],
#  155351: ['248', '7', 'мировой'],
#  155352: ['256', '9', 'экономики'],
#  155353: ['266', '1', 'и'],
#  155354: ['268', '12', 'безопасность'],
#  155355: ['280', '1', '.'],
#  155356: ['283', '1', 'В'],
#  155357: ['285', '9', 'частности'],
#  155358: ['294', '1', ','],
#  155359: ['296', '6', 'лидеры'],
#  155360: ['303', '8', 'намерены'],
#  155361: ['312', '10', 'обменяться'],
#  155362: ['323', '8', 'мнениями'],
#  155363: ['332', '1', 'о'],
#  155364: ['334', '12', 'перспективах'],
#  155365: ['347', '7', 'военных'],
#  155366: ['355', '8', 'действий'],
#  155367: ['364', '4', 'НАТО'],
#  155368: ['369', '1', 'в'],
#  155369: ['371', '11', 'Афганистане'],
#  155370: ['382', '1', ','],
#  155371: ['384', '9', 'волнениях'],
#  155372: ['394', '1', 'в'],
#  155373: ['396', '9', 'Пакистане'],
#  155374: ['406', '1', 'и'],
#  155375: ['408', '7', 'угрозах'],
#  155376: ['416', '12', 'экстремистов'],
#  155377: ['429', '1', 'в'],
#  155378: ['431', '8', 'Северной'],
#  155379: ['440', '6', 'Африке'],
#  155380: ['446', '1', '.'],
#  155381: ['448', '1', 'В'],
#  155382: ['450', '11', 'воскресенье'],
#  155383: ['462', '6', 'Николя'],
#  155384: ['469', '7', 'Саркози'],
#  155385: ['477', '8', 'выпустил'],
#  155386: ['486', '9', 'заявление'],
#  155387: ['496', '1', 'с'],
#  155388: ['498', '10', 'осуждением'],
#  155389: ['509', '8', 'убийства'],
#  155390: ['518', '4', 'двух'],
#  155391: ['523', '11', 'французских'],
#  155392: ['535', '10', 'заложников'],
#  155393: ['546', '1', 'в'],
#  155394: ['548', '6', 'Нигере'],
#  155395: ['554', '1', '.'],
#  155396: ['557', '1', 'В'],
#  155397: ['559', '8', 'недавнем'],
#  155398: ['568', '11', 'выступлении'],
#  155399: ['580', '2', 'по'],
#  155400: ['583', '12', 'французскому'],
#  155401: ['596', '11', 'телевидению'],
#  155402: ['608', '7', 'Саркози'],
#  155403: ['616', '7', 'выразил'],
#  155404: ['624', '6', 'мнение'],
#  155405: ['631', '1', 'о'],
#  155406: ['633', '13', 'необходимости'],
#  155407: ['647', '8', 'изменить'],
#  155408: ['656', '8', 'ситуацию'],
#  155409: ['665', '1', 'в'],
#  155410: ['667', '10', 'глобальной'],
#  155411: ['678', '9', 'экономике'],
#  155412: ['687', '1', ','],
#  155413: ['689', '3', 'при'],
#  155414: ['693', '7', 'которой'],
#  155415: ['701', '6', 'доллар'],
#  155416: ['708', '8', 'остается'],
#  155417: ['717', '7', 'главным'],
#  155418: ['725', '12', 'инструментом'],
#  155419: ['738', '8', 'расчетов'],
#  155420: ['747', '1', 'и'],
#  155421: ['749', '7', 'мировой'],
#  155422: ['757', '9', 'резервной'],
#  155423: ['767', '7', 'валютой'],
#  155424: ['774', '1', '.'],
#  155425: ['776', '13', 'Вашингтонская'],
#  155426: ['790', '7', 'встреча'],
#  155427: ['798', '8', 'проходит'],
#  155428: ['807', '1', 'в'],
#  155429: ['809', '5', 'канун'],
#  155430: ['815', '8', 'передачи'],
#  155431: ['824', '7', 'Франции'],
#  155432: ['832', '10', 'полномочий'],
#  155433: ['843', '5', 'главы'],
#  155434: ['849', '1', '«'],
#  155435: ['850', '7', 'Большой'],
#  155436: ['858', '9', 'двадцатки'],
#  155437: ['867', '1', '»'],
#  155438: ['868', '1', '.'],
#  155439: ['870', '9', 'Президент'],
#  155440: ['880', '7', 'Саркози'],
#  155441: ['888', '7', 'выразил'],
#  155442: ['896', '1', 'в'],
#  155443: ['898', '4', 'этой'],
#  155444: ['903', '5', 'связи'],
#  155445: ['909', '7', 'надежду'],
#  155446: ['917', '2', 'на'],
#  155447: ['920', '2', 'то'],
#  155448: ['922', '1', ','],
#  155449: ['924', '3', 'что'],
#  155450: ['928', '3', 'ему'],
#  155451: ['932', '7', 'удастся'],
#  155452: ['940', '2', 'за'],
#  155453: ['943', '5', 'время'],
#  155454: ['949', '16', 'председательства'],
#  155455: ['966', '1', 'в'],
#  155456: ['968', '4', 'G-20'],
#  155457: ['973', '8', 'провести'],
#  155458: ['982', '5', 'целый'],
#  155459: ['988', '3', 'ряд'],
#  155460: ['992', '6', 'реформ'],
#  155461: ['998', '1', '.'],
#  165156: ['0', '9', '22-летний'],
#  165157: ['10', '6', 'житель'],
#  165158: ['17', '7', 'Аризоны'],
#  165159: ['24', '1', ','],
#  165160: ['26', '9', 'открывший'],
#  165161: ['36', '8', 'стрельбу'],
#  165162: ['44', '1', ','],
#  165163: ['46', '1', 'в'],
#  165164: ['48', '10', 'результате'],
#  165165: ['59', '7', 'которой'],
#  165166: ['67', '10', 'пострадали'],
#  165167: ['78', '2', '20'],
#  165168: ['81', '7', 'человек'],
#  165169: ['88', '1', ','],
#  165170: ['90', '1', 'и'],
#  165171: ['92', '12', 'попытавшийся'],
#  165172: ['105', '5', 'убить'],
#  165173: ['111', '5', 'члена'],
#  165174: ['117', '9', 'Конгресса'],
#  165175: ['127', '3', 'США'],
#  165176: ['130', '1', ','],
#  165177: ['132', '7', 'впервые'],
#  165178: ['140', '8', 'предстал'],
#  165179: ['149', '5', 'перед'],
#  165180: ['155', '5', 'судом'],
#  165181: ['161', '2', 'по'],
#  165182: ['164', '9', 'обвинению'],
#  165183: ['174', '1', 'в'],
#  165184: ['176', '10', 'совершении'],
#  165185: ['187', '12', 'федерального'],
#  165186: ['200', '12', 'преступления'],
#  165187: ['212', '1', '.'],
#  165188: ['215', '1', 'В'],
#  165189: ['217', '11', 'понедельник'],
#  165190: ['229', '6', 'Джаред'],
#  165191: ['236', '6', 'Лофнер'],
#  165192: ['243', '1', 'в'],
#  165193: ['245', '10', 'наручниках'],
#  165194: ['256', '1', 'и'],
#  165195: ['258', '1', 'в'],
#  165196: ['260', '13', 'сопровождении'],
#  165197: ['274', '10', 'нескольких'],
#  165198: ['285', '10', 'охранников'],
#  165199: ['296', '9', 'доставлен'],
#  165200: ['306', '1', 'в'],
#  165201: ['308', '3', 'суд'],
#  165202: ['312', '1', 'в'],
#  165203: ['314', '6', 'города'],
#  165204: ['321', '6', 'Феникс'],
#  165205: ['327', '1', '.'],
#  165206: ['329', '8', 'Побритый'],
#  165207: ['338', '6', 'наголо'],
#  165208: ['345', '1', 'и'],
#  165209: ['347', '6', 'одетый'],
#  165210: ['354', '1', 'в'],
#  165211: ['356', '8', 'тюремную'],
#  165212: ['365', '5', 'форму'],
#  165213: ['370', '1', ','],
#  165214: ['372', '2', 'он'],
#  165215: ['375', '6', 'сказал'],
#  165216: ['381', '1', ','],
#  165217: ['383', '3', 'что'],
#  165218: ['387', '5', 'знает'],
#  165219: ['393', '4', 'свои'],
#  165220: ['398', '5', 'права'],
#  165221: ['403', '1', '.'],
#  165222: ['406', '6', 'Лофнер'],
#  165223: ['413', '8', 'предстал'],
#  165224: ['422', '5', 'перед'],
#  165225: ['428', '5', 'судом'],
#  165226: ['434', '5', 'через'],
#  165227: ['440', '3', 'два'],
#  165228: ['444', '3', 'дня'],
#  165229: ['448', '5', 'после'],
#  165230: ['454', '8', 'стрельбы'],
#  165231: ['463', '1', 'в'],
#  165232: ['465', '6', 'Тусоне'],
#  165233: ['471', '1', '.'],
#  165234: ['473', '5', 'Тогда'],
#  165235: ['479', '4', 'были'],
#  165236: ['484', '5', 'убиты'],
#  165237: ['490', '5', 'шесть'],
#  165238: ['496', '7', 'человек'],
#  165239: ['503', '1', ','],
#  165240: ['505', '1', 'а'],
#  165241: ['507', '4', 'член'],
#  165242: ['512', '6', 'Палаты'],
#  165243: ['519', '14', 'представителей'],
#  165244: ['534', '9', 'Конгресса'],
#  165245: ['544', '3', 'США'],
#  165246: ['548', '2', 'от'],
#  165247: ['551', '5', 'штата'],
#  165248: ['557', '7', 'Аризона'],
#  165249: ['565', '8', 'Гэбриэль'],
#  165250: ['574', '8', 'Гиффордс'],
#  165251: ['583', '8', 'получила'],
#  165252: ['592', '7', 'ранение'],
#  ...}

# %%
factrueval_dev_tokens_list
# Out:
# [['143783', '0', '1', 'В'],
#  ['143784', '2', '11', 'понедельник'],
#  ['143785', '14', '2', '28'],
#  ['143786', '17', '4', 'июня'],
#  ['143787', '22', '1', 'у'],
#  ['143788', '24', '6', 'здания'],
#  ['143789', '31', '5', 'мэрии'],
#  ['143790', '37', '6', 'Москвы'],
#  ['143791', '44', '2', 'на'],
#  ['143792', '47', '8', 'Тверской'],
#  ['143793', '56', '7', 'площади'],
#  ['143794', '64', '10', 'состоялась'],
#  ['143795', '75', '9', 'очередная'],
#  ['143796', '85', '19', 'несанкционированная'],
#  ['143797', '105', '5', 'акция'],
#  ['143798', '111', '8', 'протеста'],
#  ['143799', '120', '1', '«'],
#  ['143800', '121', '4', 'День'],
#  ['143801', '126', '5', 'гнева'],
#  ['143802', '131', '1', '»'],
#  ['143803', '132', '1', ','],
#  ['143804', '134', '1', 'в'],
#  ['143805', '136', '4', 'этот'],
#  ['143806', '141', '3', 'раз'],
#  ['143807', '145', '12', 'направленная'],
#  ['143808', '157', '1', ','],
#  ['143809', '159', '7', 'главным'],
#  ['143810', '167', '7', 'образом'],
#  ['143811', '174', '1', ','],
#  ['143812', '176', '6', 'против'],
#  ['143813', '183', '8', 'политики'],
#  ['143814', '192', '10', 'московских'],
#  ['143815', '203', '1', 'и'],
#  ['143816', '205', '12', 'подмосковных'],
#  ['143817', '218', '7', 'властей'],
#  ['143818', '225', '1', '.'],
#  [],
#  ['143819', '227', '5', 'Среди'],
#  ['143820', '233', '10', 'требований'],
#  ['143821', '243', '1', ','],
#  ['143822', '245', '11', 'выдвигаемых'],
#  ['143823', '257', '14', 'организаторами'],
#  ['143824', '272', '5', 'акции'],
#  ['143825', '277', '1', ':'],
#  ['143826', '279', '1', '«'],
#  ['143827', '280', '11', 'немедленная'],
#  ['143828', '292', '8', 'отставка'],
#  ['143829', '301', '4', 'мэра'],
#  ['143830', '306', '6', 'Москвы'],
#  ['143831', '313', '4', 'Юрия'],
#  ['143832', '318', '7', 'Лужкова'],
#  ['143833', '325', '1', ','],
#  ['143834', '327', '13', 'расследование'],
#  ['143835', '341', '6', 'итогов'],
#  ['143836', '348', '3', 'его'],
#  ['143837', '352', '12', 'деятельности'],
#  ['143838', '364', '1', '»'],
#  ['143839', '365', '1', ','],
#  ['143840', '367', '1', '«'],
#  ['143841', '368', '5', 'созыв'],
#  ['143842', '374', '11', 'московского'],
#  ['143843', '386', '13', 'общественного'],
#  ['143844', '400', '6', 'форума'],
#  ['143845', '407', '3', 'для'],
#  ['143846', '411', '10', 'обсуждения'],
#  ['143847', '422', '5', 'путей'],
#  ['143848', '428', '14', 'реформирования'],
#  ['143849', '443', '8', 'основных'],
#  ['143850', '452', '4', 'сфер'],
#  ['143851', '457', '17', 'жизнедеятельности'],
#  ['143852', '475', '1', 'в'],
#  ['143853', '477', '6', 'Москве'],
#  ['143854', '483', '1', '»'],
#  ['143855', '484', '1', ','],
#  ['143856', '486', '1', '«'],
#  ['143857', '487', '14', 'восстановление'],
#  ['143858', '502', '6', 'прямых'],
#  ['143859', '509', '7', 'выборов'],
#  ['143860', '517', '4', 'глав'],
#  ['143861', '522', '8', 'регионов'],
#  ['143862', '531', '6', 'России'],
#  ['143863', '537', '1', '»'],
#  ['143864', '538', '1', ','],
#  ['143865', '540', '1', '«'],
#  ['143866', '541', '7', 'роспуск'],
#  ['143867', '549', '12', 'нелегитимной'],
#  ['143868', '562', '10', 'Мосгордумы'],
#  ['143869', '572', '1', '»'],
#  ['143870', '573', '1', ','],
#  ['143871', '575', '8', 'отставка'],
#  ['143872', '584', '13', 'подмосковного'],
#  ['143873', '598', '11', 'губернатора'],
#  ['143874', '610', '6', 'Бориса'],
#  ['143875', '617', '7', 'Громова'],
#  ['143876', '625', '1', 'и'],
#  ['143877', '627', '2', 'др'],
#  ['143878', '629', '1', '.'],
#  [],
#  ['143879', '631', '10', 'Участникам'],
#  ['143880', '642', '5', 'акции'],
#  ['143881', '648', '12', 'предлагалось'],
#  ['143882', '661', '8', 'принести'],
#  ['143883', '670', '1', 'с'],
#  ['143884', '672', '5', 'собой'],
#  ['143885', '678', '4', 'лист'],
#  ['143886', '683', '6', 'бумаги'],
#  ['143887', '690', '3', 'или'],
#  ['143888', '694', '5', 'кусок'],
#  ['143889', '700', '5', 'ткани'],
#  ['143890', '706', '7', 'чёрного'],
#  ['143891', '714', '5', 'цвета'],
#  ['143892', '719', '1', ','],
#  ['143893', '721', '15', 'символизирующие'],
#  ['143894', '737', '1', '«'],
#  ['143895', '738', '6', 'чёрную'],
#  ['143896', '745', '5', 'метку'],
#  ['143897', '750', '1', '»'],
#  ['143898', '752', '3', 'для'],
#  ['143899', '756', '4', 'Юрия'],
#  ['143900', '761', '7', 'Лужкова'],
#  ['143901', '768', '1', '.'],
#  [],
#  ['143902', '771', '6', 'Начало'],
#  ['143903', '778', '5', 'акции'],
#  ['143904', '784', '4', 'было'],
#  ['143905', '789', '8', 'намечено'],
#  ['143906', '798', '2', 'на'],
#  ['143907', '801', '2', '19'],
#  ['143908', '804', '5', 'часов'],
#  ['143909', '809', '1', ';'],
#  ['143910', '811', '14', 'подчёркивалось'],
#  ['143911', '825', '1', ','],
#  ['143912', '827', '3', 'что'],
#  ['143913', '831', '3', 'она'],
#  ['143914', '835', '9', 'состоится'],
#  ['143915', '845', '8', 'несмотря'],
#  ['143916', '854', '2', 'на'],
#  ['143917', '857', '6', 'запрет'],
#  ['143918', '864', '7', 'властей'],
#  ['143919', '871', '1', '.'],
#  [],
#  ['143920', '873', '10', 'Освещающие'],
#  ['143921', '884', '5', 'акцию'],
#  ['143922', '890', '8', 'блоггеры'],
#  ['143923', '899', '8', 'сообщили'],
#  ['143924', '907', '1', ','],
#  ['143925', '909', '3', 'что'],
#  ['143926', '913', '8', 'автобусы'],
#  ['143927', '922', '1', 'с'],
#  ['143928', '924', '8', 'милицией'],
#  ['143929', '933', '5', 'стали'],
#  ['143930', '939', '8', 'занимать'],
#  ['143931', '948', '7', 'площадь'],
#  ['143932', '956', '1', 'у'],
#  ['143933', '958', '9', 'памятника'],
#  ['143934', '968', '4', 'Юрию'],
#  ['143935', '973', '11', 'Долгорукому'],
#  ['143936', '985', '3', 'ещё'],
#  ['143937', '989', '1', 'с'],
#  ['143938', '991', '2', '15'],
#  ['143939', '994', '5', 'часов'],
#  ['143940', '1000', '3', 'дня'],
#  ['143941', '1003', '1', ','],
#  ['143942', '1005', '11', 'центральная'],
#  ['143943', '1017', '5', 'часть'],
#  ['143944', '1023', '7', 'площади'],
#  ['143945', '1031', '4', 'была'],
#  ['143946', '1036', '9', 'огорожена'],
#  ['143947', '1045', '1', '.'],
#  [],
#  ['143948', '1047', '2', 'Ко'],
#  ['143949', '1050', '7', 'времени'],
#  ['143950', '1058', '6', 'начала'],
#  ['143951', '1065', '5', 'акции'],
#  ['143952', '1071', '6', 'вокруг'],
#  ['143953', '1078', '11', 'огороженной'],
#  ['143954', '1090', '10', 'территории'],
#  ['143955', '1101', '9', 'собралось'],
#  ['143956', '1111', '9', 'множество'],
#  ['143957', '1121', '11', 'журналистов'],
#  ['143958', '1133', '1', 'и'],
#  ['143959', '1135', '8', 'прохожих'],
#  ['143960', '1143', '1', ','],
#  ['143961', '1145', '2', 'по'],
#  ['143962', '1148', '4', 'мере'],
#  ['143963', '1153', '8', 'прибытия'],
#  ['143964', '1162', '5', 'самих'],
#  ['143965', '1168', '10', 'участников'],
#  ['143966', '1179', '5', 'акции'],
#  ['143967', '1185', '7', 'милиция'],
#  ['143968', '1193', '6', 'начала'],
#  ['143969', '1200', '10', 'планомерно'],
#  ['143970', '1211', '2', 'их'],
#  ['143971', '1214', '11', 'задерживать'],
#  ['143972', '1226', '1', 'и'],
#  ['143973', '1228', '11', 'заталкивать'],
#  ['143974', '1240', '1', 'в'],
#  ['143975', '1242', '8', 'автобусы'],
#  ['143976', '1250', '1', '.'],
#  [],
#  ['143977', '1253', '5', 'Всего'],
#  ['143978', '1258', '1', ','],
#  ['143979', '1260', '2', 'по'],
#  ['143980', '1263', '10', 'сообщениям'],
#  ['143981', '1274', '9', 'блоггеров'],
#  ['143982', '1284', '1', 'и'],
#  ['143983', '1286', '3', 'СМИ'],
#  ['143984', '1289', '1', ','],
#  ['143985', '1291', '4', 'было'],
#  ['143986', '1296', '9', 'задержано'],
#  ['143987', '1306', '5', 'более'],
#  ['143988', '1312', '2', '30'],
#  ['143989', '1315', '7', 'человек'],
#  ['143990', '1322', '1', '.'],
#  [],
#  ['143991', '1324', '12', 'Пользователь'],
#  ['143992', '1337', '2', 'ЖЖ'],
#  ['143993', '1340', '5', 'zyalt'],
#  ['143994', '1346', '8', 'сообщает'],
#  ['143995', '1354', '1', ','],
#  ['143996', '1356', '3', 'что'],
#  ['143997', '1360', '5', 'среди'],
#  ['143998', '1366', '11', 'задержанных'],
#  ['143999', '1378', '8', 'оказался'],
#  ['144000', '1387', '7', 'депутат'],
#  ['144001', '1395', '14', 'муниципального'],
#  ['144002', '1410', '8', 'собрания'],
#  ['144003', '1419', '6', 'района'],
#  ['144004', '1426', '8', 'Отрадное'],
#  ['144005', '1434', '1', ','],
#  ['144006', '1436', '14', 'сопредседатель'],
#  ['144007', '1451', '11', 'московского'],
#  ['144008', '1463', '9', 'отделения'],
#  ['144009', '1473', '8', 'движения'],
#  ['144010', '1482', '1', '«'],
#  ['144011', '1483', '12', 'Солидарность'],
#  ['144012', '1495', '1', '»'],
#  ['144013', '1497', '6', 'Михаил'],
#  ['144014', '1504', '9', 'Вельмакин'],
#  ['144015', '1513', '1', ','],
#  ['144016', '1515', '9', 'известный'],
#  ['144017', '1525', '13', 'правозащитник'],
#  ['144018', '1539', '3', 'Лев'],
#  ['144019', '1543', '9', 'Пономарев'],
#  ['144020', '1552', '1', ','],
#  ['144021', '1554', '11', 'координатор'],
#  ['144022', '1566', '8', 'движения'],
#  ['144023', '1575', '1', '«'],
#  ['144024', '1576', '5', 'Левый'],
#  ['144025', '1582', '5', 'фронт'],
#  ['144026', '1587', '1', '»'],
#  ['144027', '1589', '6', 'Сергей'],
#  ['144028', '1596', '8', 'Удальцов'],
#  ['144029', '1604', '1', '.'],
#  [],
#  ['144030', '1607', '14', 'Организаторами'],
#  ['144031', '1622', '5', 'акции'],
#  ['144032', '1628', '9', 'выступили'],
#  ['144033', '1638', '8', 'движение'],
#  ['144034', '1647', '1', '«'],
#  ['144035', '1648', '2', 'За'],
#  ['144036', '1651', '5', 'права'],
#  ['144037', '1657', '8', 'человека'],
#  ['144038', '1665', '1', '»'],
#  ['144039', '1666', '1', ','],
#  ['144040', '1668', '4', 'Союз'],
#  ['144041', '1673', '15', 'координационных'],
#  ['144042', '1689', '7', 'советов'],
#  ['144043', '1697', '1', '('],
#  ['144044', '1698', '3', 'СКС'],
#  ['144045', '1701', '1', ')'],
#  ['144046', '1702', '1', ','],
#  ['144047', '1704', '8', 'институт'],
#  ['144048', '1713', '1', '«'],
#  ['144049', '1714', '12', 'Коллективное'],
#  ['144050', '1727', '8', 'действие'],
#  ['144051', '1735', '1', '»'],
#  ['144052', '1736', '1', ','],
#  ['144053', '1738', '1', '«'],
#  ['144054', '1739', '8', 'Жилищная'],
#  ['144055', '1748', '12', 'солидарность'],
#  ['144056', '1760', '1', '»'],
#  ['144057', '1761', '1', ','],
#  ['144058', '1763', '8', 'Движение'],
#  ['144059', '1772', '9', 'общежитий'],
#  ['144060', '1782', '6', 'Москвы'],
#  ['144061', '1788', '1', ','],
#  ['144062', '1790', '8', 'Движение'],
#  ['144063', '1799', '1', 'в'],
#  ['144064', '1801', '6', 'защиту'],
#  ['144065', '1808', '11', 'Химкинского'],
#  ['144066', '1820', '4', 'леса'],
#  ['144067', '1824', '1', ','],
#  ['144068', '1826', '8', 'движение'],
#  ['144069', '1835', '1', '«'],
#  ['144070', '1836', '10', 'Московский'],
#  ['144071', '1847', '5', 'совет'],
#  ['144072', '1852', '1', '»'],
#  ['144073', '1853', '1', ','],
#  ['144074', '1855', '1', '«'],
#  ['144075', '1856', '15', 'Координационный'],
#  ['144076', '1872', '5', 'совет'],
#  ['144077', '1878', '12', 'пострадавших'],
#  ['144078', '1891', '12', 'соинвесторов'],
#  ['144079', '1903', '1', '»'],
#  ['144080', '1904', '1', '.'],
#  [],
#  ['149382', '0', '5', 'Конец'],
#  ['149383', '6', '5', 'света'],
#  ['149384', '11', '1', ','],
#  ['149385', '13', '7', 'который'],
#  ['149386', '21', '9', 'предрекал'],
#  ['149387', '31', '11', 'проповедник'],
#  ['149388', '42', '1', '-'],
#  ['149389', '43', '10', 'евангелист'],
#  ['149390', '54', '7', 'Герольд'],
#  ['149391', '62', '7', 'Кемпинг'],
#  ['149392', '70', '5', 'утром'],
#  ['149393', '76', '1', 'в'],
#  ['149394', '78', '5', '06.00'],
#  ['149395', '84', '2', 'по'],
#  ['149396', '87', '11', 'московскому'],
#  ['149397', '99', '7', 'времени'],
#  ['149398', '107', '2', '21'],
#  ['149399', '110', '3', 'мая'],
#  ['149400', '114', '4', '2011'],
#  ['149401', '119', '4', 'года'],
#  ['149402', '124', '3', 'так'],
#  ['149403', '128', '1', 'и'],
#  ['149404', '130', '2', 'не'],
#  ['149405', '133', '8', 'наступил'],
#  ['149406', '141', '1', '.'],
#  [],
#  ['149407', '144', '3', 'Это'],
#  ['149408', '148', '6', 'далеко'],
#  ['149409', '155', '2', 'не'],
#  ['149410', '158', '6', 'первое'],
#  ['149411', '165', '11', 'несбывшееся'],
#  ['149412', '177', '12', 'предсказание'],
#  ['149413', '190', '12', 'апокалипсиса'],
#  ['149414', '202', '1', '.'],
#  [],
#  ['149415', '204', '8', 'Поначалу'],
#  ['149416', '213', '2', 'на'],
#  ['149417', '216', '4', 'него'],
#  ['149418', '221', '11', 'практически'],
#  ['149419', '233', '2', 'не'],
#  ['149420', '236', '8', 'обратили'],
#  ['149421', '245', '8', 'внимания'],
#  ['149422', '253', '1', ','],
#  ['149423', '255', '6', 'однако'],
#  ['149424', '261', '1', ','],
#  ['149425', '263', '1', 'с'],
#  ['149426', '265', '12', 'приближением'],
#  ['149427', '278', '4', 'этой'],
#  ['149428', '283', '4', 'даты'],
#  ['149429', '287', '1', ','],
#  ['149430', '289', '6', 'немало'],
#  ['149431', '296', '3', 'СМИ'],
#  ['149432', '300', '1', 'в'],
#  ['149433', '302', '7', 'поисках'],
#  ['149434', '310', '6', 'сюжета'],
#  ['149435', '316', '1', ','],
#  ['149436', '318', '15', 'останавливались'],
#  ['149437', '334', '2', 'на'],
#  ['149438', '337', '4', 'этом'],
#  ['149439', '341', '1', ','],
#  ['149440', '343', '8', 'создавая'],
#  ['149441', '352', '10', 'прекрасную'],
#  ['149442', '363', '10', 'бесплатную'],
#  ['149443', '374', '11', 'PR-компанию'],
#  ['149444', '386', '3', 'для'],
#  ['149445', '390', '12', 'горе-пророка'],
#  ['149446', '402', '1', '.'],
#  [],
#  ['149447', '404', '6', 'Вполне'],
#  ['149448', '411', '8', 'вероятно'],
#  ['149449', '419', '1', ','],
#  ['149450', '421', '3', 'что'],
#  ['149451', '425', '7', 'Герольд'],
#  ['149452', '433', '7', 'Кемпинг'],
#  ['149453', '441', '8', 'объяснит'],
#  ['149454', '450', '3', 'это'],
#  ['149455', '454', '10', 'какой-либо'],
#  ['149456', '465', '11', 'неточностью'],
#  ['149457', '477', '1', 'и'],
#  ['149458', '479', '9', 'перенесет'],
#  ['149459', '489', '10', 'катастрофу'],
#  ['149460', '500', '2', 'на'],
#  ['149461', '503', '9', 'некоторое'],
#  ['149462', '513', '5', 'время'],
#  ['149463', '519', '6', 'вперёд'],
#  ['149464', '525', '1', ','],
#  ['149465', '527', '1', 'и'],
#  ['149466', '529', '2', 'по'],
#  ['149467', '532', '8', 'прежнему'],
#  ['149468', '541', '5', 'будет'],
#  ['149469', '547', '10', 'оставаться'],
#  ['149470', '558', '1', 'в'],
#  ['149471', '560', '6', 'центре'],
#  ['149472', '567', '8', 'внимания'],
#  ['149473', '575', '1', '.'],
#  [],
#  ['149474', '577', '3', 'Так'],
#  ['149475', '580', '1', ','],
#  ['149476', '582', '8', 'согласно'],
#  ['149477', '591', '3', 'его'],
#  ['149478', '595', '12', 'пророчествам'],
#  ['149479', '607', '1', ','],
#  ['149480', '609', '1', '6'],
#  ['149481', '611', '8', 'сентября'],
#  ['149482', '620', '4', '1994'],
#  ['149483', '625', '4', 'года'],
#  ['149484', '630', '2', 'на'],
#  ['149485', '633', '5', 'Землю'],
#  ['149486', '639', '6', 'должен'],
#  ['149487', '646', '3', 'был'],
#  ['149488', '650', '10', 'опуститься'],
#  ['149489', '661', '5', 'Иисус'],
#  ['149490', '667', '7', 'Христос'],
#  ['149491', '674', '1', '.'],
#  [],
#  ['149492', '677', '9', 'Следующее'],
#  ['149493', '687', '8', 'подобное'],
#  ['149494', '696', '11', 'мероприятие'],
#  ['149495', '707', '1', ','],
#  ['149496', '709', '2', 'по'],
#  ['149497', '712', '9', 'прогнозам'],
#  ['149498', '722', '4', 'майя'],
#  ['149499', '726', '1', ','],
#  ['149500', '728', '9', 'ожидается'],
#  ['149501', '738', '2', '21'],
#  ['149502', '741', '7', 'декабря'],
#  ['149503', '749', '4', '2012'],
#  ['149504', '754', '4', 'года'],
#  ['149505', '758', '1', ','],
#  ['149506', '760', '6', 'однако'],
#  ['149507', '767', '2', 'не'],
#  ['149508', '770', '7', 'следует'],
#  ['149509', '778', '8', 'забывать'],
#  ['149510', '786', '1', ','],
#  ['149511', '788', '3', 'что'],
#  ['149512', '792', '5', 'конец'],
#  ['149513', '798', '4', 'этой'],
#  ['149514', '803', '11', 'цивилизации'],
#  ['149515', '815', '8', 'наступил'],
#  ['149516', '824', '11', 'значительно'],
#  ['149517', '836', '6', 'раньше'],
#  ['149518', '842', '1', ','],
#  ['149519', '844', '1', 'и'],
#  ['149520', '846', '3', 'это'],
#  ['149521', '850', '9', 'отчего-то'],
#  ['149522', '860', '2', 'не'],
#  ['149523', '863', '10', 'отображено'],
#  ['149524', '874', '1', 'в'],
#  ['149525', '876', '2', 'их'],
#  ['149526', '879', '8', 'наследии'],
#  ['149527', '887', '1', ','],
#  ['149528', '889', '7', 'поэтому'],
#  ['149529', '897', '1', 'и'],
#  ['149530', '899', '13', 'достоверность'],
#  ['149531', '913', '9', 'подобного'],
#  ['149532', '923', '10', 'прорицания'],
#  ['149533', '934', '6', 'далеко'],
#  ['149534', '941', '2', 'не'],
#  ['149535', '944', '8', 'очевидна'],
#  ['149536', '952', '1', '.'],
#  [],
#  ['149537', '955', '4', 'Если'],
#  ['149538', '959', '1', '-'],
#  ['149539', '960', '2', 'же'],
#  ['149540', '963', '1', 'и'],
#  ['149541', '965', '4', 'майя'],
#  ['149542', '970', '8', 'ошиблись'],
#  ['149543', '978', '1', ','],
#  ['149544', '980', '2', 'то'],
#  ['149545', '983', '13', 'расслабляться'],
#  ['149546', '997', '9', 'всё-равно'],
#  ['149547', '1007', '2', 'не'],
#  ['149548', '1010', '5', 'стоит'],
#  ['149549', '1015', '1', '.'],
#  [],
#  ['149550', '1017', '16', 'Апокалиптических'],
#  ['149551', '1034', '6', 'теорий'],
#  ['149552', '1041', '3', 'ещё'],
#  ['149553', '1045', '10', 'достаточно'],
#  ['149554', '1055', '1', ':'],
#  [],
#  ['149555', '1058', '1', '*'],
#  ['149556', '1060', '4', '2021'],
#  ['149557', '1065', '3', 'год'],
#  ['149558', '1069', '1', '—'],
#  ['149559', '1071', '8', 'инверсия'],
#  ['149560', '1080', '10', 'магнитного'],
#  ['149561', '1091', '4', 'поля'],
#  ['149562', '1096', '5', 'Земли'],
#  ['149563', '1102', '9', 'уничтожит'],
#  ['149564', '1112', '5', 'часть'],
#  ['149565', '1118', '12', 'человечества'],
#  ['149566', '1130', '1', '.'],
#  [],
#  ['149567', '1132', '1', '*'],
#  ['149568', '1134', '4', '2060'],
#  ['149569', '1139', '3', 'год'],
#  ['149570', '1143', '1', '—'],
#  ['149571', '1145', '8', 'Согласно'],
#  ['149572', '1154', '8', 'расчётам'],
#  ['149573', '1163', '6', 'Исаака'],
#  ['149574', '1170', '7', 'Ньютона'],
#  ['149575', '1177', '1', ','],
#  ['149576', '1179', '9', 'сделанным'],
#  ['149577', '1189', '1', 'в'],
#  ['149578', '1191', '4', '1704'],
#  ['149579', '1196', '4', 'году'],
#  ['149580', '1201', '2', 'по'],
#  ['149581', '1204', '10', 'библейской'],
#  ['149582', '1215', '5', 'книге'],
#  ['149583', '1221', '7', 'Даниила'],
#  ['149584', '1229', '6', 'станет'],
#  ['149585', '1236', '9', 'последним'],
#  ['149586', '1246', '3', 'для'],
#  ['149587', '1250', '5', 'людей'],
#  ['149588', '1255', '1', '.'],
#  [],
#  ['149589', '1257', '1', '*'],
#  ['149590', '1259', '4', '2242'],
#  ['149591', '1264', '3', 'год'],
#  ['149592', '1268', '1', '—'],
#  ['149593', '1270', '5', 'конец'],
#  ['149594', '1276', '5', 'эпохи'],
#  ['149595', '1282', '6', 'Солнца'],
#  ['149596', '1289', '8', 'согласно'],
#  ['149597', '1298', '6', 'теории'],
#  ['149598', '1305', '5', 'смены'],
#  ['149599', '1311', '9', 'планетных'],
#  ['149600', '1321', '4', 'эпох'],
#  ['149601', '1325', '1', ','],
#  ['149602', '1327', '7', 'которая'],
#  ['149603', '1335', '4', 'была'],
#  ['149604', '1340', '8', 'изложена'],
#  ['149605', '1349', '1', 'в'],
#  ['149606', '1351', '7', 'работах'],
#  ['149607', '1359', '3', 'ибн'],
#  ['149608', '1363', '4', 'Эзра'],
#  ['149609', '1367', '1', ','],
#  ['149610', '1369', '7', 'Авраама'],
#  ['149611', '1377', '1', 'и'],
#  ['149612', '1379', '3', 'Абу'],
#  ['149613', '1383', '6', 'Машара'],
#  ['149614', '1389', '1', '.'],
#  [],
#  ['149615', '1391', '1', '*'],
#  ['149616', '1393', '4', '2892'],
#  ['149617', '1398', '3', 'год'],
#  ['149618', '1402', '1', '—'],
#  ['149619', '1404', '11', 'апокалипсис'],
#  ['149620', '1416', '9', 'обещанный'],
#  ['149621', '1426', '6', 'Авелем'],
#  ['149622', '1432', '1', '.'],
#  [],
#  ['149623', '1434', '1', '*'],
#  ['149624', '1436', '4', '3797'],
#  ['149625', '1441', '3', 'год'],
#  ['149626', '1445', '1', '—'],
#  ['149627', '1447', '7', 'кончину'],
#  ['149628', '1455', '4', 'миру'],
#  ['149629', '1460', '7', 'предрёк'],
#  ['149630', '1468', '3', 'сам'],
#  ['149631', '1472', '11', 'Нострадамус'],
#  ['149632', '1483', '1', '.'],
#  [],
#  ['149633', '1485', '1', '*'],
#  ['149634', '1487', '4', '5079'],
#  ['149635', '1492', '3', 'год'],
#  ['149636', '1496', '1', '—'],
#  ['149637', '1498', '5', 'сочла'],
#  ['149638', '1504', '9', 'последним'],
#  ['149639', '1514', '8', 'всемирно'],
#  ['149640', '1523', '9', 'известная'],
#  ['149641', '1533', '5', 'Ванга'],
#  ['149642', '1539', '1', '…'],
#  [],
#  ['155118', '0', '12', 'Промышленный'],
#  ['155119', '13', '1', 'и'],
#  ['155120', '15', '12', 'коммерческий'],
#  ['155121', '28', '4', 'банк'],
#  ['155122', '33', '5', 'Китая'],
#  ['155123', '39', '1', '('],
#  ['155124', '40', '10', 'Industrial'],
#  ['155125', '51', '3', 'and'],
#  ['155126', '55', '10', 'Commercial'],
#  ['155127', '66', '4', 'Bank'],
#  ['155128', '71', '2', 'of'],
#  ['155129', '74', '5', 'China'],
#  ['155130', '79', '1', ')'],
#  ['155131', '80', '1', ','],
#  ['155132', '82', '2', 'по'],
#  ['155133', '85', '9', 'некоторым'],
#  ['155134', '95', '11', 'показателям'],
#  ['155135', '107', '1', '—'],
#  ['155136', '109', '10', 'крупнейший'],
#  ['155137', '120', '4', 'банк'],
#  ['155138', '125', '4', 'мира'],
#  ['155139', '129', '1', ','],
#  ['155140', '131', '8', 'подписал'],
#  ['155141', '140', '10', 'соглашение'],
#  ['155142', '151', '1', 'о'],
#  ['155143', '153', '7', 'покупке'],
#  ['155144', '161', '11', 'контрольной'],
#  ['155145', '173', '4', 'доли'],
#  ['155146', '178', '1', 'в'],
#  ['155147', '180', '12', 'американском'],
#  ['155148', '193', '9', 'отделении'],
#  ['155149', '203', '4', 'Bank'],
#  ['155150', '208', '2', 'of'],
#  ['155151', '211', '4', 'East'],
#  ['155152', '216', '4', 'Asia'],
#  ['155153', '220', '1', ','],
#  ['155154', '222', '11', 'управляющим'],
#  ['155155', '234', '4', '13-ю'],
#  ['155156', '239', '9', 'филиалами'],
#  ['155157', '249', '1', 'в'],
#  ['155158', '251', '10', 'Калифорнии'],
#  ['155159', '262', '1', 'и'],
#  ['155160', '264', '9', 'Нью-Йорке'],
#  ['155161', '273', '1', '.'],
#  [],
#  ['155162', '275', '2', 'За'],
#  ['155163', '278', '2', '80'],
#  ['155164', '281', '9', 'процентов'],
#  ['155165', '291', '5', 'акций'],
#  ['155166', '297', '4', 'этой'],
#  ['155167', '302', '10', 'финансовой'],
#  ['155168', '313', '9', 'структуры'],
#  ['155169', '322', '1', ','],
#  ['155170', '324', '14', 'подконтрольный'],
#  ['155171', '339', '10', 'китайскому'],
#  ['155172', '350', '13', 'правительству'],
#  ['155173', '364', '4', 'банк'],
#  ['155174', '369', '8', 'заплатит'],
#  ['155175', '378', '5', 'около'],
#  ['155176', '384', '3', '100'],
#  ['155177', '388', '3', 'млн'],
#  ['155178', '392', '8', 'долларов'],
#  ['155179', '400', '1', '.'],
#  [],
#  ['155180', '403', '10', 'Соглашение'],
#  ['155181', '414', '4', 'было'],
#  ['155182', '419', '9', 'подписано'],
#  ['155183', '429', '1', 'в'],
#  ['155184', '431', '8', 'минувшую'],
#  ['155185', '440', '7', 'пятницу'],
#  ['155186', '448', '1', 'в'],
#  ['155187', '450', '6', 'Чикаго'],
#  ['155188', '456', '1', ','],
#  ['155189', '458', '1', 'в'],
#  ['155190', '460', '9', 'последний'],
#  ['155191', '470', '4', 'день'],
#  ['155192', '475', '6', 'визита'],
#  ['155193', '482', '12', 'председателя'],
#  ['155194', '495', '3', 'КНР'],
#  ['155195', '499', '2', 'Ху'],
#  ['155196', '502', '8', 'Цзиньтао'],
#  ['155197', '511', '1', 'в'],
#  ['155198', '513', '3', 'США'],
#  ['155199', '516', '1', '.'],
#  [],
#  ['155200', '518', '6', 'Сделка'],
#  ['155201', '525', '7', 'ожидает'],
#  ['155202', '533', '11', 'утверждения'],
#  ['155203', '545', '13', 'американскими'],
#  ['155204', '559', '13', 'регулирующими'],
#  ['155205', '573', '8', 'органами'],
#  ['155206', '581', '1', ','],
#  ['155207', '583', '3', 'что'],
#  ['155208', '587', '5', 'может'],
#  ['155209', '593', '9', 'задержать'],
#  ['155210', '603', '2', 'ее'],
#  ['155211', '606', '10', 'завершение'],
#  ['155212', '617', '2', 'до'],
#  ['155213', '620', '5', 'конца'],
#  ['155214', '626', '5', 'этого'],
#  ['155215', '632', '4', 'года'],
#  ['155216', '636', '1', '.'],
#  [],
#  ['155217', '639', '4', 'Доля'],
#  ['155218', '644', '13', 'правительства'],
#  ['155219', '658', '5', 'Китая'],
#  ['155220', '664', '1', 'в'],
#  ['155221', '666', '10', 'Industrial'],
#  ['155222', '677', '3', 'and'],
#  ['155223', '681', '10', 'Commercial'],
#  ['155224', '692', '4', 'Bank'],
#  ['155225', '697', '2', 'of'],
#  ['155226', '700', '5', 'China'],
#  ['155227', '706', '10', 'составляет'],
#  ['155228', '717', '2', '70'],
#  ['155229', '720', '9', 'процентов'],
#  ['155230', '729', '1', '.'],
#  [],
#  ['155231', '731', '4', 'Если'],
#  ['155232', '736', '6', 'сделка'],
#  ['155233', '743', '5', 'будет'],
#  ['155234', '749', '10', 'утверждена'],
#  ['155235', '759', '1', ','],
#  ['155236', '761', '2', 'то'],
#  ['155237', '764', '15', 'государственный'],
#  ['155238', '780', '9', 'китайский'],
#  ['155239', '790', '4', 'банк'],
#  ['155240', '795', '7', 'впервые'],
#  ['155241', '803', '1', 'в'],
#  ['155242', '805', '7', 'истории'],
#  ['155243', '813', '7', 'получит'],
#  ['155244', '821', '8', 'контроль'],
#  ['155245', '830', '3', 'над'],
#  ['155246', '834', '12', 'американским'],
#  ['155247', '847', '10', 'финансовым'],
#  ['155248', '858', '11', 'учреждением'],
#  ['155249', '869', '1', '.'],
#  [],
#  ['155250', '871', '10', 'Американцы'],
#  ['155251', '882', '6', 'смогут'],
#  ['155252', '889', '6', 'делать'],
#  ['155253', '896', '6', 'вклады'],
#  ['155254', '903', '1', 'в'],
#  ['155255', '905', '3', 'его'],
#  ['155256', '909', '8', 'филиалах'],
#  ['155257', '917', '1', ','],
#  ['155258', '919', '1', 'а'],
#  ['155259', '921', '9', 'инвесторы'],
#  ['155260', '931', '6', 'смогут'],
#  ['155261', '938', '9', 'открывать'],
#  ['155262', '948', '5', 'счета'],
#  ['155263', '954', '1', 'и'],
#  ['155264', '956', '6', 'играть'],
#  ['155265', '963', '2', 'на'],
#  ['155266', '966', '5', 'курсе'],
#  ['155267', '972', '4', 'юаня'],
#  ['155268', '976', '1', '.'],
#  [],
#  ['155269', '979', '2', 'За'],
#  ['155270', '982', '9', 'последние'],
#  ['155271', '992', '4', 'годы'],
#  ['155272', '997', '7', 'размеры'],
#  ['155273', '1005', '11', 'иностранных'],
#  ['155274', '1017', '10', 'инвестиций'],
#  ['155275', '1028', '5', 'Китая'],
#  ['155276', '1034', '5', 'резко'],
#  ['155277', '1040', '11', 'увеличились'],
#  ['155278', '1051', '1', ','],
#  ['155279', '1053', '6', 'однако'],
#  ['155280', '1060', '10', 'расширение'],
#  ['155281', '1071', '9', 'китайских'],
#  ['155282', '1081', '10', 'финансовых'],
#  ['155283', '1092', '10', 'учреждений'],
#  ['155284', '1103', '9', 'проходило'],
#  ['155285', '1113', '7', 'гораздо'],
#  ['155286', '1121', '9', 'медленнее'],
#  ['155287', '1130', '1', '.'],
#  [],
#  ['155288', '1132', '3', 'При'],
#  ['155289', '1136', '10', 'подписании'],
#  ['155290', '1147', '6', 'нового'],
#  ['155291', '1154', '10', 'соглашения'],
#  ['155292', '1165', '7', 'министр'],
#  ['155293', '1173', '8', 'торговли'],
#  ['155294', '1182', '5', 'Китая'],
#  ['155295', '1188', '4', 'Чэнь'],
#  ['155296', '1193', '5', 'Дэмин'],
#  ['155297', '1199', '6', 'заявил'],
#  ['155298', '1205', '1', ','],
#  ['155299', '1207', '3', 'что'],
#  ['155300', '1211', '5', 'одним'],
#  ['155301', '1217', '2', 'из'],
#  ['155302', '1220', '11', 'приоритетов'],
#  ['155303', '1232', '8', 'является'],
#  ['155304', '1241', '7', 'перевод'],
#  ['155305', '1249', '8', 'огромных'],
#  ['155306', '1258', '8', 'резервов'],
#  ['155307', '1267', '11', 'иностранной'],
#  ['155308', '1279', '6', 'валюты'],
#  ['155309', '1286', '1', 'в'],
#  ['155310', '1288', '10', 'зарубежные'],
#  ['155311', '1299', '6', 'активы'],
#  ['155312', '1305', '1', '.'],
#  [],
#  ['155313', '0', '5', 'Барак'],
#  ['155314', '6', '5', 'Обама'],
#  ['155315', '12', '9', 'принимает'],
#  ['155316', '22', '1', 'в'],
#  ['155317', '24', '5', 'Белом'],
#  ['155318', '30', '4', 'доме'],
#  ['155319', '35', '6', 'своего'],
#  ['155320', '42', '12', 'французского'],
#  ['155321', '55', '7', 'коллегу'],
#  ['155322', '63', '6', 'Николя'],
#  ['155323', '70', '7', 'Саркози'],
#  ['155324', '77', '1', '.'],
#  [],
#  ['155325', '79', '3', 'Как'],
#  ['155326', '83', '4', 'было'],
#  ['155327', '88', '9', 'объявлено'],
#  ['155328', '97', '1', ','],
#  ['155329', '99', '9', 'президент'],
#  ['155330', '109', '7', 'Франции'],
#  ['155331', '117', '6', 'прибыл'],
#  ['155332', '124', '1', 'в'],
#  ['155333', '126', '9', 'Вашингтон'],
#  ['155334', '135', '1', ','],
#  ['155335', '137', '5', 'чтобы'],
#  ['155336', '143', '8', 'обсудить'],
#  ['155337', '152', '1', 'с'],
#  ['155338', '154', '6', 'главой'],
#  ['155339', '161', '13', 'администрации'],
#  ['155340', '175', '3', 'США'],
#  ['155341', '179', '3', 'ряд'],
#  ['155342', '183', '8', 'насущных'],
#  ['155343', '192', '7', 'проблем'],
#  ['155344', '199', '1', ','],
#  ['155345', '201', '7', 'главное'],
#  ['155346', '209', '5', 'место'],
#  ['155347', '215', '5', 'среди'],
#  ['155348', '221', '7', 'которых'],
#  ['155349', '229', '8', 'занимает'],
#  ['155350', '238', '9', 'состояние'],
#  ['155351', '248', '7', 'мировой'],
#  ['155352', '256', '9', 'экономики'],
#  ['155353', '266', '1', 'и'],
#  ['155354', '268', '12', 'безопасность'],
#  ['155355', '280', '1', '.'],
#  [],
#  ['155356', '283', '1', 'В'],
#  ['155357', '285', '9', 'частности'],
#  ['155358', '294', '1', ','],
#  ['155359', '296', '6', 'лидеры'],
#  ['155360', '303', '8', 'намерены'],
#  ['155361', '312', '10', 'обменяться'],
#  ['155362', '323', '8', 'мнениями'],
#  ['155363', '332', '1', 'о'],
#  ['155364', '334', '12', 'перспективах'],
#  ['155365', '347', '7', 'военных'],
#  ['155366', '355', '8', 'действий'],
#  ['155367', '364', '4', 'НАТО'],
#  ['155368', '369', '1', 'в'],
#  ['155369', '371', '11', 'Афганистане'],
#  ['155370', '382', '1', ','],
#  ['155371', '384', '9', 'волнениях'],
#  ['155372', '394', '1', 'в'],
#  ['155373', '396', '9', 'Пакистане'],
#  ['155374', '406', '1', 'и'],
#  ['155375', '408', '7', 'угрозах'],
#  ['155376', '416', '12', 'экстремистов'],
#  ['155377', '429', '1', 'в'],
#  ['155378', '431', '8', 'Северной'],
#  ['155379', '440', '6', 'Африке'],
#  ['155380', '446', '1', '.'],
#  [],
#  ['155381', '448', '1', 'В'],
#  ['155382', '450', '11', 'воскресенье'],
#  ['155383', '462', '6', 'Николя'],
#  ['155384', '469', '7', 'Саркози'],
#  ['155385', '477', '8', 'выпустил'],
#  ['155386', '486', '9', 'заявление'],
#  ['155387', '496', '1', 'с'],
#  ['155388', '498', '10', 'осуждением'],
#  ['155389', '509', '8', 'убийства'],
#  ['155390', '518', '4', 'двух'],
#  ['155391', '523', '11', 'французских'],
#  ['155392', '535', '10', 'заложников'],
#  ['155393', '546', '1', 'в'],
#  ['155394', '548', '6', 'Нигере'],
#  ['155395', '554', '1', '.'],
#  [],
#  ['155396', '557', '1', 'В'],
#  ['155397', '559', '8', 'недавнем'],
#  ['155398', '568', '11', 'выступлении'],
#  ['155399', '580', '2', 'по'],
#  ['155400', '583', '12', 'французскому'],
#  ['155401', '596', '11', 'телевидению'],
#  ['155402', '608', '7', 'Саркози'],
#  ['155403', '616', '7', 'выразил'],
#  ['155404', '624', '6', 'мнение'],
#  ['155405', '631', '1', 'о'],
#  ['155406', '633', '13', 'необходимости'],
#  ['155407', '647', '8', 'изменить'],
#  ['155408', '656', '8', 'ситуацию'],
#  ['155409', '665', '1', 'в'],
#  ['155410', '667', '10', 'глобальной'],
#  ['155411', '678', '9', 'экономике'],
#  ['155412', '687', '1', ','],
#  ['155413', '689', '3', 'при'],
#  ['155414', '693', '7', 'которой'],
#  ['155415', '701', '6', 'доллар'],
#  ['155416', '708', '8', 'остается'],
#  ['155417', '717', '7', 'главным'],
#  ['155418', '725', '12', 'инструментом'],
#  ['155419', '738', '8', 'расчетов'],
#  ['155420', '747', '1', 'и'],
#  ['155421', '749', '7', 'мировой'],
#  ['155422', '757', '9', 'резервной'],
#  ['155423', '767', '7', 'валютой'],
#  ['155424', '774', '1', '.'],
#  [],
#  ['155425', '776', '13', 'Вашингтонская'],
#  ['155426', '790', '7', 'встреча'],
#  ['155427', '798', '8', 'проходит'],
#  ['155428', '807', '1', 'в'],
#  ['155429', '809', '5', 'канун'],
#  ['155430', '815', '8', 'передачи'],
#  ['155431', '824', '7', 'Франции'],
#  ['155432', '832', '10', 'полномочий'],
#  ['155433', '843', '5', 'главы'],
#  ['155434', '849', '1', '«'],
#  ['155435', '850', '7', 'Большой'],
#  ['155436', '858', '9', 'двадцатки'],
#  ['155437', '867', '1', '»'],
#  ['155438', '868', '1', '.'],
#  [],
#  ['155439', '870', '9', 'Президент'],
#  ['155440', '880', '7', 'Саркози'],
#  ['155441', '888', '7', 'выразил'],
#  ['155442', '896', '1', 'в'],
#  ['155443', '898', '4', 'этой'],
#  ['155444', '903', '5', 'связи'],
#  ['155445', '909', '7', 'надежду'],
#  ['155446', '917', '2', 'на'],
#  ['155447', '920', '2', 'то'],
#  ['155448', '922', '1', ','],
#  ['155449', '924', '3', 'что'],
#  ['155450', '928', '3', 'ему'],
#  ['155451', '932', '7', 'удастся'],
#  ['155452', '940', '2', 'за'],
#  ['155453', '943', '5', 'время'],
#  ['155454', '949', '16', 'председательства'],
#  ['155455', '966', '1', 'в'],
#  ['155456', '968', '4', 'G-20'],
#  ['155457', '973', '8', 'провести'],
#  ['155458', '982', '5', 'целый'],
#  ['155459', '988', '3', 'ряд'],
#  ['155460', '992', '6', 'реформ'],
#  ['155461', '998', '1', '.'],
#  [],
#  ['165156', '0', '9', '22-летний'],
#  ['165157', '10', '6', 'житель'],
#  ['165158', '17', '7', 'Аризоны'],
#  ['165159', '24', '1', ','],
#  ['165160', '26', '9', 'открывший'],
#  ['165161', '36', '8', 'стрельбу'],
#  ['165162', '44', '1', ','],
#  ['165163', '46', '1', 'в'],
#  ['165164', '48', '10', 'результате'],
#  ['165165', '59', '7', 'которой'],
#  ['165166', '67', '10', 'пострадали'],
#  ['165167', '78', '2', '20'],
#  ['165168', '81', '7', 'человек'],
#  ['165169', '88', '1', ','],
#  ['165170', '90', '1', 'и'],
#  ['165171', '92', '12', 'попытавшийся'],
#  ['165172', '105', '5', 'убить'],
#  ['165173', '111', '5', 'члена'],
#  ['165174', '117', '9', 'Конгресса'],
#  ['165175', '127', '3', 'США'],
#  ['165176', '130', '1', ','],
#  ['165177', '132', '7', 'впервые'],
#  ['165178', '140', '8', 'предстал'],
#  ['165179', '149', '5', 'перед'],
#  ['165180', '155', '5', 'судом'],
#  ['165181', '161', '2', 'по'],
#  ['165182', '164', '9', 'обвинению'],
#  ['165183', '174', '1', 'в'],
#  ['165184', '176', '10', 'совершении'],
#  ['165185', '187', '12', 'федерального'],
#  ['165186', '200', '12', 'преступления'],
#  ['165187', '212', '1', '.'],
#  [],
#  ['165188', '215', '1', 'В'],
#  ['165189', '217', '11', 'понедельник'],
#  ['165190', '229', '6', 'Джаред'],
#  ['165191', '236', '6', 'Лофнер'],
#  ['165192', '243', '1', 'в'],
#  ['165193', '245', '10', 'наручниках'],
#  ['165194', '256', '1', 'и'],
#  ['165195', '258', '1', 'в'],
#  ['165196', '260', '13', 'сопровождении'],
#  ['165197', '274', '10', 'нескольких'],
#  ['165198', '285', '10', 'охранников'],
#  ['165199', '296', '9', 'доставлен'],
#  ['165200', '306', '1', 'в'],
#  ['165201', '308', '3', 'суд'],
#  ['165202', '312', '1', 'в'],
#  ['165203', '314', '6', 'города'],
#  ['165204', '321', '6', 'Феникс'],
#  ['165205', '327', '1', '.'],
#  [],
#  ['165206', '329', '8', 'Побритый'],
#  ['165207', '338', '6', 'наголо'],
#  ['165208', '345', '1', 'и'],
#  ['165209', '347', '6', 'одетый'],
#  ['165210', '354', '1', 'в'],
#  ['165211', '356', '8', 'тюремную'],
#  ...]

# %%
factrueval_dev_spans
# Out:
# {'22763': ['loc_name', '37', '6', '143790', '1', '#', '143790', 'Москвы'],
#  '22764': ['org_descr', '31', '5', '143789', '1', '#', '143789', 'мэрии'],
#  '22765': ['loc_name', '47', '8', '143792', '1', '#', '143792', 'Тверской'],
#  '22766': ['loc_descr', '56', '7', '143793', '1', '#', '143793', 'площади'],
#  '22767': ['name', '313', '4', '143831', '1', '#', '143831', 'Юрия'],
#  '22768': ['surname', '318', '7', '143832', '1', '#', '143832', 'Лужкова'],
#  '22769': ['loc_name', '306', '6', '143830', '1', '#', '143830', 'Москвы'],
#  '22770': ['loc_name', '477', '6', '143853', '1', '#', '143853', 'Москве'],
#  '22771': ['loc_name', '531', '6', '143862', '1', '#', '143862', 'России'],
#  '22772': ['org_name',
#   '562',
#   '10',
#   '143868',
#   '1',
#   '#',
#   '143868',
#   'Мосгордумы'],
#  '22773': ['name', '610', '6', '143874', '1', '#', '143874', 'Бориса'],
#  '22774': ['surname', '617', '7', '143875', '1', '#', '143875', 'Громова'],
#  '22775': ['name', '756', '4', '143899', '1', '#', '143899', 'Юрия'],
#  '22776': ['surname', '761', '7', '143900', '1', '#', '143900', 'Лужкова'],
#  '22777': ['job', '301', '4', '143829', '1', '#', '143829', 'мэра'],
#  '22778': ['job', '598', '11', '143873', '1', '#', '143873', 'губернатора'],
#  '22779': ['job',
#   '584',
#   '25',
#   '143872',
#   '2',
#   '#',
#   '143872',
#   '143873',
#   'подмосковного',
#   'губернатора'],
#  '68733': ['geo_adj',
#   '584',
#   '13',
#   '143872',
#   '1',
#   '#',
#   '143872',
#   'подмосковного'],
#  '22782': ['name', '968', '4', '143934', '1', '#', '143934', 'Юрию'],
#  '22783': ['nickname',
#   '973',
#   '11',
#   '143935',
#   '1',
#   '#',
#   '143935',
#   'Долгорукому'],
#  '22784': ['loc_descr', '958', '9', '143933', '1', '#', '143933', 'памятника'],
#  '22785': ['nickname', '1340', '5', '143993', '1', '#', '143993', 'zyalt'],
#  '22788': ['loc_name', '1426', '8', '144004', '1', '#', '144004', 'Отрадное'],
#  '22789': ['loc_descr', '1419', '6', '144003', '1', '#', '144003', 'района'],
#  '22790': ['org_descr',
#   '1395',
#   '23',
#   '144001',
#   '2',
#   '#',
#   '144001',
#   '144002',
#   'муниципального',
#   'собрания'],
#  '22793': ['org_name',
#   '1483',
#   '12',
#   '144011',
#   '1',
#   '#',
#   '144011',
#   'Солидарность'],
#  '22794': ['org_descr', '1473', '8', '144009', '1', '#', '144009', 'движения'],
#  '22795': ['org_name',
#   '1451',
#   '21',
#   '144007',
#   '2',
#   '#',
#   '144007',
#   '144008',
#   'московского',
#   'отделения'],
#  '22796': ['name', '1497', '6', '144013', '1', '#', '144013', 'Михаил'],
#  '22797': ['surname', '1504', '9', '144014', '1', '#', '144014', 'Вельмакин'],
#  '22798': ['name', '1539', '3', '144018', '1', '#', '144018', 'Лев'],
#  '22799': ['surname', '1543', '9', '144019', '1', '#', '144019', 'Пономарев'],
#  '22800': ['org_name',
#   '1576',
#   '11',
#   '144024',
#   '2',
#   '#',
#   '144024',
#   '144025',
#   'Левый',
#   'фронт'],
#  '22801': ['org_descr', '1566', '8', '144022', '1', '#', '144022', 'движения'],
#  '22802': ['name', '1589', '6', '144027', '1', '#', '144027', 'Сергей'],
#  '22803': ['surname', '1596', '8', '144028', '1', '#', '144028', 'Удальцов'],
#  '22804': ['job', '1387', '7', '144000', '1', '#', '144000', 'депутат'],
#  '22805': ['job',
#   '1436',
#   '14',
#   '144006',
#   '1',
#   '#',
#   '144006',
#   'сопредседатель'],
#  '22806': ['job', '1525', '13', '144017', '1', '#', '144017', 'правозащитник'],
#  '22807': ['job', '1554', '11', '144021', '1', '#', '144021', 'координатор'],
#  '22808': ['org_descr',
#   '1463',
#   '9',
#   '144008',
#   '1',
#   '#',
#   '144008',
#   'отделения'],
#  '22809': ['org_name',
#   '1648',
#   '17',
#   '144035',
#   '3',
#   '#',
#   '144035',
#   '144036',
#   '144037',
#   'За',
#   'права',
#   'человека'],
#  '22810': ['org_descr', '1638', '8', '144033', '1', '#', '144033', 'движение'],
#  '22811': ['org_name',
#   '1668',
#   '28',
#   '144040',
#   '3',
#   '#',
#   '144040',
#   '144041',
#   '144042',
#   'Союз',
#   'координационных',
#   'советов'],
#  '22812': ['org_descr', '1668', '4', '144040', '1', '#', '144040', 'Союз'],
#  '22813': ['org_name', '1698', '3', '144044', '1', '#', '144044', 'СКС'],
#  '22814': ['org_name',
#   '1714',
#   '21',
#   '144049',
#   '2',
#   '#',
#   '144049',
#   '144050',
#   'Коллективное',
#   'действие'],
#  '22815': ['org_descr', '1704', '8', '144047', '1', '#', '144047', 'институт'],
#  '22816': ['org_name',
#   '1739',
#   '21',
#   '144054',
#   '2',
#   '#',
#   '144054',
#   '144055',
#   'Жилищная',
#   'солидарность'],
#  '22817': ['org_name',
#   '1763',
#   '25',
#   '144058',
#   '3',
#   '#',
#   '144058',
#   '144059',
#   '144060',
#   'Движение',
#   'общежитий',
#   'Москвы'],
#  '22818': ['org_descr', '1763', '8', '144058', '1', '#', '144058', 'Движение'],
#  '22819': ['org_name',
#   '1790',
#   '34',
#   '144062',
#   '5',
#   '#',
#   '144062',
#   '144063',
#   '144064',
#   '144065',
#   '144066',
#   'Движение',
#   'в',
#   'защиту',
#   'Химкинского',
#   'леса'],
#  '22820': ['org_descr', '1790', '8', '144062', '1', '#', '144062', 'Движение'],
#  '22821': ['org_name',
#   '1836',
#   '16',
#   '144070',
#   '2',
#   '#',
#   '144070',
#   '144071',
#   'Московский',
#   'совет'],
#  '22822': ['org_descr', '1826', '8', '144068', '1', '#', '144068', 'движение'],
#  '22823': ['org_name',
#   '1856',
#   '47',
#   '144075',
#   '4',
#   '#',
#   '144075',
#   '144076',
#   '144077',
#   '144078',
#   'Координационный',
#   'совет',
#   'пострадавших',
#   'соинвесторов'],
#  '22824': ['org_descr', '1872', '5', '144076', '1', '#', '144076', 'совет'],
#  '22825': ['org_descr',
#   '1856',
#   '21',
#   '144075',
#   '2',
#   '#',
#   '144075',
#   '144076',
#   'Координационный',
#   'совет'],
#  '38271': ['loc_name',
#   '1808',
#   '16',
#   '144065',
#   '2',
#   '#',
#   '144065',
#   '144066',
#   'Химкинского',
#   'леса'],
#  '38272': ['loc_descr', '1820', '4', '144066', '1', '#', '144066', 'леса'],
#  '22826': ['name', '54', '7', '149390', '1', '#', '149390', 'Герольд'],
#  '22827': ['surname', '62', '7', '149391', '1', '#', '149391', 'Кемпинг'],
#  '22828': ['job',
#   '31',
#   '22',
#   '149387',
#   '3',
#   '#',
#   '149387',
#   '149388',
#   '149389',
#   'проповедник',
#   '-',
#   'евангелист'],
#  '22829': ['name', '425', '7', '149451', '1', '#', '149451', 'Герольд'],
#  '22830': ['surname', '433', '7', '149452', '1', '#', '149452', 'Кемпинг'],
#  '22831': ['name', '661', '5', '149489', '1', '#', '149489', 'Иисус'],
#  '22832': ['surname', '667', '7', '149490', '1', '#', '149490', 'Христос'],
#  '22833': ['loc_name', '633', '5', '149485', '1', '#', '149485', 'Землю'],
#  '22834': ['loc_name', '1096', '5', '149562', '1', '#', '149562', 'Земли'],
#  '22835': ['name', '1163', '6', '149573', '1', '#', '149573', 'Исаака'],
#  '22836': ['surname', '1170', '7', '149574', '1', '#', '149574', 'Ньютона'],
#  '22837': ['name', '1221', '7', '149583', '1', '#', '149583', 'Даниила'],
#  '22838': ['loc_name', '1282', '6', '149595', '1', '#', '149595', 'Солнца'],
#  '22839': ['name', '1369', '7', '149610', '1', '#', '149610', 'Авраама'],
#  '22840': ['name', '1426', '6', '149621', '1', '#', '149621', 'Авелем'],
#  '22841': ['nickname',
#   '1472',
#   '11',
#   '149631',
#   '1',
#   '#',
#   '149631',
#   'Нострадамус'],
#  '22842': ['nickname', '1533', '5', '149641', '1', '#', '149641', 'Ванга'],
#  '43049': ['patronymic',
#   '1359',
#   '8',
#   '149607',
#   '2',
#   '#',
#   '149607',
#   '149608',
#   'ибн',
#   'Эзра'],
#  '43050': ['name',
#   '1379',
#   '10',
#   '149612',
#   '2',
#   '#',
#   '149612',
#   '149613',
#   'Абу',
#   'Машара'],
#  '22848': ['loc_name', '33', '5', '155122', '1', '#', '155122', 'Китая'],
#  '22849': ['org_name',
#   '0',
#   '32',
#   '155118',
#   '4',
#   '#',
#   '155118',
#   '155119',
#   '155120',
#   '155121',
#   'Промышленный',
#   'и',
#   'коммерческий',
#   'банк'],
#  '22850': ['org_descr', '28', '4', '155121', '1', '#', '155121', 'банк'],
#  '22851': ['org_name',
#   '40',
#   '39',
#   '155124',
#   '6',
#   '#',
#   '155124',
#   '155125',
#   '155126',
#   '155127',
#   '155128',
#   '155129',
#   'Industrial',
#   'and',
#   'Commercial',
#   'Bank',
#   'of',
#   'China'],
#  '22852': ['org_descr',
#   '180',
#   '22',
#   '155147',
#   '2',
#   '#',
#   '155147',
#   '155148',
#   'американском',
#   'отделении'],
#  '22853': ['org_name',
#   '203',
#   '17',
#   '155149',
#   '4',
#   '#',
#   '155149',
#   '155150',
#   '155151',
#   '155152',
#   'Bank',
#   'of',
#   'East',
#   'Asia'],
#  '22854': ['org_descr', '193', '9', '155148', '1', '#', '155148', 'отделении'],
#  '22856': ['loc_name',
#   '251',
#   '10',
#   '155158',
#   '1',
#   '#',
#   '155158',
#   'Калифорнии'],
#  '22857': ['loc_name', '264', '9', '155160', '1', '#', '155160', 'Нью-Йорке'],
#  '81230': ['geo_adj',
#   '180',
#   '12',
#   '155147',
#   '1',
#   '#',
#   '155147',
#   'американском'],
#  '81235': ['geo_adj', '339', '10', '155171', '1', '#', '155171', 'китайскому'],
#  '81236': ['org_descr',
#   '350',
#   '13',
#   '155172',
#   '1',
#   '#',
#   '155172',
#   'правительству'],
#  '81237': ['org_descr', '364', '4', '155173', '1', '#', '155173', 'банк'],
#  '81238': ['org_descr',
#   '324',
#   '44',
#   '155170',
#   '4',
#   '#',
#   '155170',
#   '155171',
#   '155172',
#   '155173',
#   'подконтрольный',
#   'китайскому',
#   'правительству',
#   'банк'],
#  '22858': ['loc_name', '450', '6', '155187', '1', '#', '155187', 'Чикаго'],
#  '22859': ['loc_name', '495', '3', '155194', '1', '#', '155194', 'КНР'],
#  '22860': ['name', '499', '2', '155195', '1', '#', '155195', 'Ху'],
#  '22861': ['surname', '502', '8', '155196', '1', '#', '155196', 'Цзиньтао'],
#  '22862': ['loc_name', '513', '3', '155198', '1', '#', '155198', 'США'],
#  '22863': ['job', '482', '12', '155193', '1', '#', '155193', 'председателя'],
#  '22865': ['loc_name', '658', '5', '155219', '1', '#', '155219', 'Китая'],
#  '22866': ['org_descr',
#   '644',
#   '13',
#   '155218',
#   '1',
#   '#',
#   '155218',
#   'правительства'],
#  '22867': ['org_name',
#   '666',
#   '39',
#   '155221',
#   '6',
#   '#',
#   '155221',
#   '155222',
#   '155223',
#   '155224',
#   '155225',
#   '155226',
#   'Industrial',
#   'and',
#   'Commercial',
#   'Bank',
#   'of',
#   'China'],
#  '81231': ['geo_adj', '780', '9', '155238', '1', '#', '155238', 'китайский'],
#  '81232': ['org_descr', '790', '4', '155239', '1', '#', '155239', 'банк'],
#  '81233': ['org_descr',
#   '780',
#   '14',
#   '155238',
#   '2',
#   '#',
#   '155238',
#   '155239',
#   'китайский',
#   'банк'],
#  '81234': ['org_descr',
#   '764',
#   '30',
#   '155237',
#   '3',
#   '#',
#   '155237',
#   '155238',
#   '155239',
#   'государственный',
#   'китайский',
#   'банк'],
#  '22868': ['loc_name', '1028', '5', '155275', '1', '#', '155275', 'Китая'],
#  '22869': ['loc_name', '1182', '5', '155294', '1', '#', '155294', 'Китая'],
#  '22870': ['name', '1188', '4', '155295', '1', '#', '155295', 'Чэнь'],
#  '22871': ['surname', '1193', '5', '155296', '1', '#', '155296', 'Дэмин'],
#  '22872': ['job',
#   '1165',
#   '16',
#   '155292',
#   '2',
#   '#',
#   '155292',
#   '155293',
#   'министр',
#   'торговли'],
#  '22873': ['job', '1165', '7', '155292', '1', '#', '155292', 'министр'],
#  '22874': ['name', '0', '5', '155313', '1', '#', '155313', 'Барак'],
#  '22875': ['surname', '6', '5', '155314', '1', '#', '155314', 'Обама'],
#  '22877': ['loc_descr', '30', '4', '155318', '1', '#', '155318', 'доме'],
#  '22878': ['name', '63', '6', '155322', '1', '#', '155322', 'Николя'],
#  '22879': ['surname', '70', '7', '155323', '1', '#', '155323', 'Саркози'],
#  '22880': ['loc_name', '109', '7', '155330', '1', '#', '155330', 'Франции'],
#  '22881': ['loc_name', '126', '9', '155333', '1', '#', '155333', 'Вашингтон'],
#  '22882': ['org_name',
#   '161',
#   '13',
#   '155339',
#   '1',
#   '#',
#   '155339',
#   'администрации'],
#  '22883': ['loc_name', '175', '3', '155340', '1', '#', '155340', 'США'],
#  '22885': ['job', '55', '7', '155321', '1', '#', '155321', 'коллегу'],
#  '22886': ['job',
#   '42',
#   '20',
#   '155320',
#   '2',
#   '#',
#   '155320',
#   '155321',
#   'французского',
#   'коллегу'],
#  '22887': ['job', '99', '9', '155329', '1', '#', '155329', 'президент'],
#  '22888': ['job', '154', '6', '155338', '1', '#', '155338', 'главой'],
#  '22930': ['loc_name',
#   '24',
#   '10',
#   '155317',
#   '2',
#   '#',
#   '155317',
#   '155318',
#   'Белом',
#   'доме'],
#  '74712': ['geo_adj',
#   '42',
#   '12',
#   '155320',
#   '1',
#   '#',
#   '155320',
#   'французского'],
#  '22889': ['org_name', '364', '4', '155367', '1', '#', '155367', 'НАТО'],
#  '22890': ['loc_name',
#   '371',
#   '11',
#   '155369',
#   '1',
#   '#',
#   '155369',
#   'Афганистане'],
#  '22891': ['loc_name', '396', '9', '155373', '1', '#', '155373', 'Пакистане'],
#  '22892': ['loc_name',
#   '431',
#   '15',
#   '155378',
#   '2',
#   '#',
#   '155378',
#   '155379',
#   'Северной',
#   'Африке'],
#  '22893': ['name', '462', '6', '155383', '1', '#', '155383', 'Николя'],
#  '22894': ['surname', '469', '7', '155384', '1', '#', '155384', 'Саркози'],
#  '22895': ['loc_name', '548', '6', '155394', '1', '#', '155394', 'Нигере'],
#  '74732': ['geo_adj',
#   '523',
#   '11',
#   '155391',
#   '1',
#   '#',
#   '155391',
#   'французских'],
#  '22896': ['surname', '608', '7', '155402', '1', '#', '155402', 'Саркози'],
#  '22897': ['loc_name', '824', '7', '155431', '1', '#', '155431', 'Франции'],
#  '22898': ['org_name',
#   '850',
#   '17',
#   '155435',
#   '2',
#   '#',
#   '155435',
#   '155436',
#   'Большой',
#   'двадцатки'],
#  '22899': ['surname', '880', '7', '155440', '1', '#', '155440', 'Саркози'],
#  '22900': ['org_name', '968', '4', '155456', '1', '#', '155456', 'G-20'],
#  '22901': ['job', '843', '5', '155433', '1', '#', '155433', 'главы'],
#  '22902': ['job', '870', '9', '155439', '1', '#', '155439', 'Президент'],
#  '22903': ['loc_name', '17', '7', '165158', '1', '#', '165158', 'Аризоны'],
#  '22904': ['org_name', '117', '9', '165174', '1', '#', '165174', 'Конгресса'],
#  '22905': ['loc_name', '127', '3', '165175', '1', '#', '165175', 'США'],
#  '22907': ['job', '111', '5', '165173', '1', '#', '165173', 'члена'],
#  '22908': ['name', '229', '6', '165190', '1', '#', '165190', 'Джаред'],
#  '22909': ['surname', '236', '6', '165191', '1', '#', '165191', 'Лофнер'],
#  '22910': ['loc_name', '321', '6', '165204', '1', '#', '165204', 'Феникс'],
#  '22911': ['loc_descr', '314', '6', '165203', '1', '#', '165203', 'города'],
#  '22912': ['surname', '406', '6', '165222', '1', '#', '165222', 'Лофнер'],
#  '22913': ['loc_name', '465', '6', '165232', '1', '#', '165232', 'Тусоне'],
#  '22914': ['org_name',
#   '512',
#   '21',
#   '165242',
#   '2',
#   '#',
#   '165242',
#   '165243',
#   'Палаты',
#   'представителей'],
#  '22915': ['org_descr', '512', '6', '165242', '1', '#', '165242', 'Палаты'],
#  '22916': ['org_name', '534', '9', '165244', '1', '#', '165244', 'Конгресса'],
#  '22917': ['loc_name', '544', '3', '165245', '1', '#', '165245', 'США'],
#  '22921': ['loc_descr', '551', '5', '165247', '1', '#', '165247', 'штата'],
#  '22922': ['loc_name', '557', '7', '165248', '1', '#', '165248', 'Аризона'],
#  '22923': ['name', '565', '8', '165249', '1', '#', '165249', 'Гэбриэль'],
#  '22924': ['surname', '574', '8', '165250', '1', '#', '165250', 'Гиффордс'],
#  '22925': ['job', '507', '4', '165241', '1', '#', '165241', 'член'],
#  '22931': ['loc_name', '709', '3', '165273', '1', '#', '165273', 'США'],
#  '22932': ['name', '713', '5', '165274', '1', '#', '165274', 'Барак'],
#  '22933': ['surname', '719', '5', '165275', '1', '#', '165275', 'Обама'],
#  '22934': ['surname', '843', '5', '165301', '1', '#', '165301', 'Обама'],
#  '22935': ['loc_name',
#   '860',
#   '10',
#   '165304',
#   '2',
#   '#',
#   '165304',
#   '165305',
#   'Белом',
#   'доме'],
#  '22936': ['loc_descr', '866', '4', '165305', '1', '#', '165305', 'доме'],
#  '22937': ['job', '699', '9', '165272', '1', '#', '165272', 'президент'],
#  '22938': ['name', '1011', '6', '165330', '1', '#', '165330', 'Мишель'],
#  '22939': ['surname', '1018', '5', '165331', '1', '#', '165331', 'Обама'],
#  '22940': ['loc_name',
#   '1038',
#   '10',
#   '165334',
#   '2',
#   '#',
#   '165334',
#   '165335',
#   'Белом',
#   'доме'],
#  '22941': ['loc_descr', '1044', '4', '165335', '1', '#', '165335', 'доме'],
#  '22942': ['loc_name', '1096', '9', '165344', '1', '#', '165344', 'Капитолия'],
#  '22943': ['org_name',
#   '1107',
#   '27',
#   '165346',
#   '3',
#   '#',
#   '165346',
#   '165347',
#   '165348',
#   'Нью-йоркская',
#   'фондовая',
#   'биржа'],
#  '22944': ['org_descr', '1129', '5', '165348', '1', '#', '165348', 'биржа'],
#  '22945': ['job', '987', '9', '165326', '1', '#', '165326', 'Президент'],
#  '22946': ['job',
#   '999',
#   '11',
#   '165328',
#   '2',
#   '#',
#   '165328',
#   '165329',
#   'первая',
#   'леди'],
#  '74725': ['geo_adj',
#   '1107',
#   '12',
#   '165346',
#   '1',
#   '#',
#   '165346',
#   'Нью-йоркская'],
#  '22947': ['surname', '1240', '8', '165363', '1', '#', '165363', 'Гиффордс'],
#  '22948': ['surname', '1547', '8', '165414', '1', '#', '165414', 'Гиффордс'],
#  '22949': ['surname', '1592', '7', '165421', '1', '#', '165421', 'Лофнеру'],
#  '22950': ['org_name', '1711', '9', '165439', '1', '#', '165439', 'Конгресса'],
#  '28806': ['org_name',
#   '13',
#   '20',
#   '650263',
#   '2',
#   '#',
#   '650263',
#   '650264',
#   'Agence',
#   'France-Presse'],
#  '28807': ['org_name',
#   '35',
#   '13',
#   '650266',
#   '2',
#   '#',
#   '650266',
#   '650267',
#   'Верховный',
#   'суд'],
#  '28808': ['org_descr', '45', '3', '650267', '1', '#', '650267', 'суд'],
#  '28809': ['loc_name', '49', '10', '650268', '1', '#', '650268', 'Бангладеша'],
#  '28810': ['loc_name', '930', '9', '650409', '1', '#', '650409', 'Бангладеш'],
#  '28811': ['loc_name', '1099', '9', '650434', '1', '#', '650434', 'Индонезии'],
#  '28812': ['loc_name', '1110', '9', '650436', '1', '#', '650436', 'Пакистана'],
#  '28813': ['loc_name', '1122', '5', '650438', '1', '#', '650438', 'Индии'],
#  '23080': ['org_name',
#   '13',
#   '62',
#   '165715',
#   '5',
#   '#',
#   '165715',
#   '165716',
#   '165717',
#   '165718',
#   '165719',
#   'Всемирной',
#   'продовольственной',
#   'и',
#   'сельскохозяйственной',
#   'организации'],
#  '23081': ['org_name', '76', '3', '165720', '1', '#', '165720', 'ООН'],
#  '23113': ['org_descr',
#   '64',
#   '11',
#   '165719',
#   '1',
#   '#',
#   '165719',
#   'организации'],
#  '44847': ['org_name', '81', '3', '165722', '1', '#', '165722', 'ФАО'],
#  '23114': ['org_name', '270', '3', '165754', '1', '#', '165754', 'ФАО'],
#  '23115': ['name', '274', '9', '165755', '1', '#', '165755', 'Абдолреза'],
#  '23116': ['surname', '284', '9', '165756', '1', '#', '165756', 'Аббассиан'],
#  '23117': ['job', '260', '9', '165753', '1', '#', '165753', 'Экономист'],
#  '23118': ['loc_name', '408', '4', '165774', '1', '#', '165774', 'Риме'],
#  '23119': ['org_name', '413', '3', '165775', '1', '#', '165775', 'ФАО'],
#  '23120': ['org_name', '564', '3', '165799', '1', '#', '165799', 'ФАО'],
#  '23121': ['loc_name', '864', '5', '165854', '1', '#', '165854', 'Гаити'],
#  '23122': ['org_name', '951', '3', '165868', '1', '#', '165868', 'ФАО'],
#  '35692': ['loc_name', '95', '9', '168483', '1', '#', '168483', 'Венесуэлы'],
#  '35693': ['loc_name', '108', '4', '168485', '1', '#', '168485', 'Кубы'],
#  '35694': ['loc_name', '309', '4', '168515', '1', '#', '168515', 'Куба'],
#  '35695': ['loc_name',
#   '401',
#   '11',
#   '168526',
#   '1',
#   '#',
#   '168526',
#   'Вашингтоном'],
#  '35696': ['loc_name', '649', '5', '168564', '1', '#', '168564', 'Кубой'],
#  '35697': ['loc_name', '710', '3', '168572', '1', '#', '168572', 'США'],
#  '35698': ['loc_name', '745', '6', '168578', '1', '#', '168578', 'Гаваны'],
#  '35699': ['org_descr',
#   '537',
#   '13',
#   '168550',
#   '1',
#   '#',
#   '168550',
#   'администрация'],
#  '35700': ['job', '551', '10', '168551', '1', '#', '168551', 'президента'],
#  '35701': ['surname', '562', '5', '168552', '1', '#', '168552', 'Обамы'],
#  '24991': ['loc_name', '47', '8', '169340', '1', '#', '169340', 'Германии'],
#  '24992': ['org_name',
#   '14',
#   '32',
#   '169337',
#   '3',
#   '#',
#   '169337',
#   '169338',
#   '169339',
#   'Министерства',
#   'сельского',
#   'хозяйства'],
#  '24993': ['org_descr',
#   '14',
#   '12',
#   '169337',
#   '1',
#   '#',
#   '169337',
#   'Министерства'],
#  '24994': ['job', '0', '13', '169336', '1', '#', '169336', 'Представитель'],
#  '24995': ['loc_name',
#   '518',
#   '11',
#   '169419',
#   '2',
#   '#',
#   '169419',
#   '169420',
#   'Южная',
#   'Корея'],
#  '24996': ['loc_name', '564', '8', '169427', '1', '#', '169427', 'Германии'],
#  '24997': ['loc_name', '740', '8', '169452', '1', '#', '169452', 'Германии'],
#  '24998': ['org_name',
#   '803',
#   '19',
#   '169461',
#   '3',
#   '#',
#   '169461',
#   '169462',
#   '169463',
#   'Harles',
#   'und',
#   'Jentzsch'],
#  '24999': ['org_descr', '794', '8', '169460', '1', '#', '169460', 'компании'],
#  '25000': ['loc_name', '881', '8', '169474', '1', '#', '169474', 'Германии'],
#  '34081': ['loc_name', '0', '7', '181228', '1', '#', '181228', 'Украина'],
#  '34082': ['loc_name', '10', '6', '181230', '1', '#', '181230', 'Турция'],
#  '34083': ['org_name',
#   '25',
#   '20',
#   '181232',
#   '2',
#   '#',
#   '181232',
#   '181233',
#   'Стратегический',
#   'совет'],
#  '34084': ['org_descr', '40', '5', '181233', '1', '#', '181233', 'совет'],
#  '34085': ['loc_name', '189', '5', '181252', '1', '#', '181252', 'Киева'],
#  '34086': ['loc_name',
#   '248',
#   '17',
#   '181261',
#   '2',
#   '#',
#   '181261',
#   '181262',
#   'Соединённые',
#   'Штаты'],
#  '34087': ['org_name', '267', '8', '181264', '1', '#', '181264', 'Евросоюз'],
#  '34088': ['loc_name', '277', '5', '181266', '1', '#', '181266', 'Китай'],
#  '34089': ['loc_name', '285', '6', '181268', '1', '#', '181268', 'Россия'],
#  '34090': ['loc_name', '344', '8', '181277', '1', '#', '181277', 'Украиной'],
#  '34091': ['loc_name',
#   '355',
#   '11',
#   '181279',
#   '1',
#   '#',
#   '181279',
#   'Казахстаном'],
#  '34092': ['loc_name', '487', '6', '181298', '1', '#', '181298', 'Турции'],
#  '34093': ['name', '494', '6', '181299', '1', '#', '181299', 'Реджеп'],
#  '34094': ['name', '501', '5', '181300', '1', '#', '181300', 'Тайип'],
#  '34095': ['surname', '507', '7', '181301', '1', '#', '181301', 'Эрдоган'],
#  '34096': ['loc_name', '532', '7', '181307', '1', '#', '181307', 'Украину'],
#  '34097': ['name', '566', '8', '181311', '1', '#', '181311', 'Виктором'],
#  '34098': ['surname', '575', '10', '181312', '1', '#', '181312', 'Януковичем'],
#  '34099': ['loc_name', '629', '6', '181319', '1', '#', '181319', 'Киевом'],
#  '34100': ['loc_name', '638', '7', '181321', '1', '#', '181321', 'Анкарой'],
#  '34101': ['job',
#   '471',
#   '15',
#   '181297',
#   '1',
#   '#',
#   '181297',
#   'премьер-министр'],
#  '34102': ['job', '554', '11', '181310', '1', '#', '181310', 'президентом'],
#  '34103': ['name', '878', '6', '181363', '1', '#', '181363', 'Виктор'],
#  '34104': ['surname', '885', '8', '181364', '1', '#', '181364', 'Янукович'],
#  '34105': ['loc_name', '896', '5', '181366', '1', '#', '181366', 'Киеве'],
#  '34106': ['loc_name', '960', '6', '181373', '1', '#', '181373', 'Турции'],
#  '34107': ['job', '868', '9', '181362', '1', '#', '181362', 'президент'],
#  '34108': ['job',
#   '942',
#   '17',
#   '181372',
#   '1',
#   '#',
#   '181372',
#   'премьер-министром'],
#  '34109': ['name', '1003', '6', '181383', '1', '#', '181383', 'Реджеп'],
#  '34110': ['surname', '1010', '7', '181384', '1', '#', '181384', 'Эрдоган'],
#  '34111': ['loc_name', '1061', '7', '181392', '1', '#', '181392', 'Украину'],
#  '34112': ['loc_name', '1122', '6', '181399', '1', '#', '181399', 'Турции'],
#  '34113': ['name', '1227', '6', '181418', '1', '#', '181418', 'Реджеп'],
#  '34114': ['surname', '1234', '7', '181419', '1', '#', '181419', 'Эрдоган'],
#  '34115': ['loc_name', '1468', '7', '181454', '1', '#', '181454', 'Украины'],
#  '34116': ['job', '1457', '10', '181453', '1', '#', '181453', 'президента'],
#  '34117': ['org_descr',
#   '1444',
#   '12',
#   '181452',
#   '1',
#   '#',
#   '181452',
#   'пресс-служба'],
#  '34118': ['job',
#   '1427',
#   '16',
#   '181451',
#   '1',
#   '#',
#   '181451',
#   'премьер-министра'],
#  '34119': ['job',
#   '1417',
#   '26',
#   '181450',
#   '2',
#   '#',
#   '181450',
#   '181451',
#   'турецкого',
#   'премьер-министра'],
#  '34120': ['loc_name', '1597', '6', '181473', '1', '#', '181473', 'Турция'],
#  '34121': ['loc_name', '1665', '5', '181484', '1', '#', '181484', 'Киеве'],
#  '34122': ['loc_descr',
#   '1736',
#   '21',
#   '181493',
#   '2',
#   '#',
#   '181493',
#   '181494',
#   'автономной',
#   'республики'],
#  '34123': ['loc_descr',
#   '1747',
#   '10',
#   '181494',
#   '1',
#   '#',
#   '181494',
#   'республики'],
#  '34124': ['loc_name', '1758', '4', '181495', '1', '#', '181495', 'Крым'],
#  '34125': ['loc_name', '1891', '6', '181515', '1', '#', '181515', 'Турции'],
#  '34126': ['name', '1898', '8', '181516', '1', '#', '181516', 'Реджепом'],
#  '34127': ['surname', '1907', '9', '181517', '1', '#', '181517', 'Эрдоганом'],
#  '34128': ['loc_name', '1931', '7', '181520', '1', '#', '181520', 'Украины'],
#  '34129': ['name', '1939', '8', '181521', '1', '#', '181521', 'Виктором'],
#  '34130': ['surname',
#   '1948',
#   '10',
#   '181522',
#   '1',
#   '#',
#   '181522',
#   'Януковичем'],
#  '34131': ['org_name',
#   '1991',
#   '14',
#   '181528',
#   '2',
#   '#',
#   '181528',
#   '181529',
#   'Русской',
#   'службе'],
#  '34132': ['org_name',
#   '2007',
#   '14',
#   '181531',
#   '2',
#   '#',
#   '181531',
#   '181532',
#   'Голоса',
#   'Америки'],
#  '34133': ['org_descr', '2029', '8', '181535', '1', '#', '181535', 'Меджлиса'],
#  '34134': ['org_name',
#   '2029',
#   '34',
#   '181535',
#   '3',
#   '#',
#   '181535',
#   '181536',
#   '181537',
#   'Меджлиса',
#   'крымско-татарского',
#   'народа'],
#  '34135': ['loc_name', '2082', '7', '181541', '1', '#', '181541', 'Украины'],
#  '34136': ['name', '2090', '7', '181542', '1', '#', '181542', 'Мустафа'],
#  '34137': ['surname', '2098', '8', '181543', '1', '#', '181543', 'Джемилев'],
#  '34138': ['job',
#   '1873',
#   '17',
#   '181514',
#   '1',
#   '#',
#   '181514',
#   'премьер-министром'],
#  '34139': ['job', '1919', '11', '181519', '1', '#', '181519', 'президентом'],
#  '34140': ['job', '2023', '5', '181534', '1', '#', '181534', 'лидер'],
#  '34141': ['job',
#   '2065',
#   '16',
#   '181539',
#   '2',
#   '#',
#   '181539',
#   '181540',
#   'народный',
#   'депутат'],
#  '34142': ['job', '2074', '7', '181540', '1', '#', '181540', 'депутат'],
#  '34143': ['loc_name', '2145', '6', '181551', '1', '#', '181551', 'Турции'],
#  '34144': ['name', '2282', '6', '181572', '1', '#', '181572', 'Реджеп'],
#  '34145': ['surname', '2289', '7', '181573', '1', '#', '181573', 'Эрдоган'],
#  '34146': ['name', '2354', '8', '181584', '1', '#', '181584', 'Виктором'],
#  '34147': ['surname',
#   '2363',
#   '10',
#   '181585',
#   '1',
#   '#',
#   '181585',
#   'Януковичем'],
#  '34148': ['name', '2386', '7', '181590', '1', '#', '181590', 'Мустафа'],
#  '34149': ['surname', '2394', '8', '181591', '1', '#', '181591', 'Джемилев'],
#  '34150': ['job',
#   '2127',
#   '17',
#   '181550',
#   '1',
#   '#',
#   '181550',
#   'премьер-министром'],
#  '34151': ['job', '2342', '11', '181583', '1', '#', '181583', 'президентом'],
#  '34152': ['org_name',
#   '2416',
#   '13',
#   '181595',
#   '2',
#   '#',
#   '181595',
#   '181596',
#   'Голос',
#   'Америки'],
#  '34153': ['loc_name', '2493', '6', '181608', '1', '#', '181608', 'Турции'],
#  '34154': ['loc_name', '2519', '6', '181613', '1', '#', '181613', 'Анкару'],
#  '34155': ['job', '2482', '10', '181607', '1', '#', '181607', 'президенту'],
#  '34157': ['loc_name', '2422', '7', '181596', '1', '#', '181596', 'Америки'],
#  '34158': ['name', '2615', '7', '181625', '1', '#', '181625', 'Мустафа'],
#  '34159': ['surname', '2623', '8', '181626', '1', '#', '181626', 'Джемилев'],
#  '34160': ['loc_name', '2689', '6', '181639', '1', '#', '181639', 'Турции'],
#  '34161': ['loc_name', '2775', '5', '181651', '1', '#', '181651', 'Крыму'],
#  '34162': ['job',
#   '2671',
#   '17',
#   '181638',
#   '1',
#   '#',
#   '181638',
#   'премьер-министром'],
#  '34163': ['loc_name', '2945', '7', '181679', '1', '#', '181679', 'Америки'],
#  '34164': ['org_name',
#   '2939',
#   '13',
#   '181678',
#   '2',
#   '#',
#   '181678',
#   '181679',
#   'Голос',
#   'Америки'],
#  '34165': ['surname', '2986', '8', '181686', '1', '#', '181686', 'Эрдогана'],
#  '34166': ['name', '3028', '7', '181692', '1', '#', '181692', 'Мустафа'],
#  '34167': ['surname', '3036', '8', '181693', '1', '#', '181693', 'Джемилев'],
#  '34168': ['loc_name', '3338', '7', '181742', '1', '#', '181742', 'Америки'],
#  '34169': ['org_name',
#   '3332',
#   '13',
#   '181741',
#   '2',
#   '#',
#   '181741',
#   '181742',
#   'Голос',
#   'Америки'],
#  '34170': ['loc_name', '3427', '6', '181756', '1', '#', '181756', 'Турцию'],
#  '34171': ['name', '3505', '7', '181768', '1', '#', '181768', 'Мустафа'],
#  '34172': ['surname', '3513', '8', '181769', '1', '#', '181769', 'Джемилев'],
#  '34173': ['loc_descr', '3555', '7', '181775', '1', '#', '181775', 'империи'],
#  '34174': ['loc_name',
#   '3545',
#   '17',
#   '181774',
#   '2',
#   '#',
#   '181774',
#   '181775',
#   'Османской',
#   'империи'],
#  '34175': ['loc_name', '3658', '5', '181792', '1', '#', '181792', 'Крыма'],
#  '34176': ['loc_name', '3664', '7', '181793', '1', '#', '181793', 'Россией'],
#  '34177': ['loc_descr', '3760', '7', '181805', '1', '#', '181805', 'империи'],
#  '34178': ['loc_name',
#   '3750',
#   '17',
#   '181804',
#   '2',
#   '#',
#   '181804',
#   '181805',
#   'Османской',
#   'империи'],
#  '34179': ['loc_name', '3778', '6', '181809', '1', '#', '181809', 'Турции'],
#  '34180': ['loc_name', '3839', '5', '181821', '1', '#', '181821', 'Крыму'],
#  '34181': ['loc_name', '3922', '6', '181837', '1', '#', '181837', 'Турция'],
#  '34182': ['loc_name', '3997', '7', '181850', '1', '#', '181850', 'Америки'],
#  '34183': ['org_name',
#   '3991',
#   '13',
#   '181849',
#   '2',
#   '#',
#   '181849',
#   '181850',
#   'Голос',
#   'Америки'],
#  '34184': ['loc_name', '4010', '7', '181853', '1', '#', '181853', 'Украины'],
#  '34185': ['loc_name', '4041', '7', '181857', '1', '#', '181857', 'Турцией'],
#  '34186': ['org_name',
#   '4084',
#   '10',
#   '181864',
#   '1',
#   '#',
#   '181864',
#   'Евросоюзом'],
#  '34187': ['name', '4110', '7', '181868', '1', '#', '181868', 'Мустафа'],
#  '34188': ['surname', '4118', '8', '181869', '1', '#', '181869', 'Джемилев'],
#  '34189': ['loc_name', '4128', '7', '181871', '1', '#', '181871', 'Украина'],
#  '34190': ['loc_name', '4138', '6', '181873', '1', '#', '181873', 'Турция'],
#  '34191': ['loc_name', '4209', '7', '181883', '1', '#', '181883', 'Украины'],
#  '34192': ['name', '4217', '6', '181884', '1', '#', '181884', 'Виктор'],
#  '34193': ['surname', '4224', '8', '181885', '1', '#', '181885', 'Янукович'],
#  '34194': ['loc_name', '4251', '6', '181888', '1', '#', '181888', 'Турции'],
#  '34195': ['name', '4258', '6', '181889', '1', '#', '181889', 'Реджеп'],
#  '34196': ['surname', '4265', '7', '181890', '1', '#', '181890', 'Эрдоган'],
#  '34197': ['job', '4199', '9', '181882', '1', '#', '181882', 'президент'],
#  '34198': ['job',
#   '4235',
#   '15',
#   '181887',
#   '1',
#   '#',
#   '181887',
#   'премьер-министр'],
#  '34199': ['loc_name', '4463', '7', '181917', '1', '#', '181917', 'Америки'],
#  '34200': ['org_name',
#   '4457',
#   '13',
#   '181916',
#   '2',
#   '#',
#   '181916',
#   '181917',
#   'Голос',
#   'Америки'],
#  '34201': ['loc_name', '4496', '5', '181923', '1', '#', '181923', 'Крыма'],
#  '34202': ['name', '4552', '7', '181931', '1', '#', '181931', 'Мустафа'],
#  '34203': ['surname', '4560', '8', '181932', '1', '#', '181932', 'Джемилев'],
#  '34204': ['org_descr',
#   '4590',
#   '18',
#   '181937',
#   '2',
#   '#',
#   '181937',
#   '181938',
#   'крымской',
#   'автономии'],
#  '34205': ['org_descr',
#   '4599',
#   '9',
#   '181938',
#   '1',
#   '#',
#   '181938',
#   'автономии'],
#  '34206': ['loc_name', '4645', '5', '181947', '1', '#', '181947', 'Крыма'],
#  '34207': ['org_descr',
#   '4635',
#   '9',
#   '181946',
#   '1',
#   '#',
#   '181946',
#   'парламент'],
#  '34208': ['loc_name', '4927', '8', '181994', '1', '#', '181994', 'Донбасса'],
#  '34209': ['loc_name', '4946', '4', '181997', '1', '#', '181997', 'Крым'],
#  '34210': ['loc_name', '5021', '7', '182008', '1', '#', '182008', 'Америки'],
#  '34211': ['org_name',
#   '5015',
#   '13',
#   '182007',
#   '2',
#   '#',
#   '182007',
#   '182008',
#   'Голос',
#   'Америки'],
#  '34212': ['name', '5104', '7', '182022', '1', '#', '182022', 'Мустафа'],
#  '34213': ['surname', '5112', '8', '182023', '1', '#', '182023', 'Джемилев'],
#  '34214': ['loc_name', '5238', '5', '182043', '1', '#', '182043', 'Крыма'],
#  '34215': ['loc_name', '5396', '4', '182069', '1', '#', '182069', 'Крым'],
#  '34216': ['loc_name', '5411', '7', '182072', '1', '#', '182072', 'Украины'],
#  '34217': ['loc_name', '5595', '7', '182099', '1', '#', '182099', 'Америки'],
#  '34218': ['org_name',
#   '5589',
#   '13',
#   '182098',
#   '2',
#   '#',
#   '182098',
#   '182099',
#   'Голос',
#   'Америки'],
#  '34219': ['loc_name', '5658', '7', '182111', '1', '#', '182111', 'Турцией'],
#  '34220': ['name', '5704', '6', '182116', '1', '#', '182116', 'Романа'],
#  '34221': ['surname', '5711', '9', '182117', '1', '#', '182117', 'Коноплева'],
#  '34222': ['loc_name', '5722', '4', '182119', '1', '#', '182119', 'Крым'],
#  '34223': ['loc_name', '5772', '6', '182125', '1', '#', '182125', 'Анкары'],
#  '34224': ['loc_name', '5811', '6', '182131', '1', '#', '182131', 'Турция'],
#  '34225': ['loc_name', '5828', '7', '182134', '1', '#', '182134', 'Россией'],
#  '34226': ['loc_name',
#   '5870',
#   '20',
#   '182138',
#   '2',
#   '#',
#   '182138',
#   '182139',
#   'Гагаузской',
#   'автономии'],
#  '34227': ['loc_descr',
#   '5881',
#   '9',
#   '182139',
#   '1',
#   '#',
#   '182139',
#   'автономии'],
#  '34228': ['loc_name',
#   '5891',
#   '21',
#   '182140',
#   '2',
#   '#',
#   '182140',
#   '182141',
#   'Молдавской',
#   'республики'],
#  '34229': ['loc_descr',
#   '5902',
#   '10',
#   '182141',
#   '1',
#   '#',
#   '182141',
#   'республики'],
#  '34230': ['loc_name', '5985', '7', '182151', '1', '#', '182151', 'Молдове'],
#  '34231': ['loc_name',
#   '6110',
#   '20',
#   '182168',
#   '2',
#   '#',
#   '182168',
#   '182169',
#   'Турецкой',
#   'республикой'],
#  '34232': ['loc_descr',
#   '6119',
#   '11',
#   '182169',
#   '1',
#   '#',
#   '182169',
#   'республикой'],
#  '34233': ['name', '6142', '5', '182174', '1', '#', '182174', 'Роман'],
#  '34234': ['surname', '6148', '8', '182175', '1', '#', '182175', 'Коноплев'],
#  '34235': ['org_name',
#   '6157',
#   '14',
#   '182176',
#   '2',
#   '#',
#   '182176',
#   '182177',
#   'Русской',
#   'службе'],
#  '34236': ['org_name',
#   '6173',
#   '14',
#   '182179',
#   '2',
#   '#',
#   '182179',
#   '182180',
#   'Голоса',
#   'Америки'],
#  '34237': ['loc_name', '6180', '7', '182180', '1', '#', '182180', 'Америки'],
#  '34238': ['job', '5694', '9', '182115', '1', '#', '182115', 'аналитика'],
#  '34239': ['job',
#   '5677',
#   '26',
#   '182114',
#   '2',
#   '#',
#   '182114',
#   '182115',
#   'приднестровского',
#   'аналитика'],
#  '34240': ['loc_name', '6284', '8', '182195', '1', '#', '182195', 'Гагаузии'],
#  '34241': ['loc_name', '6304', '6', '182200', '1', '#', '182200', 'Турция'],
#  '34242': ['loc_name', '6381', '8', '182216', '1', '#', '182216', 'Гагаузии'],
#  '34243': ['name', '6472', '6', '182236', '1', '#', '182236', 'Романа'],
#  '34244': ['surname', '6479', '9', '182237', '1', '#', '182237', 'Коноплева'],
#  '34245': ['loc_name', '6541', '7', '182243', '1', '#', '182243', 'Молдовы'],
#  '25001': ['name', '0', '8', '182429', '1', '#', '182429', 'Фернандо'],
#  '25002': ['surname', '9', '6', '182430', '1', '#', '182430', 'Алонсо'],
#  '25003': ['loc_name', '79', '6', '182441', '1', '#', '182441', 'Монако'],
#  '25004': ['name', '120', '7', '182447', '1', '#', '182447', 'Михаэль'],
#  '25005': ['surname', '128', '7', '182448', '1', '#', '182448', 'Шумахер'],
#  '25006': ['loc_name', '163', '8', '182453', '1', '#', '182453', 'Раскассэ'],
#  '25007': ['loc_name',
#   '173',
#   '11',
#   '182455',
#   '2',
#   '#',
#   '182455',
#   '182456',
#   'La',
#   'Rascasse'],
#  '25008': ['name', '350', '8', '182483', '1', '#', '182483', 'Фернандо'],
#  '25009': ['surname', '359', '6', '182484', '1', '#', '182484', 'Алонсо'],
#  '25010': ['org_name', '395', '3', '182490', '1', '#', '182490', 'FIA'],
#  '25011': ['name', '433', '7', '182496', '1', '#', '182496', 'Михаэль'],
#  '25012': ['org_name', '590', '7', '182523', '1', '#', '182523', 'Феррари'],
#  '25013': ['org_descr', '582', '7', '182522', '1', '#', '182522', 'Команда'],
#  '25014': ['name', '789', '6', '182551', '1', '#', '182551', 'Фелипе'],
#  '25015': ['surname', '796', '5', '182552', '1', '#', '182552', 'Масса'],
#  '25016': ['org_name', '917', '7', '182574', '1', '#', '182574', 'Феррари'],
#  '25017': ['name', '1073', '4', '182597', '1', '#', '182597', 'Кими'],
#  '25018': ['surname',
#   '1078',
#   '10',
#   '182598',
#   '1',
#   '#',
#   '182598',
#   'Райкконена'],
#  '25019': ['name', '1091', '5', '182600', '1', '#', '182600', 'Марка'],
#  '25020': ['surname', '1097', '7', '182601', '1', '#', '182601', 'Уэббера'],
#  '25021': ['surname', '1190', '6', '182617', '1', '#', '182617', 'Алонсо'],
#  '25022': ['name', '1293', '5', '182632', '1', '#', '182632', 'Хуану'],
#  '25023': ['name', '1299', '5', '182633', '1', '#', '182633', 'Пабло'],
#  '25024': ['surname', '1305', '7', '182634', '1', '#', '182634', 'Монтойе'],
#  '25025': ['org_descr', '1316', '7', '182636', '1', '#', '182636', 'команды'],
#  '25026': ['org_name',
#   '1324',
#   '17',
#   '182637',
#   '1',
#   '#',
#   '182637',
#   'МакЛарен-Мерседес'],
#  '25027': ['name', '1344', '5', '182639', '1', '#', '182639', 'Дэвид'],
#  '25028': ['surname', '1350', '8', '182640', '1', '#', '182640', 'Култхард'],
#  '25029': ['org_name',
#   '1403',
#   '8',
#   '182648',
#   '2',
#   '#',
#   '182648',
#   '182649',
#   'Red',
#   'Bull'],
#  '25030': ['org_descr', '1395', '7', '182647', '1', '#', '182647', 'команды'],
#  '25031': ['name', '1524', '6', '182668', '1', '#', '182668', 'Эдуард'],
#  '25032': ['surname', '1531', '6', '182669', '1', '#', '182669', 'Мишлен'],
#  '25033': ['org_descr',
#   '1561',
#   '15',
#   '182674',
#   '2',
#   '#',
#   '182674',
#   '182675',
#   'группы',
#   'компаний'],
#  '25034': ['org_name', '1577', '8', '182676', '1', '#', '182676', 'Michelin'],
#  '25035': ['job', '1549', '11', '182673', '1', '#', '182673', 'президентов'],
#  '25688': ['loc_descr', '498', '4', '182767', '1', '#', '182767', 'реку'],
#  '25689': ['loc_name', '503', '5', '182768', '1', '#', '182768', 'Нарву'],
#  '25690': ['loc_name', '756', '7', '182811', '1', '#', '182811', 'Таллине'],
#  '25691': ['loc_name', '772', '5', '182815', '1', '#', '182815', 'Тарту'],
#  '25699': ['loc_name', '10', '6', '182841', '1', '#', '182841', 'Москве'],
#  '25700': ['name', '43', '5', '182847', '1', '#', '182847', 'Егора'],
#  '25701': ['surname', '49', '9', '182848', '1', '#', '182848', 'Свиридова'],
#  '25702': ['loc_descr', '113', '8', '182857', '1', '#', '182857', 'бульвару'],
#  '25703': ['loc_name',
#   '98',
#   '23',
#   '182856',
#   '2',
#   '#',
#   '182856',
#   '182857',
#   'Кронштадтскому',
#   'бульвару'],
#  '25704': ['org_name', '139', '8', '182862', '1', '#', '182862', 'Спартака'],
#  '25705': ['name', '149', '5', '182864', '1', '#', '182864', 'Егора'],
#  '25706': ['surname', '155', '9', '182865', '1', '#', '182865', 'Свиридова'],
#  '25707': ['job', '127', '10', '182860', '1', '#', '182860', 'болельщика'],
#  '25711': ['loc_descr', '534', '7', '182933', '1', '#', '182933', 'площади'],
#  '25712': ['loc_name',
#   '525',
#   '16',
#   '182932',
#   '2',
#   '#',
#   '182932',
#   '182933',
#   'Манежной',
#   'площади'],
#  '25713': ['loc_descr', '726', '8', '182963', '1', '#', '182963', 'бульваре'],
#  '25714': ['loc_name',
#   '712',
#   '13',
#   '182962',
#   '1',
#   '#',
#   '182962',
#   'Кронштадтском'],
#  '25715': ['surname', '844', '9', '182981', '1', '#', '182981', 'Свиридова'],
#  '25716': ['name', '885', '5', '182991', '1', '#', '182991', 'Егора'],
#  '25720': ['name', '902', '5', '182996', '1', '#', '182996', 'Егора'],
#  '25721': ['loc_name', '1078', '7', '183032', '1', '#', '183032', 'Америки'],
#  '25722': ['org_name',
#   '1071',
#   '14',
#   '183031',
#   '2',
#   '#',
#   '183031',
#   '183032',
#   'Голоса',
#   'Америки'],
#  '25723': ['org_name',
#   '1093',
#   '38',
#   '183035',
#   '4',
#   '#',
#   '183035',
#   '183036',
#   '183037',
#   '183038',
#   'Движения',
#   'против',
#   'нелегальной',
#   'иммиграции'],
#  '25724': ['org_descr', '1093', '8', '183035', '1', '#', '183035', 'Движения'],
#  '25725': ['name', '1132', '9', '183039', '1', '#', '183039', 'Александр'],
#  '25726': ['surname', '1142', '5', '183040', '1', '#', '183040', 'Белов'],
#  '25727': ['job', '1087', '5', '183034', '1', '#', '183034', 'лидер'],
#  '25730': ['org_name', '1185', '4', '183050', '1', '#', '183050', 'ДПНИ'],
#  '25731': ['loc_descr', '1208', '8', '183054', '1', '#', '183054', 'бульвару'],
#  '25732': ['loc_name',
#   '1193',
#   '14',
#   '183053',
#   '1',
#   '#',
#   '183053',
#   'Кронштадтскому'],
#  '25733': ['org_name', '1253', '6', '183060', '1', '#', '183060', 'Яблоко'],
#  '25734': ['org_descr', '1245', '6', '183058', '1', '#', '183058', 'партии'],
#  '25735': ['name', '1298', '5', '183068', '1', '#', '183068', 'Егора'],
#  '25736': ['surname', '1304', '9', '183069', '1', '#', '183069', 'Свиридова'],
#  '25737': ['name', '1388', '6', '183083', '1', '#', '183083', 'Сергея'],
#  '25738': ['surname', '1395', '9', '183084', '1', '#', '183084', 'Митрохина'],
#  '25739': ['name', '1492', '5', '183099', '1', '#', '183099', 'Егора'],
#  '25740': ['surname', '1498', '9', '183100', '1', '#', '183100', 'Свиридова'],
#  '25741': ['org_descr', '1381', '6', '183082', '1', '#', '183082', 'партии'],
#  '25742': ['job', '1375', '5', '183081', '1', '#', '183081', 'главу'],
#  '25745': ['name', '1514', '9', '183103', '1', '#', '183103', 'Александр'],
#  '25746': ['surname', '1524', '5', '183104', '1', '#', '183104', 'Белов'],
#  '25747': ['surname', '1652', '9', '183128', '1', '#', '183128', 'Свиридова'],
#  '25748': ['name', '1664', '1', '183130', '1', '#', '183130', 'В'],
#  '25749': ['surname', '1666', '1', '183132', '1', '#', '183132', 'Л'],
#  '25750': ['org_name', '1727', '6', '183143', '1', '#', '183143', 'Яблоко'],
#  '25751': ['org_descr', '1719', '6', '183141', '1', '#', '183141', 'партии'],
#  '25752': ['name', '1735', '5', '183145', '1', '#', '183145', 'Артур'],
#  '25753': ['surname',
#   '1741',
#   '11',
#   '183146',
#   '1',
#   '#',
#   '183146',
#   'Гороховский'],
#  '25754': ['surname', '1844', '5', '183167', '1', '#', '183167', 'Белов'],
#  '25755': ['org_name', '1873', '4', '183173', '1', '#', '183173', 'ГУВД'],
#  '25756': ['job',
#   '1697',
#   '21',
#   '183139',
#   '2',
#   '#',
#   '183139',
#   '183140',
#   'советник',
#   'руководителя'],
#  '25758': ['surname', '2157', '5', '183229', '1', '#', '183229', 'Белов'],
#  '25761': ['org_name', '2177', '6', '183233', '1', '#', '183233', 'Яблока'],
#  '25762': ['name', '2221', '10', '183240', '1', '#', '183240', 'Александра'],
#  '25763': ['surname', '2232', '6', '183241', '1', '#', '183241', 'Белова'],
#  '25764': ['name', '2272', '10', '183249', '1', '#', '183249', 'Александра'],
#  '25765': ['surname', '2283', '5', '183250', '1', '#', '183250', 'Брода'],
#  '25766': ['org_name',
#   '2328',
#   '19',
#   '183258',
#   '2',
#   '#',
#   '183258',
#   '183259',
#   'Общественной',
#   'палаты'],
#  '25767': ['org_descr', '2341', '6', '183259', '1', '#', '183259', 'палаты'],
#  '25768': ['org_name',
#   '2350',
#   '62',
#   '183261',
#   '6',
#   '#',
#   '183261',
#   '183262',
#   '183263',
#   '183264',
#   '183265',
#   '183266',
#   'российско-американской',
#   'рабочей',
#   'группы',
#   'по',
#   'гражданскому',
#   'обществу'],
#  '25769': ['org_descr',
#   '2373',
#   '14',
#   '183262',
#   '2',
#   '#',
#   '183262',
#   '183263',
#   'рабочей',
#   'группы'],
#  '25770': ['job', '2322', '5', '183257', '1', '#', '183257', 'члена'],
#  '25772': ['surname', '2459', '9', '183276', '1', '#', '183276', 'Свиридова'],
#  '25773': ['name', '2565', '9', '183290', '1', '#', '183290', 'Александр'],
#  '25774': ['surname', '2575', '4', '183291', '1', '#', '183291', 'Брод'],
#  '25775': ['org_descr', '2629', '6', '183301', '1', '#', '183301', 'партии'],
#  '25776': ['org_name', '2637', '6', '183303', '1', '#', '183303', 'Яблоко'],
#  '25777': ['surname', '2675', '9', '183310', '1', '#', '183310', 'Свиридова'],
#  '25778': ['org_name', '2807', '4', '183328', '1', '#', '183328', 'ДПНИ'],
#  '25781': ['loc_name', '2855', '7', '183339', '1', '#', '183339', 'Америки'],
#  '25782': ['org_name',
#   '2848',
#   '14',
#   '183338',
#   '2',
#   '#',
#   '183338',
#   '183339',
#   'Голосу',
#   'Америки'],
#  '25783': ['name', '2864', '9', '183341', '1', '#', '183341', 'Александр'],
#  '25784': ['surname', '2874', '5', '183342', '1', '#', '183342', 'Белов'],
#  '25787': ['surname', '2978', '4', '183363', '1', '#', '183363', 'Брод'],
#  '25788': ['surname', '3010', '9', '183371', '1', '#', '183371', 'Свиридове'],
#  '25793': ['name', '3294', '5', '183419', '1', '#', '183419', 'Егору'],
#  '25794': ['surname', '3300', '9', '183420', '1', '#', '183420', 'Свиридову'],
#  '25795': ['name', '3330', '8', '183423', '1', '#', '183423', 'Всеволод'],
#  '25796': ['surname', '3339', '6', '183424', '1', '#', '183424', 'Чаплин'],
#  '25797': ['org_name',
#   '3353',
#   '57',
#   '183427',
#   '7',
#   '#',
#   '183427',
#   '183428',
#   '183429',
#   '183430',
#   '183431',
#   '183432',
#   '183433',
#   'синодального',
#   'Отдела',
#   'по',
#   'взаимоотношениям',
#   'Церкви',
#   'и',
#   'общества'],
#  '25798': ['org_descr', '3366', '6', '183428', '1', '#', '183428', 'Отдела'],
#  '25799': ['org_descr',
#   '3353',
#   '19',
#   '183427',
#   '2',
#   '#',
#   '183427',
#   '183428',
#   'синодального',
#   'Отдела'],
#  '25800': ['loc_name', '3450', '6', '183444', '1', '#', '183444', 'Россия'],
#  '25801': ['job', '3320', '9', '183422', '1', '#', '183422', 'протоирей'],
#  '25802': ['job', '3347', '5', '183426', '1', '#', '183426', 'глава'],
#  '69844': ['org_descr', '3393', '6', '183431', '1', '#', '183431', 'Церкви'],
#  '25805': ['loc_name', '3616', '6', '183476', '1', '#', '183476', 'Россию'],
#  '25806': ['name', '3959', '6', '183538', '1', '#', '183538', 'Виктор'],
#  '25807': ['surname',
#   '3966',
#   '10',
#   '183539',
#   '1',
#   '#',
#   '183539',
#   'Шендерович'],
#  '25808': ['loc_name', '4051', '8', '183553', '1', '#', '183553', 'Манежную'],
#  '25809': ['loc_descr', '4060', '7', '183554', '1', '#', '183554', 'площадь'],
#  '25810': ['org_name',
#   '4083',
#   '28',
#   '183560',
#   '3',
#   '#',
#   '183560',
#   '183561',
#   '183562',
#   'Русская',
#   'Православная',
#   'Церковь'],
#  '25811': ['org_descr', '4104', '7', '183562', '1', '#', '183562', 'Церковь'],
#  '25812': ['org_name', '4238', '4', '183591', '1', '#', '183591', 'ДПНИ'],
#  '25813': ['job', '3938', '8', '183535', '1', '#', '183535', 'писатель'],
#  '25814': ['job', '3949', '9', '183537', '1', '#', '183537', 'журналист'],
#  '25819': ['name', '4402', '5', '183622', '1', '#', '183622', 'Егору'],
#  '25820': ['surname', '4408', '9', '183623', '1', '#', '183623', 'Свиридову'],
#  '25821': ['name', '4432', '6', '183627', '1', '#', '183627', 'Виктор'],
#  '25822': ['surname',
#   '4439',
#   '10',
#   '183628',
#   '1',
#   '#',
#   '183628',
#   'Шендерович'],
#  '25823': ['org_name',
#   '4696',
#   '28',
#   '183676',
#   '3',
#   '#',
#   '183676',
#   '183677',
#   '183678',
#   'Русская',
#   'Православная',
#   'Церковь'],
#  '25824': ['org_descr', '4717', '7', '183678', '1', '#', '183678', 'Церковь'],
#  '25825': ['surname',
#   '4805',
#   '10',
#   '183694',
#   '1',
#   '#',
#   '183694',
#   'Шендерович'],
#  '25826': ['name', '4818', '9', '183696', '1', '#', '183696', 'Александр'],
#  '25827': ['surname', '4828', '4', '183697', '1', '#', '183697', 'Брод'],
#  '25828': ['org_name', '4879', '3', '183708', '1', '#', '183708', 'РПЦ'],
#  '25829': ['surname', '4984', '4', '183726', '1', '#', '183726', 'Брод'],
#  '25834': ['surname', '5122', '4', '183750', '1', '#', '183750', 'Брод'],
#  '25835': ['org_name',
#   '5292',
#   '14',
#   '183777',
#   '2',
#   '#',
#   '183777',
#   '183778',
#   'Русская',
#   'правда'],
#  '25836': ['org_descr', '5284', '6', '183775', '1', '#', '183775', 'газеты'],
#  '25837': ['surname', '5324', '5', '183785', '1', '#', '183785', 'Брода'],
#  '25838': ['name', '5496', '6', '183814', '1', '#', '183814', 'Виктор'],
#  '25839': ['surname',
#   '5503',
#   '10',
#   '183815',
#   '1',
#   '#',
#   '183815',
#   'Шендерович'],
#  '25842': ['name', '5757', '5', '183855', '1', '#', '183855', 'Егора'],
#  '25843': ['surname', '5763', '9', '183856', '1', '#', '183856', 'Свиридова'],
#  '25844': ['loc_name', '5807', '6', '183863', '1', '#', '183863', 'России'],
#  '25856': ['org_name',
#   '160',
#   '26',
#   '186414',
#   '3',
#   '#',
#   '186414',
#   '186415',
#   '186416',
#   'Комитет',
#   'защиты',
#   'журналистов'],
#  '25857': ['org_descr', '160', '7', '186414', '1', '#', '186414', 'Комитет'],
#  '25858': ['org_name', '188', '3', '186418', '1', '#', '186418', 'КЗЖ'],
#  '25859': ['org_name',
#   '194',
#   '32',
#   '186421',
#   '4',
#   '#',
#   '186421',
#   '186422',
#   '186423',
#   '186424',
#   'Committee',
#   'to',
#   'Protect',
#   'Journalists'],
#  '82650': ['org_name', '132', '9', '186409', '1', '#', '186409', 'Интернете'],
#  '25861': ['loc_name', '425', '5', '186463', '1', '#', '186463', 'Китае'],
#  '25862': ['loc_name', '432', '4', '186465', '1', '#', '186465', 'Кубе'],
#  '25863': ['loc_name', '438', '7', '186467', '1', '#', '186467', 'Эритрее'],
#  '25864': ['loc_name', '450', '7', '186470', '1', '#', '186470', 'Эфиопии'],
#  '82651': ['org_name', '652', '9', '186502', '1', '#', '186502', 'Интернете'],
#  '82652': ['job',
#   '722',
#   '21',
#   '186519',
#   '3',
#   '#',
#   '186519',
#   '186520',
#   '186521',
#   'журналист',
#   '-',
#   'интернетчик'],
#  '25865': ['loc_name', '851', '5', '186535', '1', '#', '186535', 'Китая'],
#  '25866': ['loc_name', '881', '4', '186540', '1', '#', '186540', 'Кубы'],
#  '25867': ['name', '964', '6', '186551', '1', '#', '186551', 'Джошуа'],
#  '25868': ['surname', '971', '6', '186552', '1', '#', '186552', 'Вольфа'],
#  '25869': ['name', '979', '6', '186554', '1', '#', '186554', 'Joshua'],
#  '25870': ['surname', '986', '4', '186555', '1', '#', '186555', 'Wolf'],
# ...
#  '34685': ['loc_name',
#   '1215',
#   '14',
#   '201430',
#   '1',
#   '#',
#   '201430',
#   'Великобритании'],
#  '34686': ['loc_name', '1358', '8', '201445', '1', '#', '201445', 'Британии'],
#  '34687': ['name', '1369', '4', '201447', '1', '#', '201447', 'Марк'],
#  '34688': ['org_name',
#   '1384',
#   '12',
#   '201449',
#   '1',
#   '#',
#   '201449',
#   'Викиновостям'],
#  '34689': ['org_name', '1412', '6', '201454', '1', '#', '201454', 'Vestas'],
#  '34690': ['loc_name', '1480', '8', '201462', '1', '#', '201462', 'Британии'],
#  '34691': ['org_descr', '1473', '6', '201461', '1', '#', '201461', 'партии'],
#  '34692': ['org_name',
#   '1448',
#   '31',
#   '201459',
#   '3',
#   '#',
#   '201459',
#   '201460',
#   '201461',
#   'Социалистической',
#   'рабочей',
#   'партии'],
#  '34693': ['org_name',
#   '1490',
#   '20',
#   '201464',
#   '2',
#   '#',
#   '201464',
#   '201465',
#   'Конгресса',
#   'профсоюзов'],
#  '34694': ['org_descr',
#   '1490',
#   '9',
#   '201464',
#   '1',
#   '#',
#   '201464',
#   'Конгресса'],
#  '34695': ['org_descr',
#   '1513',
#   '9',
#   '201467',
#   '1',
#   '#',
#   '201467',
#   'профсоюза'],
#  '34696': ['org_name', '1523', '5', '201468', '1', '#', '201468', 'Юнайт'],
#  '34697': ['name', '1539', '5', '201471', '1', '#', '201471', 'Марку'],
#  '34698': ['org_name', '1566', '6', '201477', '1', '#', '201477', 'Vistas'],
#  '34699': ['org_name', '1630', '7', '201485', '1', '#', '201485', 'Visteon'],
#  '34700': ['org_descr', '1623', '6', '201484', '1', '#', '201484', 'завода'],
#  '34701': ['loc_name', '1640', '8', '201487', '1', '#', '201487', 'Белфасте'],
#  '34702': ['name', '1735', '4', '201503', '1', '#', '201503', 'Марк'],
#  '34703': ['org_name', '1761', '7', '201508', '1', '#', '201508', 'Visteon'],
#  '34704': ['org_name', '1788', '6', '201511', '1', '#', '201511', 'Vestas'],
#  '34705': ['name', '1877', '4', '201531', '1', '#', '201531', 'Марк'],
#  '34706': ['loc_name', '12', '8', '201560', '1', '#', '201560', 'Германии'],
#  '34707': ['org_name', '718', '3', '201656', '1', '#', '201656', 'ХДС'],
#  '34708': ['loc_name', '1240', '8', '201743', '1', '#', '201743', 'Германии'],
#  '26143': ['name', '54', '3', '202985', '1', '#', '202985', 'Исы'],
#  '26144': ['surname', '58', '8', '202986', '1', '#', '202986', 'Ямадаева'],
#  '26145': ['surname', '89', '7', '202991', '1', '#', '202991', 'Ямадаев'],
#  '26146': ['name', '296', '3', '203021', '1', '#', '203021', 'Исе'],
#  '26147': ['surname', '300', '8', '203022', '1', '#', '203022', 'Ямадаеву'],
#  '26148': ['org_descr',
#   '380',
#   '12',
#   '203036',
#   '1',
#   '#',
#   '203036',
#   'радиостанция'],
#  '26149': ['org_name', '394', '4', '203038', '1', '#', '203038', 'Маяк'],
#  '26150': ['name', '423', '3', '203045', '1', '#', '203045', 'Ису'],
#  '26151': ['surname', '427', '8', '203046', '1', '#', '203046', 'Ямадаева'],
#  '26152': ['org_name',
#   '505',
#   '38',
#   '203056',
#   '4',
#   '#',
#   '203056',
#   '203057',
#   '203058',
#   '203059',
#   'Следственного',
#   'комитета',
#   'при',
#   'прокуратуре'],
#  '26153': ['org_descr', '519', '8', '203057', '1', '#', '203057', 'комитета'],
#  '26154': ['name', '544', '8', '203060', '1', '#', '203060', 'Владимир'],
#  '26155': ['surname', '553', '6', '203061', '1', '#', '203061', 'Маркин'],
#  '26156': ['job', '491', '13', '203055', '1', '#', '203055', 'представитель'],
#  '26157': ['job',
#   '479',
#   '25',
#   '203054',
#   '2',
#   '#',
#   '203054',
#   '203055',
#   'официальный',
#   'представитель'],
#  '26158': ['org_name',
#   '575',
#   '19',
#   '203064',
#   '2',
#   '#',
#   '203064',
#   '203065',
#   'Исламского',
#   'комитета'],
#  '26159': ['org_descr', '586', '8', '203065', '1', '#', '203065', 'комитета'],
#  '26160': ['loc_name', '595', '6', '203066', '1', '#', '203066', 'России'],
#  '26161': ['name', '602', '6', '203067', '1', '#', '203067', 'Гейдар'],
#  '26162': ['surname', '609', '7', '203068', '1', '#', '203068', 'Джемаль'],
#  '26163': ['org_name',
#   '629',
#   '16',
#   '203072',
#   '2',
#   '#',
#   '203072',
#   '203073',
#   'Свободной',
#   'прессе'],
#  '26164': ['name', '696', '3', '203084', '1', '#', '203084', 'Ису'],
#  '26165': ['name', '849', '6', '203118', '1', '#', '203118', 'Сулима'],
#  '26166': ['loc_name', '858', '8', '203120', '1', '#', '203120', 'Эмиратах'],
#  '26167': ['name', '911', '7', '203130', '1', '#', '203130', 'Рамзану'],
#  '26168': ['surname', '919', '8', '203131', '1', '#', '203131', 'Кадырову'],
#  '26169': ['job', '562', '12', '203063', '1', '#', '203063', 'Председатель'],
#  '26170': ['name', '945', '3', '203137', '1', '#', '203137', 'Иса'],
#  '26171': ['surname', '949', '7', '203138', '1', '#', '203138', 'Ямадаев'],
#  '26172': ['name', '973', '6', '203141', '1', '#', '203141', 'Сулимы'],
#  '26173': ['surname', '980', '8', '203142', '1', '#', '203142', 'Ямадаева'],
#  '26174': ['loc_name',
#   '996',
#   '20',
#   '203145',
#   '2',
#   '#',
#   '203145',
#   '203146',
#   'Российской',
#   'Федерации'],
#  '26175': ['loc_descr',
#   '1007',
#   '9',
#   '203146',
#   '1',
#   '#',
#   '203146',
#   'Федерации'],
#  '26176': ['loc_name', '1032', '3', '203151', '1', '#', '203151', 'ОАЭ'],
#  '26177': ['name', '1136', '6', '203166', '1', '#', '203166', 'Сулима'],
#  '26178': ['surname', '1143', '8', '203167', '1', '#', '203167', 'Ямадаева'],
#  '26179': ['org_name',
#   '1156',
#   '23',
#   '203170',
#   '2',
#   '#',
#   '203170',
#   '203171',
#   'Генеральная',
#   'прокуратура'],
#  '26180': ['org_descr',
#   '1168',
#   '11',
#   '203171',
#   '1',
#   '#',
#   '203171',
#   'прокуратура'],
#  '26181': ['loc_name', '1180', '3', '203172', '1', '#', '203172', 'ОАЭ'],
#  '26182': ['org_name', '1196', '6', '203177', '1', '#', '203177', 'Gzt.Ru'],
#  '26183': ['name', '1227', '6', '203184', '1', '#', '203184', 'Сулима'],
#  '26184': ['surname', '1234', '8', '203185', '1', '#', '203185', 'Ямадаева'],
#  '26185': ['name', '1320', '3', '203202', '1', '#', '203202', 'Иса'],
#  '26186': ['surname', '1324', '7', '203203', '1', '#', '203203', 'Ямадаев'],
#  '26187': ['surname', '1360', '9', '203208', '1', '#', '203208', 'Ямадаевых'],
#  '26188': ['loc_name', '10', '6', '209069', '1', '#', '209069', 'Москве'],
#  '26189': ['loc_name', '411', '6', '209123', '1', '#', '209123', 'России'],
#  '26190': ['loc_name', '437', '2', '209127', '1', '#', '209127', 'РФ'],
#  '26191': ['name', '440', '7', '209128', '1', '#', '209128', 'Алексей'],
#  '26192': ['surname', '448', '6', '209129', '1', '#', '209129', 'Кудрин'],
#  '26193': ['job',
#   '420',
#   '16',
#   '209125',
#   '2',
#   '#',
#   '209125',
#   '209126',
#   'Министр',
#   'финансов'],
#  '26194': ['job', '420', '7', '209125', '1', '#', '209125', 'Министр'],
#  '26195': ['loc_name', '715', '2', '209158', '1', '#', '209158', 'РФ'],
#  '26196': ['name', '718', '8', '209159', '1', '#', '209159', 'Владимир'],
#  '26197': ['surname', '727', '5', '209160', '1', '#', '209160', 'Путин'],
#  '26198': ['loc_name',
#   '967',
#   '20',
#   '209200',
#   '2',
#   '#',
#   '209200',
#   '209201',
#   'Российской',
#   'федерации'],
#  '26199': ['loc_descr', '978', '9', '209201', '1', '#', '209201', 'федерации'],
#  '26200': ['loc_name', '1137', '6', '209229', '1', '#', '209229', 'России'],
#  '26201': ['job',
#   '699',
#   '15',
#   '209157',
#   '1',
#   '#',
#   '209157',
#   'премьер-министр'],
#  '26202': ['name', '1348', '1', '209258', '1', '#', '209258', 'А'],
#  '26203': ['surname', '1351', '6', '209260', '1', '#', '209260', 'Кудрин'],
#  '26204': ['loc_name', '31', '6', '209293', '1', '#', '209293', 'Африки'],
#  '26205': ['loc_name', '91', '5', '209303', '1', '#', '209303', 'Ливии'],
#  '26206': ['loc_name', '99', '6', '209305', '1', '#', '209305', 'Италию'],
#  '26207': ['loc_name', '336', '7', '209348', '1', '#', '209348', 'Эритреи'],
#  '26208': ['loc_name', '750', '6', '209416', '1', '#', '209416', 'Мальты'],
#  '26209': ['loc_name', '759', '6', '209418', '1', '#', '209418', 'Италии'],
#  '26210': ['loc_name', '0', '6', '209755', '1', '#', '209755', 'Россия'],
#  '26211': ['loc_name', '9', '6', '209757', '1', '#', '209757', 'Турция'],
#  '26212': ['loc_name', '256', '6', '209793', '1', '#', '209793', 'Турцию'],
#  '34246': ['loc_name', '32', '4', '209980', '1', '#', '209980', 'Неву'],
#  '34247': ['loc_name', '270', '8', '210020', '1', '#', '210020', 'Славянка'],
#  '34248': ['loc_descr', '265', '4', '210019', '1', '#', '210019', 'реке'],
#  '34249': ['loc_descr', '357', '4', '210033', '1', '#', '210033', 'реки'],
#  '34250': ['loc_name', '362', '8', '210034', '1', '#', '210034', 'Славянки'],
#  '34251': ['org_descr', '400', '2', '210040', '1', '#', '210040', 'ГУ'],
#  '34252': ['org_name',
#   '400',
#   '33',
#   '210040',
#   '5',
#   '#',
#   '210040',
#   '210041',
#   '210042',
#   '210043',
#   '210044',
#   'ГУ',
#   'МЧС',
#   'России',
#   'по',
#   'Санкт-Петербургу'],
#  '34253': ['org_name', '403', '3', '210041', '1', '#', '210041', 'МЧС'],
#  '34254': ['loc_name', '407', '6', '210042', '1', '#', '210042', 'России'],
#  '34255': ['loc_name',
#   '417',
#   '16',
#   '210044',
#   '1',
#   '#',
#   '210044',
#   'Санкт-Петербургу'],
#  '34256': ['org_descr',
#   '373',
#   '14',
#   '210036',
#   '2',
#   '#',
#   '210036',
#   '210037',
#   'Рабочая',
#   'группа'],
#  '34257': ['loc_name', '510', '8', '210059', '1', '#', '210059', 'Славянку'],
#  '34258': ['org_name',
#   '556',
#   '26',
#   '210068',
#   '3',
#   '#',
#   '210068',
#   '210069',
#   '210070',
#   'Южная',
#   'водозаборная',
#   'станция'],
#  '34259': ['org_descr',
#   '562',
#   '20',
#   '210069',
#   '2',
#   '#',
#   '210069',
#   '210070',
#   'водозаборная',
#   'станция'],
#  '34260': ['org_descr', '583', '3', '210071', '1', '#', '210071', 'ГУП'],
#  '34261': ['org_name', '588', '9', '210073', '1', '#', '210073', 'Водоканал'],
#  '34262': ['loc_name', '668', '4', '210089', '1', '#', '210089', 'Невы'],
#  '34263': ['loc_name', '745', '8', '210109', '1', '#', '210109', 'Славянки'],
#  '34264': ['loc_descr', '740', '4', '210108', '1', '#', '210108', 'реки'],
#  '34265': ['loc_name', '899', '8', '210136', '1', '#', '210136', 'Славянки'],
#  '34266': ['loc_descr', '894', '4', '210135', '1', '#', '210135', 'реки'],
#  '34267': ['org_name',
#   '918',
#   '26',
#   '210138',
#   '3',
#   '#',
#   '210138',
#   '210139',
#   '210140',
#   'южная',
#   'водозаборная',
#   'станция'],
#  '34268': ['org_descr',
#   '924',
#   '20',
#   '210139',
#   '2',
#   '#',
#   '210139',
#   '210140',
#   'водозаборная',
#   'станция'],
#  '34269': ['org_name',
#   '946',
#   '10',
#   '210142',
#   '1',
#   '#',
#   '210142',
#   'Водоканала'],
#  '34270': ['name', '1076', '7', '210169', '1', '#', '210169', 'Татьяна'],
#  '34271': ['surname', '1084', '9', '210170', '1', '#', '210170', 'Скригонюк'],
#  '34272': ['org_name', '1131', '3', '210175', '1', '#', '210175', 'МЧС'],
#  '34273': ['loc_name',
#   '1138',
#   '16',
#   '210177',
#   '1',
#   '#',
#   '210177',
#   'Санкт-Петербургу'],
#  '34274': ['loc_name',
#   '1157',
#   '10',
#   '210179',
#   '1',
#   '#',
#   '210179',
#   'Ленобласти'],
#  '34275': ['org_descr',
#   '1118',
#   '12',
#   '210174',
#   '1',
#   '#',
#   '210174',
#   'пресс-службы'],
#  '34276': ['org_name',
#   '1131',
#   '36',
#   '210175',
#   '5',
#   '#',
#   '210175',
#   '210176',
#   '210177',
#   '210178',
#   '210179',
#   'МЧС',
#   'по',
#   'Санкт-Петербургу',
#   'и',
#   'Ленобласти'],
#  '34277': ['job',
#   '1095',
#   '22',
#   '210172',
#   '2',
#   '#',
#   '210172',
#   '210173',
#   'заместитель',
#   'начальника'],
#  '34278': ['org_name',
#   '1203',
#   '16',
#   '210184',
#   '1',
#   '#',
#   '210184',
#   'Росприроднадзора'],
#  '34279': ['org_name', '1222', '9', '210186', '1', '#', '210186', 'Рыбохраны'],
#  '34280': ['loc_name', '1279', '8', '210197', '1', '#', '210197', 'Славянке'],
#  '34281': ['loc_name', '1400', '4', '210216', '1', '#', '210216', 'Невы'],
#  '34282': ['org_name', '1183', '7', '210181', '1', '#', '210181', 'Гринпис'],
#  '34283': ['loc_name', '1707', '4', '210273', '1', '#', '210273', 'Невы'],
#  '34284': ['loc_name', '1717', '8', '210275', '1', '#', '210275', 'Славянку'],
#  '34285': ['loc_descr', '1712', '4', '210274', '1', '#', '210274', 'реку'],
#  '34286': ['org_name', '1798', '7', '210286', '1', '#', '210286', 'Гринпис'],
#  '34287': ['loc_name',
#   '1830',
#   '14',
#   '210290',
#   '1',
#   '#',
#   '210290',
#   'Петро-Славянка'],
#  '34288': ['loc_descr', '1822', '7', '210289', '1', '#', '210289', 'поселка'],
#  '34289': ['org_name',
#   '1941',
#   '16',
#   '210308',
#   '1',
#   '#',
#   '210308',
#   'Росприроднадзору'],
#  '34290': ['loc_name', '2064', '8', '210324', '1', '#', '210324', 'Славянку'],
#  '34291': ['loc_descr', '2059', '4', '210323', '1', '#', '210323', 'реку'],
#  '34292': ['loc_name', '2168', '8', '210341', '1', '#', '210341', 'Рыбацкое'],
#  '34293': ['loc_descr', '2158', '8', '210339', '1', '#', '210339', 'промзоны'],
#  '26213': ['loc_name', '0', '6', '210354', '1', '#', '210354', 'Россия'],
#  '26214': ['loc_name', '12', '7', '210356', '1', '#', '210356', 'Украине'],
#  '26215': ['org_name', '67', '8', '210365', '1', '#', '210365', 'Лента.ру'],
#  '26216': ['org_descr',
#   '124',
#   '17',
#   '210372',
#   '2',
#   '#',
#   '210372',
#   '210373',
#   'Национальный',
#   'банк'],
#  '26217': ['loc_name', '142', '7', '210374', '1', '#', '210374', 'Украины'],
#  '26218': ['org_descr', '137', '4', '210373', '1', '#', '210373', 'банк'],
#  '38269': ['org_descr',
#   '104',
#   '13',
#   '210370',
#   '1',
#   '#',
#   '210370',
#   'правительство'],
#  '38270': ['org_descr',
#   '93',
#   '24',
#   '210369',
#   '2',
#   '#',
#   '210369',
#   '210370',
#   'украинское',
#   'правительство'],
#  '77695': ['geo_adj', '93', '10', '210369', '1', '#', '210369', 'украинское'],
#  '26219': ['org_name',
#   '226',
#   '32',
#   '210388',
#   '3',
#   '#',
#   '210388',
#   '210389',
#   '210390',
#   'российском',
#   'министерстве',
#   'финансов'],
#  '26220': ['org_descr',
#   '237',
#   '12',
#   '210389',
#   '1',
#   '#',
#   '210389',
#   'министерстве'],
#  '26221': ['org_name',
#   '237',
#   '21',
#   '210389',
#   '2',
#   '#',
#   '210389',
#   '210390',
#   'министерстве',
#   'финансов'],
#  '26222': ['org_name', '431', '9', '210416', '1', '#', '210416', 'Интерфакс'],
#  '77696': ['geo_adj', '226', '10', '210388', '1', '#', '210388', 'российском'],
#  '26223': ['org_name',
#   '609',
#   '34',
#   '210447',
#   '3',
#   '#',
#   '210447',
#   '210448',
#   '210449',
#   'Хмельницкой',
#   'атомной',
#   'электростанции'],
#  '26224': ['org_descr',
#   '629',
#   '14',
#   '210449',
#   '1',
#   '#',
#   '210449',
#   'электростанции'],
#  '26225': ['org_descr',
#   '621',
#   '22',
#   '210448',
#   '2',
#   '#',
#   '210448',
#   '210449',
#   'атомной',
#   'электростанции'],
#  '26226': ['org_name', '645', '4', '210451', '1', '#', '210451', 'ХАЭС'],
#  '77697': ['geo_adj',
#   '609',
#   '11',
#   '210447',
#   '1',
#   '#',
#   '210447',
#   'Хмельницкой'],
#  '26227': ['org_name', '9', '10', '243070', '1', '#', '243070', 'Майкрософт'],
#  '26228': ['org_descr', '0', '7', '243068', '1', '#', '243068', 'Концерн'],
#  '26229': ['org_descr',
#   '32',
#   '24',
#   '243073',
#   '2',
#   '#',
#   '243073',
#   '243074',
#   'антимонопольной',
#   'комиссии'],
#  '26230': ['org_descr', '48', '8', '243074', '1', '#', '243074', 'комиссии'],
#  '26231': ['org_descr', '70', '5', '243076', '1', '#', '243076', 'союза'],
#  '26232': ['org_name',
#   '57',
#   '18',
#   '243075',
#   '2',
#   '#',
#   '243075',
#   '243076',
#   'Европейского',
#   'союза'],
#  '26233': ['org_name', '187', '2', '243089', '1', '#', '243089', 'ЕС'],
#  '26234': ['org_name', '214', '2', '243094', '1', '#', '243094', 'ЕС'],
#  '26235': ['org_name',
#   '220',
#   '10',
#   '243097',
#   '1',
#   '#',
#   '243097',
#   'Майкрософт'],
#  '26236': ['org_name', '281', '2', '243107', '1', '#', '243107', 'ЕС'],
#  '26237': ['org_name',
#   '296',
#   '10',
#   '243111',
#   '1',
#   '#',
#   '243111',
#   'Майкрософт'],
#  '26238': ['org_name',
#   '355',
#   '10',
#   '243123',
#   '1',
#   '#',
#   '243123',
#   'Майкрософт'],
#  '26239': ['org_descr', '559', '8', '243155', '1', '#', '243155', 'Комиссия'],
#  '26240': ['org_name', '568', '2', '243156', '1', '#', '243156', 'ЕС'],
#  '26241': ['org_name',
#   '644',
#   '10',
#   '243171',
#   '1',
#   '#',
#   '243171',
#   'Майкрософт'],
#  '26242': ['org_name', '742', '2', '243182', '1', '#', '243182', 'ЕС'],
#  '26243': ['org_name',
#   '912',
#   '10',
#   '243209',
#   '1',
#   '#',
#   '243209',
#   'Майкрософт'],
#  '26244': ['org_name', '1037', '2', '243231', '1', '#', '243231', 'ЕС'],
#  '26245': ['org_name',
#   '1052',
#   '10',
#   '243235',
#   '1',
#   '#',
#   '243235',
#   'Майкрософт'],
#  '26246': ['loc_name', '8', '8', '256951', '1', '#', '256951', 'Ботсване'],
#  '26247': ['org_descr', '467', '9', '257020', '1', '#', '257020', 'Госпиталя'],
#  '26248': ['org_name',
#   '467',
#   '26',
#   '257020',
#   '3',
#   '#',
#   '257020',
#   '257021',
#   '257022',
#   'Госпиталя',
#   'принцессы',
#   'Марины'],
#  ...}

# %%
factrueval_dev_objects
# Out:
# {'10433': ['Org', '22763', '22764'],
#  '10547': ['LocOrg', '22763'],
#  '10434': ['Location', '22765', '22766'],
#  '10435': ['Person', '22767', '22768'],
#  '10436': ['LocOrg', '22769'],
#  '10437': ['Location', '22770'],
#  '10438': ['LocOrg', '22771'],
#  '10439': ['Org', '22772'],
#  '10440': ['Person', '22773', '22774'],
#  '10441': ['Person', '22775', '22776'],
#  '40649': ['LocOrg', '68733'],
#  '10443': ['Location', '22782', '22783', '22784'],
#  '10444': ['Person', '22782', '22783'],
#  '10445': ['Person', '22785'],
#  '10447': ['Org', '22788', '22789', '22790'],
#  '10454': ['LocOrg', '22788', '22789'],
#  '10455': ['Org', '22793', '22794'],
#  '10456': ['Org', '22793', '22794', '22795', '22808'],
#  '10450': ['Person', '22796', '22797'],
#  '10451': ['Person', '22798', '22799'],
#  '10452': ['Org', '22800', '22801'],
#  '10453': ['Person', '22802', '22803'],
#  '10457': ['Org', '22809', '22810'],
#  '10458': ['Org', '22811', '22812'],
#  '10459': ['Org', '22813'],
#  '10460': ['Org', '22814', '22815'],
#  '10461': ['Org', '22816'],
#  '10462': ['Org', '22817', '22818'],
#  '10463': ['Org', '22819', '22820'],
#  '10464': ['Org', '22821', '22822'],
#  '10465': ['Org', '22823', '22824', '22825'],
#  '20385': ['Location', '38271', '38272'],
#  '10466': ['Person', '22826', '22827'],
#  '10467': ['Person', '22829', '22830'],
#  '10468': ['Person', '22831', '22832'],
#  '10469': ['Location', '22833'],
#  '10470': ['Location', '22834'],
#  '10471': ['Person', '22835', '22836'],
#  '10472': ['Person', '22837'],
#  '10473': ['Location', '22838'],
#  '10474': ['Person', '22839'],
#  '10475': ['Person', '22840'],
#  '10476': ['Person', '22841'],
#  '10477': ['Person', '22842'],
#  '23280': ['Person', '43049'],
#  '23281': ['Person', '43050'],
#  '10481': ['Org', '22848', '22849', '22850'],
#  '10482': ['Org', '22851'],
#  '10495': ['Org', '22852', '22853', '22854'],
#  '10494': ['Org', '22853'],
#  '10485': ['Location', '22856'],
#  '10486': ['Location', '22857'],
#  '49009': ['Org', '81235', '81236'],
#  '49010': ['Org', '81237', '81238'],
#  '10487': ['Location', '22858'],
#  '10488': ['LocOrg', '22859'],
#  '10489': ['Person', '22860', '22861'],
#  '10490': ['Location', '22862'],
#  '10492': ['Org', '22865', '22866'],
#  '10496': ['LocOrg', '22865'],
#  '10493': ['Org', '22867'],
#  '49008': ['Org', '81231', '81232', '81233', '81234'],
#  '10497': ['LocOrg', '22868'],
#  '10498': ['LocOrg', '22869'],
#  '10499': ['Person', '22870', '22871'],
#  '10500': ['Person', '22874', '22875'],
#  '10534': ['Location', '22877', '22930'],
#  '10502': ['Person', '22878', '22879'],
#  '10503': ['LocOrg', '22880'],
#  '10504': ['Location', '22881'],
#  '10505': ['Org', '22882', '22883'],
#  '10518': ['LocOrg', '22883'],
#  '10507': ['Org', '22889'],
#  '10508': ['Location', '22890'],
#  '10509': ['Location', '22891'],
#  '10510': ['Location', '22892'],
#  '10511': ['Person', '22893', '22894'],
#  '10512': ['Location', '22895'],
#  '10513': ['Person', '22896'],
#  '10514': ['LocOrg', '22897'],
#  '10515': ['Org', '22898'],
#  '10516': ['Person', '22899'],
#  '10517': ['Org', '22900'],
#  '10519': ['Location', '22903'],
#  '10520': ['Org', '22904', '22905'],
#  '10522': ['LocOrg', '22905'],
#  '10523': ['Person', '22908', '22909'],
#  '10524': ['Location', '22910', '22911'],
#  '10525': ['Person', '22912'],
#  '10526': ['Location', '22913'],
#  '10527': ['Org', '22914', '22915', '22916', '22917'],
#  '10533': ['Org', '22916', '22917'],
#  '10532': ['LocOrg', '22917'],
#  '10530': ['LocOrg', '22921', '22922'],
#  '10531': ['Person', '22923', '22924'],
#  '10535': ['LocOrg', '22931'],
#  '10536': ['Person', '22932', '22933'],
#  '10537': ['Person', '22934'],
#  '10538': ['Location', '22935', '22936'],
#  '10539': ['Person', '22938', '22939'],
#  '10540': ['Location', '22940', '22941'],
#  '10541': ['Location', '22942'],
#  '10542': ['Org', '22943', '22944'],
#  '10543': ['Person', '22947'],
#  '10544': ['Person', '22948'],
#  '10545': ['Person', '22949'],
#  '10546': ['Org', '22950'],
#  '14300': ['Org', '28806'],
#  '14302': ['Org', '28807', '28808', '28809'],
#  '14301': ['LocOrg', '28809'],
#  '14303': ['LocOrg', '28810'],
#  '14304': ['LocOrg', '28811'],
#  '14305': ['LocOrg', '28812'],
#  '14306': ['LocOrg', '28813'],
#  '10604': ['Org', '23080', '23113'],
#  '10603': ['Org', '23081'],
#  '24407': ['Org', '44847'],
#  '10605': ['Org', '23114'],
#  '10606': ['Person', '23115', '23116'],
#  '10607': ['Location', '23118'],
#  '10608': ['Org', '23119'],
#  '10609': ['Org', '23120'],
#  '10610': ['LocOrg', '23121'],
#  '10611': ['Org', '23122'],
#  '18770': ['Location', '35692'],
#  '18771': ['Location', '35693'],
#  '18772': ['LocOrg', '35694'],
#  '18773': ['LocOrg', '35695'],
#  '18774': ['LocOrg', '35696'],
#  '18775': ['LocOrg', '35697'],
#  '18776': ['LocOrg', '35698'],
#  '18777': ['Org', '35699', '35700', '35701'],
#  '18778': ['Person', '35701'],
#  '11903': ['LocOrg', '24991'],
#  '11905': ['Org', '24991', '24992', '24993'],
#  '11906': ['LocOrg', '24995'],
#  '11907': ['Location', '24996'],
#  '11908': ['Location', '24997'],
#  '11909': ['Org', '24998', '24999'],
#  '11910': ['LocOrg', '25000'],
#  '17654': ['LocOrg', '34081'],
#  '17655': ['LocOrg', '34082'],
#  '17656': ['Org', '34083', '34084'],
#  '17657': ['LocOrg', '34085'],
#  '17658': ['LocOrg', '34086'],
#  '17659': ['Org', '34087'],
#  '17660': ['LocOrg', '34088'],
#  '17661': ['LocOrg', '34089'],
#  '17662': ['LocOrg', '34090'],
#  '17663': ['LocOrg', '34091'],
#  '17664': ['LocOrg', '34092'],
#  '17665': ['Person', '34093', '34094', '34095'],
#  '17666': ['LocOrg', '34096'],
#  '17667': ['Person', '34097', '34098'],
#  '17668': ['LocOrg', '34099'],
#  '17669': ['LocOrg', '34100'],
#  '17670': ['Person', '34103', '34104'],
#  '17671': ['Location', '34105'],
#  '17672': ['LocOrg', '34106'],
#  '17673': ['Person', '34109', '34110'],
#  '17674': ['Location', '34111'],
#  '17675': ['LocOrg', '34112'],
#  '17676': ['Person', '34113', '34114'],
#  '17677': ['LocOrg', '34115'],
#  '17678': ['Org', '34115', '34116', '34117'],
#  '17679': ['LocOrg', '34120'],
#  '17680': ['Location', '34121'],
#  '17681': ['LocOrg', '34122', '34123', '34124'],
#  '17682': ['LocOrg', '34125'],
#  '17683': ['Person', '34126', '34127'],
#  '17684': ['LocOrg', '34128'],
#  '17685': ['Person', '34129', '34130'],
#  '17686': ['Org', '34131', '34132'],
#  '17687': ['Org', '34132'],
#  '17688': ['Org', '34133', '34134'],
#  '17689': ['LocOrg', '34135'],
#  '17690': ['Person', '34136', '34137'],
#  '17691': ['LocOrg', '34143'],
#  '17692': ['Person', '34144', '34145'],
#  '17693': ['Person', '34146', '34147'],
#  '17694': ['Person', '34148', '34149'],
#  '17704': ['Org', '34152'],
#  '17702': ['LocOrg', '34153'],
#  '17703': ['LocOrg', '34154'],
#  '17699': ['LocOrg', '34157'],
#  '17705': ['Person', '34158', '34159'],
#  '17706': ['LocOrg', '34160'],
#  '17707': ['Location', '34161'],
#  '17708': ['LocOrg', '34163'],
#  '17709': ['Org', '34164'],
#  '17710': ['Person', '34165'],
#  '17712': ['Person', '34166', '34167'],
#  '17713': ['LocOrg', '34168'],
#  '17714': ['Org', '34169'],
#  '17715': ['LocOrg', '34170'],
#  '17716': ['Person', '34171', '34172'],
#  '17717': ['LocOrg', '34173', '34174'],
#  '17718': ['Location', '34175'],
#  '17719': ['LocOrg', '34176'],
#  '17720': ['LocOrg', '34177', '34178'],
#  '17721': ['Location', '34179'],
#  '17722': ['Location', '34180'],
#  '17723': ['LocOrg', '34181'],
#  '17724': ['LocOrg', '34182'],
#  '17725': ['Org', '34183'],
#  '17726': ['LocOrg', '34184'],
#  '17727': ['LocOrg', '34185'],
#  '17728': ['Org', '34186'],
#  '17729': ['Person', '34187', '34188'],
#  '17730': ['LocOrg', '34189'],
#  '17731': ['LocOrg', '34190'],
#  '17732': ['LocOrg', '34191'],
#  '17733': ['Person', '34192', '34193'],
#  '17734': ['LocOrg', '34194'],
#  '17735': ['Person', '34195', '34196'],
#  '17736': ['LocOrg', '34199'],
#  '17737': ['Org', '34200'],
#  '17738': ['LocOrg', '34201'],
#  '17739': ['Person', '34202', '34203'],
#  '17740': ['LocOrg', '34204', '34205'],
#  '17741': ['LocOrg', '34206'],
#  '17742': ['Org', '34206', '34207'],
#  '17743': ['Location', '34208'],
#  '17744': ['LocOrg', '34209'],
#  '17745': ['LocOrg', '34210'],
#  '17746': ['Org', '34211'],
#  '17747': ['Person', '34212', '34213'],
#  '17748': ['Location', '34214'],
#  '17749': ['Location', '34215'],
#  '17750': ['LocOrg', '34216'],
#  '17751': ['LocOrg', '34217'],
#  '17752': ['Org', '34218'],
#  '17753': ['LocOrg', '34219'],
#  '17754': ['Person', '34220', '34221'],
#  '17755': ['Location', '34222'],
#  '17756': ['LocOrg', '34223'],
#  '17757': ['LocOrg', '34224'],
#  '17758': ['LocOrg', '34225'],
#  '17759': ['LocOrg', '34226', '34227', '34228', '34229'],
#  '17760': ['LocOrg', '34228', '34229'],
#  '17761': ['Location', '34230'],
#  '17762': ['LocOrg', '34231', '34232'],
#  '17763': ['Person', '34233', '34234'],
#  '17764': ['Org', '34235', '34236'],
#  '17765': ['Org', '34236'],
#  '17766': ['LocOrg', '34237'],
#  '17767': ['Location', '34240'],
#  '17768': ['LocOrg', '34241'],
#  '17769': ['Location', '34242'],
#  '17770': ['Person', '34243', '34244'],
#  '17771': ['LocOrg', '34245'],
#  '11911': ['Person', '25001', '25002'],
#  '11912': ['Location', '25003'],
#  '11913': ['Person', '25004', '25005'],
#  '11914': ['Location', '25006'],
#  '11915': ['Location', '25007'],
#  '11916': ['Person', '25008', '25009'],
#  '11917': ['Org', '25010'],
#  '11918': ['Person', '25011'],
#  '11919': ['Org', '25012', '25013'],
#  '11920': ['Person', '25014', '25015'],
#  '11921': ['Org', '25016'],
#  '11922': ['Person', '25017', '25018'],
#  '11923': ['Person', '25019', '25020'],
#  '11924': ['Person', '25021'],
#  '11925': ['Person', '25022', '25023', '25024'],
#  '11926': ['Org', '25025', '25026'],
#  '11927': ['Person', '25027', '25028'],
#  '11928': ['Org', '25029', '25030'],
#  '11929': ['Person', '25031', '25032'],
#  '11930': ['Org', '25033', '25034'],
#  '12348': ['Location', '25688', '25689'],
#  '12349': ['Location', '25690'],
#  '12350': ['Location', '25691'],
#  '12356': ['Location', '25699'],
#  '12357': ['Person', '25700', '25701'],
#  '12358': ['Location', '25702', '25703'],
#  '12359': ['Org', '25704'],
#  '12360': ['Person', '25705', '25706'],
#  '12363': ['Location', '25711', '25712'],
#  '12364': ['Location', '25713', '25714'],
#  '12365': ['Person', '25715'],
#  '12366': ['Person', '25716'],
#  '12369': ['Person', '25720'],
#  '12370': ['LocOrg', '25721'],
#  '12371': ['Org', '25722'],
#  '12372': ['Org', '25723', '25724'],
#  '12373': ['Person', '25725', '25726'],
#  '12376': ['Org', '25730'],
#  '12377': ['Location', '25731', '25732'],
#  '12378': ['Org', '25733', '25734'],
#  '12379': ['Person', '25735', '25736'],
#  '12380': ['Person', '25737', '25738'],
#  '12381': ['Person', '25739', '25740'],
#  '12383': ['Person', '25745', '25746'],
#  '12384': ['Person', '25747'],
#  '12385': ['Person', '25748', '25749'],
#  '12386': ['Org', '25750', '25751'],
#  '12387': ['Person', '25752', '25753'],
#  '12388': ['Person', '25754'],
#  '12389': ['Org', '25755'],
#  '12390': ['Person', '25758'],
#  '12393': ['Org', '25761'],
#  '12394': ['Person', '25762', '25763'],
#  '12395': ['Person', '25764', '25765'],
#  '12396': ['Org', '25766', '25767'],
#  '12397': ['Org', '25768', '25769'],
#  '12398': ['Person', '25772'],
#  '12399': ['Person', '25773', '25774'],
#  '12400': ['Org', '25775', '25776'],
#  '12401': ['Person', '25777'],
#  '12402': ['Org', '25778'],
#  '12404': ['LocOrg', '25781'],
#  '12405': ['Org', '25782'],
#  '12406': ['Person', '25783', '25784'],
#  '12408': ['Person', '25787'],
#  '12409': ['Person', '25788'],
#  '12412': ['Person', '25793', '25794'],
#  '12413': ['Person', '25795', '25796'],
#  '12414': ['Org', '25797', '25798', '25799'],
#  '12415': ['LocOrg', '25800'],
#  '41365': ['Org', '69844'],
#  '12420': ['LocOrg', '25805'],
#  '12421': ['Person', '25806', '25807'],
#  '12422': ['Location', '25808', '25809'],
#  '12423': ['Org', '25810', '25811'],
#  '12424': ['Org', '25812'],
#  '12429': ['Person', '25819', '25820'],
#  '12430': ['Person', '25821', '25822'],
#  '12431': ['Org', '25823', '25824'],
#  '12432': ['Person', '25825'],
#  '12433': ['Person', '25826', '25827'],
#  '12434': ['Org', '25828'],
#  '12435': ['Person', '25829'],
#  '12439': ['Person', '25834'],
#  '12440': ['Org', '25835', '25836'],
#  '12441': ['Person', '25837'],
#  '12443': ['Person', '25838', '25839'],
#  '12446': ['Person', '25842', '25843'],
#  '12447': ['LocOrg', '25844'],
#  '12454': ['Org', '25856', '25857'],
#  '12455': ['Org', '25858'],
#  '12456': ['Org', '25859'],
#  '49706': ['Org', '82650'],
#  '12458': ['Location', '25861'],
#  '12459': ['Location', '25862'],
#  '12460': ['Location', '25863'],
#  '12461': ['Location', '25864'],
#  '49707': ['Org', '82651'],
#  '12462': ['Location', '25865'],
#  '12463': ['Location', '25866'],
#  '12464': ['Person', '25867', '25868'],
#  '12465': ['Person', '25869', '25870'],
#  '12468': ['Org', '25876'],
#  '12469': ['Person', '25877', '25878'],
#  '12470': ['Person', '25879', '25880'],
#  '12471': ['LocOrg', '25881'],
#  '49708': ['Org', '82654'],
#  '49709': ['Org', '82655'],
#  '49710': ['Org', '82656'],
#  '12473': ['Location', '25887'],
#  '12474': ['Location', '25888'],
#  '12475': ['Location', '25889'],
#  '12480': ['Location', '25897'],
#  '12481': ['Location', '25898'],
#  '12482': ['Org', '25899'],
#  '12483': ['Person', '25900', '25901'],
#  '12484': ['Person', '25902', '25903'],
#  '12485': ['Org', '25904'],
#  '12486': ['Person', '25905', '25906'],
#  '12487': ['Person', '25907', '25908'],
#  '12488': ['Location', '25909'],
#  '12489': ['Location', '25910'],
#  '12497': ['LocOrg', '25927'],
#  '12498': ['LocOrg', '25928'],
#  '12499': ['Person', '25929', '25930'],
#  '12500': ['Person', '25931', '25932'],
#  '12501': ['Location', '25933', '25934'],
#  '12502': ['Org', '25935', '25936'],
#  '12503': ['LocOrg', '25935'],
#  '49711': ['Org', '82657'],
#  '49712': ['Org', '82658'],
#  '12504': ['LocOrg', '25938'],
#  '12505': ['LocOrg', '25939'],
#  '12508': ['LocOrg', '25944'],
#  '12509': ['LocOrg', '25945'],
#  '12510': ['Org', '25945', '25946'],
#  '12511': ['LocOrg', '25947'],
#  '12512': ['LocOrg', '25948'],
#  '12513': ['LocOrg', '25949'],
#  '12514': ['LocOrg', '25950'],
#  '12515': ['LocOrg', '25951'],
#  '12516': ['LocOrg', '25952'],
#  '12517': ['Location', '25955'],
#  '12518': ['Org', '25956', '25957'],
#  '12519': ['Location', '25958'],
#  '12523': ['Person', '25964', '25965'],
#  '12524': ['Org', '25966', '25967', '25968'],
#  '12526': ['Person', '25971', '25972'],
#  '12527': ['Org', '25973', '25974', '25975'],
#  '12528': ['LocOrg', '25976'],
#  '12530': ['Person', '25980', '25981'],
#  '12531': ['Location', '25982'],
#  '12532': ['Person', '25983', '25984'],
#  '12533': ['Person', '25985', '25986'],
#  '12534': ['Person', '25987', '25988'],
#  '12535': ['Person', '25989', '25990'],
#  '12536': ['Person', '25991', '25992'],
#  '12537': ['Person', '25993', '25994'],
#  '12538': ['Person', '25995', '25996'],
#  '12544': ['Location', '26002'],
#  '12545': ['Org', '26003', '26004'],
#  '12546': ['Location', '26005'],
#  '12547': ['Org', '26006'],
#  '12550': ['LocOrg', '26010'],
#  '12551': ['Person', '26011', '26012'],
#  '12552': ['Person', '26013', '26014'],
#  '12553': ['Location', '26015'],
#  '12556': ['Org', '26022'],
#  '12557': ['Person', '26023'],
#  '12558': ['LocOrg', '26024'],
#  '12559': ['Location', '26025'],
#  '12567': ['Org', '26033'],
#  '12568': ['Org', '26034'],
#  '12569': ['Person', '26035', '26036'],
#  '12570': ['LocOrg', '26037'],
#  '12578': ['Org', '26037', '26056'],
#  '12571': ['Person', '26038', '26039'],
#  '12573': ['Location', '26045'],
#  '45838': ['LocOrg', '74753'],
#  '12580': ['Org', '26062'],
#  '12581': ['LocOrg', '26063'],
#  '12582': ['Org', '26064', '26065'],
#  '12586': ['Person', '26070', '26071'],
#  '12587': ['Org', '26072'],
#  '12588': ['Org', '26073'],
#  '12589': ['LocOrg', '26074'],
#  '12593': ['Person', '26080', '26081'],
#  '12594': ['LocOrg', '26082'],
#  '12595': ['LocOrg', '26083'],
#  '12596': ['Location', '26084'],
#  '12597': ['Location', '26085'],
#  '12605': ['Person', '26095', '26096'],
#  '12606': ['Org', '26097'],
#  '12607': ['Location', '26098'],
#  '12608': ['LocOrg', '26099'],
#  '12609': ['Org', '26100'],
#  '12610': ['LocOrg', '26101'],
#  '12611': ['LocOrg', '26102'],
#  '12612': ['LocOrg', '26103'],
#  '12613': ['Person', '26104'],
#  '12623': ['Location', '26115'],
#  '12624': ['LocOrg', '26116', '26117'],
#  '12625': ['Location', '26118'],
#  '12626': ['Location', '26119'],
#  '12627': ['Person', '26120', '26121'],
#  '12628': ['Person', '26122', '26123'],
#  '12629': ['Location', '26124'],
#  '12630': ['Location', '26125'],
#  '12631': ['LocOrg', '26126'],
#  '12632': ['Person', '26127'],
#  '12633': ['Org', '26128', '26129'],
#  '26561': ['Location', '26129'],
#  '12634': ['Location', '26130'],
#  '12635': ['Location', '26131'],
#  '12636': ['Location', '26132'],
#  '41734': ['LocOrg', '28823'],
#  '41733': ['LocOrg', '28824'],
#  '41737': ['LocOrg', '70437'],
#  '41717': ['Org', '70352', '70353', '70354'],
#  '41663': ['LocOrg', '70354'],
#  '41664': ['Person', '70355', '70356', '70357'],
#  '41665': ['LocOrg', '70358'],
#  '41666': ['Person', '70359', '70360', '70361'],
#  '41667': ['LocOrg', '70362'],
#  '41668': ['LocOrg', '70363'],
#  '41669': ['LocOrg', '70364'],
#  '41670': ['LocOrg', '70365'],
#  '41671': ['LocOrg', '70366'],
#  '41672': ['LocOrg', '70367'],
#  '41673': ['Location', '70368'],
#  '41674': ['Person', '70369', '70370', '70371'],
#  '41675': ['Org', '70372'],
#  '41676': ['Person', '70387'],
#  '41677': ['Location', '70388'],
#  '41679': ['LocOrg', '70390'],
#  '41680': ['Person', '70391'],
#  '41682': ['Person', '70393', '70394', '70395'],
#  '41683': ['Person', '70396', '70397', '70398'],
#  '18046': ['Person', '34643', '34644'],
#  '18047': ['LocOrg', '34645'],
#  '18048': ['Person', '34646', '34647'],
#  '18049': ['Org', '34649', '34650'],
#  '18050': ['LocOrg', '34651'],
#  '18051': ['Person', '34652'],
#  '18052': ['Person', '34653'],
#  '18053': ['Person', '34654'],
#  '18054': ['Person', '34655'],
#  '18055': ['Org', '34656', '34657', '34658'],
#  '18056': ['LocOrg', '34659'],
#  '18057': ['LocOrg', '34660'],
#  '18058': ['Person', '34661'],
#  '18066': ['Org', '34663', '34664', '34673'],
#  '18060': ['Location', '34665'],
#  '18061': ['Location', '34666', '34667'],
#  '18062': ['Location', '34668'],
#  '18063': ['Location', '34669'],
#  '18064': ['Org', '34670'],
#  '18065': ['Location', '34671', '34672'],
#  '18067': ['Person', '34674'],
#  '18068': ['Org', '34675'],
#  '18070': ['Org', '34675', '34676', '34678'],
#  '18071': ['Org', '34679'],
#  '18072': ['Person', '34680'],
#  '18073': ['Org', '34681'],
#  '18074': ['Location', '34682'],
#  '18075': ['Location', '34683'],
#  '18076': ['Org', '34684'],
#  '18077': ['Location', '34685'],
#  '18078': ['Location', '34686'],
#  '18079': ['Person', '34687'],
#  '18080': ['Org', '34688'],
#  '18081': ['Org', '34689'],
#  '18082': ['LocOrg', '34690'],
#  '18083': ['Org', '34690', '34691', '34692'],
#  '18084': ['Org', '34693', '34694'],
#  '18085': ['Org', '34695', '34696'],
#  '18086': ['Person', '34697'],
#  '18087': ['Org', '34698'],
#  '18088': ['Org', '34699', '34700'],
#  '18089': ['Location', '34701'],
#  '18090': ['Person', '34702'],
#  '18091': ['Org', '34703'],
#  '18092': ['Org', '34704'],
#  '18093': ['Person', '34705'],
#  '18094': ['Location', '34706'],
#  '18095': ['Org', '34707'],
#  '18096': ['Location', '34708'],
#  '12643': ['Person', '26143', '26144'],
#  '12644': ['Person', '26145'],
#  '12645': ['Person', '26146', '26147'],
#  '12646': ['Org', '26148', '26149'],
#  '12647': ['Person', '26150', '26151'],
#  '12648': ['Org', '26152', '26153'],
#  '12649': ['Person', '26154', '26155'],
#  '12650': ['Org', '26158', '26159', '26160'],
#  '12651': ['LocOrg', '26160'],
#  '12652': ['Person', '26161', '26162'],
#  '12653': ['Org', '26163'],
#  '12654': ['Person', '26164'],
#  '12655': ['Person', '26165'],
#  '12656': ['Location', '26166'],
#  '12657': ['Person', '26167', '26168'],
#  '12658': ['Person', '26170', '26171'],
#  '12659': ['Person', '26172', '26173'],
#  '12660': ['LocOrg', '26174', '26175'],
#  '12661': ['Location', '26176'],
#  '12662': ['Person', '26177', '26178'],
#  '12663': ['Org', '26179', '26180', '26181'],
#  '12664': ['LocOrg', '26181'],
#  '12665': ['Org', '26182'],
#  '12666': ['Person', '26183', '26184'],
#  '12667': ['Person', '26185', '26186'],
#  '12668': ['Location', '26188'],
#  '12669': ['Location', '26189'],
#  '12670': ['LocOrg', '26190'],
#  '12671': ['Person', '26191', '26192'],
#  '12672': ['LocOrg', '26195'],
#  '12673': ['Person', '26196', '26197'],
#  '12674': ['Location', '26198', '26199'],
#  '12675': ['Location', '26200'],
#  '12676': ['Person', '26202', '26203'],
#  '12677': ['Location', '26204'],
#  '12678': ['Location', '26205'],
#  '12679': ['Location', '26206'],
#  '12680': ['Location', '26207'],
#  '12681': ['LocOrg', '26208'],
#  '12682': ['LocOrg', '26209'],
#  '12683': ['LocOrg', '26210'],
#  '12684': ['LocOrg', '26211'],
#  '12685': ['Location', '26212'],
#  '17772': ['Location', '34246'],
#  '17773': ['Location', '34247', '34248'],
#  '17774': ['Location', '34249', '34250'],
#  '17775': ['Org', '34251', '34252'],
#  '17776': ['Org', '34253', '34254'],
#  '17777': ['LocOrg', '34254'],
#  '17778': ['Location', '34255'],
#  '17779': ['Org', '34256'],
#  '17780': ['Location', '34257'],
#  '17781': ['Org', '34258', '34259', '34260', '34261'],
#  '17782': ['Org', '34260', '34261'],
#  '17783': ['Location', '34262'],
#  '17784': ['Location', '34263', '34264'],
#  '17785': ['Location', '34265', '34266'],
#  '17786': ['Org', '34267', '34268', '34269'],
#  '17787': ['Org', '34269'],
#  '17788': ['Person', '34270', '34271'],
#  '17789': ['Org', '34272'],
#  '17790': ['Location', '34273'],
#  '17791': ['Location', '34274'],
#  '17792': ['Org', '34275', '34276'],
#  '17793': ['Org', '34278'],
#  '17794': ['Org', '34279'],
#  '17795': ['Location', '34280'],
#  '17796': ['Location', '34281'],
#  '17797': ['Org', '34282'],
#  '17798': ['Location', '34283'],
#  '17799': ['Location', '34284', '34285'],
#  '17800': ['Org', '34286'],
#  '17801': ['Location', '34287', '34288'],
#  '17802': ['Org', '34289'],
#  '17803': ['Location', '34290', '34291'],
#  '17804': ['Location', '34292', '34293'],
#  '12686': ['LocOrg', '26213'],
#  '12687': ['LocOrg', '26214'],
#  '12688': ['Org', '26215'],
#  '12692': ['Org', '26216', '26217', '26218'],
#  '12691': ['LocOrg', '26217'],
#  '20383': ['Org', '38269', '38270'],
#  '12693': ['Org', '26219', '26220', '26221'],
#  '12694': ['Org', '26222'],
#  '12695': ['Org', '26223', '26224', '26225'],
#  '12696': ['Org', '26226'],
#  '12697': ['Org', '26227', '26228'],
#  '12698': ['Org', '26229', '26230', '26231', '26232'],
#  '12699': ['Org', '26231', '26232'],
#  '12700': ['Org', '26233'],
#  '12701': ['Org', '26234'],
#  '12702': ['Org', '26235'],
#  '12703': ['Org', '26236'],
#  '12704': ['Org', '26237'],
#  '12705': ['Org', '26238'],
#  '12706': ['Org', '26239', '26240'],
#  '12707': ['Org', '26240'],
#  '12708': ['Org', '26241'],
#  '12709': ['Org', '26242'],
#  '12710': ['Org', '26243'],
#  '12711': ['Org', '26244'],
#  '12712': ['Org', '26245'],
#  '12713': ['Location', '26246'],
#  '12714': ['Org', '26247', '26248'],
#  '12715': ['Person', '26249'],
#  '12716': ['Location', '26250'],
#  '12717': ['LocOrg', '26252'],
#  '13447': ['Org', '27421'],
#  '13448': ['Org', '27422'],
#  '13449': ['Org', '27423'],
#  '13450': ['Org', '27423', '27424'],
#  '13451': ['LocOrg', '27425'],
#  '13452': ['Org', '27425', '27426'],
#  '13453': ['Org', '27427'],
#  '13454': ['Org', '27428'],
#  '13455': ['Person', '27429', '27430'],
#  '13456': ['LocOrg', '27432'],
#  '13457': ['Org', '27432', '27433'],
#  '13458': ['Org', '27434', '27435'],
#  '13459': ['Org', '27436', '27437'],
#  '13460': ['Org', '27438'],
#  '13461': ['Person', '27439', '27440'],
#  '13462': ['Person', '27441', '27442'],
#  '13463': ['Person', '27445'],
#  '13464': ['Org', '27446'],
#  '13465': ['Org', '27447'],
#  '13466': ['Person', '27448'],
#  '13467': ['Person', '27450'],
#  '13468': ['Person', '27451', '27452'],
#  '13469': ['Org', '27453'],
#  '13470': ['Person', '27454'],
#  '13471': ['Org', '27455', '27456'],
#  '13472': ['Person', '27457', '27458'],
#  '49075': ['Org', '81357', '81358', '81359'],
#  '13473': ['Person', '27461', '27462'],
#  '13474': ['Org', '27463', '27464'],
#  '13475': ['Org', '27465', '27466', '27467'],
#  '13476': ['Org', '27469'],
#  '13477': ['Person', '27470', '27471'],
#  '13478': ['Person', '27472', '27473'],
#  '17462': ['Org', '33754', '33755', '33756'],
#  '17463': ['Location', '33757', '33758'],
#  '17464': ['Location', '33759', '33760'],
#  '17465': ['LocOrg', '33761'],
#  '17466': ['Person', '33762', '33763', '33764'],
#  '17467': ['Location', '33765'],
#  '17468': ['Org', '33766'],
#  '17469': ['Org', '33766', '33767', '33768'],
#  '17470': ['Person', '33769', '33770'],
#  '17471': ['LocOrg', '33771', '33772'],
#  '17472': ['Org', '33773'],
#  '17473': ['Org', '33773', '33774'],
#  '17474': ['Person', '33775', '33776'],
#  '17475': ['Location', '33787'],
#  '17476': ['Person', '33788', '33789'],
#  '17477': ['Org', '33790', '33791'],
#  '17478': ['Org', '33792', '33793', '33794'],
#  '17479': ['Person', '33795', '33796'],
#  '17480': ['Person', '33797', '33798'],
#  '17481': ['Person', '33799', '33800'],
#  '17482': ['Person', '33801', '33802', '33803'],
#  '17483': ['Person', '33809', '33810'],
#  '17484': ['Location', '33811'],
#  '17485': ['Person', '33812', '33813'],
#  '17486': ['LocOrg', '33814'],
#  '17487': ['LocOrg', '33815'],
#  '17488': ['Person', '33816'],
#  '17489': ['Person', '33817'],
#  '17490': ['Person', '33818', '33819'],
#  '17491': ['LocOrg', '33820', '33821'],
#  '17492': ['Person', '33822', '33823'],
#  '17493': ['Person', '33826', '33827'],
#  '17494': ['LocOrg', '33828'],
#  '17495': ['Person', '33829', '33830'],
#  '17496': ['LocOrg', '33831'],
#  '17497': ['Location', '33832'],
#  '17498': ['Location', '33833'],
#  '17499': ['Location', '33834'],
#  '17500': ['Location', '33835', '33836'],
#  '17501': ['Location', '33837', '33838'],
#  '17502': ['Person', '33839'],
#  '17503': ['Org', '33843'],
#  '17504': ['LocOrg', '33844'],
#  '17505': ['Person', '33845', '33846'],
#  '17506': ['Location', '33847'],
#  '17507': ['Person', '33848'],
#  '13479': ['LocOrg', '27475'],
#  '13480': ['Location', '27476'],
#  '13481': ['LocOrg', '27477'],
#  '13482': ['LocOrg', '27478'],
#  '13483': ['Person', '27479', '27480'],
#  '13484': ['Org', '27481'],
#  '13485': ['LocOrg', '27483'],
#  '13486': ['Org', '27484'],
#  '13487': ['Person', '27485'],
#  '13488': ['Org', '27486'],
#  '13489': ['LocOrg', '27487'],
#  '13490': ['Person', '27492'],
#  '13491': ['LocOrg', '27493'],
#  '13492': ['Org', '27495', '27496'],
#  '13493': ['Org', '27497'],
#  '13494': ['Location', '27498'],
#  '13495': ['Org', '27499', '27500'],
#  '13500': ['Org', '27501', '27502'],
#  '13497': ['Location', '27504'],
#  '13499': ['Org', '27505', '27506', '27507', '27508'],
#  '13501': ['Person', '27510', '27511'],
#  '13526': ['Org', '27512', '27513', '27566'],
#  '13503': ['Person', '27515', '27516'],
#  '13504': ['Location', '27517'],
#  '13505': ['Location', '27518'],
#  '13506': ['Org', '27519', '27520'],
#  '13507': ['Location', '27521'],
#  '13508': ['Person', '27522', '27523'],
#  '13509': ['Person', '27524', '27525'],
#  '13510': ['Org', '27526', '27527', '27528'],
#  '13511': ['Org', '27527'],
#  '13512': ['Org', '27529', '27530', '27531'],
#  '13513': ['Org', '27531'],
#  '13514': ['Person', '27532', '27533'],
#  '13515': ['Person', '27534', '27535'],
#  '13516': ['Person', '27536', '27537'],
#  '13517': ['Person', '27538', '27539'],
#  '13518': ['Location', '27540'],
#  '13519': ['Org', '27541', '27542'],
#  '13520': ['Org', '27543', '27544'],
#  '13521': ['Person', '27545', '27546'],
#  '13522': ['Location', '27547'],
#  '13528': ['Org', '27548', '27549', '27568'],
#  '13524': ['Org', '27551', '27552'],
#  '13527': ['Org', '27553', '27554', '27567'],
#  '13529': ['Org', '27569', '27570'],
#  '13530': ['LocOrg', '27571'],
#  '13531': ['Person', '27572', '27573'],
#  '13532': ['Location', '27574'],
#  '13533': ['LocOrg', '27576'],
#  '13534': ['Person', '27577', '27578'],
#  '13535': ['Org', '27579'],
#  '13536': ['Org', '27580', '27581'],
#  '13553': ['LocOrg', '27581', '27608'],
#  '13538': ['Location', '27582', '27583'],
#  '13539': ['Person', '27584', '27585'],
#  '13540': ['LocOrg', '27586'],
#  '13541': ['Location', '27587'],
#  '13542': ['Location', '27587', '27588', '27589'],
#  '13543': ['Person', '27590'],
#  '13544': ['LocOrg', '27591'],
#  '13545': ['LocOrg', '27592'],
#  '13546': ['Person', '27593', '27594'],
#  '13548': ['Org', '27595', '27596', '27597', '27598', '27599'],
#  '13549': ['LocOrg', '27597'],
#  '13550': ['Org', '27598', '27599'],
#  '13551': ['Org', '27600'],
#  '13552': ['LocOrg', '27601'],
#  '13554': ['Person', '27609', '27610'],
#  '13555': ['Location', '27611'],
#  '13556': ['LocOrg', '27612'],
#  '13563': ['Person', '27614', '27627'],
#  '13558': ['Org', '27615', '27616'],
#  '13559': ['Person', '27617', '27618'],
#  '13560': ['LocOrg', '27619'],
#  '13561': ['Org', '27620', '27621'],
#  '13562': ['Location', '27622'],
#  '17446': ['LocOrg', '33724'],
#  '17447': ['Org', '33724', '33725'],
#  '17448': ['Location', '33726', '33727', '33728'],
#  '17449': ['LocOrg', '33729'],
#  '17450': ['LocOrg', '33730'],
#  '17454': ['Location', '33734', '33738'],
#  '17452': ['Location', '33735', '33736'],
#  '17453': ['LocOrg', '33737'],
#  '17455': ['LocOrg', '33739'],
#  '17456': ['Person', '33740', '33741'],
#  '17457': ['LocOrg', '33742'],
#  '17458': ['Person', '33743', '33744'],
#  '17459': ['Location', '33745'],
#  '17460': ['LocOrg', '33746'],
#  '17461': ['Person', '33747', '33748'],
#  '13564': ['Location', '27628', '27629'],
#  '13565': ['Location', '27630'],
#  '13566': ['Location', '27631'],
#  '13567': ['Project', '27632', '27633'],
#  '13568': ['Org', '27634', '27635'],
#  '13570': ['Org', '27636', '27637', '27638'],
#  '13571': ['Person', '27639', '27640'],
#  '13572': ['Org', '27641', '27642'],
#  '13573': ['Person', '27643', '27644'],
#  '13574': ['Org', '27645', '27646'],
#  '13575': ['Org', '27647'],
#  '13576': ['Org', '27648'],
#  '13577': ['Org', '27649'],
#  '13578': ['Org', '27650'],
#  '13579': ['Org', '27651'],
#  '13580': ['Person', '27654'],
#  '13581': ['LocOrg', '27655'],
#  '13582': ['Person', '27656', '27657'],
#  '13583': ['Person', '27658', '27659'],
#  '13584': ['Person', '27660', '27661'],
#  '13585': ['LocOrg', '27662'],
#  '13586': ['LocOrg', '27663'],
#  '13587': ['Org', '27664'],
#  '13588': ['Person', '27665'],
#  '49713': ['Org', '82659'],
#  '13589': ['Person', '27666', '27667'],
#  '13590': ['Org', '27668'],
#  '13591': ['Person', '27669', '27670'],
#  '13592': ['Person', '27671', '27672'],
#  '13593': ['Org', '27673'],
#  '13594': ['Person', '27674', '27675'],
#  '13595': ['Org', '27678'],
#  '13596': ['Person', '27679', '27680'],
#  '13597': ['Org', '27681', '27682'],
#  '13598': ['LocOrg', '27682'],
#  '13599': ['Person', '27683', '27684'],
#  '13600': ['Location', '27685', '27686', '27687'],
#  '13601': ['Person', '27688', '27689'],
#  '13602': ['Location', '27690', '27691'],
#  '17508': ['Person', '33849', '33850'],
#  '17509': ['Org', '33851', '33852'],
#  '17510': ['Location', '33853'],
#  '17511': ['Org', '33854'],
#  '17512': ['Person', '33855'],
#  '17513': ['Org', '33856'],
#  '17514': ['Org', '33858', '33859'],
#  '17515': ['Org', '33860'],
#  '17516': ['Org', '33861'],
#  '17517': ['Location', '33862', '33863', '33864'],
#  '17518': ['Person', '33865'],
#  '17519': ['Location', '33866'],
#  '17520': ['Org', '33867', '33868'],
#  '17521': ['Org', '33869', '33870'],
#  '17522': ['Person', '33871'],
#  '17523': ['Person', '33872'],
#  '17524': ['Location', '33873'],
#  '17525': ['Org', '33874', '33875', '33876', '33877'],
#  '17526': ['Org', '33876', '33877'],
#  '17527': ['Person', '33878'],
#  '17528': ['Person', '33879'],
#  '17529': ['Org', '33880'],
#  '17530': ['LocOrg', '33882'],
#  '17531': ['Org', '33883', '33884', '33885'],
#  '17532': ['Org', '33884'],
#  '17533': ['Location', '33886'],
#  '17534': ['Org', '33887', '33888', '33889'],
#  '17535': ['Person', '33890', '33891'],
#  '17536': ['Person', '33892', '33893'],
#  '17537': ['LocOrg', '33894'],
#  '17538': ['Org', '33894', '33895'],
#  '17539': ['Person', '33896'],
#  '17540': ['LocOrg', '33897'],
#  '17541': ['Org', '33897', '33898'],
#  '17542': ['Location', '33899'],
#  '17543': ['Org', '33899', '33900'],
#  '17544': ['Org', '33903'],
#  '17545': ['Org', '33904'],
#  '17546': ['LocOrg', '33905'],
#  '17547': ['Org', '33905', '33906'],
#  '17548': ['Org', '33907'],
#  '17549': ['Org', '33908'],
#  '17550': ['LocOrg', '33909'],
#  '17551': ['Org', '33910', '33911'],
#  '17552': ['Location', '33911'],
#  '17553': ['Location', '33912'],
#  '17554': ['Location', '33913'],
#  '17555': ['Location', '33914'],
#  '17556': ['LocOrg', '33915'],
#  '17557': ['Org', '33916'],
#  '17558': ['Location', '33917'],
#  '17559': ['LocOrg', '33918'],
#  '17560': ['Person', '33919', '33920'],
#  '17561': ['Person', '33921', '33922'],
#  '17562': ['Location', '33923'],
#  '17563': ['Org', '33924'],
#  '17564': ['Location', '33925'],
#  '13604': ['Org', '27694'],
#  '13605': ['Org', '27695', '27696'],
#  '13606': ['Org', '27697', '27698'],
#  '13607': ['Org', '27699', '27700'],
#  '13608': ['Org', '27701'],
#  '13609': ['Org', '27702'],
#  '13610': ['Org', '27703'],
#  '13611': ['Org', '27704'],
#  '13612': ['Org', '27705'],
#  '13613': ['Org', '27706', '27707'],
#  '13614': ['Org', '27708'],
#  '13615': ['Org', '27709'],
#  '17593': ['Location', '33978', '33979'],
#  '17594': ['Location', '33980', '33981'],
#  '17595': ['Org', '33982'],
#  '17596': ['Person', '33983', '33984'],
#  '17597': ['LocOrg', '33985', '33986'],
#  '17598': ['Person', '33987', '33988', '33989'],
#  '17599': ['LocOrg', '33990'],
#  '17600': ['Org', '33990', '33991'],
#  '17601': ['Org', '33992'],
#  '17602': ['Person', '33993'],
#  '17603': ['LocOrg', '33994'],
#  '17604': ['LocOrg', '33999'],
#  '17605': ['Location', '34000', '34001', '34002'],
#  '17606': ['Person', '34003', '34004'],
#  '17607': ['Org', '34005', '34006'],
#  '17608': ['LocOrg', '34006'],
#  '17609': ['Org', '34007', '34008', '34009'],
#  '17611': ['LocOrg', '34009'],
#  '17610': ['Person', '34010', '34011'],
#  '17612': ['Person', '34017', '34018', '34019', '34020'],
#  '17613': ['Person', '34023', '34024'],
#  '17614': ['LocOrg', '34025'],
#  '17615': ['Org', '34026', '34027'],
#  '17616': ['Person', '34027'],
#  '17617': ['Location', '34028'],
#  '17618': ['Person', '34029'],
#  '13616': ['LocOrg', '27714'],
#  '13617': ['Person', '27715', '27716'],
#  '13618': ['Org', '27717', '27718'],
#  '13619': ['Location', '27719'],
#  '13620': ['LocOrg', '27720'],
#  '13621': ['Location', '27724'],
#  '13622': ['Location', '27725'],
#  '13623': ['Location', '27726'],
#  '13624': ['Person', '27727'],
#  '13625': ['Person', '27728'],
#  '13626': ['LocOrg', '27729'],
#  '13627': ['Person', '27730', '27731'],
#  '13628': ['LocOrg', '27733'],
#  '13629': ['Person', '27734'],
#  '13630': ['LocOrg', '27735'],
#  '13631': ['LocOrg', '27736'],
#  '13632': ['Person', '27737', '27738'],
#  '13633': ['Location', '27739'],
#  '13634': ['Location', '27742'],
#  '13635': ['Org', '27743', '27744'],
#  '13637': ['Org', '27747', '27748'],
#  '13640': ['Org', '27752', '27753'],
#  '13641': ['LocOrg', '27753'],
#  '13642': ['Person', '27754', '27755'],
#  '13643': ['Person', '27756', '27757'],
#  '13644': ['Org', '27760', '27761'],
#  '13645': ['Location', '27762'],
#  '13646': ['Person', '27763', '27764'],
#  '13647': ['Org', '27765', '27766'],
#  '13648': ['Org', '27767', '27768'],
#  '13649': ['LocOrg', '27768'],
#  '13650': ['LocOrg', '27769'],
#  '13651': ['Location', '27770'],
#  '13652': ['Org', '27772', '27773', '27774'],
#  '13653': ['Person', '27775', '27776'],
#  '13654': ['Org', '27777', '27778'],
#  '13655': ['Person', '27779', '27780'],
#  '13656': ['Org', '27781'],
#  '13657': ['Person', '27782', '27783'],
#  '13658': ['Org', '27784', '27785'],
#  '13659': ['Org', '27786'],
#  '13661': ['Person', '27794', '27795'],
#  '13662': ['Org', '27796', '27797'],
#  '13663': ['Person', '27798', '27799'],
#  '13664': ['Person', '27800'],
#  '13665': ['Person', '27801'],
#  '13666': ['Location', '27802'],
#  '13668': ['Person', '27807'],
#  '13669': ['LocOrg', '27808'],
#  '14808': ['Org', '29603', '29604', '29605', '29607', '29608'],
#  ...}

# %%
all_ne = []
for key, value in factrueval_dev_objects.items():
    spans = value[1:]
    ne = value[0]
    all_tokens = []
    for span in spans:
        span_obj = factrueval_dev_spans[span]
        token = int(span_obj[3])
        num_of_tokens = int(span_obj[4])
        for i in range(num_of_tokens):
            all_tokens.append(token + i)
    all_ne.append([ne, sorted(all_tokens)])

# %%
all_ne
# Out:
# [['Org', [143789, 143790]],
#  ['LocOrg', [143790]],
#  ['Location', [143792, 143793]],
#  ['Person', [143831, 143832]],
#  ['LocOrg', [143830]],
#  ['Location', [143853]],
#  ['LocOrg', [143862]],
#  ['Org', [143868]],
#  ['Person', [143874, 143875]],
#  ['Person', [143899, 143900]],
#  ['LocOrg', [143872]],
#  ['Location', [143933, 143934, 143935]],
#  ['Person', [143934, 143935]],
#  ['Person', [143993]],
#  ['Org', [144001, 144002, 144003, 144004]],
#  ['LocOrg', [144003, 144004]],
#  ['Org', [144009, 144011]],
#  ['Org', [144007, 144008, 144008, 144009, 144011]],
#  ['Person', [144013, 144014]],
#  ['Person', [144018, 144019]],
#  ['Org', [144022, 144024, 144025]],
#  ['Person', [144027, 144028]],
#  ['Org', [144033, 144035, 144036, 144037]],
#  ['Org', [144040, 144040, 144041, 144042]],
#  ['Org', [144044]],
#  ['Org', [144047, 144049, 144050]],
#  ['Org', [144054, 144055]],
#  ['Org', [144058, 144058, 144059, 144060]],
#  ['Org', [144062, 144062, 144063, 144064, 144065, 144066]],
#  ['Org', [144068, 144070, 144071]],
#  ['Org', [144075, 144075, 144076, 144076, 144076, 144077, 144078]],
#  ['Location', [144065, 144066, 144066]],
#  ['Person', [149390, 149391]],
#  ['Person', [149451, 149452]],
#  ['Person', [149489, 149490]],
#  ['Location', [149485]],
#  ['Location', [149562]],
#  ['Person', [149573, 149574]],
#  ['Person', [149583]],
#  ['Location', [149595]],
#  ['Person', [149610]],
#  ['Person', [149621]],
#  ['Person', [149631]],
#  ['Person', [149641]],
#  ['Person', [149607, 149608]],
#  ['Person', [149612, 149613]],
#  ['Org', [155118, 155119, 155120, 155121, 155121, 155122]],
#  ['Org', [155124, 155125, 155126, 155127, 155128, 155129]],
#  ['Org', [155147, 155148, 155148, 155149, 155150, 155151, 155152]],
#  ['Org', [155149, 155150, 155151, 155152]],
#  ['Location', [155158]],
#  ['Location', [155160]],
#  ['Org', [155171, 155172]],
#  ['Org', [155170, 155171, 155172, 155173, 155173]],
#  ['Location', [155187]],
#  ['LocOrg', [155194]],
#  ['Person', [155195, 155196]],
#  ['Location', [155198]],
#  ['Org', [155218, 155219]],
#  ['LocOrg', [155219]],
#  ['Org', [155221, 155222, 155223, 155224, 155225, 155226]],
#  ['Org', [155237, 155238, 155238, 155238, 155239, 155239, 155239]],
#  ['LocOrg', [155275]],
#  ['LocOrg', [155294]],
#  ['Person', [155295, 155296]],
#  ['Person', [155313, 155314]],
#  ['Location', [155317, 155318, 155318]],
#  ['Person', [155322, 155323]],
#  ['LocOrg', [155330]],
#  ['Location', [155333]],
#  ['Org', [155339, 155340]],
#  ['LocOrg', [155340]],
#  ['Org', [155367]],
#  ['Location', [155369]],
#  ['Location', [155373]],
#  ['Location', [155378, 155379]],
#  ['Person', [155383, 155384]],
#  ['Location', [155394]],
#  ['Person', [155402]],
#  ['LocOrg', [155431]],
#  ['Org', [155435, 155436]],
#  ['Person', [155440]],
#  ['Org', [155456]],
#  ['Location', [165158]],
#  ['Org', [165174, 165175]],
#  ['LocOrg', [165175]],
#  ['Person', [165190, 165191]],
#  ['Location', [165203, 165204]],
#  ['Person', [165222]],
#  ['Location', [165232]],
#  ['Org', [165242, 165242, 165243, 165244, 165245]],
#  ['Org', [165244, 165245]],
#  ['LocOrg', [165245]],
#  ['LocOrg', [165247, 165248]],
#  ['Person', [165249, 165250]],
#  ['LocOrg', [165273]],
#  ['Person', [165274, 165275]],
#  ['Person', [165301]],
#  ['Location', [165304, 165305, 165305]],
#  ['Person', [165330, 165331]],
#  ['Location', [165334, 165335, 165335]],
#  ['Location', [165344]],
#  ['Org', [165346, 165347, 165348, 165348]],
#  ['Person', [165363]],
#  ['Person', [165414]],
#  ['Person', [165421]],
#  ['Org', [165439]],
#  ['Org', [650263, 650264]],
#  ['Org', [650266, 650267, 650267, 650268]],
#  ['LocOrg', [650268]],
#  ['LocOrg', [650409]],
#  ['LocOrg', [650434]],
#  ['LocOrg', [650436]],
#  ['LocOrg', [650438]],
#  ['Org', [165715, 165716, 165717, 165718, 165719, 165719]],
#  ['Org', [165720]],
#  ['Org', [165722]],
#  ['Org', [165754]],
#  ['Person', [165755, 165756]],
#  ['Location', [165774]],
#  ['Org', [165775]],
#  ['Org', [165799]],
#  ['LocOrg', [165854]],
#  ['Org', [165868]],
#  ['Location', [168483]],
#  ['Location', [168485]],
#  ['LocOrg', [168515]],
#  ['LocOrg', [168526]],
#  ['LocOrg', [168564]],
#  ['LocOrg', [168572]],
#  ['LocOrg', [168578]],
#  ['Org', [168550, 168551, 168552]],
#  ['Person', [168552]],
#  ['LocOrg', [169340]],
#  ['Org', [169337, 169337, 169338, 169339, 169340]],
#  ['LocOrg', [169419, 169420]],
#  ['Location', [169427]],
#  ['Location', [169452]],
#  ['Org', [169460, 169461, 169462, 169463]],
#  ['LocOrg', [169474]],
#  ['LocOrg', [181228]],
#  ['LocOrg', [181230]],
#  ['Org', [181232, 181233, 181233]],
#  ['LocOrg', [181252]],
#  ['LocOrg', [181261, 181262]],
#  ['Org', [181264]],
#  ['LocOrg', [181266]],
#  ['LocOrg', [181268]],
#  ['LocOrg', [181277]],
#  ['LocOrg', [181279]],
#  ['LocOrg', [181298]],
#  ['Person', [181299, 181300, 181301]],
#  ['LocOrg', [181307]],
#  ['Person', [181311, 181312]],
#  ['LocOrg', [181319]],
#  ['LocOrg', [181321]],
#  ['Person', [181363, 181364]],
#  ['Location', [181366]],
#  ['LocOrg', [181373]],
#  ['Person', [181383, 181384]],
#  ['Location', [181392]],
#  ['LocOrg', [181399]],
#  ['Person', [181418, 181419]],
#  ['LocOrg', [181454]],
#  ['Org', [181452, 181453, 181454]],
#  ['LocOrg', [181473]],
#  ['Location', [181484]],
#  ['LocOrg', [181493, 181494, 181494, 181495]],
#  ['LocOrg', [181515]],
#  ['Person', [181516, 181517]],
#  ['LocOrg', [181520]],
#  ['Person', [181521, 181522]],
#  ['Org', [181528, 181529, 181531, 181532]],
#  ['Org', [181531, 181532]],
#  ['Org', [181535, 181535, 181536, 181537]],
#  ['LocOrg', [181541]],
#  ['Person', [181542, 181543]],
#  ['LocOrg', [181551]],
#  ['Person', [181572, 181573]],
#  ['Person', [181584, 181585]],
#  ['Person', [181590, 181591]],
#  ['Org', [181595, 181596]],
#  ['LocOrg', [181608]],
#  ['LocOrg', [181613]],
#  ['LocOrg', [181596]],
#  ['Person', [181625, 181626]],
#  ['LocOrg', [181639]],
#  ['Location', [181651]],
#  ['LocOrg', [181679]],
#  ['Org', [181678, 181679]],
#  ['Person', [181686]],
#  ['Person', [181692, 181693]],
#  ['LocOrg', [181742]],
#  ['Org', [181741, 181742]],
#  ['LocOrg', [181756]],
#  ['Person', [181768, 181769]],
#  ['LocOrg', [181774, 181775, 181775]],
#  ['Location', [181792]],
#  ['LocOrg', [181793]],
#  ['LocOrg', [181804, 181805, 181805]],
#  ['Location', [181809]],
#  ['Location', [181821]],
#  ['LocOrg', [181837]],
#  ['LocOrg', [181850]],
#  ['Org', [181849, 181850]],
#  ['LocOrg', [181853]],
#  ['LocOrg', [181857]],
#  ['Org', [181864]],
#  ['Person', [181868, 181869]],
#  ['LocOrg', [181871]],
#  ['LocOrg', [181873]],
#  ['LocOrg', [181883]],
#  ['Person', [181884, 181885]],
#  ['LocOrg', [181888]],
#  ['Person', [181889, 181890]],
#  ['LocOrg', [181917]],
#  ['Org', [181916, 181917]],
#  ['LocOrg', [181923]],
#  ['Person', [181931, 181932]],
#  ['LocOrg', [181937, 181938, 181938]],
#  ['LocOrg', [181947]],
#  ['Org', [181946, 181947]],
#  ['Location', [181994]],
#  ['LocOrg', [181997]],
#  ['LocOrg', [182008]],
#  ['Org', [182007, 182008]],
#  ['Person', [182022, 182023]],
#  ['Location', [182043]],
#  ['Location', [182069]],
#  ['LocOrg', [182072]],
#  ['LocOrg', [182099]],
#  ['Org', [182098, 182099]],
#  ['LocOrg', [182111]],
#  ['Person', [182116, 182117]],
#  ['Location', [182119]],
#  ['LocOrg', [182125]],
#  ['LocOrg', [182131]],
#  ['LocOrg', [182134]],
#  ['LocOrg', [182138, 182139, 182139, 182140, 182141, 182141]],
#  ['LocOrg', [182140, 182141, 182141]],
#  ['Location', [182151]],
#  ['LocOrg', [182168, 182169, 182169]],
#  ['Person', [182174, 182175]],
#  ['Org', [182176, 182177, 182179, 182180]],
#  ['Org', [182179, 182180]],
#  ['LocOrg', [182180]],
#  ['Location', [182195]],
#  ['LocOrg', [182200]],
#  ['Location', [182216]],
#  ['Person', [182236, 182237]],
#  ['LocOrg', [182243]],
#  ['Person', [182429, 182430]],
#  ['Location', [182441]],
#  ['Person', [182447, 182448]],
#  ['Location', [182453]],
#  ['Location', [182455, 182456]],
#  ['Person', [182483, 182484]],
#  ['Org', [182490]],
#  ['Person', [182496]],
#  ['Org', [182522, 182523]],
#  ['Person', [182551, 182552]],
#  ['Org', [182574]],
#  ['Person', [182597, 182598]],
#  ['Person', [182600, 182601]],
#  ['Person', [182617]],
#  ['Person', [182632, 182633, 182634]],
#  ['Org', [182636, 182637]],
#  ['Person', [182639, 182640]],
#  ['Org', [182647, 182648, 182649]],
#  ['Person', [182668, 182669]],
#  ['Org', [182674, 182675, 182676]],
#  ['Location', [182767, 182768]],
#  ['Location', [182811]],
#  ['Location', [182815]],
#  ['Location', [182841]],
#  ['Person', [182847, 182848]],
#  ['Location', [182856, 182857, 182857]],
#  ['Org', [182862]],
#  ['Person', [182864, 182865]],
#  ['Location', [182932, 182933, 182933]],
#  ['Location', [182962, 182963]],
#  ['Person', [182981]],
#  ['Person', [182991]],
#  ['Person', [182996]],
#  ['LocOrg', [183032]],
#  ['Org', [183031, 183032]],
#  ['Org', [183035, 183035, 183036, 183037, 183038]],
#  ['Person', [183039, 183040]],
#  ['Org', [183050]],
#  ['Location', [183053, 183054]],
#  ['Org', [183058, 183060]],
#  ['Person', [183068, 183069]],
#  ['Person', [183083, 183084]],
#  ['Person', [183099, 183100]],
#  ['Person', [183103, 183104]],
#  ['Person', [183128]],
#  ['Person', [183130, 183132]],
#  ['Org', [183141, 183143]],
#  ['Person', [183145, 183146]],
#  ['Person', [183167]],
#  ['Org', [183173]],
#  ['Person', [183229]],
#  ['Org', [183233]],
#  ['Person', [183240, 183241]],
#  ['Person', [183249, 183250]],
#  ['Org', [183258, 183259, 183259]],
#  ['Org', [183261, 183262, 183262, 183263, 183263, 183264, 183265, 183266]],
#  ['Person', [183276]],
#  ['Person', [183290, 183291]],
#  ['Org', [183301, 183303]],
#  ['Person', [183310]],
#  ['Org', [183328]],
#  ['LocOrg', [183339]],
#  ['Org', [183338, 183339]],
#  ['Person', [183341, 183342]],
#  ['Person', [183363]],
#  ['Person', [183371]],
#  ['Person', [183419, 183420]],
#  ['Person', [183423, 183424]],
#  ['Org',
#   [183427,
#    183427,
#    183428,
#    183428,
#    183428,
#    183429,
#    183430,
#    183431,
#    183432,
#    183433]],
#  ['LocOrg', [183444]],
#  ['Org', [183431]],
#  ['LocOrg', [183476]],
#  ['Person', [183538, 183539]],
#  ['Location', [183553, 183554]],
#  ['Org', [183560, 183561, 183562, 183562]],
#  ['Org', [183591]],
#  ['Person', [183622, 183623]],
#  ['Person', [183627, 183628]],
#  ['Org', [183676, 183677, 183678, 183678]],
#  ['Person', [183694]],
#  ['Person', [183696, 183697]],
#  ['Org', [183708]],
#  ['Person', [183726]],
#  ['Person', [183750]],
#  ['Org', [183775, 183777, 183778]],
#  ['Person', [183785]],
#  ['Person', [183814, 183815]],
#  ['Person', [183855, 183856]],
#  ['LocOrg', [183863]],
#  ['Org', [186414, 186414, 186415, 186416]],
#  ['Org', [186418]],
#  ['Org', [186421, 186422, 186423, 186424]],
#  ['Org', [186409]],
#  ['Location', [186463]],
#  ['Location', [186465]],
#  ['Location', [186467]],
#  ['Location', [186470]],
#  ['Org', [186502]],
#  ['Location', [186535]],
#  ['Location', [186540]],
#  ['Person', [186551, 186552]],
#  ['Person', [186554, 186555]],
#  ['Org', [186593]],
#  ['Person', [186594, 186595]],
#  ['Person', [186597, 186598]],
#  ['LocOrg', [186602]],
#  ['Org', [186588]],
#  ['Org', [186608]],
#  ['Org', [186631]],
#  ['Location', [186687]],
#  ['Location', [186690]],
#  ['Location', [186693]],
#  ['Location', [186708]],
#  ['Location', [186728]],
#  ['Org', [186738, 186739]],
#  ['Person', [186740, 186741]],
#  ['Person', [186743, 186744]],
#  ['Org', [186749]],
#  ['Person', [186750, 186751]],
#  ['Person', [186753, 186754]],
#  ['Location', [186770]],
#  ['Location', [186772]],
#  ['LocOrg', [186784]],
#  ['LocOrg', [186812]],
#  ['Person', [186829, 186830]],
#  ['Person', [186832, 186833]],
#  ['Location', [186849, 186850]],
#  ['Org', [186852, 186853]],
#  ['LocOrg', [186853]],
#  ['Org', [186819]],
#  ['Org', [186839]],
#  ['LocOrg', [186862]],
#  ['LocOrg', [186873]],
#  ['LocOrg', [186877]],
#  ['LocOrg', [186913]],
#  ['Org', [186912, 186913]],
#  ['LocOrg', [186934]],
#  ['LocOrg', [186948]],
#  ['LocOrg', [186958]],
#  ['LocOrg', [186967, 186968]],
#  ['LocOrg', [186970]],
#  ['LocOrg', [186973]],
#  ['Location', [186988]],
#  ['Org', [186989, 186989, 186990, 186991]],
#  ['Location', [186996]],
#  ['Person', [187007, 187008]],
#  ['Org', [187011, 187012, 187012, 187014, 187015]],
#  ['Person', [187036, 187037]],
#  ['Org', [187040, 187041, 187041, 187043, 187044]],
#  ['LocOrg', [187065]],
#  ['Person', [188860, 188861]],
#  ['Location', [188869]],
#  ['Person', [188887, 188888]],
#  ['Person', [188898, 188899]],
#  ['Person', [188909, 188910]],
#  ['Person', [188920, 188921]],
#  ['Person', [188931, 188932]],
#  ['Person', [188942, 188943]],
#  ['Person', [188953, 188954, 188955, 188956]],
#  ['Location', [188975]],
#  ['Org', [188969, 188969, 188970, 188971, 188972, 188973, 188974, 188975]],
#  ['Location', [188979]],
#  ['Org', [188997]],
#  ['LocOrg', [189020]],
#  ['Person', [189021, 189022]],
#  ['Person', [189034, 189035]],
#  ['Location', [189049]],
#  ['Org', [189085, 189086]],
#  ['Person', [189114]],
#  ['LocOrg', [189128]],
#  ['Location', [189086]],
#  ['Org', [189133, 189134]],
#  ['Org', [189138]],
#  ['Person', [189141, 189142]],
#  ['LocOrg', [189164]],
#  ['Org', [189163, 189164]],
#  ['Person', [189170, 189171]],
#  ['Location', [189134]],
#  ['LocOrg', [189139]],
#  ['Org', [189196]],
#  ['LocOrg', [189204]],
#  ['Org', [189206, 189207, 189207]],
#  ['Person', [189221, 189222]],
#  ['Org', [189219, 189220]],
#  ['Org', [189231]],
#  ['LocOrg', [189235]],
#  ['Person', [189256, 189257]],
#  ['LocOrg', [189261]],
#  ['LocOrg', [189281]],
#  ['Location', [189285]],
#  ['Location', [189287]],
#  ['Person', [189290, 189291]],
#  ['Org', [189296]],
#  ['Location', [189302]],
#  ['LocOrg', [189309]],
#  ['Org', [189316]],
#  ['LocOrg', [189319]],
#  ['LocOrg', [189321]],
#  ['LocOrg', [189337]],
#  ['Person', [189348]],
#  ['Location', [189399]],
#  ['LocOrg', [189404, 189405, 189405]],
#  ['Location', [189407]],
#  ['Location', [189424]],
#  ['Person', [189430, 189431]],
#  ['Person', [189433, 189434]],
#  ['Location', [189442]],
#  ['Location', [189445]],
#  ['LocOrg', [189451]],
#  ['Person', [189458]],
#  ['Org', [189465, 189466]],
#  ['Location', [189466]],
#  ['Location', [189469]],
#  ['Location', [189471]],
#  ['Location', [189483]],
#  ['LocOrg', [826611]],
#  ['LocOrg', [826624]],
#  ['LocOrg', [826614]],
#  ['Org', [826627, 826628, 826629, 826629, 826630]],
#  ['LocOrg', [826630]],
#  ['Person', [826631, 826632, 826633]],
#  ['LocOrg', [826658]],
#  ['Person', [826674, 826675, 826676]],
#  ['LocOrg', [826677]],
#  ['LocOrg', [826705]],
#  ['LocOrg', [826712]],
#  ['LocOrg', [826718]],
#  ['LocOrg', [826732]],
#  ['LocOrg', [826740]],
#  ['Location', [826753, 826754]],
#  ['Person', [826770, 826771, 826772]],
#  ['Org', [826773]],
#  ['Person', [826779]],
#  ['Location', [826785]],
#  ['LocOrg', [826796, 826797]],
#  ['Person', [826807]],
#  ['Person', [826828, 826829, 826830]],
#  ['Person', [826831, 826832, 826833]],
#  ['Person', [197708, 197709]],
#  ['LocOrg', [197714]],
#  ['Person', [197719, 197720]],
#  ['Org', [197737, 197739, 197740]],
#  ['LocOrg', [197740]],
#  ['Person', [197750]],
#  ['Person', [197769]],
#  ['Person', [197771]],
#  ['Person', [197788]],
#  ['Org', [197796, 197797, 197797, 197798, 197799, 197800]],
#  ['LocOrg', [197798]],
#  ['LocOrg', [197800]],
#  ['Person', [197808]],
#  ['Org', [201238, 201238, 201239, 201240, 201241, 201242]],
#  ['Location', [201246]],
#  ['Location', [201249, 201250]],
#  ['Location', [201252]],
#  ['Location', [201274]],
#  ['Org', [201288]],
#  ['Location', [201293, 201294]],
#  ['Person', [201326]],
#  ['Org', [201333]],
#  ['Org', [201330, 201330, 201331, 201332, 201333]],
#  ['Org', [201370]],
#  ['Person', [201379]],
#  ['Org', [201392]],
#  ['Location', [201413]],
#  ['Location', [201420, 201421]],
#  ['Org', [201425]],
#  ['Location', [201430]],
#  ['Location', [201445]],
#  ['Person', [201447]],
#  ['Org', [201449]],
#  ['Org', [201454]],
#  ['LocOrg', [201462]],
#  ['Org', [201459, 201460, 201461, 201461, 201462]],
#  ['Org', [201464, 201464, 201465]],
#  ['Org', [201467, 201468]],
#  ['Person', [201471]],
#  ['Org', [201477]],
#  ['Org', [201484, 201485]],
#  ['Location', [201487]],
#  ['Person', [201503]],
#  ['Org', [201508]],
#  ['Org', [201511]],
#  ['Person', [201531]],
#  ['Location', [201560]],
#  ['Org', [201656]],
#  ['Location', [201743]],
#  ['Person', [202985, 202986]],
#  ['Person', [202991]],
#  ['Person', [203021, 203022]],
#  ['Org', [203036, 203038]],
#  ['Person', [203045, 203046]],
#  ['Org', [203056, 203057, 203057, 203058, 203059]],
#  ['Person', [203060, 203061]],
#  ['Org', [203064, 203065, 203065, 203066]],
#  ['LocOrg', [203066]],
#  ['Person', [203067, 203068]],
#  ['Org', [203072, 203073]],
#  ['Person', [203084]],
#  ['Person', [203118]],
#  ['Location', [203120]],
#  ['Person', [203130, 203131]],
#  ['Person', [203137, 203138]],
#  ['Person', [203141, 203142]],
#  ['LocOrg', [203145, 203146, 203146]],
#  ['Location', [203151]],
#  ['Person', [203166, 203167]],
#  ['Org', [203170, 203171, 203171, 203172]],
#  ['LocOrg', [203172]],
#  ['Org', [203177]],
#  ['Person', [203184, 203185]],
#  ['Person', [203202, 203203]],
#  ['Location', [209069]],
#  ['Location', [209123]],
#  ['LocOrg', [209127]],
#  ['Person', [209128, 209129]],
#  ['LocOrg', [209158]],
#  ['Person', [209159, 209160]],
#  ['Location', [209200, 209201, 209201]],
#  ['Location', [209229]],
#  ['Person', [209258, 209260]],
#  ['Location', [209293]],
#  ['Location', [209303]],
#  ['Location', [209305]],
#  ['Location', [209348]],
#  ['LocOrg', [209416]],
#  ['LocOrg', [209418]],
#  ['LocOrg', [209755]],
#  ['LocOrg', [209757]],
#  ['Location', [209793]],
#  ['Location', [209980]],
#  ['Location', [210019, 210020]],
#  ['Location', [210033, 210034]],
#  ['Org', [210040, 210040, 210041, 210042, 210043, 210044]],
#  ['Org', [210041, 210042]],
#  ['LocOrg', [210042]],
#  ['Location', [210044]],
#  ['Org', [210036, 210037]],
#  ['Location', [210059]],
#  ['Org', [210068, 210069, 210069, 210070, 210070, 210071, 210073]],
#  ['Org', [210071, 210073]],
#  ['Location', [210089]],
#  ['Location', [210108, 210109]],
#  ['Location', [210135, 210136]],
#  ['Org', [210138, 210139, 210139, 210140, 210140, 210142]],
#  ['Org', [210142]],
#  ['Person', [210169, 210170]],
#  ['Org', [210175]],
#  ['Location', [210177]],
#  ['Location', [210179]],
#  ['Org', [210174, 210175, 210176, 210177, 210178, 210179]],
#  ['Org', [210184]],
#  ['Org', [210186]],
#  ['Location', [210197]],
#  ['Location', [210216]],
#  ['Org', [210181]],
#  ['Location', [210273]],
#  ['Location', [210274, 210275]],
#  ['Org', [210286]],
#  ['Location', [210289, 210290]],
#  ['Org', [210308]],
#  ['Location', [210323, 210324]],
#  ['Location', [210339, 210341]],
#  ['LocOrg', [210354]],
#  ['LocOrg', [210356]],
#  ['Org', [210365]],
#  ['Org', [210372, 210373, 210373, 210374]],
#  ['LocOrg', [210374]],
#  ['Org', [210369, 210370, 210370]],
#  ['Org', [210388, 210389, 210389, 210389, 210390, 210390]],
#  ['Org', [210416]],
#  ['Org', [210447, 210448, 210448, 210449, 210449, 210449]],
#  ['Org', [210451]],
#  ['Org', [243068, 243070]],
#  ['Org', [243073, 243074, 243074, 243075, 243076, 243076]],
#  ['Org', [243075, 243076, 243076]],
#  ['Org', [243089]],
#  ['Org', [243094]],
#  ['Org', [243097]],
#  ['Org', [243107]],
#  ['Org', [243111]],
#  ['Org', [243123]],
#  ['Org', [243155, 243156]],
#  ['Org', [243156]],
#  ['Org', [243171]],
#  ['Org', [243182]],
#  ['Org', [243209]],
#  ['Org', [243231]],
#  ['Org', [243235]],
#  ['Location', [256951]],
#  ['Org', [257020, 257020, 257021, 257022]],
#  ['Person', [257022]],
#  ['Location', [257024]],
#  ['LocOrg', [257076]],
#  ['Org', [265503]],
#  ['Org', [265517]],
#  ['Org', [265536]],
#  ['Org', [265535, 265536]],
#  ['LocOrg', [265568]],
#  ['Org', [265567, 265568]],
#  ['Org', [265587]],
#  ['Org', [265629]],
#  ['Person', [265630, 265631]],
#  ['LocOrg', [267700]],
#  ['Org', [267699, 267700]],
#  ['Org', [267715, 267715, 267716]],
#  ['Org', [267720, 267720, 267721]],
#  ['Org', [267724]],
#  ['Person', [267727, 267728]],
#  ['Person', [267737, 267738]],
#  ['Person', [267752]],
#  ['Org', [267758]],
#  ['Org', [267779]],
#  ['Person', [267788]],
#  ['Person', [267790]],
#  ['Person', [267809, 267810]],
#  ['Org', [267880]],
#  ['Person', [267905]],
#  ['Org', [267914, 267915, 267916]],
#  ['Person', [267941, 267942]],
#  ['Org', [267964, 267964, 267965, 267965]],
#  ['Person', [268009, 268010]],
#  ['Org', [268006, 268006, 268007]],
#  ['Org', [268031, 268031, 268031, 268032, 268032, 268033, 268034]],
#  ['Org', [268051]],
#  ['Person', [268062, 268063]],
#  ['Person', [268074, 268075]],
#  ['Org', [268090, 268090, 268091, 268091, 268091, 268092]],
#  ['Location', [268094, 268096]],
#  ['Location',
#   [268099, 268099, 268100, 268101, 268102, 268103, 268104, 268105]],
#  ['LocOrg', [268102]],
#  ['Person', [268103, 268104, 268105]],
#  ['Location', [268115]],
#  ['Org', [268137]],
#  ['Org', [268135, 268136, 268136, 268137]],
#  ['Person', [268154, 268155]],
#  ['LocOrg', [268157, 268158, 268158]],
#  ['Org', [268165]],
#  ['Org', [268164, 268165]],
#  ['Person', [268171, 268172]],
#  ['Location', [268199]],
#  ['Person', [268204, 268205]],
#  ['Org', [268213, 268214, 268214]],
#  ['Org', [268248, 268248, 268249, 268249, 268249, 268250]],
#  ['Person', [268269, 268270]],
#  ['Person', [268282, 268283]],
#  ['Person', [268293, 268294]],
#  ['Person', [268361, 268362, 268363]],
#  ['Person', [268376, 268377]],
#  ['Location', [268379]],
#  ['Person', [268383, 268384]],
#  ['LocOrg', [268382]],
#  ['LocOrg', [268397]],
#  ['Person', [268401]],
#  ['Person', [268432]],
#  ['Person', [268433, 268434]],
#  ['LocOrg', [268444, 268445, 268445]],
#  ['Person', [268446, 268447]],
#  ['Person', [268453, 268454]],
#  ['LocOrg', [268486]],
#  ['Person', [268493, 268494]],
#  ['LocOrg', [268507]],
#  ['Location', [268578]],
#  ['Location', [268588]],
#  ['Location', [268606]],
#  ['Location', [268637, 268638, 268638]],
#  ['Location', [268646, 268646, 268647]],
#  ['Person', [268670]],
#  ['Org', [268696, 268697, 268698, 268699]],
#  ['LocOrg', [268699]],
#  ['Person', [268714, 268715]],
#  ['Location', [268721]],
#  ['Person', [268729]],
#  ['LocOrg', [269978]],
#  ['Location', [269994]],
#  ['LocOrg', [269997]],
#  ['LocOrg', [270030]],
#  ['Person', [270031, 270032]],
#  ['Org', [270044]],
#  ['LocOrg', [270065]],
#  ['Org', [270067, 270068]],
#  ['Person', [270096]],
#  ['Org', [270091]],
#  ['LocOrg', [270108]],
#  ['Person', [270220]],
#  ['LocOrg', [270231]],
#  ['Org', [271867, 271869]],
#  ['Org', [271892]],
#  ['Location', [271912]],
#  ['Org', [271921, 271922, 271923, 271923]],
#  ['Org', [271996, 271997, 271998, 272000]],
#  ['Location', [271981]],
#  ['Org',
#   [271984, 271985, 271985, 271986, 271986, 271986, 271987, 271988, 271989]],
#  ['Person', [272053, 272054]],
#  ['Org', [272060, 272061, 272061, 272062]],
#  ['Person', [272069, 272070]],
#  ['Location', [272064]],
#  ['Location', [272066]],
#  ['Org', [272073, 272074, 272075]],
#  ['Location', [272077]],
#  ['Person', [272080, 272081]],
#  ['Person', [272160, 272161]],
#  ['Org', [272154, 272154, 272155, 272156, 272157, 272158]],
#  ['Org', [272158]],
#  ['Org', [272165, 272165, 272166, 272167, 272168, 272169, 272170]],
#  ['Org', [272170]],
#  ['Person', [272150, 272151]],
#  ['Person', [272142, 272143]],
#  ['Person', [272134, 272135]],
#  ['Person', [272116, 272117]],
#  ['Location', [272119]],
#  ['Org', [272138, 272139, 272140, 272140]],
#  ['Org', [272146, 272147, 272147, 272148]],
#  ['Person', [272098, 272099]],
#  ['Location', [272095]],
#  ['Org', [272107, 272108, 272108, 272110]],
#  ['Org', [272113, 272113, 272114, 272115, 272116, 272117]],
#  ['Org', [272086, 272087, 272087, 272089, 272090, 272091, 272092]],
#  ['Org', [272243, 272243, 272244]],
#  ['LocOrg', [272248]],
#  ['Person', [272260, 272261]],
#  ['Location', [272263]],
#  ['LocOrg', [272266]],
#  ['Person', [272269, 272270]],
#  ['Org', [272284]],
#  ['Org', [272289, 272290, 272291, 272292]],
#  ['LocOrg', [272290, 272290, 272291, 272292]],
#  ['Location', [272300, 272301, 272301]],
#  ['Person', [272310, 272311]],
#  ['LocOrg', [272322]],
#  ['Location', [272334]],
#  ['Location', [272332, 272333, 272333, 272334, 272334]],
#  ['Person', [272343]],
#  ['LocOrg', [272356]],
#  ['LocOrg', [272358]],
#  ['Person', [272359, 272360]],
#  ['Org', [272364, 272364, 272365, 272365, 272367, 272368, 272368]],
#  ['LocOrg', [272365]],
#  ['Org', [272367, 272368, 272368]],
#  ['Org', [272338]],
#  ['LocOrg', [272268]],
#  ['Person', [272376, 272377]],
#  ['Location', [272379]],
#  ['LocOrg', [272381]],
#  ['Person', [272382, 272384]],
#  ['Org', [272397, 272398, 272398]],
#  ['Person', [272399, 272400]],
#  ['LocOrg', [272419]],
#  ['Org', [272427, 272428, 272429, 272429]],
#  ['Location', [272433]],
#  ['LocOrg', [272436]],
#  ['Org', [272435, 272436]],
#  ['Location', [272450, 272451, 272451, 272452, 272452, 272452]],
#  ['LocOrg', [272456]],
#  ['LocOrg', [272459]],
#  ['Location', [272468, 272469, 272469]],
#  ['Location', [272475, 272476, 272476]],
#  ['LocOrg', [272480, 272481]],
#  ['LocOrg', [272513]],
#  ['Person', [272514, 272515]],
#  ['LocOrg', [272524]],
#  ['Person', [272525, 272526]],
#  ['Location', [272545]],
#  ['LocOrg', [272549]],
#  ['Person', [272550, 272551]],
#  ['Location', [273042, 273043]],
#  ['Location', [273045]],
#  ['Location', [273065]],
#  ['Project', [273077, 273079, 273080]],
#  ['Org', [273073, 273074, 273074, 273075]],
#  ['Org', [274958, 274959, 274959, 274961, 274962]],
#  ['Person', [274967, 274968]],
#  ['Org', [274971, 274972, 274973, 274973, 274974]],
#  ['Person', [274977, 274978]],
#  ['Org', [274981, 274982, 274983, 274983, 274984]],
#  ['Org', [275024]],
#  ['Org', [275027]],
#  ['Org', [275032]],
#  ['Org', [275037, 275038]],
#  ['Org', [275040, 275041]],
#  ['Person', [275054]],
#  ['LocOrg', [275057]],
#  ['Person', [275069, 275070]],
#  ['Person', [275072, 275073]],
#  ['Person', [275082, 275083]],
#  ['LocOrg', [275087]],
#  ['LocOrg', [275095]],
#  ['Org', [275094, 275095]],
#  ['Person', [275099]],
#  ['Org', [275113]],
#  ['Person', [275115, 275116]],
#  ['Org', [275138]],
#  ['Person', [275171, 275172]],
#  ['Person', [275218, 275219]],
#  ['Org', [275259]],
#  ['Person', [275309, 275310]],
#  ['Org', [275321]],
#  ['Person', [275322, 275323]],
#  ['Org', [275326, 275327]],
#  ['LocOrg', [275327]],
#  ['Person', [275328, 275329]],
#  ['Location', [275339, 275340, 275340, 275340, 275341, 275341]],
#  ['Person', [275348, 275349]],
#  ['Location', [275354, 275355, 275355]],
#  ['Person', [282136, 282137]],
#  ['Org', [282140, 282141, 282141]],
#  ['Location', [282152]],
#  ['Org', [282155]],
#  ['Person', [282164]],
#  ['Org', [282168]],
#  ['Org', [282183, 282184, 282184]],
#  ['Org', [282187]],
#  ['Org', [282189]],
#  ['Location', [282185, 282185, 282186, 282187, 282188, 282189]],
#  ['Person', [282191]],
#  ['Location', [282216]],
#  ['Org', [282241, 282242, 282242]],
#  ['Org', [282251, 282252, 282253, 282253]],
#  ['Person', [282259]],
#  ['Person', [282271]],
#  ['Location', [282282]],
#  ['Org', [282289, 282289, 282290, 282291, 282292, 282292]],
#  ['Org', [282291, 282292, 282292]],
#  ['Person', [282296]],
#  ['Person', [282299]],
#  ['Org', [282318]],
#  ['LocOrg', [280728]],
#  ['Org', [280738, 280738, 280739, 280739, 280740, 280741]],
#  ['Org', [280739]],
#  ['Location', [280743]],
#  ['Org', [280751, 280752, 280752, 280752, 280753, 280753, 280754, 280754]],
#  ['Person', [280755, 280756]],
#  ['Person', [280758, 280759]],
#  ['LocOrg', [280764]],
#  ['Org', [280763, 280764]],
#  ['Person', [280776]],
#  ['LocOrg', [280783]],
#  ['Org', [280782, 280783]],
#  ['Location', [280797]],
#  ['Org', [280796, 280797]],
#  ['Org', [280818]],
#  ['Org', [280856]],
#  ['LocOrg', [280869]],
#  ['Org', [280868, 280869]],
#  ['Org', [280891, 280892]],
#  ['Org', [280894, 280895]],
#  ['LocOrg', [280898]],
#  ['Org', [280929, 280930]],
#  ['Location', [280930]],
#  ['Location', [280933]],
#  ['Location', [280940]],
#  ['Location', [280942]],
#  ['LocOrg', [280948]],
#  ['Org', [280989]],
#  ['Location', [280992]],
#  ['LocOrg', [280994]],
#  ['Person', [280997, 280998]],
#  ['Person', [281000, 281001]],
#  ['Location', [281009]],
#  ['Org', [281020]],
#  ['Location', [281025]],
#  ['Org', [281293]],
#  ['Org', [281296, 281298]],
#  ['Org', [281308, 281309]],
#  ['Org', [281313, 281314, 281315]],
#  ['Org', [281329]],
#  ['Org', [281344]],
#  ['Org', [281363]],
#  ['Org', [281375]],
#  ['Org', [281417]],
#  ['Org', [281477, 281478]],
#  ['Org', [281486]],
#  ['Org', [281497]],
#  ['Location', [282908, 282909, 282909]],
#  ['Location', [282910, 282911]],
#  ['Org', [282921]],
#  ['Person', [282922, 282923]],
#  ['LocOrg', [282929, 282930, 282930]],
#  ['Person', [282931, 282932, 282933]],
#  ['LocOrg', [282936]],
#  ['Org', [282935, 282936]],
#  ['Org', [282941]],
#  ['Person', [282964]],
#  ['LocOrg', [282969]],
#  ['LocOrg', [282981]],
#  ['Location', [282983, 282984, 282984, 282985, 282985, 282985]],
#  ['Person', [282986, 282987]],
#  ['Org', [282990, 282991]],
#  ['LocOrg', [282991]],
#  ['Org', [282994, 282994, 282995, 282996, 282996]],
#  ['LocOrg', [282996]],
#  ['Person', [282998, 282999]],
#  ['Person', [283046, 283046, 283047, 283048, 283048, 283049]],
#  ['Person', [283066, 283067]],
#  ['LocOrg', [283083]],
#  ['Org', [283106, 283107]],
#  ['Person', [283107]],
#  ['Location', [283116]],
#  ['Person', [283141]],
#  ['LocOrg', [291178]],
#  ['Person', [291179, 291180]],
#  ['Org', [291184, 291185, 291185]],
#  ['Location', [291187]],
#  ['LocOrg', [291200]],
#  ['Location', [291229]],
#  ['Location', [291237]],
#  ['Location', [291239, 291240]],
#  ['Person', [291205]],
#  ['Person', [291242]],
#  ['LocOrg', [291249]],
#  ['Person', [291250, 291251]],
#  ['LocOrg', [291270, 291271]],
#  ['Person', [291290]],
#  ['LocOrg', [291308]],
#  ['LocOrg', [291313]],
#  ['Person', [291314, 291315]],
#  ['Location', [291319]],
#  ['Location', [291341]],
#  ['Org', [291338, 291338, 291339, 291339, 291340, 291341]],
#  ['Org', [291362, 291364]],
#  ['Org', [291417, 291418, 291419]],
#  ['LocOrg', [291419]],
#  ['Person', [291420, 291421]],
#  ['Person', [291442, 291443]],
#  ['Org', [291452, 291453, 291453]],
#  ['Location', [291468]],
#  ['Person', [291483, 291484]],
#  ['Org', [291493, 291494, 291494]],
#  ['Org', [291515, 291516]],
#  ['LocOrg', [291516]],
#  ['LocOrg', [291522]],
#  ['Location', [291526]],
#  ['Org', [292237, 292238, 292238, 292239]],
#  ['Person', [292240, 292241]],
#  ['Org', [292244, 292245, 292246]],
#  ['Person', [292247, 292248]],
#  ['Org', [292251]],
#  ['Person', [292252, 292253]],
#  ['Org', [292278, 292279, 292279]],
#  ['Org', [292281, 292282]],
#  ['Person', [292316, 292317]],
#  ['Org', [292330, 292331, 292332]],
#  ['Person', [292340, 292341]],
#  ['Person', [292351]],
#  ['Person', [292363]],
#  ['Location', [292375]],
#  ['Person', [292396]],
#  ['LocOrg', [292403]],
#  ['Org',
#   [292443, 292443, 292444, 292444, 292444, 292444, 292445, 292445, 292446]],
#  ...]

# %%
for ne_tokens in all_ne:
    ne = ne_tokens[0]
    token = ne_tokens[1]
    for i in range(len(token)):
        if token[i] in factrueval_dev_tokens.keys():
            if len(token) == 1:
                factrueval_dev_tokens[token[i]].append("S-" + ne)
            elif (i == 0 and token[i + 1] - token[i] > 1) or (i == len(token) - 1 and token[i] - token[i - 1] > 1) or (token[i] - token[i - 1] > 1 and token[i + 1] - token[i] > 1):
                factrueval_dev_tokens[token[i]].append("S-" + ne)
            elif (i == 0  and token[i + 1] - token[i] == 1) or (i != len(token) - 1 and token[i] - token[i - 1] > 1 and token[i + 1] - token[i] == 1):
                factrueval_dev_tokens[token[i]].append("B-" + ne)
            elif (i == len(token) - 1 and token[i] - token[i - 1] == 1) or (i != 0 and token[i] - token[i - 1] == 1 and token[i + 1] - token[i] > 1):
                factrueval_dev_tokens[token[i]].append("E-" + ne)
            else: 
                factrueval_dev_tokens[token[i]].append("I-" + ne)

# %%
factrueval_dev_tokens
# Out:
# {143783: ['0', '1', 'В'],
#  143784: ['2', '11', 'понедельник'],
#  143785: ['14', '2', '28'],
#  143786: ['17', '4', 'июня'],
#  143787: ['22', '1', 'у'],
#  143788: ['24', '6', 'здания'],
#  143789: ['31', '5', 'мэрии', 'B-Org'],
#  143790: ['37', '6', 'Москвы', 'E-Org', 'S-LocOrg'],
#  143791: ['44', '2', 'на'],
#  143792: ['47', '8', 'Тверской', 'B-Location'],
#  143793: ['56', '7', 'площади', 'E-Location'],
#  143794: ['64', '10', 'состоялась'],
#  143795: ['75', '9', 'очередная'],
#  143796: ['85', '19', 'несанкционированная'],
#  143797: ['105', '5', 'акция'],
#  143798: ['111', '8', 'протеста'],
#  143799: ['120', '1', '«'],
#  143800: ['121', '4', 'День'],
#  143801: ['126', '5', 'гнева'],
#  143802: ['131', '1', '»'],
#  143803: ['132', '1', ','],
#  143804: ['134', '1', 'в'],
#  143805: ['136', '4', 'этот'],
#  143806: ['141', '3', 'раз'],
#  143807: ['145', '12', 'направленная'],
#  143808: ['157', '1', ','],
#  143809: ['159', '7', 'главным'],
#  143810: ['167', '7', 'образом'],
#  143811: ['174', '1', ','],
#  143812: ['176', '6', 'против'],
#  143813: ['183', '8', 'политики'],
#  143814: ['192', '10', 'московских'],
#  143815: ['203', '1', 'и'],
#  143816: ['205', '12', 'подмосковных'],
#  143817: ['218', '7', 'властей'],
#  143818: ['225', '1', '.'],
#  143819: ['227', '5', 'Среди'],
#  143820: ['233', '10', 'требований'],
#  143821: ['243', '1', ','],
#  143822: ['245', '11', 'выдвигаемых'],
#  143823: ['257', '14', 'организаторами'],
#  143824: ['272', '5', 'акции'],
#  143825: ['277', '1', ':'],
#  143826: ['279', '1', '«'],
#  143827: ['280', '11', 'немедленная'],
#  143828: ['292', '8', 'отставка'],
#  143829: ['301', '4', 'мэра'],
#  143830: ['306', '6', 'Москвы', 'S-LocOrg'],
#  143831: ['313', '4', 'Юрия', 'B-Person'],
#  143832: ['318', '7', 'Лужкова', 'E-Person'],
#  143833: ['325', '1', ','],
#  143834: ['327', '13', 'расследование'],
#  143835: ['341', '6', 'итогов'],
#  143836: ['348', '3', 'его'],
#  143837: ['352', '12', 'деятельности'],
#  143838: ['364', '1', '»'],
#  143839: ['365', '1', ','],
#  143840: ['367', '1', '«'],
#  143841: ['368', '5', 'созыв'],
#  143842: ['374', '11', 'московского'],
#  143843: ['386', '13', 'общественного'],
#  143844: ['400', '6', 'форума'],
#  143845: ['407', '3', 'для'],
#  143846: ['411', '10', 'обсуждения'],
#  143847: ['422', '5', 'путей'],
#  143848: ['428', '14', 'реформирования'],
#  143849: ['443', '8', 'основных'],
#  143850: ['452', '4', 'сфер'],
#  143851: ['457', '17', 'жизнедеятельности'],
#  143852: ['475', '1', 'в'],
#  143853: ['477', '6', 'Москве', 'S-Location'],
#  143854: ['483', '1', '»'],
#  143855: ['484', '1', ','],
#  143856: ['486', '1', '«'],
#  143857: ['487', '14', 'восстановление'],
#  143858: ['502', '6', 'прямых'],
#  143859: ['509', '7', 'выборов'],
#  143860: ['517', '4', 'глав'],
#  143861: ['522', '8', 'регионов'],
#  143862: ['531', '6', 'России', 'S-LocOrg'],
#  143863: ['537', '1', '»'],
#  143864: ['538', '1', ','],
#  143865: ['540', '1', '«'],
#  143866: ['541', '7', 'роспуск'],
#  143867: ['549', '12', 'нелегитимной'],
#  143868: ['562', '10', 'Мосгордумы', 'S-Org'],
#  143869: ['572', '1', '»'],
#  143870: ['573', '1', ','],
#  143871: ['575', '8', 'отставка'],
#  143872: ['584', '13', 'подмосковного', 'S-LocOrg'],
#  143873: ['598', '11', 'губернатора'],
#  143874: ['610', '6', 'Бориса', 'B-Person'],
#  143875: ['617', '7', 'Громова', 'E-Person'],
#  143876: ['625', '1', 'и'],
#  143877: ['627', '2', 'др'],
#  143878: ['629', '1', '.'],
#  143879: ['631', '10', 'Участникам'],
#  143880: ['642', '5', 'акции'],
#  143881: ['648', '12', 'предлагалось'],
#  143882: ['661', '8', 'принести'],
#  143883: ['670', '1', 'с'],
#  143884: ['672', '5', 'собой'],
#  143885: ['678', '4', 'лист'],
#  143886: ['683', '6', 'бумаги'],
#  143887: ['690', '3', 'или'],
#  143888: ['694', '5', 'кусок'],
#  143889: ['700', '5', 'ткани'],
#  143890: ['706', '7', 'чёрного'],
#  143891: ['714', '5', 'цвета'],
#  143892: ['719', '1', ','],
#  143893: ['721', '15', 'символизирующие'],
#  143894: ['737', '1', '«'],
#  143895: ['738', '6', 'чёрную'],
#  143896: ['745', '5', 'метку'],
#  143897: ['750', '1', '»'],
#  143898: ['752', '3', 'для'],
#  143899: ['756', '4', 'Юрия', 'B-Person'],
#  143900: ['761', '7', 'Лужкова', 'E-Person'],
#  143901: ['768', '1', '.'],
#  143902: ['771', '6', 'Начало'],
#  143903: ['778', '5', 'акции'],
#  143904: ['784', '4', 'было'],
#  143905: ['789', '8', 'намечено'],
#  143906: ['798', '2', 'на'],
#  143907: ['801', '2', '19'],
#  143908: ['804', '5', 'часов'],
#  143909: ['809', '1', ';'],
#  143910: ['811', '14', 'подчёркивалось'],
#  143911: ['825', '1', ','],
#  143912: ['827', '3', 'что'],
#  143913: ['831', '3', 'она'],
#  143914: ['835', '9', 'состоится'],
#  143915: ['845', '8', 'несмотря'],
#  143916: ['854', '2', 'на'],
#  143917: ['857', '6', 'запрет'],
#  143918: ['864', '7', 'властей'],
#  143919: ['871', '1', '.'],
#  143920: ['873', '10', 'Освещающие'],
#  143921: ['884', '5', 'акцию'],
#  143922: ['890', '8', 'блоггеры'],
#  143923: ['899', '8', 'сообщили'],
#  143924: ['907', '1', ','],
#  143925: ['909', '3', 'что'],
#  143926: ['913', '8', 'автобусы'],
#  143927: ['922', '1', 'с'],
#  143928: ['924', '8', 'милицией'],
#  143929: ['933', '5', 'стали'],
#  143930: ['939', '8', 'занимать'],
#  143931: ['948', '7', 'площадь'],
#  143932: ['956', '1', 'у'],
#  143933: ['958', '9', 'памятника', 'B-Location'],
#  143934: ['968', '4', 'Юрию', 'I-Location', 'B-Person'],
#  143935: ['973', '11', 'Долгорукому', 'E-Location', 'E-Person'],
#  143936: ['985', '3', 'ещё'],
#  143937: ['989', '1', 'с'],
#  143938: ['991', '2', '15'],
#  143939: ['994', '5', 'часов'],
#  143940: ['1000', '3', 'дня'],
#  143941: ['1003', '1', ','],
#  143942: ['1005', '11', 'центральная'],
#  143943: ['1017', '5', 'часть'],
#  143944: ['1023', '7', 'площади'],
#  143945: ['1031', '4', 'была'],
#  143946: ['1036', '9', 'огорожена'],
#  143947: ['1045', '1', '.'],
#  143948: ['1047', '2', 'Ко'],
#  143949: ['1050', '7', 'времени'],
#  143950: ['1058', '6', 'начала'],
#  143951: ['1065', '5', 'акции'],
#  143952: ['1071', '6', 'вокруг'],
#  143953: ['1078', '11', 'огороженной'],
#  143954: ['1090', '10', 'территории'],
#  143955: ['1101', '9', 'собралось'],
#  143956: ['1111', '9', 'множество'],
#  143957: ['1121', '11', 'журналистов'],
#  143958: ['1133', '1', 'и'],
#  143959: ['1135', '8', 'прохожих'],
#  143960: ['1143', '1', ','],
#  143961: ['1145', '2', 'по'],
#  143962: ['1148', '4', 'мере'],
#  143963: ['1153', '8', 'прибытия'],
#  143964: ['1162', '5', 'самих'],
#  143965: ['1168', '10', 'участников'],
#  143966: ['1179', '5', 'акции'],
#  143967: ['1185', '7', 'милиция'],
#  143968: ['1193', '6', 'начала'],
#  143969: ['1200', '10', 'планомерно'],
#  143970: ['1211', '2', 'их'],
#  143971: ['1214', '11', 'задерживать'],
#  143972: ['1226', '1', 'и'],
#  143973: ['1228', '11', 'заталкивать'],
#  143974: ['1240', '1', 'в'],
#  143975: ['1242', '8', 'автобусы'],
#  143976: ['1250', '1', '.'],
#  143977: ['1253', '5', 'Всего'],
#  143978: ['1258', '1', ','],
#  143979: ['1260', '2', 'по'],
#  143980: ['1263', '10', 'сообщениям'],
#  143981: ['1274', '9', 'блоггеров'],
#  143982: ['1284', '1', 'и'],
#  143983: ['1286', '3', 'СМИ'],
#  143984: ['1289', '1', ','],
#  143985: ['1291', '4', 'было'],
#  143986: ['1296', '9', 'задержано'],
#  143987: ['1306', '5', 'более'],
#  143988: ['1312', '2', '30'],
#  143989: ['1315', '7', 'человек'],
#  143990: ['1322', '1', '.'],
#  143991: ['1324', '12', 'Пользователь'],
#  143992: ['1337', '2', 'ЖЖ'],
#  143993: ['1340', '5', 'zyalt', 'S-Person'],
#  143994: ['1346', '8', 'сообщает'],
#  143995: ['1354', '1', ','],
#  143996: ['1356', '3', 'что'],
#  143997: ['1360', '5', 'среди'],
#  143998: ['1366', '11', 'задержанных'],
#  143999: ['1378', '8', 'оказался'],
#  144000: ['1387', '7', 'депутат'],
#  144001: ['1395', '14', 'муниципального', 'B-Org'],
#  144002: ['1410', '8', 'собрания', 'I-Org'],
#  144003: ['1419', '6', 'района', 'I-Org', 'B-LocOrg'],
#  144004: ['1426', '8', 'Отрадное', 'E-Org', 'E-LocOrg'],
#  144005: ['1434', '1', ','],
#  144006: ['1436', '14', 'сопредседатель'],
#  144007: ['1451', '11', 'московского', 'B-Org'],
#  144008: ['1463', '9', 'отделения', 'I-Org', 'I-Org'],
#  144009: ['1473', '8', 'движения', 'S-Org', 'E-Org'],
#  144010: ['1482', '1', '«'],
#  144011: ['1483', '12', 'Солидарность', 'S-Org', 'S-Org'],
#  144012: ['1495', '1', '»'],
#  144013: ['1497', '6', 'Михаил', 'B-Person'],
#  144014: ['1504', '9', 'Вельмакин', 'E-Person'],
#  144015: ['1513', '1', ','],
#  144016: ['1515', '9', 'известный'],
#  144017: ['1525', '13', 'правозащитник'],
#  144018: ['1539', '3', 'Лев', 'B-Person'],
#  144019: ['1543', '9', 'Пономарев', 'E-Person'],
#  144020: ['1552', '1', ','],
#  144021: ['1554', '11', 'координатор'],
#  144022: ['1566', '8', 'движения', 'S-Org'],
#  144023: ['1575', '1', '«'],
#  144024: ['1576', '5', 'Левый', 'B-Org'],
#  144025: ['1582', '5', 'фронт', 'E-Org'],
#  144026: ['1587', '1', '»'],
#  144027: ['1589', '6', 'Сергей', 'B-Person'],
#  144028: ['1596', '8', 'Удальцов', 'E-Person'],
#  144029: ['1604', '1', '.'],
#  144030: ['1607', '14', 'Организаторами'],
#  144031: ['1622', '5', 'акции'],
#  144032: ['1628', '9', 'выступили'],
#  144033: ['1638', '8', 'движение', 'S-Org'],
#  144034: ['1647', '1', '«'],
#  144035: ['1648', '2', 'За', 'B-Org'],
#  144036: ['1651', '5', 'права', 'I-Org'],
#  144037: ['1657', '8', 'человека', 'E-Org'],
#  144038: ['1665', '1', '»'],
#  144039: ['1666', '1', ','],
#  144040: ['1668', '4', 'Союз', 'I-Org', 'I-Org'],
#  144041: ['1673', '15', 'координационных', 'I-Org'],
#  144042: ['1689', '7', 'советов', 'E-Org'],
#  144043: ['1697', '1', '('],
#  144044: ['1698', '3', 'СКС', 'S-Org'],
#  144045: ['1701', '1', ')'],
#  144046: ['1702', '1', ','],
#  144047: ['1704', '8', 'институт', 'S-Org'],
#  144048: ['1713', '1', '«'],
#  144049: ['1714', '12', 'Коллективное', 'B-Org'],
#  144050: ['1727', '8', 'действие', 'E-Org'],
#  144051: ['1735', '1', '»'],
#  144052: ['1736', '1', ','],
#  144053: ['1738', '1', '«'],
#  144054: ['1739', '8', 'Жилищная', 'B-Org'],
#  144055: ['1748', '12', 'солидарность', 'E-Org'],
#  144056: ['1760', '1', '»'],
#  144057: ['1761', '1', ','],
#  144058: ['1763', '8', 'Движение', 'I-Org', 'I-Org'],
#  144059: ['1772', '9', 'общежитий', 'I-Org'],
#  144060: ['1782', '6', 'Москвы', 'E-Org'],
#  144061: ['1788', '1', ','],
#  144062: ['1790', '8', 'Движение', 'I-Org', 'I-Org'],
#  144063: ['1799', '1', 'в', 'I-Org'],
#  144064: ['1801', '6', 'защиту', 'I-Org'],
#  144065: ['1808', '11', 'Химкинского', 'I-Org', 'B-Location'],
#  144066: ['1820', '4', 'леса', 'E-Org', 'I-Location', 'I-Location'],
#  144067: ['1824', '1', ','],
#  144068: ['1826', '8', 'движение', 'S-Org'],
#  144069: ['1835', '1', '«'],
#  144070: ['1836', '10', 'Московский', 'B-Org'],
#  144071: ['1847', '5', 'совет', 'E-Org'],
#  144072: ['1852', '1', '»'],
#  144073: ['1853', '1', ','],
#  144074: ['1855', '1', '«'],
#  144075: ['1856', '15', 'Координационный', 'I-Org', 'I-Org'],
#  144076: ['1872', '5', 'совет', 'I-Org', 'I-Org', 'I-Org'],
#  144077: ['1878', '12', 'пострадавших', 'I-Org'],
#  144078: ['1891', '12', 'соинвесторов', 'E-Org'],
#  144079: ['1903', '1', '»'],
#  144080: ['1904', '1', '.'],
#  149382: ['0', '5', 'Конец'],
#  149383: ['6', '5', 'света'],
#  149384: ['11', '1', ','],
#  149385: ['13', '7', 'который'],
#  149386: ['21', '9', 'предрекал'],
#  149387: ['31', '11', 'проповедник'],
#  149388: ['42', '1', '-'],
#  149389: ['43', '10', 'евангелист'],
#  149390: ['54', '7', 'Герольд', 'B-Person'],
#  149391: ['62', '7', 'Кемпинг', 'E-Person'],
#  149392: ['70', '5', 'утром'],
#  149393: ['76', '1', 'в'],
#  149394: ['78', '5', '06.00'],
#  149395: ['84', '2', 'по'],
#  149396: ['87', '11', 'московскому'],
#  149397: ['99', '7', 'времени'],
#  149398: ['107', '2', '21'],
#  149399: ['110', '3', 'мая'],
#  149400: ['114', '4', '2011'],
#  149401: ['119', '4', 'года'],
#  149402: ['124', '3', 'так'],
#  149403: ['128', '1', 'и'],
#  149404: ['130', '2', 'не'],
#  149405: ['133', '8', 'наступил'],
#  149406: ['141', '1', '.'],
#  149407: ['144', '3', 'Это'],
#  149408: ['148', '6', 'далеко'],
#  149409: ['155', '2', 'не'],
#  149410: ['158', '6', 'первое'],
#  149411: ['165', '11', 'несбывшееся'],
#  149412: ['177', '12', 'предсказание'],
#  149413: ['190', '12', 'апокалипсиса'],
#  149414: ['202', '1', '.'],
#  149415: ['204', '8', 'Поначалу'],
#  149416: ['213', '2', 'на'],
#  149417: ['216', '4', 'него'],
#  149418: ['221', '11', 'практически'],
#  149419: ['233', '2', 'не'],
#  149420: ['236', '8', 'обратили'],
#  149421: ['245', '8', 'внимания'],
#  149422: ['253', '1', ','],
#  149423: ['255', '6', 'однако'],
#  149424: ['261', '1', ','],
#  149425: ['263', '1', 'с'],
#  149426: ['265', '12', 'приближением'],
#  149427: ['278', '4', 'этой'],
#  149428: ['283', '4', 'даты'],
#  149429: ['287', '1', ','],
#  149430: ['289', '6', 'немало'],
#  149431: ['296', '3', 'СМИ'],
#  149432: ['300', '1', 'в'],
#  149433: ['302', '7', 'поисках'],
#  149434: ['310', '6', 'сюжета'],
#  149435: ['316', '1', ','],
#  149436: ['318', '15', 'останавливались'],
#  149437: ['334', '2', 'на'],
#  149438: ['337', '4', 'этом'],
#  149439: ['341', '1', ','],
#  149440: ['343', '8', 'создавая'],
#  149441: ['352', '10', 'прекрасную'],
#  149442: ['363', '10', 'бесплатную'],
#  149443: ['374', '11', 'PR-компанию'],
#  149444: ['386', '3', 'для'],
#  149445: ['390', '12', 'горе-пророка'],
#  149446: ['402', '1', '.'],
#  149447: ['404', '6', 'Вполне'],
#  149448: ['411', '8', 'вероятно'],
#  149449: ['419', '1', ','],
#  149450: ['421', '3', 'что'],
#  149451: ['425', '7', 'Герольд', 'B-Person'],
#  149452: ['433', '7', 'Кемпинг', 'E-Person'],
#  149453: ['441', '8', 'объяснит'],
#  149454: ['450', '3', 'это'],
#  149455: ['454', '10', 'какой-либо'],
#  149456: ['465', '11', 'неточностью'],
#  149457: ['477', '1', 'и'],
#  149458: ['479', '9', 'перенесет'],
#  149459: ['489', '10', 'катастрофу'],
#  149460: ['500', '2', 'на'],
#  149461: ['503', '9', 'некоторое'],
#  149462: ['513', '5', 'время'],
#  149463: ['519', '6', 'вперёд'],
#  149464: ['525', '1', ','],
#  149465: ['527', '1', 'и'],
#  149466: ['529', '2', 'по'],
#  149467: ['532', '8', 'прежнему'],
#  149468: ['541', '5', 'будет'],
#  149469: ['547', '10', 'оставаться'],
#  149470: ['558', '1', 'в'],
#  149471: ['560', '6', 'центре'],
#  149472: ['567', '8', 'внимания'],
#  149473: ['575', '1', '.'],
#  149474: ['577', '3', 'Так'],
#  149475: ['580', '1', ','],
#  149476: ['582', '8', 'согласно'],
#  149477: ['591', '3', 'его'],
#  149478: ['595', '12', 'пророчествам'],
#  149479: ['607', '1', ','],
#  149480: ['609', '1', '6'],
#  149481: ['611', '8', 'сентября'],
#  149482: ['620', '4', '1994'],
#  149483: ['625', '4', 'года'],
#  149484: ['630', '2', 'на'],
#  149485: ['633', '5', 'Землю', 'S-Location'],
#  149486: ['639', '6', 'должен'],
#  149487: ['646', '3', 'был'],
#  149488: ['650', '10', 'опуститься'],
#  149489: ['661', '5', 'Иисус', 'B-Person'],
#  149490: ['667', '7', 'Христос', 'E-Person'],
#  149491: ['674', '1', '.'],
#  149492: ['677', '9', 'Следующее'],
#  149493: ['687', '8', 'подобное'],
#  149494: ['696', '11', 'мероприятие'],
#  149495: ['707', '1', ','],
#  149496: ['709', '2', 'по'],
#  149497: ['712', '9', 'прогнозам'],
#  149498: ['722', '4', 'майя'],
#  149499: ['726', '1', ','],
#  149500: ['728', '9', 'ожидается'],
#  149501: ['738', '2', '21'],
#  149502: ['741', '7', 'декабря'],
#  149503: ['749', '4', '2012'],
#  149504: ['754', '4', 'года'],
#  149505: ['758', '1', ','],
#  149506: ['760', '6', 'однако'],
#  149507: ['767', '2', 'не'],
#  149508: ['770', '7', 'следует'],
#  149509: ['778', '8', 'забывать'],
#  149510: ['786', '1', ','],
#  149511: ['788', '3', 'что'],
#  149512: ['792', '5', 'конец'],
#  149513: ['798', '4', 'этой'],
#  149514: ['803', '11', 'цивилизации'],
#  149515: ['815', '8', 'наступил'],
#  149516: ['824', '11', 'значительно'],
#  149517: ['836', '6', 'раньше'],
#  149518: ['842', '1', ','],
#  149519: ['844', '1', 'и'],
#  149520: ['846', '3', 'это'],
#  149521: ['850', '9', 'отчего-то'],
#  149522: ['860', '2', 'не'],
#  149523: ['863', '10', 'отображено'],
#  149524: ['874', '1', 'в'],
#  149525: ['876', '2', 'их'],
#  149526: ['879', '8', 'наследии'],
#  149527: ['887', '1', ','],
#  149528: ['889', '7', 'поэтому'],
#  149529: ['897', '1', 'и'],
#  149530: ['899', '13', 'достоверность'],
#  149531: ['913', '9', 'подобного'],
#  149532: ['923', '10', 'прорицания'],
#  149533: ['934', '6', 'далеко'],
#  149534: ['941', '2', 'не'],
#  149535: ['944', '8', 'очевидна'],
#  149536: ['952', '1', '.'],
#  149537: ['955', '4', 'Если'],
#  149538: ['959', '1', '-'],
#  149539: ['960', '2', 'же'],
#  149540: ['963', '1', 'и'],
#  149541: ['965', '4', 'майя'],
#  149542: ['970', '8', 'ошиблись'],
#  149543: ['978', '1', ','],
#  149544: ['980', '2', 'то'],
#  149545: ['983', '13', 'расслабляться'],
#  149546: ['997', '9', 'всё-равно'],
#  149547: ['1007', '2', 'не'],
#  149548: ['1010', '5', 'стоит'],
#  149549: ['1015', '1', '.'],
#  149550: ['1017', '16', 'Апокалиптических'],
#  149551: ['1034', '6', 'теорий'],
#  149552: ['1041', '3', 'ещё'],
#  149553: ['1045', '10', 'достаточно'],
#  149554: ['1055', '1', ':'],
#  149555: ['1058', '1', '*'],
#  149556: ['1060', '4', '2021'],
#  149557: ['1065', '3', 'год'],
#  149558: ['1069', '1', '—'],
#  149559: ['1071', '8', 'инверсия'],
#  149560: ['1080', '10', 'магнитного'],
#  149561: ['1091', '4', 'поля'],
#  149562: ['1096', '5', 'Земли', 'S-Location'],
#  149563: ['1102', '9', 'уничтожит'],
#  149564: ['1112', '5', 'часть'],
#  149565: ['1118', '12', 'человечества'],
#  149566: ['1130', '1', '.'],
#  149567: ['1132', '1', '*'],
#  149568: ['1134', '4', '2060'],
#  149569: ['1139', '3', 'год'],
#  149570: ['1143', '1', '—'],
#  149571: ['1145', '8', 'Согласно'],
#  149572: ['1154', '8', 'расчётам'],
#  149573: ['1163', '6', 'Исаака', 'B-Person'],
#  149574: ['1170', '7', 'Ньютона', 'E-Person'],
#  149575: ['1177', '1', ','],
#  149576: ['1179', '9', 'сделанным'],
#  149577: ['1189', '1', 'в'],
#  149578: ['1191', '4', '1704'],
#  149579: ['1196', '4', 'году'],
#  149580: ['1201', '2', 'по'],
#  149581: ['1204', '10', 'библейской'],
#  149582: ['1215', '5', 'книге'],
#  149583: ['1221', '7', 'Даниила', 'S-Person'],
#  149584: ['1229', '6', 'станет'],
#  149585: ['1236', '9', 'последним'],
#  149586: ['1246', '3', 'для'],
#  149587: ['1250', '5', 'людей'],
#  149588: ['1255', '1', '.'],
#  149589: ['1257', '1', '*'],
#  149590: ['1259', '4', '2242'],
#  149591: ['1264', '3', 'год'],
#  149592: ['1268', '1', '—'],
#  149593: ['1270', '5', 'конец'],
#  149594: ['1276', '5', 'эпохи'],
#  149595: ['1282', '6', 'Солнца', 'S-Location'],
#  149596: ['1289', '8', 'согласно'],
#  149597: ['1298', '6', 'теории'],
#  149598: ['1305', '5', 'смены'],
#  149599: ['1311', '9', 'планетных'],
#  149600: ['1321', '4', 'эпох'],
#  149601: ['1325', '1', ','],
#  149602: ['1327', '7', 'которая'],
#  149603: ['1335', '4', 'была'],
#  149604: ['1340', '8', 'изложена'],
#  149605: ['1349', '1', 'в'],
#  149606: ['1351', '7', 'работах'],
#  149607: ['1359', '3', 'ибн', 'B-Person'],
#  149608: ['1363', '4', 'Эзра', 'E-Person'],
#  149609: ['1367', '1', ','],
#  149610: ['1369', '7', 'Авраама', 'S-Person'],
#  149611: ['1377', '1', 'и'],
#  149612: ['1379', '3', 'Абу', 'B-Person'],
#  149613: ['1383', '6', 'Машара', 'E-Person'],
#  149614: ['1389', '1', '.'],
#  149615: ['1391', '1', '*'],
#  149616: ['1393', '4', '2892'],
#  149617: ['1398', '3', 'год'],
#  149618: ['1402', '1', '—'],
#  149619: ['1404', '11', 'апокалипсис'],
#  149620: ['1416', '9', 'обещанный'],
#  149621: ['1426', '6', 'Авелем', 'S-Person'],
#  149622: ['1432', '1', '.'],
#  149623: ['1434', '1', '*'],
#  149624: ['1436', '4', '3797'],
#  149625: ['1441', '3', 'год'],
#  149626: ['1445', '1', '—'],
#  149627: ['1447', '7', 'кончину'],
#  149628: ['1455', '4', 'миру'],
#  149629: ['1460', '7', 'предрёк'],
#  149630: ['1468', '3', 'сам'],
#  149631: ['1472', '11', 'Нострадамус', 'S-Person'],
#  149632: ['1483', '1', '.'],
#  149633: ['1485', '1', '*'],
#  149634: ['1487', '4', '5079'],
#  149635: ['1492', '3', 'год'],
#  149636: ['1496', '1', '—'],
#  149637: ['1498', '5', 'сочла'],
#  149638: ['1504', '9', 'последним'],
#  149639: ['1514', '8', 'всемирно'],
#  149640: ['1523', '9', 'известная'],
#  149641: ['1533', '5', 'Ванга', 'S-Person'],
#  149642: ['1539', '1', '…'],
#  155118: ['0', '12', 'Промышленный', 'B-Org'],
#  155119: ['13', '1', 'и', 'I-Org'],
#  155120: ['15', '12', 'коммерческий', 'I-Org'],
#  155121: ['28', '4', 'банк', 'I-Org', 'I-Org'],
#  155122: ['33', '5', 'Китая', 'E-Org'],
#  155123: ['39', '1', '('],
#  155124: ['40', '10', 'Industrial', 'B-Org'],
#  155125: ['51', '3', 'and', 'I-Org'],
#  155126: ['55', '10', 'Commercial', 'I-Org'],
#  155127: ['66', '4', 'Bank', 'I-Org'],
#  155128: ['71', '2', 'of', 'I-Org'],
#  155129: ['74', '5', 'China', 'E-Org'],
#  155130: ['79', '1', ')'],
#  155131: ['80', '1', ','],
#  155132: ['82', '2', 'по'],
#  155133: ['85', '9', 'некоторым'],
#  155134: ['95', '11', 'показателям'],
#  155135: ['107', '1', '—'],
#  155136: ['109', '10', 'крупнейший'],
#  155137: ['120', '4', 'банк'],
#  155138: ['125', '4', 'мира'],
#  155139: ['129', '1', ','],
#  155140: ['131', '8', 'подписал'],
#  155141: ['140', '10', 'соглашение'],
#  155142: ['151', '1', 'о'],
#  155143: ['153', '7', 'покупке'],
#  155144: ['161', '11', 'контрольной'],
#  155145: ['173', '4', 'доли'],
#  155146: ['178', '1', 'в'],
#  155147: ['180', '12', 'американском', 'B-Org'],
#  155148: ['193', '9', 'отделении', 'I-Org', 'I-Org'],
#  155149: ['203', '4', 'Bank', 'I-Org', 'B-Org'],
#  155150: ['208', '2', 'of', 'I-Org', 'I-Org'],
#  155151: ['211', '4', 'East', 'I-Org', 'I-Org'],
#  155152: ['216', '4', 'Asia', 'E-Org', 'E-Org'],
#  155153: ['220', '1', ','],
#  155154: ['222', '11', 'управляющим'],
#  155155: ['234', '4', '13-ю'],
#  155156: ['239', '9', 'филиалами'],
#  155157: ['249', '1', 'в'],
#  155158: ['251', '10', 'Калифорнии', 'S-Location'],
#  155159: ['262', '1', 'и'],
#  155160: ['264', '9', 'Нью-Йорке', 'S-Location'],
#  155161: ['273', '1', '.'],
#  155162: ['275', '2', 'За'],
#  155163: ['278', '2', '80'],
#  155164: ['281', '9', 'процентов'],
#  155165: ['291', '5', 'акций'],
#  155166: ['297', '4', 'этой'],
#  155167: ['302', '10', 'финансовой'],
#  155168: ['313', '9', 'структуры'],
#  155169: ['322', '1', ','],
#  155170: ['324', '14', 'подконтрольный', 'B-Org'],
#  155171: ['339', '10', 'китайскому', 'B-Org', 'I-Org'],
#  155172: ['350', '13', 'правительству', 'E-Org', 'I-Org'],
#  155173: ['364', '4', 'банк', 'I-Org', 'I-Org'],
#  155174: ['369', '8', 'заплатит'],
#  155175: ['378', '5', 'около'],
#  155176: ['384', '3', '100'],
#  155177: ['388', '3', 'млн'],
#  155178: ['392', '8', 'долларов'],
#  155179: ['400', '1', '.'],
#  155180: ['403', '10', 'Соглашение'],
#  155181: ['414', '4', 'было'],
#  155182: ['419', '9', 'подписано'],
#  155183: ['429', '1', 'в'],
#  155184: ['431', '8', 'минувшую'],
#  155185: ['440', '7', 'пятницу'],
#  155186: ['448', '1', 'в'],
#  155187: ['450', '6', 'Чикаго', 'S-Location'],
#  155188: ['456', '1', ','],
#  155189: ['458', '1', 'в'],
#  155190: ['460', '9', 'последний'],
#  155191: ['470', '4', 'день'],
#  155192: ['475', '6', 'визита'],
#  155193: ['482', '12', 'председателя'],
#  155194: ['495', '3', 'КНР', 'S-LocOrg'],
#  155195: ['499', '2', 'Ху', 'B-Person'],
#  155196: ['502', '8', 'Цзиньтао', 'E-Person'],
#  155197: ['511', '1', 'в'],
#  155198: ['513', '3', 'США', 'S-Location'],
#  155199: ['516', '1', '.'],
#  155200: ['518', '6', 'Сделка'],
#  155201: ['525', '7', 'ожидает'],
#  155202: ['533', '11', 'утверждения'],
#  155203: ['545', '13', 'американскими'],
#  155204: ['559', '13', 'регулирующими'],
#  155205: ['573', '8', 'органами'],
#  155206: ['581', '1', ','],
#  155207: ['583', '3', 'что'],
#  155208: ['587', '5', 'может'],
#  155209: ['593', '9', 'задержать'],
#  155210: ['603', '2', 'ее'],
#  155211: ['606', '10', 'завершение'],
#  155212: ['617', '2', 'до'],
#  155213: ['620', '5', 'конца'],
#  155214: ['626', '5', 'этого'],
#  155215: ['632', '4', 'года'],
#  155216: ['636', '1', '.'],
#  155217: ['639', '4', 'Доля'],
#  155218: ['644', '13', 'правительства', 'B-Org'],
#  155219: ['658', '5', 'Китая', 'E-Org', 'S-LocOrg'],
#  155220: ['664', '1', 'в'],
#  155221: ['666', '10', 'Industrial', 'B-Org'],
#  155222: ['677', '3', 'and', 'I-Org'],
#  155223: ['681', '10', 'Commercial', 'I-Org'],
#  155224: ['692', '4', 'Bank', 'I-Org'],
#  155225: ['697', '2', 'of', 'I-Org'],
#  155226: ['700', '5', 'China', 'E-Org'],
#  155227: ['706', '10', 'составляет'],
#  155228: ['717', '2', '70'],
#  155229: ['720', '9', 'процентов'],
#  155230: ['729', '1', '.'],
#  155231: ['731', '4', 'Если'],
#  155232: ['736', '6', 'сделка'],
#  155233: ['743', '5', 'будет'],
#  155234: ['749', '10', 'утверждена'],
#  155235: ['759', '1', ','],
#  155236: ['761', '2', 'то'],
#  155237: ['764', '15', 'государственный', 'B-Org'],
#  155238: ['780', '9', 'китайский', 'I-Org', 'I-Org', 'I-Org'],
#  155239: ['790', '4', 'банк', 'I-Org', 'I-Org', 'I-Org'],
#  155240: ['795', '7', 'впервые'],
#  155241: ['803', '1', 'в'],
#  155242: ['805', '7', 'истории'],
#  155243: ['813', '7', 'получит'],
#  155244: ['821', '8', 'контроль'],
#  155245: ['830', '3', 'над'],
#  155246: ['834', '12', 'американским'],
#  155247: ['847', '10', 'финансовым'],
#  155248: ['858', '11', 'учреждением'],
#  155249: ['869', '1', '.'],
#  155250: ['871', '10', 'Американцы'],
#  155251: ['882', '6', 'смогут'],
#  155252: ['889', '6', 'делать'],
#  155253: ['896', '6', 'вклады'],
#  155254: ['903', '1', 'в'],
#  155255: ['905', '3', 'его'],
#  155256: ['909', '8', 'филиалах'],
#  155257: ['917', '1', ','],
#  155258: ['919', '1', 'а'],
#  155259: ['921', '9', 'инвесторы'],
#  155260: ['931', '6', 'смогут'],
#  155261: ['938', '9', 'открывать'],
#  155262: ['948', '5', 'счета'],
#  155263: ['954', '1', 'и'],
#  155264: ['956', '6', 'играть'],
#  155265: ['963', '2', 'на'],
#  155266: ['966', '5', 'курсе'],
#  155267: ['972', '4', 'юаня'],
#  155268: ['976', '1', '.'],
#  155269: ['979', '2', 'За'],
#  155270: ['982', '9', 'последние'],
#  155271: ['992', '4', 'годы'],
#  155272: ['997', '7', 'размеры'],
#  155273: ['1005', '11', 'иностранных'],
#  155274: ['1017', '10', 'инвестиций'],
#  155275: ['1028', '5', 'Китая', 'S-LocOrg'],
#  155276: ['1034', '5', 'резко'],
#  155277: ['1040', '11', 'увеличились'],
#  155278: ['1051', '1', ','],
#  155279: ['1053', '6', 'однако'],
#  155280: ['1060', '10', 'расширение'],
#  155281: ['1071', '9', 'китайских'],
#  155282: ['1081', '10', 'финансовых'],
#  155283: ['1092', '10', 'учреждений'],
#  155284: ['1103', '9', 'проходило'],
#  155285: ['1113', '7', 'гораздо'],
#  155286: ['1121', '9', 'медленнее'],
#  155287: ['1130', '1', '.'],
#  155288: ['1132', '3', 'При'],
#  155289: ['1136', '10', 'подписании'],
#  155290: ['1147', '6', 'нового'],
#  155291: ['1154', '10', 'соглашения'],
#  155292: ['1165', '7', 'министр'],
#  155293: ['1173', '8', 'торговли'],
#  155294: ['1182', '5', 'Китая', 'S-LocOrg'],
#  155295: ['1188', '4', 'Чэнь', 'B-Person'],
#  155296: ['1193', '5', 'Дэмин', 'E-Person'],
#  155297: ['1199', '6', 'заявил'],
#  155298: ['1205', '1', ','],
#  155299: ['1207', '3', 'что'],
#  155300: ['1211', '5', 'одним'],
#  155301: ['1217', '2', 'из'],
#  155302: ['1220', '11', 'приоритетов'],
#  155303: ['1232', '8', 'является'],
#  155304: ['1241', '7', 'перевод'],
#  155305: ['1249', '8', 'огромных'],
#  155306: ['1258', '8', 'резервов'],
#  155307: ['1267', '11', 'иностранной'],
#  155308: ['1279', '6', 'валюты'],
#  155309: ['1286', '1', 'в'],
#  155310: ['1288', '10', 'зарубежные'],
#  155311: ['1299', '6', 'активы'],
#  155312: ['1305', '1', '.'],
#  155313: ['0', '5', 'Барак', 'B-Person'],
#  155314: ['6', '5', 'Обама', 'E-Person'],
#  155315: ['12', '9', 'принимает'],
#  155316: ['22', '1', 'в'],
#  155317: ['24', '5', 'Белом', 'B-Location'],
#  155318: ['30', '4', 'доме', 'I-Location', 'I-Location'],
#  155319: ['35', '6', 'своего'],
#  155320: ['42', '12', 'французского'],
#  155321: ['55', '7', 'коллегу'],
#  155322: ['63', '6', 'Николя', 'B-Person'],
#  155323: ['70', '7', 'Саркози', 'E-Person'],
#  155324: ['77', '1', '.'],
#  155325: ['79', '3', 'Как'],
#  155326: ['83', '4', 'было'],
#  155327: ['88', '9', 'объявлено'],
#  155328: ['97', '1', ','],
#  155329: ['99', '9', 'президент'],
#  155330: ['109', '7', 'Франции', 'S-LocOrg'],
#  155331: ['117', '6', 'прибыл'],
#  155332: ['124', '1', 'в'],
#  155333: ['126', '9', 'Вашингтон', 'S-Location'],
#  155334: ['135', '1', ','],
#  155335: ['137', '5', 'чтобы'],
#  155336: ['143', '8', 'обсудить'],
#  155337: ['152', '1', 'с'],
#  155338: ['154', '6', 'главой'],
#  155339: ['161', '13', 'администрации', 'B-Org'],
#  155340: ['175', '3', 'США', 'E-Org', 'S-LocOrg'],
#  155341: ['179', '3', 'ряд'],
#  155342: ['183', '8', 'насущных'],
#  155343: ['192', '7', 'проблем'],
#  155344: ['199', '1', ','],
#  155345: ['201', '7', 'главное'],
#  155346: ['209', '5', 'место'],
#  155347: ['215', '5', 'среди'],
#  155348: ['221', '7', 'которых'],
#  155349: ['229', '8', 'занимает'],
#  155350: ['238', '9', 'состояние'],
#  155351: ['248', '7', 'мировой'],
#  155352: ['256', '9', 'экономики'],
#  155353: ['266', '1', 'и'],
#  155354: ['268', '12', 'безопасность'],
#  155355: ['280', '1', '.'],
#  155356: ['283', '1', 'В'],
#  155357: ['285', '9', 'частности'],
#  155358: ['294', '1', ','],
#  155359: ['296', '6', 'лидеры'],
#  155360: ['303', '8', 'намерены'],
#  155361: ['312', '10', 'обменяться'],
#  155362: ['323', '8', 'мнениями'],
#  155363: ['332', '1', 'о'],
#  155364: ['334', '12', 'перспективах'],
#  155365: ['347', '7', 'военных'],
#  155366: ['355', '8', 'действий'],
#  155367: ['364', '4', 'НАТО', 'S-Org'],
#  155368: ['369', '1', 'в'],
#  155369: ['371', '11', 'Афганистане', 'S-Location'],
#  155370: ['382', '1', ','],
#  155371: ['384', '9', 'волнениях'],
#  155372: ['394', '1', 'в'],
#  155373: ['396', '9', 'Пакистане', 'S-Location'],
#  155374: ['406', '1', 'и'],
#  155375: ['408', '7', 'угрозах'],
#  155376: ['416', '12', 'экстремистов'],
#  155377: ['429', '1', 'в'],
#  155378: ['431', '8', 'Северной', 'B-Location'],
#  155379: ['440', '6', 'Африке', 'E-Location'],
#  155380: ['446', '1', '.'],
#  155381: ['448', '1', 'В'],
#  155382: ['450', '11', 'воскресенье'],
#  155383: ['462', '6', 'Николя', 'B-Person'],
#  155384: ['469', '7', 'Саркози', 'E-Person'],
#  155385: ['477', '8', 'выпустил'],
#  155386: ['486', '9', 'заявление'],
#  155387: ['496', '1', 'с'],
#  155388: ['498', '10', 'осуждением'],
#  155389: ['509', '8', 'убийства'],
#  155390: ['518', '4', 'двух'],
#  155391: ['523', '11', 'французских'],
#  155392: ['535', '10', 'заложников'],
#  155393: ['546', '1', 'в'],
#  155394: ['548', '6', 'Нигере', 'S-Location'],
#  155395: ['554', '1', '.'],
#  155396: ['557', '1', 'В'],
#  155397: ['559', '8', 'недавнем'],
#  155398: ['568', '11', 'выступлении'],
#  155399: ['580', '2', 'по'],
#  155400: ['583', '12', 'французскому'],
#  155401: ['596', '11', 'телевидению'],
#  155402: ['608', '7', 'Саркози', 'S-Person'],
#  155403: ['616', '7', 'выразил'],
#  155404: ['624', '6', 'мнение'],
#  155405: ['631', '1', 'о'],
#  155406: ['633', '13', 'необходимости'],
#  155407: ['647', '8', 'изменить'],
#  155408: ['656', '8', 'ситуацию'],
#  155409: ['665', '1', 'в'],
#  155410: ['667', '10', 'глобальной'],
#  155411: ['678', '9', 'экономике'],
#  155412: ['687', '1', ','],
#  155413: ['689', '3', 'при'],
#  155414: ['693', '7', 'которой'],
#  155415: ['701', '6', 'доллар'],
#  155416: ['708', '8', 'остается'],
#  155417: ['717', '7', 'главным'],
#  155418: ['725', '12', 'инструментом'],
#  155419: ['738', '8', 'расчетов'],
#  155420: ['747', '1', 'и'],
#  155421: ['749', '7', 'мировой'],
#  155422: ['757', '9', 'резервной'],
#  155423: ['767', '7', 'валютой'],
#  155424: ['774', '1', '.'],
#  155425: ['776', '13', 'Вашингтонская'],
#  155426: ['790', '7', 'встреча'],
#  155427: ['798', '8', 'проходит'],
#  155428: ['807', '1', 'в'],
#  155429: ['809', '5', 'канун'],
#  155430: ['815', '8', 'передачи'],
#  155431: ['824', '7', 'Франции', 'S-LocOrg'],
#  155432: ['832', '10', 'полномочий'],
#  155433: ['843', '5', 'главы'],
#  155434: ['849', '1', '«'],
#  155435: ['850', '7', 'Большой', 'B-Org'],
#  155436: ['858', '9', 'двадцатки', 'E-Org'],
#  155437: ['867', '1', '»'],
#  155438: ['868', '1', '.'],
#  155439: ['870', '9', 'Президент'],
#  155440: ['880', '7', 'Саркози', 'S-Person'],
#  155441: ['888', '7', 'выразил'],
#  155442: ['896', '1', 'в'],
#  155443: ['898', '4', 'этой'],
#  155444: ['903', '5', 'связи'],
#  155445: ['909', '7', 'надежду'],
#  155446: ['917', '2', 'на'],
#  155447: ['920', '2', 'то'],
#  155448: ['922', '1', ','],
#  155449: ['924', '3', 'что'],
#  155450: ['928', '3', 'ему'],
#  155451: ['932', '7', 'удастся'],
#  155452: ['940', '2', 'за'],
#  155453: ['943', '5', 'время'],
#  155454: ['949', '16', 'председательства'],
#  155455: ['966', '1', 'в'],
#  155456: ['968', '4', 'G-20', 'S-Org'],
#  155457: ['973', '8', 'провести'],
#  155458: ['982', '5', 'целый'],
#  155459: ['988', '3', 'ряд'],
#  155460: ['992', '6', 'реформ'],
#  155461: ['998', '1', '.'],
#  165156: ['0', '9', '22-летний'],
#  165157: ['10', '6', 'житель'],
#  165158: ['17', '7', 'Аризоны', 'S-Location'],
#  165159: ['24', '1', ','],
#  165160: ['26', '9', 'открывший'],
#  165161: ['36', '8', 'стрельбу'],
#  165162: ['44', '1', ','],
#  165163: ['46', '1', 'в'],
#  165164: ['48', '10', 'результате'],
#  165165: ['59', '7', 'которой'],
#  165166: ['67', '10', 'пострадали'],
#  165167: ['78', '2', '20'],
#  165168: ['81', '7', 'человек'],
#  165169: ['88', '1', ','],
#  165170: ['90', '1', 'и'],
#  165171: ['92', '12', 'попытавшийся'],
#  165172: ['105', '5', 'убить'],
#  165173: ['111', '5', 'члена'],
#  165174: ['117', '9', 'Конгресса', 'B-Org'],
#  165175: ['127', '3', 'США', 'E-Org', 'S-LocOrg'],
#  165176: ['130', '1', ','],
#  165177: ['132', '7', 'впервые'],
#  165178: ['140', '8', 'предстал'],
#  165179: ['149', '5', 'перед'],
#  165180: ['155', '5', 'судом'],
#  165181: ['161', '2', 'по'],
#  165182: ['164', '9', 'обвинению'],
#  165183: ['174', '1', 'в'],
#  165184: ['176', '10', 'совершении'],
#  165185: ['187', '12', 'федерального'],
#  165186: ['200', '12', 'преступления'],
#  165187: ['212', '1', '.'],
#  165188: ['215', '1', 'В'],
#  165189: ['217', '11', 'понедельник'],
#  165190: ['229', '6', 'Джаред', 'B-Person'],
#  165191: ['236', '6', 'Лофнер', 'E-Person'],
#  165192: ['243', '1', 'в'],
#  165193: ['245', '10', 'наручниках'],
#  165194: ['256', '1', 'и'],
#  165195: ['258', '1', 'в'],
#  165196: ['260', '13', 'сопровождении'],
#  165197: ['274', '10', 'нескольких'],
#  165198: ['285', '10', 'охранников'],
#  165199: ['296', '9', 'доставлен'],
#  165200: ['306', '1', 'в'],
#  165201: ['308', '3', 'суд'],
#  165202: ['312', '1', 'в'],
#  165203: ['314', '6', 'города', 'B-Location'],
#  165204: ['321', '6', 'Феникс', 'E-Location'],
#  165205: ['327', '1', '.'],
#  165206: ['329', '8', 'Побритый'],
#  165207: ['338', '6', 'наголо'],
#  165208: ['345', '1', 'и'],
#  165209: ['347', '6', 'одетый'],
#  165210: ['354', '1', 'в'],
#  165211: ['356', '8', 'тюремную'],
#  165212: ['365', '5', 'форму'],
#  165213: ['370', '1', ','],
#  165214: ['372', '2', 'он'],
#  165215: ['375', '6', 'сказал'],
#  165216: ['381', '1', ','],
#  165217: ['383', '3', 'что'],
#  165218: ['387', '5', 'знает'],
#  165219: ['393', '4', 'свои'],
#  165220: ['398', '5', 'права'],
#  165221: ['403', '1', '.'],
#  165222: ['406', '6', 'Лофнер', 'S-Person'],
#  165223: ['413', '8', 'предстал'],
#  165224: ['422', '5', 'перед'],
#  165225: ['428', '5', 'судом'],
#  165226: ['434', '5', 'через'],
#  165227: ['440', '3', 'два'],
#  165228: ['444', '3', 'дня'],
#  165229: ['448', '5', 'после'],
#  165230: ['454', '8', 'стрельбы'],
#  165231: ['463', '1', 'в'],
#  165232: ['465', '6', 'Тусоне', 'S-Location'],
#  165233: ['471', '1', '.'],
#  165234: ['473', '5', 'Тогда'],
#  165235: ['479', '4', 'были'],
#  165236: ['484', '5', 'убиты'],
#  165237: ['490', '5', 'шесть'],
#  165238: ['496', '7', 'человек'],
#  165239: ['503', '1', ','],
#  165240: ['505', '1', 'а'],
#  165241: ['507', '4', 'член'],
#  165242: ['512', '6', 'Палаты', 'I-Org', 'I-Org'],
#  165243: ['519', '14', 'представителей', 'I-Org'],
#  165244: ['534', '9', 'Конгресса', 'I-Org', 'B-Org'],
#  165245: ['544', '3', 'США', 'E-Org', 'E-Org', 'S-LocOrg'],
#  165246: ['548', '2', 'от'],
#  165247: ['551', '5', 'штата', 'B-LocOrg'],
#  165248: ['557', '7', 'Аризона', 'E-LocOrg'],
#  165249: ['565', '8', 'Гэбриэль', 'B-Person'],
#  165250: ['574', '8', 'Гиффордс', 'E-Person'],
#  165251: ['583', '8', 'получила'],
#  165252: ['592', '7', 'ранение'],
#  ...}

# %%
for i in range(len(factrueval_dev_tokens_list)):
        if factrueval_dev_tokens_list[i] == []:
            continue
        number_of_token = factrueval_dev_tokens_list[i][0]
        if int(number_of_token) in factrueval_dev_tokens.keys() and len(factrueval_dev_tokens[int(number_of_token)]) >= 4:
            ne = factrueval_dev_tokens[int(number_of_token)][3]
            factrueval_dev_tokens_list[i].append(ne)
        else:
            factrueval_dev_tokens_list[i].append("O")

# %%
factrueval_dev_tokens_list
# Out:
# [['143783', '0', '1', 'В', 'O'],
#  ['143784', '2', '11', 'понедельник', 'O'],
#  ['143785', '14', '2', '28', 'O'],
#  ['143786', '17', '4', 'июня', 'O'],
#  ['143787', '22', '1', 'у', 'O'],
#  ['143788', '24', '6', 'здания', 'O'],
#  ['143789', '31', '5', 'мэрии', 'B-Org'],
#  ['143790', '37', '6', 'Москвы', 'E-Org'],
#  ['143791', '44', '2', 'на', 'O'],
#  ['143792', '47', '8', 'Тверской', 'B-Location'],
#  ['143793', '56', '7', 'площади', 'E-Location'],
#  ['143794', '64', '10', 'состоялась', 'O'],
#  ['143795', '75', '9', 'очередная', 'O'],
#  ['143796', '85', '19', 'несанкционированная', 'O'],
#  ['143797', '105', '5', 'акция', 'O'],
#  ['143798', '111', '8', 'протеста', 'O'],
#  ['143799', '120', '1', '«', 'O'],
#  ['143800', '121', '4', 'День', 'O'],
#  ['143801', '126', '5', 'гнева', 'O'],
#  ['143802', '131', '1', '»', 'O'],
#  ['143803', '132', '1', ',', 'O'],
#  ['143804', '134', '1', 'в', 'O'],
#  ['143805', '136', '4', 'этот', 'O'],
#  ['143806', '141', '3', 'раз', 'O'],
#  ['143807', '145', '12', 'направленная', 'O'],
#  ['143808', '157', '1', ',', 'O'],
#  ['143809', '159', '7', 'главным', 'O'],
#  ['143810', '167', '7', 'образом', 'O'],
#  ['143811', '174', '1', ',', 'O'],
#  ['143812', '176', '6', 'против', 'O'],
#  ['143813', '183', '8', 'политики', 'O'],
#  ['143814', '192', '10', 'московских', 'O'],
#  ['143815', '203', '1', 'и', 'O'],
#  ['143816', '205', '12', 'подмосковных', 'O'],
#  ['143817', '218', '7', 'властей', 'O'],
#  ['143818', '225', '1', '.', 'O'],
#  [],
#  ['143819', '227', '5', 'Среди', 'O'],
#  ['143820', '233', '10', 'требований', 'O'],
#  ['143821', '243', '1', ',', 'O'],
#  ['143822', '245', '11', 'выдвигаемых', 'O'],
#  ['143823', '257', '14', 'организаторами', 'O'],
#  ['143824', '272', '5', 'акции', 'O'],
#  ['143825', '277', '1', ':', 'O'],
#  ['143826', '279', '1', '«', 'O'],
#  ['143827', '280', '11', 'немедленная', 'O'],
#  ['143828', '292', '8', 'отставка', 'O'],
#  ['143829', '301', '4', 'мэра', 'O'],
#  ['143830', '306', '6', 'Москвы', 'S-LocOrg'],
#  ['143831', '313', '4', 'Юрия', 'B-Person'],
#  ['143832', '318', '7', 'Лужкова', 'E-Person'],
#  ['143833', '325', '1', ',', 'O'],
#  ['143834', '327', '13', 'расследование', 'O'],
#  ['143835', '341', '6', 'итогов', 'O'],
#  ['143836', '348', '3', 'его', 'O'],
#  ['143837', '352', '12', 'деятельности', 'O'],
#  ['143838', '364', '1', '»', 'O'],
#  ['143839', '365', '1', ',', 'O'],
#  ['143840', '367', '1', '«', 'O'],
#  ['143841', '368', '5', 'созыв', 'O'],
#  ['143842', '374', '11', 'московского', 'O'],
#  ['143843', '386', '13', 'общественного', 'O'],
#  ['143844', '400', '6', 'форума', 'O'],
#  ['143845', '407', '3', 'для', 'O'],
#  ['143846', '411', '10', 'обсуждения', 'O'],
#  ['143847', '422', '5', 'путей', 'O'],
#  ['143848', '428', '14', 'реформирования', 'O'],
#  ['143849', '443', '8', 'основных', 'O'],
#  ['143850', '452', '4', 'сфер', 'O'],
#  ['143851', '457', '17', 'жизнедеятельности', 'O'],
#  ['143852', '475', '1', 'в', 'O'],
#  ['143853', '477', '6', 'Москве', 'S-Location'],
#  ['143854', '483', '1', '»', 'O'],
#  ['143855', '484', '1', ',', 'O'],
#  ['143856', '486', '1', '«', 'O'],
#  ['143857', '487', '14', 'восстановление', 'O'],
#  ['143858', '502', '6', 'прямых', 'O'],
#  ['143859', '509', '7', 'выборов', 'O'],
#  ['143860', '517', '4', 'глав', 'O'],
#  ['143861', '522', '8', 'регионов', 'O'],
#  ['143862', '531', '6', 'России', 'S-LocOrg'],
#  ['143863', '537', '1', '»', 'O'],
#  ['143864', '538', '1', ',', 'O'],
#  ['143865', '540', '1', '«', 'O'],
#  ['143866', '541', '7', 'роспуск', 'O'],
#  ['143867', '549', '12', 'нелегитимной', 'O'],
#  ['143868', '562', '10', 'Мосгордумы', 'S-Org'],
#  ['143869', '572', '1', '»', 'O'],
#  ['143870', '573', '1', ',', 'O'],
#  ['143871', '575', '8', 'отставка', 'O'],
#  ['143872', '584', '13', 'подмосковного', 'S-LocOrg'],
#  ['143873', '598', '11', 'губернатора', 'O'],
#  ['143874', '610', '6', 'Бориса', 'B-Person'],
#  ['143875', '617', '7', 'Громова', 'E-Person'],
#  ['143876', '625', '1', 'и', 'O'],
#  ['143877', '627', '2', 'др', 'O'],
#  ['143878', '629', '1', '.', 'O'],
#  [],
#  ['143879', '631', '10', 'Участникам', 'O'],
#  ['143880', '642', '5', 'акции', 'O'],
#  ['143881', '648', '12', 'предлагалось', 'O'],
#  ['143882', '661', '8', 'принести', 'O'],
#  ['143883', '670', '1', 'с', 'O'],
#  ['143884', '672', '5', 'собой', 'O'],
#  ['143885', '678', '4', 'лист', 'O'],
#  ['143886', '683', '6', 'бумаги', 'O'],
#  ['143887', '690', '3', 'или', 'O'],
#  ['143888', '694', '5', 'кусок', 'O'],
#  ['143889', '700', '5', 'ткани', 'O'],
#  ['143890', '706', '7', 'чёрного', 'O'],
#  ['143891', '714', '5', 'цвета', 'O'],
#  ['143892', '719', '1', ',', 'O'],
#  ['143893', '721', '15', 'символизирующие', 'O'],
#  ['143894', '737', '1', '«', 'O'],
#  ['143895', '738', '6', 'чёрную', 'O'],
#  ['143896', '745', '5', 'метку', 'O'],
#  ['143897', '750', '1', '»', 'O'],
#  ['143898', '752', '3', 'для', 'O'],
#  ['143899', '756', '4', 'Юрия', 'B-Person'],
#  ['143900', '761', '7', 'Лужкова', 'E-Person'],
#  ['143901', '768', '1', '.', 'O'],
#  [],
#  ['143902', '771', '6', 'Начало', 'O'],
#  ['143903', '778', '5', 'акции', 'O'],
#  ['143904', '784', '4', 'было', 'O'],
#  ['143905', '789', '8', 'намечено', 'O'],
#  ['143906', '798', '2', 'на', 'O'],
#  ['143907', '801', '2', '19', 'O'],
#  ['143908', '804', '5', 'часов', 'O'],
#  ['143909', '809', '1', ';', 'O'],
#  ['143910', '811', '14', 'подчёркивалось', 'O'],
#  ['143911', '825', '1', ',', 'O'],
#  ['143912', '827', '3', 'что', 'O'],
#  ['143913', '831', '3', 'она', 'O'],
#  ['143914', '835', '9', 'состоится', 'O'],
#  ['143915', '845', '8', 'несмотря', 'O'],
#  ['143916', '854', '2', 'на', 'O'],
#  ['143917', '857', '6', 'запрет', 'O'],
#  ['143918', '864', '7', 'властей', 'O'],
#  ['143919', '871', '1', '.', 'O'],
#  [],
#  ['143920', '873', '10', 'Освещающие', 'O'],
#  ['143921', '884', '5', 'акцию', 'O'],
#  ['143922', '890', '8', 'блоггеры', 'O'],
#  ['143923', '899', '8', 'сообщили', 'O'],
#  ['143924', '907', '1', ',', 'O'],
#  ['143925', '909', '3', 'что', 'O'],
#  ['143926', '913', '8', 'автобусы', 'O'],
#  ['143927', '922', '1', 'с', 'O'],
#  ['143928', '924', '8', 'милицией', 'O'],
#  ['143929', '933', '5', 'стали', 'O'],
#  ['143930', '939', '8', 'занимать', 'O'],
#  ['143931', '948', '7', 'площадь', 'O'],
#  ['143932', '956', '1', 'у', 'O'],
#  ['143933', '958', '9', 'памятника', 'B-Location'],
#  ['143934', '968', '4', 'Юрию', 'I-Location'],
#  ['143935', '973', '11', 'Долгорукому', 'E-Location'],
#  ['143936', '985', '3', 'ещё', 'O'],
#  ['143937', '989', '1', 'с', 'O'],
#  ['143938', '991', '2', '15', 'O'],
#  ['143939', '994', '5', 'часов', 'O'],
#  ['143940', '1000', '3', 'дня', 'O'],
#  ['143941', '1003', '1', ',', 'O'],
#  ['143942', '1005', '11', 'центральная', 'O'],
#  ['143943', '1017', '5', 'часть', 'O'],
#  ['143944', '1023', '7', 'площади', 'O'],
#  ['143945', '1031', '4', 'была', 'O'],
#  ['143946', '1036', '9', 'огорожена', 'O'],
#  ['143947', '1045', '1', '.', 'O'],
#  [],
#  ['143948', '1047', '2', 'Ко', 'O'],
#  ['143949', '1050', '7', 'времени', 'O'],
#  ['143950', '1058', '6', 'начала', 'O'],
#  ['143951', '1065', '5', 'акции', 'O'],
#  ['143952', '1071', '6', 'вокруг', 'O'],
#  ['143953', '1078', '11', 'огороженной', 'O'],
#  ['143954', '1090', '10', 'территории', 'O'],
#  ['143955', '1101', '9', 'собралось', 'O'],
#  ['143956', '1111', '9', 'множество', 'O'],
#  ['143957', '1121', '11', 'журналистов', 'O'],
#  ['143958', '1133', '1', 'и', 'O'],
#  ['143959', '1135', '8', 'прохожих', 'O'],
#  ['143960', '1143', '1', ',', 'O'],
#  ['143961', '1145', '2', 'по', 'O'],
#  ['143962', '1148', '4', 'мере', 'O'],
#  ['143963', '1153', '8', 'прибытия', 'O'],
#  ['143964', '1162', '5', 'самих', 'O'],
#  ['143965', '1168', '10', 'участников', 'O'],
#  ['143966', '1179', '5', 'акции', 'O'],
#  ['143967', '1185', '7', 'милиция', 'O'],
#  ['143968', '1193', '6', 'начала', 'O'],
#  ['143969', '1200', '10', 'планомерно', 'O'],
#  ['143970', '1211', '2', 'их', 'O'],
#  ['143971', '1214', '11', 'задерживать', 'O'],
#  ['143972', '1226', '1', 'и', 'O'],
#  ['143973', '1228', '11', 'заталкивать', 'O'],
#  ['143974', '1240', '1', 'в', 'O'],
#  ['143975', '1242', '8', 'автобусы', 'O'],
#  ['143976', '1250', '1', '.', 'O'],
#  [],
#  ['143977', '1253', '5', 'Всего', 'O'],
#  ['143978', '1258', '1', ',', 'O'],
#  ['143979', '1260', '2', 'по', 'O'],
#  ['143980', '1263', '10', 'сообщениям', 'O'],
#  ['143981', '1274', '9', 'блоггеров', 'O'],
#  ['143982', '1284', '1', 'и', 'O'],
#  ['143983', '1286', '3', 'СМИ', 'O'],
#  ['143984', '1289', '1', ',', 'O'],
#  ['143985', '1291', '4', 'было', 'O'],
#  ['143986', '1296', '9', 'задержано', 'O'],
#  ['143987', '1306', '5', 'более', 'O'],
#  ['143988', '1312', '2', '30', 'O'],
#  ['143989', '1315', '7', 'человек', 'O'],
#  ['143990', '1322', '1', '.', 'O'],
#  [],
#  ['143991', '1324', '12', 'Пользователь', 'O'],
#  ['143992', '1337', '2', 'ЖЖ', 'O'],
#  ['143993', '1340', '5', 'zyalt', 'S-Person'],
#  ['143994', '1346', '8', 'сообщает', 'O'],
#  ['143995', '1354', '1', ',', 'O'],
#  ['143996', '1356', '3', 'что', 'O'],
#  ['143997', '1360', '5', 'среди', 'O'],
#  ['143998', '1366', '11', 'задержанных', 'O'],
#  ['143999', '1378', '8', 'оказался', 'O'],
#  ['144000', '1387', '7', 'депутат', 'O'],
#  ['144001', '1395', '14', 'муниципального', 'B-Org'],
#  ['144002', '1410', '8', 'собрания', 'I-Org'],
#  ['144003', '1419', '6', 'района', 'I-Org'],
#  ['144004', '1426', '8', 'Отрадное', 'E-Org'],
#  ['144005', '1434', '1', ',', 'O'],
#  ['144006', '1436', '14', 'сопредседатель', 'O'],
#  ['144007', '1451', '11', 'московского', 'B-Org'],
#  ['144008', '1463', '9', 'отделения', 'I-Org'],
#  ['144009', '1473', '8', 'движения', 'S-Org'],
#  ['144010', '1482', '1', '«', 'O'],
#  ['144011', '1483', '12', 'Солидарность', 'S-Org'],
#  ['144012', '1495', '1', '»', 'O'],
#  ['144013', '1497', '6', 'Михаил', 'B-Person'],
#  ['144014', '1504', '9', 'Вельмакин', 'E-Person'],
#  ['144015', '1513', '1', ',', 'O'],
#  ['144016', '1515', '9', 'известный', 'O'],
#  ['144017', '1525', '13', 'правозащитник', 'O'],
#  ['144018', '1539', '3', 'Лев', 'B-Person'],
#  ['144019', '1543', '9', 'Пономарев', 'E-Person'],
#  ['144020', '1552', '1', ',', 'O'],
#  ['144021', '1554', '11', 'координатор', 'O'],
#  ['144022', '1566', '8', 'движения', 'S-Org'],
#  ['144023', '1575', '1', '«', 'O'],
#  ['144024', '1576', '5', 'Левый', 'B-Org'],
#  ['144025', '1582', '5', 'фронт', 'E-Org'],
#  ['144026', '1587', '1', '»', 'O'],
#  ['144027', '1589', '6', 'Сергей', 'B-Person'],
#  ['144028', '1596', '8', 'Удальцов', 'E-Person'],
#  ['144029', '1604', '1', '.', 'O'],
#  [],
#  ['144030', '1607', '14', 'Организаторами', 'O'],
#  ['144031', '1622', '5', 'акции', 'O'],
#  ['144032', '1628', '9', 'выступили', 'O'],
#  ['144033', '1638', '8', 'движение', 'S-Org'],
#  ['144034', '1647', '1', '«', 'O'],
#  ['144035', '1648', '2', 'За', 'B-Org'],
#  ['144036', '1651', '5', 'права', 'I-Org'],
#  ['144037', '1657', '8', 'человека', 'E-Org'],
#  ['144038', '1665', '1', '»', 'O'],
#  ['144039', '1666', '1', ',', 'O'],
#  ['144040', '1668', '4', 'Союз', 'I-Org'],
#  ['144041', '1673', '15', 'координационных', 'I-Org'],
#  ['144042', '1689', '7', 'советов', 'E-Org'],
#  ['144043', '1697', '1', '(', 'O'],
#  ['144044', '1698', '3', 'СКС', 'S-Org'],
#  ['144045', '1701', '1', ')', 'O'],
#  ['144046', '1702', '1', ',', 'O'],
#  ['144047', '1704', '8', 'институт', 'S-Org'],
#  ['144048', '1713', '1', '«', 'O'],
#  ['144049', '1714', '12', 'Коллективное', 'B-Org'],
#  ['144050', '1727', '8', 'действие', 'E-Org'],
#  ['144051', '1735', '1', '»', 'O'],
#  ['144052', '1736', '1', ',', 'O'],
#  ['144053', '1738', '1', '«', 'O'],
#  ['144054', '1739', '8', 'Жилищная', 'B-Org'],
#  ['144055', '1748', '12', 'солидарность', 'E-Org'],
#  ['144056', '1760', '1', '»', 'O'],
#  ['144057', '1761', '1', ',', 'O'],
#  ['144058', '1763', '8', 'Движение', 'I-Org'],
#  ['144059', '1772', '9', 'общежитий', 'I-Org'],
#  ['144060', '1782', '6', 'Москвы', 'E-Org'],
#  ['144061', '1788', '1', ',', 'O'],
#  ['144062', '1790', '8', 'Движение', 'I-Org'],
#  ['144063', '1799', '1', 'в', 'I-Org'],
#  ['144064', '1801', '6', 'защиту', 'I-Org'],
#  ['144065', '1808', '11', 'Химкинского', 'I-Org'],
#  ['144066', '1820', '4', 'леса', 'E-Org'],
#  ['144067', '1824', '1', ',', 'O'],
#  ['144068', '1826', '8', 'движение', 'S-Org'],
#  ['144069', '1835', '1', '«', 'O'],
#  ['144070', '1836', '10', 'Московский', 'B-Org'],
#  ['144071', '1847', '5', 'совет', 'E-Org'],
#  ['144072', '1852', '1', '»', 'O'],
#  ['144073', '1853', '1', ',', 'O'],
#  ['144074', '1855', '1', '«', 'O'],
#  ['144075', '1856', '15', 'Координационный', 'I-Org'],
#  ['144076', '1872', '5', 'совет', 'I-Org'],
#  ['144077', '1878', '12', 'пострадавших', 'I-Org'],
#  ['144078', '1891', '12', 'соинвесторов', 'E-Org'],
#  ['144079', '1903', '1', '»', 'O'],
#  ['144080', '1904', '1', '.', 'O'],
#  [],
#  ['149382', '0', '5', 'Конец', 'O'],
#  ['149383', '6', '5', 'света', 'O'],
#  ['149384', '11', '1', ',', 'O'],
#  ['149385', '13', '7', 'который', 'O'],
#  ['149386', '21', '9', 'предрекал', 'O'],
#  ['149387', '31', '11', 'проповедник', 'O'],
#  ['149388', '42', '1', '-', 'O'],
#  ['149389', '43', '10', 'евангелист', 'O'],
#  ['149390', '54', '7', 'Герольд', 'B-Person'],
#  ['149391', '62', '7', 'Кемпинг', 'E-Person'],
#  ['149392', '70', '5', 'утром', 'O'],
#  ['149393', '76', '1', 'в', 'O'],
#  ['149394', '78', '5', '06.00', 'O'],
#  ['149395', '84', '2', 'по', 'O'],
#  ['149396', '87', '11', 'московскому', 'O'],
#  ['149397', '99', '7', 'времени', 'O'],
#  ['149398', '107', '2', '21', 'O'],
#  ['149399', '110', '3', 'мая', 'O'],
#  ['149400', '114', '4', '2011', 'O'],
#  ['149401', '119', '4', 'года', 'O'],
#  ['149402', '124', '3', 'так', 'O'],
#  ['149403', '128', '1', 'и', 'O'],
#  ['149404', '130', '2', 'не', 'O'],
#  ['149405', '133', '8', 'наступил', 'O'],
#  ['149406', '141', '1', '.', 'O'],
#  [],
#  ['149407', '144', '3', 'Это', 'O'],
#  ['149408', '148', '6', 'далеко', 'O'],
#  ['149409', '155', '2', 'не', 'O'],
#  ['149410', '158', '6', 'первое', 'O'],
#  ['149411', '165', '11', 'несбывшееся', 'O'],
#  ['149412', '177', '12', 'предсказание', 'O'],
#  ['149413', '190', '12', 'апокалипсиса', 'O'],
#  ['149414', '202', '1', '.', 'O'],
#  [],
#  ['149415', '204', '8', 'Поначалу', 'O'],
#  ['149416', '213', '2', 'на', 'O'],
#  ['149417', '216', '4', 'него', 'O'],
#  ['149418', '221', '11', 'практически', 'O'],
#  ['149419', '233', '2', 'не', 'O'],
#  ['149420', '236', '8', 'обратили', 'O'],
#  ['149421', '245', '8', 'внимания', 'O'],
#  ['149422', '253', '1', ',', 'O'],
#  ['149423', '255', '6', 'однако', 'O'],
#  ['149424', '261', '1', ',', 'O'],
#  ['149425', '263', '1', 'с', 'O'],
#  ['149426', '265', '12', 'приближением', 'O'],
#  ['149427', '278', '4', 'этой', 'O'],
#  ['149428', '283', '4', 'даты', 'O'],
#  ['149429', '287', '1', ',', 'O'],
#  ['149430', '289', '6', 'немало', 'O'],
#  ['149431', '296', '3', 'СМИ', 'O'],
#  ['149432', '300', '1', 'в', 'O'],
#  ['149433', '302', '7', 'поисках', 'O'],
#  ['149434', '310', '6', 'сюжета', 'O'],
#  ['149435', '316', '1', ',', 'O'],
#  ['149436', '318', '15', 'останавливались', 'O'],
#  ['149437', '334', '2', 'на', 'O'],
#  ['149438', '337', '4', 'этом', 'O'],
#  ['149439', '341', '1', ',', 'O'],
#  ['149440', '343', '8', 'создавая', 'O'],
#  ['149441', '352', '10', 'прекрасную', 'O'],
#  ['149442', '363', '10', 'бесплатную', 'O'],
#  ['149443', '374', '11', 'PR-компанию', 'O'],
#  ['149444', '386', '3', 'для', 'O'],
#  ['149445', '390', '12', 'горе-пророка', 'O'],
#  ['149446', '402', '1', '.', 'O'],
#  [],
#  ['149447', '404', '6', 'Вполне', 'O'],
#  ['149448', '411', '8', 'вероятно', 'O'],
#  ['149449', '419', '1', ',', 'O'],
#  ['149450', '421', '3', 'что', 'O'],
#  ['149451', '425', '7', 'Герольд', 'B-Person'],
#  ['149452', '433', '7', 'Кемпинг', 'E-Person'],
#  ['149453', '441', '8', 'объяснит', 'O'],
#  ['149454', '450', '3', 'это', 'O'],
#  ['149455', '454', '10', 'какой-либо', 'O'],
#  ['149456', '465', '11', 'неточностью', 'O'],
#  ['149457', '477', '1', 'и', 'O'],
#  ['149458', '479', '9', 'перенесет', 'O'],
#  ['149459', '489', '10', 'катастрофу', 'O'],
#  ['149460', '500', '2', 'на', 'O'],
#  ['149461', '503', '9', 'некоторое', 'O'],
#  ['149462', '513', '5', 'время', 'O'],
#  ['149463', '519', '6', 'вперёд', 'O'],
#  ['149464', '525', '1', ',', 'O'],
#  ['149465', '527', '1', 'и', 'O'],
#  ['149466', '529', '2', 'по', 'O'],
#  ['149467', '532', '8', 'прежнему', 'O'],
#  ['149468', '541', '5', 'будет', 'O'],
#  ['149469', '547', '10', 'оставаться', 'O'],
#  ['149470', '558', '1', 'в', 'O'],
#  ['149471', '560', '6', 'центре', 'O'],
#  ['149472', '567', '8', 'внимания', 'O'],
#  ['149473', '575', '1', '.', 'O'],
#  [],
#  ['149474', '577', '3', 'Так', 'O'],
#  ['149475', '580', '1', ',', 'O'],
#  ['149476', '582', '8', 'согласно', 'O'],
#  ['149477', '591', '3', 'его', 'O'],
#  ['149478', '595', '12', 'пророчествам', 'O'],
#  ['149479', '607', '1', ',', 'O'],
#  ['149480', '609', '1', '6', 'O'],
#  ['149481', '611', '8', 'сентября', 'O'],
#  ['149482', '620', '4', '1994', 'O'],
#  ['149483', '625', '4', 'года', 'O'],
#  ['149484', '630', '2', 'на', 'O'],
#  ['149485', '633', '5', 'Землю', 'S-Location'],
#  ['149486', '639', '6', 'должен', 'O'],
#  ['149487', '646', '3', 'был', 'O'],
#  ['149488', '650', '10', 'опуститься', 'O'],
#  ['149489', '661', '5', 'Иисус', 'B-Person'],
#  ['149490', '667', '7', 'Христос', 'E-Person'],
#  ['149491', '674', '1', '.', 'O'],
#  [],
#  ['149492', '677', '9', 'Следующее', 'O'],
#  ['149493', '687', '8', 'подобное', 'O'],
#  ['149494', '696', '11', 'мероприятие', 'O'],
#  ['149495', '707', '1', ',', 'O'],
#  ['149496', '709', '2', 'по', 'O'],
#  ['149497', '712', '9', 'прогнозам', 'O'],
#  ['149498', '722', '4', 'майя', 'O'],
#  ['149499', '726', '1', ',', 'O'],
#  ['149500', '728', '9', 'ожидается', 'O'],
#  ['149501', '738', '2', '21', 'O'],
#  ['149502', '741', '7', 'декабря', 'O'],
#  ['149503', '749', '4', '2012', 'O'],
#  ['149504', '754', '4', 'года', 'O'],
#  ['149505', '758', '1', ',', 'O'],
#  ['149506', '760', '6', 'однако', 'O'],
#  ['149507', '767', '2', 'не', 'O'],
#  ['149508', '770', '7', 'следует', 'O'],
#  ['149509', '778', '8', 'забывать', 'O'],
#  ['149510', '786', '1', ',', 'O'],
#  ['149511', '788', '3', 'что', 'O'],
#  ['149512', '792', '5', 'конец', 'O'],
#  ['149513', '798', '4', 'этой', 'O'],
#  ['149514', '803', '11', 'цивилизации', 'O'],
#  ['149515', '815', '8', 'наступил', 'O'],
#  ['149516', '824', '11', 'значительно', 'O'],
#  ['149517', '836', '6', 'раньше', 'O'],
#  ['149518', '842', '1', ',', 'O'],
#  ['149519', '844', '1', 'и', 'O'],
#  ['149520', '846', '3', 'это', 'O'],
#  ['149521', '850', '9', 'отчего-то', 'O'],
#  ['149522', '860', '2', 'не', 'O'],
#  ['149523', '863', '10', 'отображено', 'O'],
#  ['149524', '874', '1', 'в', 'O'],
#  ['149525', '876', '2', 'их', 'O'],
#  ['149526', '879', '8', 'наследии', 'O'],
#  ['149527', '887', '1', ',', 'O'],
#  ['149528', '889', '7', 'поэтому', 'O'],
#  ['149529', '897', '1', 'и', 'O'],
#  ['149530', '899', '13', 'достоверность', 'O'],
#  ['149531', '913', '9', 'подобного', 'O'],
#  ['149532', '923', '10', 'прорицания', 'O'],
#  ['149533', '934', '6', 'далеко', 'O'],
#  ['149534', '941', '2', 'не', 'O'],
#  ['149535', '944', '8', 'очевидна', 'O'],
#  ['149536', '952', '1', '.', 'O'],
#  [],
#  ['149537', '955', '4', 'Если', 'O'],
#  ['149538', '959', '1', '-', 'O'],
#  ['149539', '960', '2', 'же', 'O'],
#  ['149540', '963', '1', 'и', 'O'],
#  ['149541', '965', '4', 'майя', 'O'],
#  ['149542', '970', '8', 'ошиблись', 'O'],
#  ['149543', '978', '1', ',', 'O'],
#  ['149544', '980', '2', 'то', 'O'],
#  ['149545', '983', '13', 'расслабляться', 'O'],
#  ['149546', '997', '9', 'всё-равно', 'O'],
#  ['149547', '1007', '2', 'не', 'O'],
#  ['149548', '1010', '5', 'стоит', 'O'],
#  ['149549', '1015', '1', '.', 'O'],
#  [],
#  ['149550', '1017', '16', 'Апокалиптических', 'O'],
#  ['149551', '1034', '6', 'теорий', 'O'],
#  ['149552', '1041', '3', 'ещё', 'O'],
#  ['149553', '1045', '10', 'достаточно', 'O'],
#  ['149554', '1055', '1', ':', 'O'],
#  [],
#  ['149555', '1058', '1', '*', 'O'],
#  ['149556', '1060', '4', '2021', 'O'],
#  ['149557', '1065', '3', 'год', 'O'],
#  ['149558', '1069', '1', '—', 'O'],
#  ['149559', '1071', '8', 'инверсия', 'O'],
#  ['149560', '1080', '10', 'магнитного', 'O'],
#  ['149561', '1091', '4', 'поля', 'O'],
#  ['149562', '1096', '5', 'Земли', 'S-Location'],
#  ['149563', '1102', '9', 'уничтожит', 'O'],
#  ['149564', '1112', '5', 'часть', 'O'],
#  ['149565', '1118', '12', 'человечества', 'O'],
#  ['149566', '1130', '1', '.', 'O'],
#  [],
#  ['149567', '1132', '1', '*', 'O'],
#  ['149568', '1134', '4', '2060', 'O'],
#  ['149569', '1139', '3', 'год', 'O'],
#  ['149570', '1143', '1', '—', 'O'],
#  ['149571', '1145', '8', 'Согласно', 'O'],
#  ['149572', '1154', '8', 'расчётам', 'O'],
#  ['149573', '1163', '6', 'Исаака', 'B-Person'],
#  ['149574', '1170', '7', 'Ньютона', 'E-Person'],
#  ['149575', '1177', '1', ',', 'O'],
#  ['149576', '1179', '9', 'сделанным', 'O'],
#  ['149577', '1189', '1', 'в', 'O'],
#  ['149578', '1191', '4', '1704', 'O'],
#  ['149579', '1196', '4', 'году', 'O'],
#  ['149580', '1201', '2', 'по', 'O'],
#  ['149581', '1204', '10', 'библейской', 'O'],
#  ['149582', '1215', '5', 'книге', 'O'],
#  ['149583', '1221', '7', 'Даниила', 'S-Person'],
#  ['149584', '1229', '6', 'станет', 'O'],
#  ['149585', '1236', '9', 'последним', 'O'],
#  ['149586', '1246', '3', 'для', 'O'],
#  ['149587', '1250', '5', 'людей', 'O'],
#  ['149588', '1255', '1', '.', 'O'],
#  [],
#  ['149589', '1257', '1', '*', 'O'],
#  ['149590', '1259', '4', '2242', 'O'],
#  ['149591', '1264', '3', 'год', 'O'],
#  ['149592', '1268', '1', '—', 'O'],
#  ['149593', '1270', '5', 'конец', 'O'],
#  ['149594', '1276', '5', 'эпохи', 'O'],
#  ['149595', '1282', '6', 'Солнца', 'S-Location'],
#  ['149596', '1289', '8', 'согласно', 'O'],
#  ['149597', '1298', '6', 'теории', 'O'],
#  ['149598', '1305', '5', 'смены', 'O'],
#  ['149599', '1311', '9', 'планетных', 'O'],
#  ['149600', '1321', '4', 'эпох', 'O'],
#  ['149601', '1325', '1', ',', 'O'],
#  ['149602', '1327', '7', 'которая', 'O'],
#  ['149603', '1335', '4', 'была', 'O'],
#  ['149604', '1340', '8', 'изложена', 'O'],
#  ['149605', '1349', '1', 'в', 'O'],
#  ['149606', '1351', '7', 'работах', 'O'],
#  ['149607', '1359', '3', 'ибн', 'B-Person'],
#  ['149608', '1363', '4', 'Эзра', 'E-Person'],
#  ['149609', '1367', '1', ',', 'O'],
#  ['149610', '1369', '7', 'Авраама', 'S-Person'],
#  ['149611', '1377', '1', 'и', 'O'],
#  ['149612', '1379', '3', 'Абу', 'B-Person'],
#  ['149613', '1383', '6', 'Машара', 'E-Person'],
#  ['149614', '1389', '1', '.', 'O'],
#  [],
#  ['149615', '1391', '1', '*', 'O'],
#  ['149616', '1393', '4', '2892', 'O'],
#  ['149617', '1398', '3', 'год', 'O'],
#  ['149618', '1402', '1', '—', 'O'],
#  ['149619', '1404', '11', 'апокалипсис', 'O'],
#  ['149620', '1416', '9', 'обещанный', 'O'],
#  ['149621', '1426', '6', 'Авелем', 'S-Person'],
#  ['149622', '1432', '1', '.', 'O'],
#  [],
#  ['149623', '1434', '1', '*', 'O'],
#  ['149624', '1436', '4', '3797', 'O'],
#  ['149625', '1441', '3', 'год', 'O'],
#  ['149626', '1445', '1', '—', 'O'],
#  ['149627', '1447', '7', 'кончину', 'O'],
#  ['149628', '1455', '4', 'миру', 'O'],
#  ['149629', '1460', '7', 'предрёк', 'O'],
#  ['149630', '1468', '3', 'сам', 'O'],
#  ['149631', '1472', '11', 'Нострадамус', 'S-Person'],
#  ['149632', '1483', '1', '.', 'O'],
#  [],
#  ['149633', '1485', '1', '*', 'O'],
#  ['149634', '1487', '4', '5079', 'O'],
#  ['149635', '1492', '3', 'год', 'O'],
#  ['149636', '1496', '1', '—', 'O'],
#  ['149637', '1498', '5', 'сочла', 'O'],
#  ['149638', '1504', '9', 'последним', 'O'],
#  ['149639', '1514', '8', 'всемирно', 'O'],
#  ['149640', '1523', '9', 'известная', 'O'],
#  ['149641', '1533', '5', 'Ванга', 'S-Person'],
#  ['149642', '1539', '1', '…', 'O'],
#  [],
#  ['155118', '0', '12', 'Промышленный', 'B-Org'],
#  ['155119', '13', '1', 'и', 'I-Org'],
#  ['155120', '15', '12', 'коммерческий', 'I-Org'],
#  ['155121', '28', '4', 'банк', 'I-Org'],
#  ['155122', '33', '5', 'Китая', 'E-Org'],
#  ['155123', '39', '1', '(', 'O'],
#  ['155124', '40', '10', 'Industrial', 'B-Org'],
#  ['155125', '51', '3', 'and', 'I-Org'],
#  ['155126', '55', '10', 'Commercial', 'I-Org'],
#  ['155127', '66', '4', 'Bank', 'I-Org'],
#  ['155128', '71', '2', 'of', 'I-Org'],
#  ['155129', '74', '5', 'China', 'E-Org'],
#  ['155130', '79', '1', ')', 'O'],
#  ['155131', '80', '1', ',', 'O'],
#  ['155132', '82', '2', 'по', 'O'],
#  ['155133', '85', '9', 'некоторым', 'O'],
#  ['155134', '95', '11', 'показателям', 'O'],
#  ['155135', '107', '1', '—', 'O'],
#  ['155136', '109', '10', 'крупнейший', 'O'],
#  ['155137', '120', '4', 'банк', 'O'],
#  ['155138', '125', '4', 'мира', 'O'],
#  ['155139', '129', '1', ',', 'O'],
#  ['155140', '131', '8', 'подписал', 'O'],
#  ['155141', '140', '10', 'соглашение', 'O'],
#  ['155142', '151', '1', 'о', 'O'],
#  ['155143', '153', '7', 'покупке', 'O'],
#  ['155144', '161', '11', 'контрольной', 'O'],
#  ['155145', '173', '4', 'доли', 'O'],
#  ['155146', '178', '1', 'в', 'O'],
#  ['155147', '180', '12', 'американском', 'B-Org'],
#  ['155148', '193', '9', 'отделении', 'I-Org'],
#  ['155149', '203', '4', 'Bank', 'I-Org'],
#  ['155150', '208', '2', 'of', 'I-Org'],
#  ['155151', '211', '4', 'East', 'I-Org'],
#  ['155152', '216', '4', 'Asia', 'E-Org'],
#  ['155153', '220', '1', ',', 'O'],
#  ['155154', '222', '11', 'управляющим', 'O'],
#  ['155155', '234', '4', '13-ю', 'O'],
#  ['155156', '239', '9', 'филиалами', 'O'],
#  ['155157', '249', '1', 'в', 'O'],
#  ['155158', '251', '10', 'Калифорнии', 'S-Location'],
#  ['155159', '262', '1', 'и', 'O'],
#  ['155160', '264', '9', 'Нью-Йорке', 'S-Location'],
#  ['155161', '273', '1', '.', 'O'],
#  [],
#  ['155162', '275', '2', 'За', 'O'],
#  ['155163', '278', '2', '80', 'O'],
#  ['155164', '281', '9', 'процентов', 'O'],
#  ['155165', '291', '5', 'акций', 'O'],
#  ['155166', '297', '4', 'этой', 'O'],
#  ['155167', '302', '10', 'финансовой', 'O'],
#  ['155168', '313', '9', 'структуры', 'O'],
#  ['155169', '322', '1', ',', 'O'],
#  ['155170', '324', '14', 'подконтрольный', 'B-Org'],
#  ['155171', '339', '10', 'китайскому', 'B-Org'],
#  ['155172', '350', '13', 'правительству', 'E-Org'],
#  ['155173', '364', '4', 'банк', 'I-Org'],
#  ['155174', '369', '8', 'заплатит', 'O'],
#  ['155175', '378', '5', 'около', 'O'],
#  ['155176', '384', '3', '100', 'O'],
#  ['155177', '388', '3', 'млн', 'O'],
#  ['155178', '392', '8', 'долларов', 'O'],
#  ['155179', '400', '1', '.', 'O'],
#  [],
#  ['155180', '403', '10', 'Соглашение', 'O'],
#  ['155181', '414', '4', 'было', 'O'],
#  ['155182', '419', '9', 'подписано', 'O'],
#  ['155183', '429', '1', 'в', 'O'],
#  ['155184', '431', '8', 'минувшую', 'O'],
#  ['155185', '440', '7', 'пятницу', 'O'],
#  ['155186', '448', '1', 'в', 'O'],
#  ['155187', '450', '6', 'Чикаго', 'S-Location'],
#  ['155188', '456', '1', ',', 'O'],
#  ['155189', '458', '1', 'в', 'O'],
#  ['155190', '460', '9', 'последний', 'O'],
#  ['155191', '470', '4', 'день', 'O'],
#  ['155192', '475', '6', 'визита', 'O'],
#  ['155193', '482', '12', 'председателя', 'O'],
#  ['155194', '495', '3', 'КНР', 'S-LocOrg'],
#  ['155195', '499', '2', 'Ху', 'B-Person'],
#  ['155196', '502', '8', 'Цзиньтао', 'E-Person'],
#  ['155197', '511', '1', 'в', 'O'],
#  ['155198', '513', '3', 'США', 'S-Location'],
#  ['155199', '516', '1', '.', 'O'],
#  [],
#  ['155200', '518', '6', 'Сделка', 'O'],
#  ['155201', '525', '7', 'ожидает', 'O'],
#  ['155202', '533', '11', 'утверждения', 'O'],
#  ['155203', '545', '13', 'американскими', 'O'],
#  ['155204', '559', '13', 'регулирующими', 'O'],
#  ['155205', '573', '8', 'органами', 'O'],
#  ['155206', '581', '1', ',', 'O'],
#  ['155207', '583', '3', 'что', 'O'],
#  ['155208', '587', '5', 'может', 'O'],
#  ['155209', '593', '9', 'задержать', 'O'],
#  ['155210', '603', '2', 'ее', 'O'],
#  ['155211', '606', '10', 'завершение', 'O'],
#  ['155212', '617', '2', 'до', 'O'],
#  ['155213', '620', '5', 'конца', 'O'],
#  ['155214', '626', '5', 'этого', 'O'],
#  ['155215', '632', '4', 'года', 'O'],
#  ['155216', '636', '1', '.', 'O'],
#  [],
#  ['155217', '639', '4', 'Доля', 'O'],
#  ['155218', '644', '13', 'правительства', 'B-Org'],
#  ['155219', '658', '5', 'Китая', 'E-Org'],
#  ['155220', '664', '1', 'в', 'O'],
#  ['155221', '666', '10', 'Industrial', 'B-Org'],
#  ['155222', '677', '3', 'and', 'I-Org'],
#  ['155223', '681', '10', 'Commercial', 'I-Org'],
#  ['155224', '692', '4', 'Bank', 'I-Org'],
#  ['155225', '697', '2', 'of', 'I-Org'],
#  ['155226', '700', '5', 'China', 'E-Org'],
#  ['155227', '706', '10', 'составляет', 'O'],
#  ['155228', '717', '2', '70', 'O'],
#  ['155229', '720', '9', 'процентов', 'O'],
#  ['155230', '729', '1', '.', 'O'],
#  [],
#  ['155231', '731', '4', 'Если', 'O'],
#  ['155232', '736', '6', 'сделка', 'O'],
#  ['155233', '743', '5', 'будет', 'O'],
#  ['155234', '749', '10', 'утверждена', 'O'],
#  ['155235', '759', '1', ',', 'O'],
#  ['155236', '761', '2', 'то', 'O'],
#  ['155237', '764', '15', 'государственный', 'B-Org'],
#  ['155238', '780', '9', 'китайский', 'I-Org'],
#  ['155239', '790', '4', 'банк', 'I-Org'],
#  ['155240', '795', '7', 'впервые', 'O'],
#  ['155241', '803', '1', 'в', 'O'],
#  ['155242', '805', '7', 'истории', 'O'],
#  ['155243', '813', '7', 'получит', 'O'],
#  ['155244', '821', '8', 'контроль', 'O'],
#  ['155245', '830', '3', 'над', 'O'],
#  ['155246', '834', '12', 'американским', 'O'],
#  ['155247', '847', '10', 'финансовым', 'O'],
#  ['155248', '858', '11', 'учреждением', 'O'],
#  ['155249', '869', '1', '.', 'O'],
#  [],
#  ['155250', '871', '10', 'Американцы', 'O'],
#  ['155251', '882', '6', 'смогут', 'O'],
#  ['155252', '889', '6', 'делать', 'O'],
#  ['155253', '896', '6', 'вклады', 'O'],
#  ['155254', '903', '1', 'в', 'O'],
#  ['155255', '905', '3', 'его', 'O'],
#  ['155256', '909', '8', 'филиалах', 'O'],
#  ['155257', '917', '1', ',', 'O'],
#  ['155258', '919', '1', 'а', 'O'],
#  ['155259', '921', '9', 'инвесторы', 'O'],
#  ['155260', '931', '6', 'смогут', 'O'],
#  ['155261', '938', '9', 'открывать', 'O'],
#  ['155262', '948', '5', 'счета', 'O'],
#  ['155263', '954', '1', 'и', 'O'],
#  ['155264', '956', '6', 'играть', 'O'],
#  ['155265', '963', '2', 'на', 'O'],
#  ['155266', '966', '5', 'курсе', 'O'],
#  ['155267', '972', '4', 'юаня', 'O'],
#  ['155268', '976', '1', '.', 'O'],
#  [],
#  ['155269', '979', '2', 'За', 'O'],
#  ['155270', '982', '9', 'последние', 'O'],
#  ['155271', '992', '4', 'годы', 'O'],
#  ['155272', '997', '7', 'размеры', 'O'],
#  ['155273', '1005', '11', 'иностранных', 'O'],
#  ['155274', '1017', '10', 'инвестиций', 'O'],
#  ['155275', '1028', '5', 'Китая', 'S-LocOrg'],
#  ['155276', '1034', '5', 'резко', 'O'],
#  ['155277', '1040', '11', 'увеличились', 'O'],
#  ['155278', '1051', '1', ',', 'O'],
#  ['155279', '1053', '6', 'однако', 'O'],
#  ['155280', '1060', '10', 'расширение', 'O'],
#  ['155281', '1071', '9', 'китайских', 'O'],
#  ['155282', '1081', '10', 'финансовых', 'O'],
#  ['155283', '1092', '10', 'учреждений', 'O'],
#  ['155284', '1103', '9', 'проходило', 'O'],
#  ['155285', '1113', '7', 'гораздо', 'O'],
#  ['155286', '1121', '9', 'медленнее', 'O'],
#  ['155287', '1130', '1', '.', 'O'],
#  [],
#  ['155288', '1132', '3', 'При', 'O'],
#  ['155289', '1136', '10', 'подписании', 'O'],
#  ['155290', '1147', '6', 'нового', 'O'],
#  ['155291', '1154', '10', 'соглашения', 'O'],
#  ['155292', '1165', '7', 'министр', 'O'],
#  ['155293', '1173', '8', 'торговли', 'O'],
#  ['155294', '1182', '5', 'Китая', 'S-LocOrg'],
#  ['155295', '1188', '4', 'Чэнь', 'B-Person'],
#  ['155296', '1193', '5', 'Дэмин', 'E-Person'],
#  ['155297', '1199', '6', 'заявил', 'O'],
#  ['155298', '1205', '1', ',', 'O'],
#  ['155299', '1207', '3', 'что', 'O'],
#  ['155300', '1211', '5', 'одним', 'O'],
#  ['155301', '1217', '2', 'из', 'O'],
#  ['155302', '1220', '11', 'приоритетов', 'O'],
#  ['155303', '1232', '8', 'является', 'O'],
#  ['155304', '1241', '7', 'перевод', 'O'],
#  ['155305', '1249', '8', 'огромных', 'O'],
#  ['155306', '1258', '8', 'резервов', 'O'],
#  ['155307', '1267', '11', 'иностранной', 'O'],
#  ['155308', '1279', '6', 'валюты', 'O'],
#  ['155309', '1286', '1', 'в', 'O'],
#  ['155310', '1288', '10', 'зарубежные', 'O'],
#  ['155311', '1299', '6', 'активы', 'O'],
#  ['155312', '1305', '1', '.', 'O'],
#  [],
#  ['155313', '0', '5', 'Барак', 'B-Person'],
#  ['155314', '6', '5', 'Обама', 'E-Person'],
#  ['155315', '12', '9', 'принимает', 'O'],
#  ['155316', '22', '1', 'в', 'O'],
#  ['155317', '24', '5', 'Белом', 'B-Location'],
#  ['155318', '30', '4', 'доме', 'I-Location'],
#  ['155319', '35', '6', 'своего', 'O'],
#  ['155320', '42', '12', 'французского', 'O'],
#  ['155321', '55', '7', 'коллегу', 'O'],
#  ['155322', '63', '6', 'Николя', 'B-Person'],
#  ['155323', '70', '7', 'Саркози', 'E-Person'],
#  ['155324', '77', '1', '.', 'O'],
#  [],
#  ['155325', '79', '3', 'Как', 'O'],
#  ['155326', '83', '4', 'было', 'O'],
#  ['155327', '88', '9', 'объявлено', 'O'],
#  ['155328', '97', '1', ',', 'O'],
#  ['155329', '99', '9', 'президент', 'O'],
#  ['155330', '109', '7', 'Франции', 'S-LocOrg'],
#  ['155331', '117', '6', 'прибыл', 'O'],
#  ['155332', '124', '1', 'в', 'O'],
#  ['155333', '126', '9', 'Вашингтон', 'S-Location'],
#  ['155334', '135', '1', ',', 'O'],
#  ['155335', '137', '5', 'чтобы', 'O'],
#  ['155336', '143', '8', 'обсудить', 'O'],
#  ['155337', '152', '1', 'с', 'O'],
#  ['155338', '154', '6', 'главой', 'O'],
#  ['155339', '161', '13', 'администрации', 'B-Org'],
#  ['155340', '175', '3', 'США', 'E-Org'],
#  ['155341', '179', '3', 'ряд', 'O'],
#  ['155342', '183', '8', 'насущных', 'O'],
#  ['155343', '192', '7', 'проблем', 'O'],
#  ['155344', '199', '1', ',', 'O'],
#  ['155345', '201', '7', 'главное', 'O'],
#  ['155346', '209', '5', 'место', 'O'],
#  ['155347', '215', '5', 'среди', 'O'],
#  ['155348', '221', '7', 'которых', 'O'],
#  ['155349', '229', '8', 'занимает', 'O'],
#  ['155350', '238', '9', 'состояние', 'O'],
#  ['155351', '248', '7', 'мировой', 'O'],
#  ['155352', '256', '9', 'экономики', 'O'],
#  ['155353', '266', '1', 'и', 'O'],
#  ['155354', '268', '12', 'безопасность', 'O'],
#  ['155355', '280', '1', '.', 'O'],
#  [],
#  ['155356', '283', '1', 'В', 'O'],
#  ['155357', '285', '9', 'частности', 'O'],
#  ['155358', '294', '1', ',', 'O'],
#  ['155359', '296', '6', 'лидеры', 'O'],
#  ['155360', '303', '8', 'намерены', 'O'],
#  ['155361', '312', '10', 'обменяться', 'O'],
#  ['155362', '323', '8', 'мнениями', 'O'],
#  ['155363', '332', '1', 'о', 'O'],
#  ['155364', '334', '12', 'перспективах', 'O'],
#  ['155365', '347', '7', 'военных', 'O'],
#  ['155366', '355', '8', 'действий', 'O'],
#  ['155367', '364', '4', 'НАТО', 'S-Org'],
#  ['155368', '369', '1', 'в', 'O'],
#  ['155369', '371', '11', 'Афганистане', 'S-Location'],
#  ['155370', '382', '1', ',', 'O'],
#  ['155371', '384', '9', 'волнениях', 'O'],
#  ['155372', '394', '1', 'в', 'O'],
#  ['155373', '396', '9', 'Пакистане', 'S-Location'],
#  ['155374', '406', '1', 'и', 'O'],
#  ['155375', '408', '7', 'угрозах', 'O'],
#  ['155376', '416', '12', 'экстремистов', 'O'],
#  ['155377', '429', '1', 'в', 'O'],
#  ['155378', '431', '8', 'Северной', 'B-Location'],
#  ['155379', '440', '6', 'Африке', 'E-Location'],
#  ['155380', '446', '1', '.', 'O'],
#  [],
#  ['155381', '448', '1', 'В', 'O'],
#  ['155382', '450', '11', 'воскресенье', 'O'],
#  ['155383', '462', '6', 'Николя', 'B-Person'],
#  ['155384', '469', '7', 'Саркози', 'E-Person'],
#  ['155385', '477', '8', 'выпустил', 'O'],
#  ['155386', '486', '9', 'заявление', 'O'],
#  ['155387', '496', '1', 'с', 'O'],
#  ['155388', '498', '10', 'осуждением', 'O'],
#  ['155389', '509', '8', 'убийства', 'O'],
#  ['155390', '518', '4', 'двух', 'O'],
#  ['155391', '523', '11', 'французских', 'O'],
#  ['155392', '535', '10', 'заложников', 'O'],
#  ['155393', '546', '1', 'в', 'O'],
#  ['155394', '548', '6', 'Нигере', 'S-Location'],
#  ['155395', '554', '1', '.', 'O'],
#  [],
#  ['155396', '557', '1', 'В', 'O'],
#  ['155397', '559', '8', 'недавнем', 'O'],
#  ['155398', '568', '11', 'выступлении', 'O'],
#  ['155399', '580', '2', 'по', 'O'],
#  ['155400', '583', '12', 'французскому', 'O'],
#  ['155401', '596', '11', 'телевидению', 'O'],
#  ['155402', '608', '7', 'Саркози', 'S-Person'],
#  ['155403', '616', '7', 'выразил', 'O'],
#  ['155404', '624', '6', 'мнение', 'O'],
#  ['155405', '631', '1', 'о', 'O'],
#  ['155406', '633', '13', 'необходимости', 'O'],
#  ['155407', '647', '8', 'изменить', 'O'],
#  ['155408', '656', '8', 'ситуацию', 'O'],
#  ['155409', '665', '1', 'в', 'O'],
#  ['155410', '667', '10', 'глобальной', 'O'],
#  ['155411', '678', '9', 'экономике', 'O'],
#  ['155412', '687', '1', ',', 'O'],
#  ['155413', '689', '3', 'при', 'O'],
#  ['155414', '693', '7', 'которой', 'O'],
#  ['155415', '701', '6', 'доллар', 'O'],
#  ['155416', '708', '8', 'остается', 'O'],
#  ['155417', '717', '7', 'главным', 'O'],
#  ['155418', '725', '12', 'инструментом', 'O'],
#  ['155419', '738', '8', 'расчетов', 'O'],
#  ['155420', '747', '1', 'и', 'O'],
#  ['155421', '749', '7', 'мировой', 'O'],
#  ['155422', '757', '9', 'резервной', 'O'],
#  ['155423', '767', '7', 'валютой', 'O'],
#  ['155424', '774', '1', '.', 'O'],
#  [],
#  ['155425', '776', '13', 'Вашингтонская', 'O'],
#  ['155426', '790', '7', 'встреча', 'O'],
#  ['155427', '798', '8', 'проходит', 'O'],
#  ['155428', '807', '1', 'в', 'O'],
#  ['155429', '809', '5', 'канун', 'O'],
#  ['155430', '815', '8', 'передачи', 'O'],
#  ['155431', '824', '7', 'Франции', 'S-LocOrg'],
#  ['155432', '832', '10', 'полномочий', 'O'],
#  ['155433', '843', '5', 'главы', 'O'],
#  ['155434', '849', '1', '«', 'O'],
#  ['155435', '850', '7', 'Большой', 'B-Org'],
#  ['155436', '858', '9', 'двадцатки', 'E-Org'],
#  ['155437', '867', '1', '»', 'O'],
#  ['155438', '868', '1', '.', 'O'],
#  [],
#  ['155439', '870', '9', 'Президент', 'O'],
#  ['155440', '880', '7', 'Саркози', 'S-Person'],
#  ['155441', '888', '7', 'выразил', 'O'],
#  ['155442', '896', '1', 'в', 'O'],
#  ['155443', '898', '4', 'этой', 'O'],
#  ['155444', '903', '5', 'связи', 'O'],
#  ['155445', '909', '7', 'надежду', 'O'],
#  ['155446', '917', '2', 'на', 'O'],
#  ['155447', '920', '2', 'то', 'O'],
#  ['155448', '922', '1', ',', 'O'],
#  ['155449', '924', '3', 'что', 'O'],
#  ['155450', '928', '3', 'ему', 'O'],
#  ['155451', '932', '7', 'удастся', 'O'],
#  ['155452', '940', '2', 'за', 'O'],
#  ['155453', '943', '5', 'время', 'O'],
#  ['155454', '949', '16', 'председательства', 'O'],
#  ['155455', '966', '1', 'в', 'O'],
#  ['155456', '968', '4', 'G-20', 'S-Org'],
#  ['155457', '973', '8', 'провести', 'O'],
#  ['155458', '982', '5', 'целый', 'O'],
#  ['155459', '988', '3', 'ряд', 'O'],
#  ['155460', '992', '6', 'реформ', 'O'],
#  ['155461', '998', '1', '.', 'O'],
#  [],
#  ['165156', '0', '9', '22-летний', 'O'],
#  ['165157', '10', '6', 'житель', 'O'],
#  ['165158', '17', '7', 'Аризоны', 'S-Location'],
#  ['165159', '24', '1', ',', 'O'],
#  ['165160', '26', '9', 'открывший', 'O'],
#  ['165161', '36', '8', 'стрельбу', 'O'],
#  ['165162', '44', '1', ',', 'O'],
#  ['165163', '46', '1', 'в', 'O'],
#  ['165164', '48', '10', 'результате', 'O'],
#  ['165165', '59', '7', 'которой', 'O'],
#  ['165166', '67', '10', 'пострадали', 'O'],
#  ['165167', '78', '2', '20', 'O'],
#  ['165168', '81', '7', 'человек', 'O'],
#  ['165169', '88', '1', ',', 'O'],
#  ['165170', '90', '1', 'и', 'O'],
#  ['165171', '92', '12', 'попытавшийся', 'O'],
#  ['165172', '105', '5', 'убить', 'O'],
#  ['165173', '111', '5', 'члена', 'O'],
#  ['165174', '117', '9', 'Конгресса', 'B-Org'],
#  ['165175', '127', '3', 'США', 'E-Org'],
#  ['165176', '130', '1', ',', 'O'],
#  ['165177', '132', '7', 'впервые', 'O'],
#  ['165178', '140', '8', 'предстал', 'O'],
#  ['165179', '149', '5', 'перед', 'O'],
#  ['165180', '155', '5', 'судом', 'O'],
#  ['165181', '161', '2', 'по', 'O'],
#  ['165182', '164', '9', 'обвинению', 'O'],
#  ['165183', '174', '1', 'в', 'O'],
#  ['165184', '176', '10', 'совершении', 'O'],
#  ['165185', '187', '12', 'федерального', 'O'],
#  ['165186', '200', '12', 'преступления', 'O'],
#  ['165187', '212', '1', '.', 'O'],
#  [],
#  ['165188', '215', '1', 'В', 'O'],
#  ['165189', '217', '11', 'понедельник', 'O'],
#  ['165190', '229', '6', 'Джаред', 'B-Person'],
#  ['165191', '236', '6', 'Лофнер', 'E-Person'],
#  ['165192', '243', '1', 'в', 'O'],
#  ['165193', '245', '10', 'наручниках', 'O'],
#  ['165194', '256', '1', 'и', 'O'],
#  ['165195', '258', '1', 'в', 'O'],
#  ['165196', '260', '13', 'сопровождении', 'O'],
#  ['165197', '274', '10', 'нескольких', 'O'],
#  ['165198', '285', '10', 'охранников', 'O'],
#  ['165199', '296', '9', 'доставлен', 'O'],
#  ['165200', '306', '1', 'в', 'O'],
#  ['165201', '308', '3', 'суд', 'O'],
#  ['165202', '312', '1', 'в', 'O'],
#  ['165203', '314', '6', 'города', 'B-Location'],
#  ['165204', '321', '6', 'Феникс', 'E-Location'],
#  ['165205', '327', '1', '.', 'O'],
#  [],
#  ['165206', '329', '8', 'Побритый', 'O'],
#  ['165207', '338', '6', 'наголо', 'O'],
#  ['165208', '345', '1', 'и', 'O'],
#  ['165209', '347', '6', 'одетый', 'O'],
#  ['165210', '354', '1', 'в', 'O'],
#  ['165211', '356', '8', 'тюремную', 'O'],
#  ...]

# %%
final = []
for el in factrueval_dev_tokens_list:
    if el == []:
        final.append(el)
    else:
        final.append([el[3], el[1], el[2], el[4]])

# %%
final
# Out:
# [['В', '0', '1', 'O'],
#  ['понедельник', '2', '11', 'O'],
#  ['28', '14', '2', 'O'],
#  ['июня', '17', '4', 'O'],
#  ['у', '22', '1', 'O'],
#  ['здания', '24', '6', 'O'],
#  ['мэрии', '31', '5', 'B-Org'],
#  ['Москвы', '37', '6', 'E-Org'],
#  ['на', '44', '2', 'O'],
#  ['Тверской', '47', '8', 'B-Location'],
#  ['площади', '56', '7', 'E-Location'],
#  ['состоялась', '64', '10', 'O'],
#  ['очередная', '75', '9', 'O'],
#  ['несанкционированная', '85', '19', 'O'],
#  ['акция', '105', '5', 'O'],
#  ['протеста', '111', '8', 'O'],
#  ['«', '120', '1', 'O'],
#  ['День', '121', '4', 'O'],
#  ['гнева', '126', '5', 'O'],
#  ['»', '131', '1', 'O'],
#  [',', '132', '1', 'O'],
#  ['в', '134', '1', 'O'],
#  ['этот', '136', '4', 'O'],
#  ['раз', '141', '3', 'O'],
#  ['направленная', '145', '12', 'O'],
#  [',', '157', '1', 'O'],
#  ['главным', '159', '7', 'O'],
#  ['образом', '167', '7', 'O'],
#  [',', '174', '1', 'O'],
#  ['против', '176', '6', 'O'],
#  ['политики', '183', '8', 'O'],
#  ['московских', '192', '10', 'O'],
#  ['и', '203', '1', 'O'],
#  ['подмосковных', '205', '12', 'O'],
#  ['властей', '218', '7', 'O'],
#  ['.', '225', '1', 'O'],
#  [],
#  ['Среди', '227', '5', 'O'],
#  ['требований', '233', '10', 'O'],
#  [',', '243', '1', 'O'],
#  ['выдвигаемых', '245', '11', 'O'],
#  ['организаторами', '257', '14', 'O'],
#  ['акции', '272', '5', 'O'],
#  [':', '277', '1', 'O'],
#  ['«', '279', '1', 'O'],
#  ['немедленная', '280', '11', 'O'],
#  ['отставка', '292', '8', 'O'],
#  ['мэра', '301', '4', 'O'],
#  ['Москвы', '306', '6', 'S-LocOrg'],
#  ['Юрия', '313', '4', 'B-Person'],
#  ['Лужкова', '318', '7', 'E-Person'],
#  [',', '325', '1', 'O'],
#  ['расследование', '327', '13', 'O'],
#  ['итогов', '341', '6', 'O'],
#  ['его', '348', '3', 'O'],
#  ['деятельности', '352', '12', 'O'],
#  ['»', '364', '1', 'O'],
#  [',', '365', '1', 'O'],
#  ['«', '367', '1', 'O'],
#  ['созыв', '368', '5', 'O'],
#  ['московского', '374', '11', 'O'],
#  ['общественного', '386', '13', 'O'],
#  ['форума', '400', '6', 'O'],
#  ['для', '407', '3', 'O'],
#  ['обсуждения', '411', '10', 'O'],
#  ['путей', '422', '5', 'O'],
#  ['реформирования', '428', '14', 'O'],
#  ['основных', '443', '8', 'O'],
#  ['сфер', '452', '4', 'O'],
#  ['жизнедеятельности', '457', '17', 'O'],
#  ['в', '475', '1', 'O'],
#  ['Москве', '477', '6', 'S-Location'],
#  ['»', '483', '1', 'O'],
#  [',', '484', '1', 'O'],
#  ['«', '486', '1', 'O'],
#  ['восстановление', '487', '14', 'O'],
#  ['прямых', '502', '6', 'O'],
#  ['выборов', '509', '7', 'O'],
#  ['глав', '517', '4', 'O'],
#  ['регионов', '522', '8', 'O'],
#  ['России', '531', '6', 'S-LocOrg'],
#  ['»', '537', '1', 'O'],
#  [',', '538', '1', 'O'],
#  ['«', '540', '1', 'O'],
#  ['роспуск', '541', '7', 'O'],
#  ['нелегитимной', '549', '12', 'O'],
#  ['Мосгордумы', '562', '10', 'S-Org'],
#  ['»', '572', '1', 'O'],
#  [',', '573', '1', 'O'],
#  ['отставка', '575', '8', 'O'],
#  ['подмосковного', '584', '13', 'S-LocOrg'],
#  ['губернатора', '598', '11', 'O'],
#  ['Бориса', '610', '6', 'B-Person'],
#  ['Громова', '617', '7', 'E-Person'],
#  ['и', '625', '1', 'O'],
#  ['др', '627', '2', 'O'],
#  ['.', '629', '1', 'O'],
#  [],
#  ['Участникам', '631', '10', 'O'],
#  ['акции', '642', '5', 'O'],
#  ['предлагалось', '648', '12', 'O'],
#  ['принести', '661', '8', 'O'],
#  ['с', '670', '1', 'O'],
#  ['собой', '672', '5', 'O'],
#  ['лист', '678', '4', 'O'],
#  ['бумаги', '683', '6', 'O'],
#  ['или', '690', '3', 'O'],
#  ['кусок', '694', '5', 'O'],
#  ['ткани', '700', '5', 'O'],
#  ['чёрного', '706', '7', 'O'],
#  ['цвета', '714', '5', 'O'],
#  [',', '719', '1', 'O'],
#  ['символизирующие', '721', '15', 'O'],
#  ['«', '737', '1', 'O'],
#  ['чёрную', '738', '6', 'O'],
#  ['метку', '745', '5', 'O'],
#  ['»', '750', '1', 'O'],
#  ['для', '752', '3', 'O'],
#  ['Юрия', '756', '4', 'B-Person'],
#  ['Лужкова', '761', '7', 'E-Person'],
#  ['.', '768', '1', 'O'],
#  [],
#  ['Начало', '771', '6', 'O'],
#  ['акции', '778', '5', 'O'],
#  ['было', '784', '4', 'O'],
#  ['намечено', '789', '8', 'O'],
#  ['на', '798', '2', 'O'],
#  ['19', '801', '2', 'O'],
#  ['часов', '804', '5', 'O'],
#  [';', '809', '1', 'O'],
#  ['подчёркивалось', '811', '14', 'O'],
#  [',', '825', '1', 'O'],
#  ['что', '827', '3', 'O'],
#  ['она', '831', '3', 'O'],
#  ['состоится', '835', '9', 'O'],
#  ['несмотря', '845', '8', 'O'],
#  ['на', '854', '2', 'O'],
#  ['запрет', '857', '6', 'O'],
#  ['властей', '864', '7', 'O'],
#  ['.', '871', '1', 'O'],
#  [],
#  ['Освещающие', '873', '10', 'O'],
#  ['акцию', '884', '5', 'O'],
#  ['блоггеры', '890', '8', 'O'],
#  ['сообщили', '899', '8', 'O'],
#  [',', '907', '1', 'O'],
#  ['что', '909', '3', 'O'],
#  ['автобусы', '913', '8', 'O'],
#  ['с', '922', '1', 'O'],
#  ['милицией', '924', '8', 'O'],
#  ['стали', '933', '5', 'O'],
#  ['занимать', '939', '8', 'O'],
#  ['площадь', '948', '7', 'O'],
#  ['у', '956', '1', 'O'],
#  ['памятника', '958', '9', 'B-Location'],
#  ['Юрию', '968', '4', 'I-Location'],
#  ['Долгорукому', '973', '11', 'E-Location'],
#  ['ещё', '985', '3', 'O'],
#  ['с', '989', '1', 'O'],
#  ['15', '991', '2', 'O'],
#  ['часов', '994', '5', 'O'],
#  ['дня', '1000', '3', 'O'],
#  [',', '1003', '1', 'O'],
#  ['центральная', '1005', '11', 'O'],
#  ['часть', '1017', '5', 'O'],
#  ['площади', '1023', '7', 'O'],
#  ['была', '1031', '4', 'O'],
#  ['огорожена', '1036', '9', 'O'],
#  ['.', '1045', '1', 'O'],
#  [],
#  ['Ко', '1047', '2', 'O'],
#  ['времени', '1050', '7', 'O'],
#  ['начала', '1058', '6', 'O'],
#  ['акции', '1065', '5', 'O'],
#  ['вокруг', '1071', '6', 'O'],
#  ['огороженной', '1078', '11', 'O'],
#  ['территории', '1090', '10', 'O'],
#  ['собралось', '1101', '9', 'O'],
#  ['множество', '1111', '9', 'O'],
#  ['журналистов', '1121', '11', 'O'],
#  ['и', '1133', '1', 'O'],
#  ['прохожих', '1135', '8', 'O'],
#  [',', '1143', '1', 'O'],
#  ['по', '1145', '2', 'O'],
#  ['мере', '1148', '4', 'O'],
#  ['прибытия', '1153', '8', 'O'],
#  ['самих', '1162', '5', 'O'],
#  ['участников', '1168', '10', 'O'],
#  ['акции', '1179', '5', 'O'],
#  ['милиция', '1185', '7', 'O'],
#  ['начала', '1193', '6', 'O'],
#  ['планомерно', '1200', '10', 'O'],
#  ['их', '1211', '2', 'O'],
#  ['задерживать', '1214', '11', 'O'],
#  ['и', '1226', '1', 'O'],
#  ['заталкивать', '1228', '11', 'O'],
#  ['в', '1240', '1', 'O'],
#  ['автобусы', '1242', '8', 'O'],
#  ['.', '1250', '1', 'O'],
#  [],
#  ['Всего', '1253', '5', 'O'],
#  [',', '1258', '1', 'O'],
#  ['по', '1260', '2', 'O'],
#  ['сообщениям', '1263', '10', 'O'],
#  ['блоггеров', '1274', '9', 'O'],
#  ['и', '1284', '1', 'O'],
#  ['СМИ', '1286', '3', 'O'],
#  [',', '1289', '1', 'O'],
#  ['было', '1291', '4', 'O'],
#  ['задержано', '1296', '9', 'O'],
#  ['более', '1306', '5', 'O'],
#  ['30', '1312', '2', 'O'],
#  ['человек', '1315', '7', 'O'],
#  ['.', '1322', '1', 'O'],
#  [],
#  ['Пользователь', '1324', '12', 'O'],
#  ['ЖЖ', '1337', '2', 'O'],
#  ['zyalt', '1340', '5', 'S-Person'],
#  ['сообщает', '1346', '8', 'O'],
#  [',', '1354', '1', 'O'],
#  ['что', '1356', '3', 'O'],
#  ['среди', '1360', '5', 'O'],
#  ['задержанных', '1366', '11', 'O'],
#  ['оказался', '1378', '8', 'O'],
#  ['депутат', '1387', '7', 'O'],
#  ['муниципального', '1395', '14', 'B-Org'],
#  ['собрания', '1410', '8', 'I-Org'],
#  ['района', '1419', '6', 'I-Org'],
#  ['Отрадное', '1426', '8', 'E-Org'],
#  [',', '1434', '1', 'O'],
#  ['сопредседатель', '1436', '14', 'O'],
#  ['московского', '1451', '11', 'B-Org'],
#  ['отделения', '1463', '9', 'I-Org'],
#  ['движения', '1473', '8', 'S-Org'],
#  ['«', '1482', '1', 'O'],
#  ['Солидарность', '1483', '12', 'S-Org'],
#  ['»', '1495', '1', 'O'],
#  ['Михаил', '1497', '6', 'B-Person'],
#  ['Вельмакин', '1504', '9', 'E-Person'],
#  [',', '1513', '1', 'O'],
#  ['известный', '1515', '9', 'O'],
#  ['правозащитник', '1525', '13', 'O'],
#  ['Лев', '1539', '3', 'B-Person'],
#  ['Пономарев', '1543', '9', 'E-Person'],
#  [',', '1552', '1', 'O'],
#  ['координатор', '1554', '11', 'O'],
#  ['движения', '1566', '8', 'S-Org'],
#  ['«', '1575', '1', 'O'],
#  ['Левый', '1576', '5', 'B-Org'],
#  ['фронт', '1582', '5', 'E-Org'],
#  ['»', '1587', '1', 'O'],
#  ['Сергей', '1589', '6', 'B-Person'],
#  ['Удальцов', '1596', '8', 'E-Person'],
#  ['.', '1604', '1', 'O'],
#  [],
#  ['Организаторами', '1607', '14', 'O'],
#  ['акции', '1622', '5', 'O'],
#  ['выступили', '1628', '9', 'O'],
#  ['движение', '1638', '8', 'S-Org'],
#  ['«', '1647', '1', 'O'],
#  ['За', '1648', '2', 'B-Org'],
#  ['права', '1651', '5', 'I-Org'],
#  ['человека', '1657', '8', 'E-Org'],
#  ['»', '1665', '1', 'O'],
#  [',', '1666', '1', 'O'],
#  ['Союз', '1668', '4', 'I-Org'],
#  ['координационных', '1673', '15', 'I-Org'],
#  ['советов', '1689', '7', 'E-Org'],
#  ['(', '1697', '1', 'O'],
#  ['СКС', '1698', '3', 'S-Org'],
#  [')', '1701', '1', 'O'],
#  [',', '1702', '1', 'O'],
#  ['институт', '1704', '8', 'S-Org'],
#  ['«', '1713', '1', 'O'],
#  ['Коллективное', '1714', '12', 'B-Org'],
#  ['действие', '1727', '8', 'E-Org'],
#  ['»', '1735', '1', 'O'],
#  [',', '1736', '1', 'O'],
#  ['«', '1738', '1', 'O'],
#  ['Жилищная', '1739', '8', 'B-Org'],
#  ['солидарность', '1748', '12', 'E-Org'],
#  ['»', '1760', '1', 'O'],
#  [',', '1761', '1', 'O'],
#  ['Движение', '1763', '8', 'I-Org'],
#  ['общежитий', '1772', '9', 'I-Org'],
#  ['Москвы', '1782', '6', 'E-Org'],
#  [',', '1788', '1', 'O'],
#  ['Движение', '1790', '8', 'I-Org'],
#  ['в', '1799', '1', 'I-Org'],
#  ['защиту', '1801', '6', 'I-Org'],
#  ['Химкинского', '1808', '11', 'I-Org'],
#  ['леса', '1820', '4', 'E-Org'],
#  [',', '1824', '1', 'O'],
#  ['движение', '1826', '8', 'S-Org'],
#  ['«', '1835', '1', 'O'],
#  ['Московский', '1836', '10', 'B-Org'],
#  ['совет', '1847', '5', 'E-Org'],
#  ['»', '1852', '1', 'O'],
#  [',', '1853', '1', 'O'],
#  ['«', '1855', '1', 'O'],
#  ['Координационный', '1856', '15', 'I-Org'],
#  ['совет', '1872', '5', 'I-Org'],
#  ['пострадавших', '1878', '12', 'I-Org'],
#  ['соинвесторов', '1891', '12', 'E-Org'],
#  ['»', '1903', '1', 'O'],
#  ['.', '1904', '1', 'O'],
#  [],
#  ['Конец', '0', '5', 'O'],
#  ['света', '6', '5', 'O'],
#  [',', '11', '1', 'O'],
#  ['который', '13', '7', 'O'],
#  ['предрекал', '21', '9', 'O'],
#  ['проповедник', '31', '11', 'O'],
#  ['-', '42', '1', 'O'],
#  ['евангелист', '43', '10', 'O'],
#  ['Герольд', '54', '7', 'B-Person'],
#  ['Кемпинг', '62', '7', 'E-Person'],
#  ['утром', '70', '5', 'O'],
#  ['в', '76', '1', 'O'],
#  ['06.00', '78', '5', 'O'],
#  ['по', '84', '2', 'O'],
#  ['московскому', '87', '11', 'O'],
#  ['времени', '99', '7', 'O'],
#  ['21', '107', '2', 'O'],
#  ['мая', '110', '3', 'O'],
#  ['2011', '114', '4', 'O'],
#  ['года', '119', '4', 'O'],
#  ['так', '124', '3', 'O'],
#  ['и', '128', '1', 'O'],
#  ['не', '130', '2', 'O'],
#  ['наступил', '133', '8', 'O'],
#  ['.', '141', '1', 'O'],
#  [],
#  ['Это', '144', '3', 'O'],
#  ['далеко', '148', '6', 'O'],
#  ['не', '155', '2', 'O'],
#  ['первое', '158', '6', 'O'],
#  ['несбывшееся', '165', '11', 'O'],
#  ['предсказание', '177', '12', 'O'],
#  ['апокалипсиса', '190', '12', 'O'],
#  ['.', '202', '1', 'O'],
#  [],
#  ['Поначалу', '204', '8', 'O'],
#  ['на', '213', '2', 'O'],
#  ['него', '216', '4', 'O'],
#  ['практически', '221', '11', 'O'],
#  ['не', '233', '2', 'O'],
#  ['обратили', '236', '8', 'O'],
#  ['внимания', '245', '8', 'O'],
#  [',', '253', '1', 'O'],
#  ['однако', '255', '6', 'O'],
#  [',', '261', '1', 'O'],
#  ['с', '263', '1', 'O'],
#  ['приближением', '265', '12', 'O'],
#  ['этой', '278', '4', 'O'],
#  ['даты', '283', '4', 'O'],
#  [',', '287', '1', 'O'],
#  ['немало', '289', '6', 'O'],
#  ['СМИ', '296', '3', 'O'],
#  ['в', '300', '1', 'O'],
#  ['поисках', '302', '7', 'O'],
#  ['сюжета', '310', '6', 'O'],
#  [',', '316', '1', 'O'],
#  ['останавливались', '318', '15', 'O'],
#  ['на', '334', '2', 'O'],
#  ['этом', '337', '4', 'O'],
#  [',', '341', '1', 'O'],
#  ['создавая', '343', '8', 'O'],
#  ['прекрасную', '352', '10', 'O'],
#  ['бесплатную', '363', '10', 'O'],
#  ['PR-компанию', '374', '11', 'O'],
#  ['для', '386', '3', 'O'],
#  ['горе-пророка', '390', '12', 'O'],
#  ['.', '402', '1', 'O'],
#  [],
#  ['Вполне', '404', '6', 'O'],
#  ['вероятно', '411', '8', 'O'],
#  [',', '419', '1', 'O'],
#  ['что', '421', '3', 'O'],
#  ['Герольд', '425', '7', 'B-Person'],
#  ['Кемпинг', '433', '7', 'E-Person'],
#  ['объяснит', '441', '8', 'O'],
#  ['это', '450', '3', 'O'],
#  ['какой-либо', '454', '10', 'O'],
#  ['неточностью', '465', '11', 'O'],
#  ['и', '477', '1', 'O'],
#  ['перенесет', '479', '9', 'O'],
#  ['катастрофу', '489', '10', 'O'],
#  ['на', '500', '2', 'O'],
#  ['некоторое', '503', '9', 'O'],
#  ['время', '513', '5', 'O'],
#  ['вперёд', '519', '6', 'O'],
#  [',', '525', '1', 'O'],
#  ['и', '527', '1', 'O'],
#  ['по', '529', '2', 'O'],
#  ['прежнему', '532', '8', 'O'],
#  ['будет', '541', '5', 'O'],
#  ['оставаться', '547', '10', 'O'],
#  ['в', '558', '1', 'O'],
#  ['центре', '560', '6', 'O'],
#  ['внимания', '567', '8', 'O'],
#  ['.', '575', '1', 'O'],
#  [],
#  ['Так', '577', '3', 'O'],
#  [',', '580', '1', 'O'],
#  ['согласно', '582', '8', 'O'],
#  ['его', '591', '3', 'O'],
#  ['пророчествам', '595', '12', 'O'],
#  [',', '607', '1', 'O'],
#  ['6', '609', '1', 'O'],
#  ['сентября', '611', '8', 'O'],
#  ['1994', '620', '4', 'O'],
#  ['года', '625', '4', 'O'],
#  ['на', '630', '2', 'O'],
#  ['Землю', '633', '5', 'S-Location'],
#  ['должен', '639', '6', 'O'],
#  ['был', '646', '3', 'O'],
#  ['опуститься', '650', '10', 'O'],
#  ['Иисус', '661', '5', 'B-Person'],
#  ['Христос', '667', '7', 'E-Person'],
#  ['.', '674', '1', 'O'],
#  [],
#  ['Следующее', '677', '9', 'O'],
#  ['подобное', '687', '8', 'O'],
#  ['мероприятие', '696', '11', 'O'],
#  [',', '707', '1', 'O'],
#  ['по', '709', '2', 'O'],
#  ['прогнозам', '712', '9', 'O'],
#  ['майя', '722', '4', 'O'],
#  [',', '726', '1', 'O'],
#  ['ожидается', '728', '9', 'O'],
#  ['21', '738', '2', 'O'],
#  ['декабря', '741', '7', 'O'],
#  ['2012', '749', '4', 'O'],
#  ['года', '754', '4', 'O'],
#  [',', '758', '1', 'O'],
#  ['однако', '760', '6', 'O'],
#  ['не', '767', '2', 'O'],
#  ['следует', '770', '7', 'O'],
#  ['забывать', '778', '8', 'O'],
#  [',', '786', '1', 'O'],
#  ['что', '788', '3', 'O'],
#  ['конец', '792', '5', 'O'],
#  ['этой', '798', '4', 'O'],
#  ['цивилизации', '803', '11', 'O'],
#  ['наступил', '815', '8', 'O'],
#  ['значительно', '824', '11', 'O'],
#  ['раньше', '836', '6', 'O'],
#  [',', '842', '1', 'O'],
#  ['и', '844', '1', 'O'],
#  ['это', '846', '3', 'O'],
#  ['отчего-то', '850', '9', 'O'],
#  ['не', '860', '2', 'O'],
#  ['отображено', '863', '10', 'O'],
#  ['в', '874', '1', 'O'],
#  ['их', '876', '2', 'O'],
#  ['наследии', '879', '8', 'O'],
#  [',', '887', '1', 'O'],
#  ['поэтому', '889', '7', 'O'],
#  ['и', '897', '1', 'O'],
#  ['достоверность', '899', '13', 'O'],
#  ['подобного', '913', '9', 'O'],
#  ['прорицания', '923', '10', 'O'],
#  ['далеко', '934', '6', 'O'],
#  ['не', '941', '2', 'O'],
#  ['очевидна', '944', '8', 'O'],
#  ['.', '952', '1', 'O'],
#  [],
#  ['Если', '955', '4', 'O'],
#  ['-', '959', '1', 'O'],
#  ['же', '960', '2', 'O'],
#  ['и', '963', '1', 'O'],
#  ['майя', '965', '4', 'O'],
#  ['ошиблись', '970', '8', 'O'],
#  [',', '978', '1', 'O'],
#  ['то', '980', '2', 'O'],
#  ['расслабляться', '983', '13', 'O'],
#  ['всё-равно', '997', '9', 'O'],
#  ['не', '1007', '2', 'O'],
#  ['стоит', '1010', '5', 'O'],
#  ['.', '1015', '1', 'O'],
#  [],
#  ['Апокалиптических', '1017', '16', 'O'],
#  ['теорий', '1034', '6', 'O'],
#  ['ещё', '1041', '3', 'O'],
#  ['достаточно', '1045', '10', 'O'],
#  [':', '1055', '1', 'O'],
#  [],
#  ['*', '1058', '1', 'O'],
#  ['2021', '1060', '4', 'O'],
#  ['год', '1065', '3', 'O'],
#  ['—', '1069', '1', 'O'],
#  ['инверсия', '1071', '8', 'O'],
#  ['магнитного', '1080', '10', 'O'],
#  ['поля', '1091', '4', 'O'],
#  ['Земли', '1096', '5', 'S-Location'],
#  ['уничтожит', '1102', '9', 'O'],
#  ['часть', '1112', '5', 'O'],
#  ['человечества', '1118', '12', 'O'],
#  ['.', '1130', '1', 'O'],
#  [],
#  ['*', '1132', '1', 'O'],
#  ['2060', '1134', '4', 'O'],
#  ['год', '1139', '3', 'O'],
#  ['—', '1143', '1', 'O'],
#  ['Согласно', '1145', '8', 'O'],
#  ['расчётам', '1154', '8', 'O'],
#  ['Исаака', '1163', '6', 'B-Person'],
#  ['Ньютона', '1170', '7', 'E-Person'],
#  [',', '1177', '1', 'O'],
#  ['сделанным', '1179', '9', 'O'],
#  ['в', '1189', '1', 'O'],
#  ['1704', '1191', '4', 'O'],
#  ['году', '1196', '4', 'O'],
#  ['по', '1201', '2', 'O'],
#  ['библейской', '1204', '10', 'O'],
#  ['книге', '1215', '5', 'O'],
#  ['Даниила', '1221', '7', 'S-Person'],
#  ['станет', '1229', '6', 'O'],
#  ['последним', '1236', '9', 'O'],
#  ['для', '1246', '3', 'O'],
#  ['людей', '1250', '5', 'O'],
#  ['.', '1255', '1', 'O'],
#  [],
#  ['*', '1257', '1', 'O'],
#  ['2242', '1259', '4', 'O'],
#  ['год', '1264', '3', 'O'],
#  ['—', '1268', '1', 'O'],
#  ['конец', '1270', '5', 'O'],
#  ['эпохи', '1276', '5', 'O'],
#  ['Солнца', '1282', '6', 'S-Location'],
#  ['согласно', '1289', '8', 'O'],
#  ['теории', '1298', '6', 'O'],
#  ['смены', '1305', '5', 'O'],
#  ['планетных', '1311', '9', 'O'],
#  ['эпох', '1321', '4', 'O'],
#  [',', '1325', '1', 'O'],
#  ['которая', '1327', '7', 'O'],
#  ['была', '1335', '4', 'O'],
#  ['изложена', '1340', '8', 'O'],
#  ['в', '1349', '1', 'O'],
#  ['работах', '1351', '7', 'O'],
#  ['ибн', '1359', '3', 'B-Person'],
#  ['Эзра', '1363', '4', 'E-Person'],
#  [',', '1367', '1', 'O'],
#  ['Авраама', '1369', '7', 'S-Person'],
#  ['и', '1377', '1', 'O'],
#  ['Абу', '1379', '3', 'B-Person'],
#  ['Машара', '1383', '6', 'E-Person'],
#  ['.', '1389', '1', 'O'],
#  [],
#  ['*', '1391', '1', 'O'],
#  ['2892', '1393', '4', 'O'],
#  ['год', '1398', '3', 'O'],
#  ['—', '1402', '1', 'O'],
#  ['апокалипсис', '1404', '11', 'O'],
#  ['обещанный', '1416', '9', 'O'],
#  ['Авелем', '1426', '6', 'S-Person'],
#  ['.', '1432', '1', 'O'],
#  [],
#  ['*', '1434', '1', 'O'],
#  ['3797', '1436', '4', 'O'],
#  ['год', '1441', '3', 'O'],
#  ['—', '1445', '1', 'O'],
#  ['кончину', '1447', '7', 'O'],
#  ['миру', '1455', '4', 'O'],
#  ['предрёк', '1460', '7', 'O'],
#  ['сам', '1468', '3', 'O'],
#  ['Нострадамус', '1472', '11', 'S-Person'],
#  ['.', '1483', '1', 'O'],
#  [],
#  ['*', '1485', '1', 'O'],
#  ['5079', '1487', '4', 'O'],
#  ['год', '1492', '3', 'O'],
#  ['—', '1496', '1', 'O'],
#  ['сочла', '1498', '5', 'O'],
#  ['последним', '1504', '9', 'O'],
#  ['всемирно', '1514', '8', 'O'],
#  ['известная', '1523', '9', 'O'],
#  ['Ванга', '1533', '5', 'S-Person'],
#  ['…', '1539', '1', 'O'],
#  [],
#  ['Промышленный', '0', '12', 'B-Org'],
#  ['и', '13', '1', 'I-Org'],
#  ['коммерческий', '15', '12', 'I-Org'],
#  ['банк', '28', '4', 'I-Org'],
#  ['Китая', '33', '5', 'E-Org'],
#  ['(', '39', '1', 'O'],
#  ['Industrial', '40', '10', 'B-Org'],
#  ['and', '51', '3', 'I-Org'],
#  ['Commercial', '55', '10', 'I-Org'],
#  ['Bank', '66', '4', 'I-Org'],
#  ['of', '71', '2', 'I-Org'],
#  ['China', '74', '5', 'E-Org'],
#  [')', '79', '1', 'O'],
#  [',', '80', '1', 'O'],
#  ['по', '82', '2', 'O'],
#  ['некоторым', '85', '9', 'O'],
#  ['показателям', '95', '11', 'O'],
#  ['—', '107', '1', 'O'],
#  ['крупнейший', '109', '10', 'O'],
#  ['банк', '120', '4', 'O'],
#  ['мира', '125', '4', 'O'],
#  [',', '129', '1', 'O'],
#  ['подписал', '131', '8', 'O'],
#  ['соглашение', '140', '10', 'O'],
#  ['о', '151', '1', 'O'],
#  ['покупке', '153', '7', 'O'],
#  ['контрольной', '161', '11', 'O'],
#  ['доли', '173', '4', 'O'],
#  ['в', '178', '1', 'O'],
#  ['американском', '180', '12', 'B-Org'],
#  ['отделении', '193', '9', 'I-Org'],
#  ['Bank', '203', '4', 'I-Org'],
#  ['of', '208', '2', 'I-Org'],
#  ['East', '211', '4', 'I-Org'],
#  ['Asia', '216', '4', 'E-Org'],
#  [',', '220', '1', 'O'],
#  ['управляющим', '222', '11', 'O'],
#  ['13-ю', '234', '4', 'O'],
#  ['филиалами', '239', '9', 'O'],
#  ['в', '249', '1', 'O'],
#  ['Калифорнии', '251', '10', 'S-Location'],
#  ['и', '262', '1', 'O'],
#  ['Нью-Йорке', '264', '9', 'S-Location'],
#  ['.', '273', '1', 'O'],
#  [],
#  ['За', '275', '2', 'O'],
#  ['80', '278', '2', 'O'],
#  ['процентов', '281', '9', 'O'],
#  ['акций', '291', '5', 'O'],
#  ['этой', '297', '4', 'O'],
#  ['финансовой', '302', '10', 'O'],
#  ['структуры', '313', '9', 'O'],
#  [',', '322', '1', 'O'],
#  ['подконтрольный', '324', '14', 'B-Org'],
#  ['китайскому', '339', '10', 'B-Org'],
#  ['правительству', '350', '13', 'E-Org'],
#  ['банк', '364', '4', 'I-Org'],
#  ['заплатит', '369', '8', 'O'],
#  ['около', '378', '5', 'O'],
#  ['100', '384', '3', 'O'],
#  ['млн', '388', '3', 'O'],
#  ['долларов', '392', '8', 'O'],
#  ['.', '400', '1', 'O'],
#  [],
#  ['Соглашение', '403', '10', 'O'],
#  ['было', '414', '4', 'O'],
#  ['подписано', '419', '9', 'O'],
#  ['в', '429', '1', 'O'],
#  ['минувшую', '431', '8', 'O'],
#  ['пятницу', '440', '7', 'O'],
#  ['в', '448', '1', 'O'],
#  ['Чикаго', '450', '6', 'S-Location'],
#  [',', '456', '1', 'O'],
#  ['в', '458', '1', 'O'],
#  ['последний', '460', '9', 'O'],
#  ['день', '470', '4', 'O'],
#  ['визита', '475', '6', 'O'],
#  ['председателя', '482', '12', 'O'],
#  ['КНР', '495', '3', 'S-LocOrg'],
#  ['Ху', '499', '2', 'B-Person'],
#  ['Цзиньтао', '502', '8', 'E-Person'],
#  ['в', '511', '1', 'O'],
#  ['США', '513', '3', 'S-Location'],
#  ['.', '516', '1', 'O'],
#  [],
#  ['Сделка', '518', '6', 'O'],
#  ['ожидает', '525', '7', 'O'],
#  ['утверждения', '533', '11', 'O'],
#  ['американскими', '545', '13', 'O'],
#  ['регулирующими', '559', '13', 'O'],
#  ['органами', '573', '8', 'O'],
#  [',', '581', '1', 'O'],
#  ['что', '583', '3', 'O'],
#  ['может', '587', '5', 'O'],
#  ['задержать', '593', '9', 'O'],
#  ['ее', '603', '2', 'O'],
#  ['завершение', '606', '10', 'O'],
#  ['до', '617', '2', 'O'],
#  ['конца', '620', '5', 'O'],
#  ['этого', '626', '5', 'O'],
#  ['года', '632', '4', 'O'],
#  ['.', '636', '1', 'O'],
#  [],
#  ['Доля', '639', '4', 'O'],
#  ['правительства', '644', '13', 'B-Org'],
#  ['Китая', '658', '5', 'E-Org'],
#  ['в', '664', '1', 'O'],
#  ['Industrial', '666', '10', 'B-Org'],
#  ['and', '677', '3', 'I-Org'],
#  ['Commercial', '681', '10', 'I-Org'],
#  ['Bank', '692', '4', 'I-Org'],
#  ['of', '697', '2', 'I-Org'],
#  ['China', '700', '5', 'E-Org'],
#  ['составляет', '706', '10', 'O'],
#  ['70', '717', '2', 'O'],
#  ['процентов', '720', '9', 'O'],
#  ['.', '729', '1', 'O'],
#  [],
#  ['Если', '731', '4', 'O'],
#  ['сделка', '736', '6', 'O'],
#  ['будет', '743', '5', 'O'],
#  ['утверждена', '749', '10', 'O'],
#  [',', '759', '1', 'O'],
#  ['то', '761', '2', 'O'],
#  ['государственный', '764', '15', 'B-Org'],
#  ['китайский', '780', '9', 'I-Org'],
#  ['банк', '790', '4', 'I-Org'],
#  ['впервые', '795', '7', 'O'],
#  ['в', '803', '1', 'O'],
#  ['истории', '805', '7', 'O'],
#  ['получит', '813', '7', 'O'],
#  ['контроль', '821', '8', 'O'],
#  ['над', '830', '3', 'O'],
#  ['американским', '834', '12', 'O'],
#  ['финансовым', '847', '10', 'O'],
#  ['учреждением', '858', '11', 'O'],
#  ['.', '869', '1', 'O'],
#  [],
#  ['Американцы', '871', '10', 'O'],
#  ['смогут', '882', '6', 'O'],
#  ['делать', '889', '6', 'O'],
#  ['вклады', '896', '6', 'O'],
#  ['в', '903', '1', 'O'],
#  ['его', '905', '3', 'O'],
#  ['филиалах', '909', '8', 'O'],
#  [',', '917', '1', 'O'],
#  ['а', '919', '1', 'O'],
#  ['инвесторы', '921', '9', 'O'],
#  ['смогут', '931', '6', 'O'],
#  ['открывать', '938', '9', 'O'],
#  ['счета', '948', '5', 'O'],
#  ['и', '954', '1', 'O'],
#  ['играть', '956', '6', 'O'],
#  ['на', '963', '2', 'O'],
#  ['курсе', '966', '5', 'O'],
#  ['юаня', '972', '4', 'O'],
#  ['.', '976', '1', 'O'],
#  [],
#  ['За', '979', '2', 'O'],
#  ['последние', '982', '9', 'O'],
#  ['годы', '992', '4', 'O'],
#  ['размеры', '997', '7', 'O'],
#  ['иностранных', '1005', '11', 'O'],
#  ['инвестиций', '1017', '10', 'O'],
#  ['Китая', '1028', '5', 'S-LocOrg'],
#  ['резко', '1034', '5', 'O'],
#  ['увеличились', '1040', '11', 'O'],
#  [',', '1051', '1', 'O'],
#  ['однако', '1053', '6', 'O'],
#  ['расширение', '1060', '10', 'O'],
#  ['китайских', '1071', '9', 'O'],
#  ['финансовых', '1081', '10', 'O'],
#  ['учреждений', '1092', '10', 'O'],
#  ['проходило', '1103', '9', 'O'],
#  ['гораздо', '1113', '7', 'O'],
#  ['медленнее', '1121', '9', 'O'],
#  ['.', '1130', '1', 'O'],
#  [],
#  ['При', '1132', '3', 'O'],
#  ['подписании', '1136', '10', 'O'],
#  ['нового', '1147', '6', 'O'],
#  ['соглашения', '1154', '10', 'O'],
#  ['министр', '1165', '7', 'O'],
#  ['торговли', '1173', '8', 'O'],
#  ['Китая', '1182', '5', 'S-LocOrg'],
#  ['Чэнь', '1188', '4', 'B-Person'],
#  ['Дэмин', '1193', '5', 'E-Person'],
#  ['заявил', '1199', '6', 'O'],
#  [',', '1205', '1', 'O'],
#  ['что', '1207', '3', 'O'],
#  ['одним', '1211', '5', 'O'],
#  ['из', '1217', '2', 'O'],
#  ['приоритетов', '1220', '11', 'O'],
#  ['является', '1232', '8', 'O'],
#  ['перевод', '1241', '7', 'O'],
#  ['огромных', '1249', '8', 'O'],
#  ['резервов', '1258', '8', 'O'],
#  ['иностранной', '1267', '11', 'O'],
#  ['валюты', '1279', '6', 'O'],
#  ['в', '1286', '1', 'O'],
#  ['зарубежные', '1288', '10', 'O'],
#  ['активы', '1299', '6', 'O'],
#  ['.', '1305', '1', 'O'],
#  [],
#  ['Барак', '0', '5', 'B-Person'],
#  ['Обама', '6', '5', 'E-Person'],
#  ['принимает', '12', '9', 'O'],
#  ['в', '22', '1', 'O'],
#  ['Белом', '24', '5', 'B-Location'],
#  ['доме', '30', '4', 'I-Location'],
#  ['своего', '35', '6', 'O'],
#  ['французского', '42', '12', 'O'],
#  ['коллегу', '55', '7', 'O'],
#  ['Николя', '63', '6', 'B-Person'],
#  ['Саркози', '70', '7', 'E-Person'],
#  ['.', '77', '1', 'O'],
#  [],
#  ['Как', '79', '3', 'O'],
#  ['было', '83', '4', 'O'],
#  ['объявлено', '88', '9', 'O'],
#  [',', '97', '1', 'O'],
#  ['президент', '99', '9', 'O'],
#  ['Франции', '109', '7', 'S-LocOrg'],
#  ['прибыл', '117', '6', 'O'],
#  ['в', '124', '1', 'O'],
#  ['Вашингтон', '126', '9', 'S-Location'],
#  [',', '135', '1', 'O'],
#  ['чтобы', '137', '5', 'O'],
#  ['обсудить', '143', '8', 'O'],
#  ['с', '152', '1', 'O'],
#  ['главой', '154', '6', 'O'],
#  ['администрации', '161', '13', 'B-Org'],
#  ['США', '175', '3', 'E-Org'],
#  ['ряд', '179', '3', 'O'],
#  ['насущных', '183', '8', 'O'],
#  ['проблем', '192', '7', 'O'],
#  [',', '199', '1', 'O'],
#  ['главное', '201', '7', 'O'],
#  ['место', '209', '5', 'O'],
#  ['среди', '215', '5', 'O'],
#  ['которых', '221', '7', 'O'],
#  ['занимает', '229', '8', 'O'],
#  ['состояние', '238', '9', 'O'],
#  ['мировой', '248', '7', 'O'],
#  ['экономики', '256', '9', 'O'],
#  ['и', '266', '1', 'O'],
#  ['безопасность', '268', '12', 'O'],
#  ['.', '280', '1', 'O'],
#  [],
#  ['В', '283', '1', 'O'],
#  ['частности', '285', '9', 'O'],
#  [',', '294', '1', 'O'],
#  ['лидеры', '296', '6', 'O'],
#  ['намерены', '303', '8', 'O'],
#  ['обменяться', '312', '10', 'O'],
#  ['мнениями', '323', '8', 'O'],
#  ['о', '332', '1', 'O'],
#  ['перспективах', '334', '12', 'O'],
#  ['военных', '347', '7', 'O'],
#  ['действий', '355', '8', 'O'],
#  ['НАТО', '364', '4', 'S-Org'],
#  ['в', '369', '1', 'O'],
#  ['Афганистане', '371', '11', 'S-Location'],
#  [',', '382', '1', 'O'],
#  ['волнениях', '384', '9', 'O'],
#  ['в', '394', '1', 'O'],
#  ['Пакистане', '396', '9', 'S-Location'],
#  ['и', '406', '1', 'O'],
#  ['угрозах', '408', '7', 'O'],
#  ['экстремистов', '416', '12', 'O'],
#  ['в', '429', '1', 'O'],
#  ['Северной', '431', '8', 'B-Location'],
#  ['Африке', '440', '6', 'E-Location'],
#  ['.', '446', '1', 'O'],
#  [],
#  ['В', '448', '1', 'O'],
#  ['воскресенье', '450', '11', 'O'],
#  ['Николя', '462', '6', 'B-Person'],
#  ['Саркози', '469', '7', 'E-Person'],
#  ['выпустил', '477', '8', 'O'],
#  ['заявление', '486', '9', 'O'],
#  ['с', '496', '1', 'O'],
#  ['осуждением', '498', '10', 'O'],
#  ['убийства', '509', '8', 'O'],
#  ['двух', '518', '4', 'O'],
#  ['французских', '523', '11', 'O'],
#  ['заложников', '535', '10', 'O'],
#  ['в', '546', '1', 'O'],
#  ['Нигере', '548', '6', 'S-Location'],
#  ['.', '554', '1', 'O'],
#  [],
#  ['В', '557', '1', 'O'],
#  ['недавнем', '559', '8', 'O'],
#  ['выступлении', '568', '11', 'O'],
#  ['по', '580', '2', 'O'],
#  ['французскому', '583', '12', 'O'],
#  ['телевидению', '596', '11', 'O'],
#  ['Саркози', '608', '7', 'S-Person'],
#  ['выразил', '616', '7', 'O'],
#  ['мнение', '624', '6', 'O'],
#  ['о', '631', '1', 'O'],
#  ['необходимости', '633', '13', 'O'],
#  ['изменить', '647', '8', 'O'],
#  ['ситуацию', '656', '8', 'O'],
#  ['в', '665', '1', 'O'],
#  ['глобальной', '667', '10', 'O'],
#  ['экономике', '678', '9', 'O'],
#  [',', '687', '1', 'O'],
#  ['при', '689', '3', 'O'],
#  ['которой', '693', '7', 'O'],
#  ['доллар', '701', '6', 'O'],
#  ['остается', '708', '8', 'O'],
#  ['главным', '717', '7', 'O'],
#  ['инструментом', '725', '12', 'O'],
#  ['расчетов', '738', '8', 'O'],
#  ['и', '747', '1', 'O'],
#  ['мировой', '749', '7', 'O'],
#  ['резервной', '757', '9', 'O'],
#  ['валютой', '767', '7', 'O'],
#  ['.', '774', '1', 'O'],
#  [],
#  ['Вашингтонская', '776', '13', 'O'],
#  ['встреча', '790', '7', 'O'],
#  ['проходит', '798', '8', 'O'],
#  ['в', '807', '1', 'O'],
#  ['канун', '809', '5', 'O'],
#  ['передачи', '815', '8', 'O'],
#  ['Франции', '824', '7', 'S-LocOrg'],
#  ['полномочий', '832', '10', 'O'],
#  ['главы', '843', '5', 'O'],
#  ['«', '849', '1', 'O'],
#  ['Большой', '850', '7', 'B-Org'],
#  ['двадцатки', '858', '9', 'E-Org'],
#  ['»', '867', '1', 'O'],
#  ['.', '868', '1', 'O'],
#  [],
#  ['Президент', '870', '9', 'O'],
#  ['Саркози', '880', '7', 'S-Person'],
#  ['выразил', '888', '7', 'O'],
#  ['в', '896', '1', 'O'],
#  ['этой', '898', '4', 'O'],
#  ['связи', '903', '5', 'O'],
#  ['надежду', '909', '7', 'O'],
#  ['на', '917', '2', 'O'],
#  ['то', '920', '2', 'O'],
#  [',', '922', '1', 'O'],
#  ['что', '924', '3', 'O'],
#  ['ему', '928', '3', 'O'],
#  ['удастся', '932', '7', 'O'],
#  ['за', '940', '2', 'O'],
#  ['время', '943', '5', 'O'],
#  ['председательства', '949', '16', 'O'],
#  ['в', '966', '1', 'O'],
#  ['G-20', '968', '4', 'S-Org'],
#  ['провести', '973', '8', 'O'],
#  ['целый', '982', '5', 'O'],
#  ['ряд', '988', '3', 'O'],
#  ['реформ', '992', '6', 'O'],
#  ['.', '998', '1', 'O'],
#  [],
#  ['22-летний', '0', '9', 'O'],
#  ['житель', '10', '6', 'O'],
#  ['Аризоны', '17', '7', 'S-Location'],
#  [',', '24', '1', 'O'],
#  ['открывший', '26', '9', 'O'],
#  ['стрельбу', '36', '8', 'O'],
#  [',', '44', '1', 'O'],
#  ['в', '46', '1', 'O'],
#  ['результате', '48', '10', 'O'],
#  ['которой', '59', '7', 'O'],
#  ['пострадали', '67', '10', 'O'],
#  ['20', '78', '2', 'O'],
#  ['человек', '81', '7', 'O'],
#  [',', '88', '1', 'O'],
#  ['и', '90', '1', 'O'],
#  ['попытавшийся', '92', '12', 'O'],
#  ['убить', '105', '5', 'O'],
#  ['члена', '111', '5', 'O'],
#  ['Конгресса', '117', '9', 'B-Org'],
#  ['США', '127', '3', 'E-Org'],
#  [',', '130', '1', 'O'],
#  ['впервые', '132', '7', 'O'],
#  ['предстал', '140', '8', 'O'],
#  ['перед', '149', '5', 'O'],
#  ['судом', '155', '5', 'O'],
#  ['по', '161', '2', 'O'],
#  ['обвинению', '164', '9', 'O'],
#  ['в', '174', '1', 'O'],
#  ['совершении', '176', '10', 'O'],
#  ['федерального', '187', '12', 'O'],
#  ['преступления', '200', '12', 'O'],
#  ['.', '212', '1', 'O'],
#  [],
#  ['В', '215', '1', 'O'],
#  ['понедельник', '217', '11', 'O'],
#  ['Джаред', '229', '6', 'B-Person'],
#  ['Лофнер', '236', '6', 'E-Person'],
#  ['в', '243', '1', 'O'],
#  ['наручниках', '245', '10', 'O'],
#  ['и', '256', '1', 'O'],
#  ['в', '258', '1', 'O'],
#  ['сопровождении', '260', '13', 'O'],
#  ['нескольких', '274', '10', 'O'],
#  ['охранников', '285', '10', 'O'],
#  ['доставлен', '296', '9', 'O'],
#  ['в', '306', '1', 'O'],
#  ['суд', '308', '3', 'O'],
#  ['в', '312', '1', 'O'],
#  ['города', '314', '6', 'B-Location'],
#  ['Феникс', '321', '6', 'E-Location'],
#  ['.', '327', '1', 'O'],
#  [],
#  ['Побритый', '329', '8', 'O'],
#  ['наголо', '338', '6', 'O'],
#  ['и', '345', '1', 'O'],
#  ['одетый', '347', '6', 'O'],
#  ['в', '354', '1', 'O'],
#  ['тюремную', '356', '8', 'O'],
#  ...]

# %%
def prepare(dataset):
    factrueval_dev_tokens = dict()
    factrueval_dev_tokens_list = []
    factrueval_dev_spans = dict()
    factrueval_dev_objects = dict()
    for file in os.listdir('./'+ dataset + '/'):
        if file.endswith('tokens'):
            with open('./' + dataset + '/' + file, 'r+', encoding='utf-8') as file_obj:
                lines = file_obj.readlines()
                tokens = [line.rstrip().split() for line in lines if line.rstrip().split() != []]
                for token in tokens:
                    factrueval_dev_tokens[int(token[0])] = token[1:]
                tokens = [line.rstrip().split() for line in lines]
                for token in tokens:
                    factrueval_dev_tokens_list.append(token)

        if file.endswith('spans'):
            with open('./' + dataset + '/' + file, 'r+', encoding='utf-8') as file_obj:
                spans = [line.rstrip().split() for line in file_obj.readlines() if line.rstrip().split() != []]
                for span in spans:
                    factrueval_dev_spans[span[0]] = span[1:]

        if file.endswith('objects'):
            with open('./' + dataset + '/' + file, 'r+', encoding='utf-8') as file_obj:
                objects = [line.rstrip().split('#')[0].split() for line in file_obj.readlines() if line.rstrip().split() != []]
                for obj in objects:
                    factrueval_dev_objects[obj[0]] = obj[1:]

    all_ne = []
    for key, value in factrueval_dev_objects.items():
        spans = value[1:]
        ne = value[0]
        all_tokens = []
        for span in spans:
            span_obj = factrueval_dev_spans[span]
            token = int(span_obj[3])
            num_of_tokens = int(span_obj[4])
            for i in range(num_of_tokens):
                all_tokens.append(token + i)
        all_ne.append([ne, sorted(all_tokens)])

    for ne_tokens in all_ne:
        ne = ne_tokens[0]
        token = ne_tokens[1]
        for i in range(len(token)):
            if token[i] in factrueval_dev_tokens.keys():
                if len(token) == 1:
                    factrueval_dev_tokens[token[i]].append("S-" + ne)
                elif (i == 0 and token[i + 1] - token[i] > 1) or (i == len(token) - 1 and token[i] - token[i - 1] > 1) or (token[i] - token[i - 1] > 1 and token[i + 1] - token[i] > 1):
                    factrueval_dev_tokens[token[i]].append("S-" + ne)
                elif (i == 0  and token[i + 1] - token[i] == 1) or (i != len(token) - 1 and token[i] - token[i - 1] > 1 and token[i + 1] - token[i] == 1):
                    factrueval_dev_tokens[token[i]].append("B-" + ne)
                elif (i == len(token) - 1 and token[i] - token[i - 1] == 1) or (i != 0 and token[i] - token[i - 1] == 1 and token[i + 1] - token[i] > 1):
                    factrueval_dev_tokens[token[i]].append("E-" + ne)
                else: 
                    factrueval_dev_tokens[token[i]].append("I-" + ne)

    for i in range(len(factrueval_dev_tokens_list)):
        if factrueval_dev_tokens_list[i] == []:
            continue
        number_of_token = factrueval_dev_tokens_list[i][0]
        if int(number_of_token) in factrueval_dev_tokens.keys() and len(factrueval_dev_tokens[int(number_of_token)]) >= 4:
            ne = factrueval_dev_tokens[int(number_of_token)][3]
            factrueval_dev_tokens_list[i].append(ne)
        else:
            factrueval_dev_tokens_list[i].append("O")

    final = []
    for el in factrueval_dev_tokens_list:
        if el == []:
            final.append(el)
        else:
            final.append([el[3], el[1], el[2], el[4]])
    return final

# %%
devset = prepare('devset')

# %%
devset
# Out:
# [['В', '0', '1', 'O'],
#  ['понедельник', '2', '11', 'O'],
#  ['28', '14', '2', 'O'],
#  ['июня', '17', '4', 'O'],
#  ['у', '22', '1', 'O'],
#  ['здания', '24', '6', 'O'],
#  ['мэрии', '31', '5', 'B-Org'],
#  ['Москвы', '37', '6', 'E-Org'],
#  ['на', '44', '2', 'O'],
#  ['Тверской', '47', '8', 'B-Location'],
#  ['площади', '56', '7', 'E-Location'],
#  ['состоялась', '64', '10', 'O'],
#  ['очередная', '75', '9', 'O'],
#  ['несанкционированная', '85', '19', 'O'],
#  ['акция', '105', '5', 'O'],
#  ['протеста', '111', '8', 'O'],
#  ['«', '120', '1', 'O'],
#  ['День', '121', '4', 'O'],
#  ['гнева', '126', '5', 'O'],
#  ['»', '131', '1', 'O'],
#  [',', '132', '1', 'O'],
#  ['в', '134', '1', 'O'],
#  ['этот', '136', '4', 'O'],
#  ['раз', '141', '3', 'O'],
#  ['направленная', '145', '12', 'O'],
#  [',', '157', '1', 'O'],
#  ['главным', '159', '7', 'O'],
#  ['образом', '167', '7', 'O'],
#  [',', '174', '1', 'O'],
#  ['против', '176', '6', 'O'],
#  ['политики', '183', '8', 'O'],
#  ['московских', '192', '10', 'O'],
#  ['и', '203', '1', 'O'],
#  ['подмосковных', '205', '12', 'O'],
#  ['властей', '218', '7', 'O'],
#  ['.', '225', '1', 'O'],
#  [],
#  ['Среди', '227', '5', 'O'],
#  ['требований', '233', '10', 'O'],
#  [',', '243', '1', 'O'],
#  ['выдвигаемых', '245', '11', 'O'],
#  ['организаторами', '257', '14', 'O'],
#  ['акции', '272', '5', 'O'],
#  [':', '277', '1', 'O'],
#  ['«', '279', '1', 'O'],
#  ['немедленная', '280', '11', 'O'],
#  ['отставка', '292', '8', 'O'],
#  ['мэра', '301', '4', 'O'],
#  ['Москвы', '306', '6', 'S-LocOrg'],
#  ['Юрия', '313', '4', 'B-Person'],
#  ['Лужкова', '318', '7', 'E-Person'],
#  [',', '325', '1', 'O'],
#  ['расследование', '327', '13', 'O'],
#  ['итогов', '341', '6', 'O'],
#  ['его', '348', '3', 'O'],
#  ['деятельности', '352', '12', 'O'],
#  ['»', '364', '1', 'O'],
#  [',', '365', '1', 'O'],
#  ['«', '367', '1', 'O'],
#  ['созыв', '368', '5', 'O'],
#  ['московского', '374', '11', 'O'],
#  ['общественного', '386', '13', 'O'],
#  ['форума', '400', '6', 'O'],
#  ['для', '407', '3', 'O'],
#  ['обсуждения', '411', '10', 'O'],
#  ['путей', '422', '5', 'O'],
#  ['реформирования', '428', '14', 'O'],
#  ['основных', '443', '8', 'O'],
#  ['сфер', '452', '4', 'O'],
#  ['жизнедеятельности', '457', '17', 'O'],
#  ['в', '475', '1', 'O'],
#  ['Москве', '477', '6', 'S-Location'],
#  ['»', '483', '1', 'O'],
#  [',', '484', '1', 'O'],
#  ['«', '486', '1', 'O'],
#  ['восстановление', '487', '14', 'O'],
#  ['прямых', '502', '6', 'O'],
#  ['выборов', '509', '7', 'O'],
#  ['глав', '517', '4', 'O'],
#  ['регионов', '522', '8', 'O'],
#  ['России', '531', '6', 'S-LocOrg'],
#  ['»', '537', '1', 'O'],
#  [',', '538', '1', 'O'],
#  ['«', '540', '1', 'O'],
#  ['роспуск', '541', '7', 'O'],
#  ['нелегитимной', '549', '12', 'O'],
#  ['Мосгордумы', '562', '10', 'S-Org'],
#  ['»', '572', '1', 'O'],
#  [',', '573', '1', 'O'],
#  ['отставка', '575', '8', 'O'],
#  ['подмосковного', '584', '13', 'S-LocOrg'],
#  ['губернатора', '598', '11', 'O'],
#  ['Бориса', '610', '6', 'B-Person'],
#  ['Громова', '617', '7', 'E-Person'],
#  ['и', '625', '1', 'O'],
#  ['др', '627', '2', 'O'],
#  ['.', '629', '1', 'O'],
#  [],
#  ['Участникам', '631', '10', 'O'],
#  ['акции', '642', '5', 'O'],
#  ['предлагалось', '648', '12', 'O'],
#  ['принести', '661', '8', 'O'],
#  ['с', '670', '1', 'O'],
#  ['собой', '672', '5', 'O'],
#  ['лист', '678', '4', 'O'],
#  ['бумаги', '683', '6', 'O'],
#  ['или', '690', '3', 'O'],
#  ['кусок', '694', '5', 'O'],
#  ['ткани', '700', '5', 'O'],
#  ['чёрного', '706', '7', 'O'],
#  ['цвета', '714', '5', 'O'],
#  [',', '719', '1', 'O'],
#  ['символизирующие', '721', '15', 'O'],
#  ['«', '737', '1', 'O'],
#  ['чёрную', '738', '6', 'O'],
#  ['метку', '745', '5', 'O'],
#  ['»', '750', '1', 'O'],
#  ['для', '752', '3', 'O'],
#  ['Юрия', '756', '4', 'B-Person'],
#  ['Лужкова', '761', '7', 'E-Person'],
#  ['.', '768', '1', 'O'],
#  [],
#  ['Начало', '771', '6', 'O'],
#  ['акции', '778', '5', 'O'],
#  ['было', '784', '4', 'O'],
#  ['намечено', '789', '8', 'O'],
#  ['на', '798', '2', 'O'],
#  ['19', '801', '2', 'O'],
#  ['часов', '804', '5', 'O'],
#  [';', '809', '1', 'O'],
#  ['подчёркивалось', '811', '14', 'O'],
#  [',', '825', '1', 'O'],
#  ['что', '827', '3', 'O'],
#  ['она', '831', '3', 'O'],
#  ['состоится', '835', '9', 'O'],
#  ['несмотря', '845', '8', 'O'],
#  ['на', '854', '2', 'O'],
#  ['запрет', '857', '6', 'O'],
#  ['властей', '864', '7', 'O'],
#  ['.', '871', '1', 'O'],
#  [],
#  ['Освещающие', '873', '10', 'O'],
#  ['акцию', '884', '5', 'O'],
#  ['блоггеры', '890', '8', 'O'],
#  ['сообщили', '899', '8', 'O'],
#  [',', '907', '1', 'O'],
#  ['что', '909', '3', 'O'],
#  ['автобусы', '913', '8', 'O'],
#  ['с', '922', '1', 'O'],
#  ['милицией', '924', '8', 'O'],
#  ['стали', '933', '5', 'O'],
#  ['занимать', '939', '8', 'O'],
#  ['площадь', '948', '7', 'O'],
#  ['у', '956', '1', 'O'],
#  ['памятника', '958', '9', 'B-Location'],
#  ['Юрию', '968', '4', 'I-Location'],
#  ['Долгорукому', '973', '11', 'E-Location'],
#  ['ещё', '985', '3', 'O'],
#  ['с', '989', '1', 'O'],
#  ['15', '991', '2', 'O'],
#  ['часов', '994', '5', 'O'],
#  ['дня', '1000', '3', 'O'],
#  [',', '1003', '1', 'O'],
#  ['центральная', '1005', '11', 'O'],
#  ['часть', '1017', '5', 'O'],
#  ['площади', '1023', '7', 'O'],
#  ['была', '1031', '4', 'O'],
#  ['огорожена', '1036', '9', 'O'],
#  ['.', '1045', '1', 'O'],
#  [],
#  ['Ко', '1047', '2', 'O'],
#  ['времени', '1050', '7', 'O'],
#  ['начала', '1058', '6', 'O'],
#  ['акции', '1065', '5', 'O'],
#  ['вокруг', '1071', '6', 'O'],
#  ['огороженной', '1078', '11', 'O'],
#  ['территории', '1090', '10', 'O'],
#  ['собралось', '1101', '9', 'O'],
#  ['множество', '1111', '9', 'O'],
#  ['журналистов', '1121', '11', 'O'],
#  ['и', '1133', '1', 'O'],
#  ['прохожих', '1135', '8', 'O'],
#  [',', '1143', '1', 'O'],
#  ['по', '1145', '2', 'O'],
#  ['мере', '1148', '4', 'O'],
#  ['прибытия', '1153', '8', 'O'],
#  ['самих', '1162', '5', 'O'],
#  ['участников', '1168', '10', 'O'],
#  ['акции', '1179', '5', 'O'],
#  ['милиция', '1185', '7', 'O'],
#  ['начала', '1193', '6', 'O'],
#  ['планомерно', '1200', '10', 'O'],
#  ['их', '1211', '2', 'O'],
#  ['задерживать', '1214', '11', 'O'],
#  ['и', '1226', '1', 'O'],
#  ['заталкивать', '1228', '11', 'O'],
#  ['в', '1240', '1', 'O'],
#  ['автобусы', '1242', '8', 'O'],
#  ['.', '1250', '1', 'O'],
#  [],
#  ['Всего', '1253', '5', 'O'],
#  [',', '1258', '1', 'O'],
#  ['по', '1260', '2', 'O'],
#  ['сообщениям', '1263', '10', 'O'],
#  ['блоггеров', '1274', '9', 'O'],
#  ['и', '1284', '1', 'O'],
#  ['СМИ', '1286', '3', 'O'],
#  [',', '1289', '1', 'O'],
#  ['было', '1291', '4', 'O'],
#  ['задержано', '1296', '9', 'O'],
#  ['более', '1306', '5', 'O'],
#  ['30', '1312', '2', 'O'],
#  ['человек', '1315', '7', 'O'],
#  ['.', '1322', '1', 'O'],
#  [],
#  ['Пользователь', '1324', '12', 'O'],
#  ['ЖЖ', '1337', '2', 'O'],
#  ['zyalt', '1340', '5', 'S-Person'],
#  ['сообщает', '1346', '8', 'O'],
#  [',', '1354', '1', 'O'],
#  ['что', '1356', '3', 'O'],
#  ['среди', '1360', '5', 'O'],
#  ['задержанных', '1366', '11', 'O'],
#  ['оказался', '1378', '8', 'O'],
#  ['депутат', '1387', '7', 'O'],
#  ['муниципального', '1395', '14', 'B-Org'],
#  ['собрания', '1410', '8', 'I-Org'],
#  ['района', '1419', '6', 'I-Org'],
#  ['Отрадное', '1426', '8', 'E-Org'],
#  [',', '1434', '1', 'O'],
#  ['сопредседатель', '1436', '14', 'O'],
#  ['московского', '1451', '11', 'B-Org'],
#  ['отделения', '1463', '9', 'I-Org'],
#  ['движения', '1473', '8', 'S-Org'],
#  ['«', '1482', '1', 'O'],
#  ['Солидарность', '1483', '12', 'S-Org'],
#  ['»', '1495', '1', 'O'],
#  ['Михаил', '1497', '6', 'B-Person'],
#  ['Вельмакин', '1504', '9', 'E-Person'],
#  [',', '1513', '1', 'O'],
#  ['известный', '1515', '9', 'O'],
#  ['правозащитник', '1525', '13', 'O'],
#  ['Лев', '1539', '3', 'B-Person'],
#  ['Пономарев', '1543', '9', 'E-Person'],
#  [',', '1552', '1', 'O'],
#  ['координатор', '1554', '11', 'O'],
#  ['движения', '1566', '8', 'S-Org'],
#  ['«', '1575', '1', 'O'],
#  ['Левый', '1576', '5', 'B-Org'],
#  ['фронт', '1582', '5', 'E-Org'],
#  ['»', '1587', '1', 'O'],
#  ['Сергей', '1589', '6', 'B-Person'],
#  ['Удальцов', '1596', '8', 'E-Person'],
#  ['.', '1604', '1', 'O'],
#  [],
#  ['Организаторами', '1607', '14', 'O'],
#  ['акции', '1622', '5', 'O'],
#  ['выступили', '1628', '9', 'O'],
#  ['движение', '1638', '8', 'S-Org'],
#  ['«', '1647', '1', 'O'],
#  ['За', '1648', '2', 'B-Org'],
#  ['права', '1651', '5', 'I-Org'],
#  ['человека', '1657', '8', 'E-Org'],
#  ['»', '1665', '1', 'O'],
#  [',', '1666', '1', 'O'],
#  ['Союз', '1668', '4', 'I-Org'],
#  ['координационных', '1673', '15', 'I-Org'],
#  ['советов', '1689', '7', 'E-Org'],
#  ['(', '1697', '1', 'O'],
#  ['СКС', '1698', '3', 'S-Org'],
#  [')', '1701', '1', 'O'],
#  [',', '1702', '1', 'O'],
#  ['институт', '1704', '8', 'S-Org'],
#  ['«', '1713', '1', 'O'],
#  ['Коллективное', '1714', '12', 'B-Org'],
#  ['действие', '1727', '8', 'E-Org'],
#  ['»', '1735', '1', 'O'],
#  [',', '1736', '1', 'O'],
#  ['«', '1738', '1', 'O'],
#  ['Жилищная', '1739', '8', 'B-Org'],
#  ['солидарность', '1748', '12', 'E-Org'],
#  ['»', '1760', '1', 'O'],
#  [',', '1761', '1', 'O'],
#  ['Движение', '1763', '8', 'I-Org'],
#  ['общежитий', '1772', '9', 'I-Org'],
#  ['Москвы', '1782', '6', 'E-Org'],
#  [',', '1788', '1', 'O'],
#  ['Движение', '1790', '8', 'I-Org'],
#  ['в', '1799', '1', 'I-Org'],
#  ['защиту', '1801', '6', 'I-Org'],
#  ['Химкинского', '1808', '11', 'I-Org'],
#  ['леса', '1820', '4', 'E-Org'],
#  [',', '1824', '1', 'O'],
#  ['движение', '1826', '8', 'S-Org'],
#  ['«', '1835', '1', 'O'],
#  ['Московский', '1836', '10', 'B-Org'],
#  ['совет', '1847', '5', 'E-Org'],
#  ['»', '1852', '1', 'O'],
#  [',', '1853', '1', 'O'],
#  ['«', '1855', '1', 'O'],
#  ['Координационный', '1856', '15', 'I-Org'],
#  ['совет', '1872', '5', 'I-Org'],
#  ['пострадавших', '1878', '12', 'I-Org'],
#  ['соинвесторов', '1891', '12', 'E-Org'],
#  ['»', '1903', '1', 'O'],
#  ['.', '1904', '1', 'O'],
#  [],
#  ['Конец', '0', '5', 'O'],
#  ['света', '6', '5', 'O'],
#  [',', '11', '1', 'O'],
#  ['который', '13', '7', 'O'],
#  ['предрекал', '21', '9', 'O'],
#  ['проповедник', '31', '11', 'O'],
#  ['-', '42', '1', 'O'],
#  ['евангелист', '43', '10', 'O'],
#  ['Герольд', '54', '7', 'B-Person'],
#  ['Кемпинг', '62', '7', 'E-Person'],
#  ['утром', '70', '5', 'O'],
#  ['в', '76', '1', 'O'],
#  ['06.00', '78', '5', 'O'],
#  ['по', '84', '2', 'O'],
#  ['московскому', '87', '11', 'O'],
#  ['времени', '99', '7', 'O'],
#  ['21', '107', '2', 'O'],
#  ['мая', '110', '3', 'O'],
#  ['2011', '114', '4', 'O'],
#  ['года', '119', '4', 'O'],
#  ['так', '124', '3', 'O'],
#  ['и', '128', '1', 'O'],
#  ['не', '130', '2', 'O'],
#  ['наступил', '133', '8', 'O'],
#  ['.', '141', '1', 'O'],
#  [],
#  ['Это', '144', '3', 'O'],
#  ['далеко', '148', '6', 'O'],
#  ['не', '155', '2', 'O'],
#  ['первое', '158', '6', 'O'],
#  ['несбывшееся', '165', '11', 'O'],
#  ['предсказание', '177', '12', 'O'],
#  ['апокалипсиса', '190', '12', 'O'],
#  ['.', '202', '1', 'O'],
#  [],
#  ['Поначалу', '204', '8', 'O'],
#  ['на', '213', '2', 'O'],
#  ['него', '216', '4', 'O'],
#  ['практически', '221', '11', 'O'],
#  ['не', '233', '2', 'O'],
#  ['обратили', '236', '8', 'O'],
#  ['внимания', '245', '8', 'O'],
#  [',', '253', '1', 'O'],
#  ['однако', '255', '6', 'O'],
#  [',', '261', '1', 'O'],
#  ['с', '263', '1', 'O'],
#  ['приближением', '265', '12', 'O'],
#  ['этой', '278', '4', 'O'],
#  ['даты', '283', '4', 'O'],
#  [',', '287', '1', 'O'],
#  ['немало', '289', '6', 'O'],
#  ['СМИ', '296', '3', 'O'],
#  ['в', '300', '1', 'O'],
#  ['поисках', '302', '7', 'O'],
#  ['сюжета', '310', '6', 'O'],
#  [',', '316', '1', 'O'],
#  ['останавливались', '318', '15', 'O'],
#  ['на', '334', '2', 'O'],
#  ['этом', '337', '4', 'O'],
#  [',', '341', '1', 'O'],
#  ['создавая', '343', '8', 'O'],
#  ['прекрасную', '352', '10', 'O'],
#  ['бесплатную', '363', '10', 'O'],
#  ['PR-компанию', '374', '11', 'O'],
#  ['для', '386', '3', 'O'],
#  ['горе-пророка', '390', '12', 'O'],
#  ['.', '402', '1', 'O'],
#  [],
#  ['Вполне', '404', '6', 'O'],
#  ['вероятно', '411', '8', 'O'],
#  [',', '419', '1', 'O'],
#  ['что', '421', '3', 'O'],
#  ['Герольд', '425', '7', 'B-Person'],
#  ['Кемпинг', '433', '7', 'E-Person'],
#  ['объяснит', '441', '8', 'O'],
#  ['это', '450', '3', 'O'],
#  ['какой-либо', '454', '10', 'O'],
#  ['неточностью', '465', '11', 'O'],
#  ['и', '477', '1', 'O'],
#  ['перенесет', '479', '9', 'O'],
#  ['катастрофу', '489', '10', 'O'],
#  ['на', '500', '2', 'O'],
#  ['некоторое', '503', '9', 'O'],
#  ['время', '513', '5', 'O'],
#  ['вперёд', '519', '6', 'O'],
#  [',', '525', '1', 'O'],
#  ['и', '527', '1', 'O'],
#  ['по', '529', '2', 'O'],
#  ['прежнему', '532', '8', 'O'],
#  ['будет', '541', '5', 'O'],
#  ['оставаться', '547', '10', 'O'],
#  ['в', '558', '1', 'O'],
#  ['центре', '560', '6', 'O'],
#  ['внимания', '567', '8', 'O'],
#  ['.', '575', '1', 'O'],
#  [],
#  ['Так', '577', '3', 'O'],
#  [',', '580', '1', 'O'],
#  ['согласно', '582', '8', 'O'],
#  ['его', '591', '3', 'O'],
#  ['пророчествам', '595', '12', 'O'],
#  [',', '607', '1', 'O'],
#  ['6', '609', '1', 'O'],
#  ['сентября', '611', '8', 'O'],
#  ['1994', '620', '4', 'O'],
#  ['года', '625', '4', 'O'],
#  ['на', '630', '2', 'O'],
#  ['Землю', '633', '5', 'S-Location'],
#  ['должен', '639', '6', 'O'],
#  ['был', '646', '3', 'O'],
#  ['опуститься', '650', '10', 'O'],
#  ['Иисус', '661', '5', 'B-Person'],
#  ['Христос', '667', '7', 'E-Person'],
#  ['.', '674', '1', 'O'],
#  [],
#  ['Следующее', '677', '9', 'O'],
#  ['подобное', '687', '8', 'O'],
#  ['мероприятие', '696', '11', 'O'],
#  [',', '707', '1', 'O'],
#  ['по', '709', '2', 'O'],
#  ['прогнозам', '712', '9', 'O'],
#  ['майя', '722', '4', 'O'],
#  [',', '726', '1', 'O'],
#  ['ожидается', '728', '9', 'O'],
#  ['21', '738', '2', 'O'],
#  ['декабря', '741', '7', 'O'],
#  ['2012', '749', '4', 'O'],
#  ['года', '754', '4', 'O'],
#  [',', '758', '1', 'O'],
#  ['однако', '760', '6', 'O'],
#  ['не', '767', '2', 'O'],
#  ['следует', '770', '7', 'O'],
#  ['забывать', '778', '8', 'O'],
#  [',', '786', '1', 'O'],
#  ['что', '788', '3', 'O'],
#  ['конец', '792', '5', 'O'],
#  ['этой', '798', '4', 'O'],
#  ['цивилизации', '803', '11', 'O'],
#  ['наступил', '815', '8', 'O'],
#  ['значительно', '824', '11', 'O'],
#  ['раньше', '836', '6', 'O'],
#  [',', '842', '1', 'O'],
#  ['и', '844', '1', 'O'],
#  ['это', '846', '3', 'O'],
#  ['отчего-то', '850', '9', 'O'],
#  ['не', '860', '2', 'O'],
#  ['отображено', '863', '10', 'O'],
#  ['в', '874', '1', 'O'],
#  ['их', '876', '2', 'O'],
#  ['наследии', '879', '8', 'O'],
#  [',', '887', '1', 'O'],
#  ['поэтому', '889', '7', 'O'],
#  ['и', '897', '1', 'O'],
#  ['достоверность', '899', '13', 'O'],
#  ['подобного', '913', '9', 'O'],
#  ['прорицания', '923', '10', 'O'],
#  ['далеко', '934', '6', 'O'],
#  ['не', '941', '2', 'O'],
#  ['очевидна', '944', '8', 'O'],
#  ['.', '952', '1', 'O'],
#  [],
#  ['Если', '955', '4', 'O'],
#  ['-', '959', '1', 'O'],
#  ['же', '960', '2', 'O'],
#  ['и', '963', '1', 'O'],
#  ['майя', '965', '4', 'O'],
#  ['ошиблись', '970', '8', 'O'],
#  [',', '978', '1', 'O'],
#  ['то', '980', '2', 'O'],
#  ['расслабляться', '983', '13', 'O'],
#  ['всё-равно', '997', '9', 'O'],
#  ['не', '1007', '2', 'O'],
#  ['стоит', '1010', '5', 'O'],
#  ['.', '1015', '1', 'O'],
#  [],
#  ['Апокалиптических', '1017', '16', 'O'],
#  ['теорий', '1034', '6', 'O'],
#  ['ещё', '1041', '3', 'O'],
#  ['достаточно', '1045', '10', 'O'],
#  [':', '1055', '1', 'O'],
#  [],
#  ['*', '1058', '1', 'O'],
#  ['2021', '1060', '4', 'O'],
#  ['год', '1065', '3', 'O'],
#  ['—', '1069', '1', 'O'],
#  ['инверсия', '1071', '8', 'O'],
#  ['магнитного', '1080', '10', 'O'],
#  ['поля', '1091', '4', 'O'],
#  ['Земли', '1096', '5', 'S-Location'],
#  ['уничтожит', '1102', '9', 'O'],
#  ['часть', '1112', '5', 'O'],
#  ['человечества', '1118', '12', 'O'],
#  ['.', '1130', '1', 'O'],
#  [],
#  ['*', '1132', '1', 'O'],
#  ['2060', '1134', '4', 'O'],
#  ['год', '1139', '3', 'O'],
#  ['—', '1143', '1', 'O'],
#  ['Согласно', '1145', '8', 'O'],
#  ['расчётам', '1154', '8', 'O'],
#  ['Исаака', '1163', '6', 'B-Person'],
#  ['Ньютона', '1170', '7', 'E-Person'],
#  [',', '1177', '1', 'O'],
#  ['сделанным', '1179', '9', 'O'],
#  ['в', '1189', '1', 'O'],
#  ['1704', '1191', '4', 'O'],
#  ['году', '1196', '4', 'O'],
#  ['по', '1201', '2', 'O'],
#  ['библейской', '1204', '10', 'O'],
#  ['книге', '1215', '5', 'O'],
#  ['Даниила', '1221', '7', 'S-Person'],
#  ['станет', '1229', '6', 'O'],
#  ['последним', '1236', '9', 'O'],
#  ['для', '1246', '3', 'O'],
#  ['людей', '1250', '5', 'O'],
#  ['.', '1255', '1', 'O'],
#  [],
#  ['*', '1257', '1', 'O'],
#  ['2242', '1259', '4', 'O'],
#  ['год', '1264', '3', 'O'],
#  ['—', '1268', '1', 'O'],
#  ['конец', '1270', '5', 'O'],
#  ['эпохи', '1276', '5', 'O'],
#  ['Солнца', '1282', '6', 'S-Location'],
#  ['согласно', '1289', '8', 'O'],
#  ['теории', '1298', '6', 'O'],
#  ['смены', '1305', '5', 'O'],
#  ['планетных', '1311', '9', 'O'],
#  ['эпох', '1321', '4', 'O'],
#  [',', '1325', '1', 'O'],
#  ['которая', '1327', '7', 'O'],
#  ['была', '1335', '4', 'O'],
#  ['изложена', '1340', '8', 'O'],
#  ['в', '1349', '1', 'O'],
#  ['работах', '1351', '7', 'O'],
#  ['ибн', '1359', '3', 'B-Person'],
#  ['Эзра', '1363', '4', 'E-Person'],
#  [',', '1367', '1', 'O'],
#  ['Авраама', '1369', '7', 'S-Person'],
#  ['и', '1377', '1', 'O'],
#  ['Абу', '1379', '3', 'B-Person'],
#  ['Машара', '1383', '6', 'E-Person'],
#  ['.', '1389', '1', 'O'],
#  [],
#  ['*', '1391', '1', 'O'],
#  ['2892', '1393', '4', 'O'],
#  ['год', '1398', '3', 'O'],
#  ['—', '1402', '1', 'O'],
#  ['апокалипсис', '1404', '11', 'O'],
#  ['обещанный', '1416', '9', 'O'],
#  ['Авелем', '1426', '6', 'S-Person'],
#  ['.', '1432', '1', 'O'],
#  [],
#  ['*', '1434', '1', 'O'],
#  ['3797', '1436', '4', 'O'],
#  ['год', '1441', '3', 'O'],
#  ['—', '1445', '1', 'O'],
#  ['кончину', '1447', '7', 'O'],
#  ['миру', '1455', '4', 'O'],
#  ['предрёк', '1460', '7', 'O'],
#  ['сам', '1468', '3', 'O'],
#  ['Нострадамус', '1472', '11', 'S-Person'],
#  ['.', '1483', '1', 'O'],
#  [],
#  ['*', '1485', '1', 'O'],
#  ['5079', '1487', '4', 'O'],
#  ['год', '1492', '3', 'O'],
#  ['—', '1496', '1', 'O'],
#  ['сочла', '1498', '5', 'O'],
#  ['последним', '1504', '9', 'O'],
#  ['всемирно', '1514', '8', 'O'],
#  ['известная', '1523', '9', 'O'],
#  ['Ванга', '1533', '5', 'S-Person'],
#  ['…', '1539', '1', 'O'],
#  [],
#  ['Промышленный', '0', '12', 'B-Org'],
#  ['и', '13', '1', 'I-Org'],
#  ['коммерческий', '15', '12', 'I-Org'],
#  ['банк', '28', '4', 'I-Org'],
#  ['Китая', '33', '5', 'E-Org'],
#  ['(', '39', '1', 'O'],
#  ['Industrial', '40', '10', 'B-Org'],
#  ['and', '51', '3', 'I-Org'],
#  ['Commercial', '55', '10', 'I-Org'],
#  ['Bank', '66', '4', 'I-Org'],
#  ['of', '71', '2', 'I-Org'],
#  ['China', '74', '5', 'E-Org'],
#  [')', '79', '1', 'O'],
#  [',', '80', '1', 'O'],
#  ['по', '82', '2', 'O'],
#  ['некоторым', '85', '9', 'O'],
#  ['показателям', '95', '11', 'O'],
#  ['—', '107', '1', 'O'],
#  ['крупнейший', '109', '10', 'O'],
#  ['банк', '120', '4', 'O'],
#  ['мира', '125', '4', 'O'],
#  [',', '129', '1', 'O'],
#  ['подписал', '131', '8', 'O'],
#  ['соглашение', '140', '10', 'O'],
#  ['о', '151', '1', 'O'],
#  ['покупке', '153', '7', 'O'],
#  ['контрольной', '161', '11', 'O'],
#  ['доли', '173', '4', 'O'],
#  ['в', '178', '1', 'O'],
#  ['американском', '180', '12', 'B-Org'],
#  ['отделении', '193', '9', 'I-Org'],
#  ['Bank', '203', '4', 'I-Org'],
#  ['of', '208', '2', 'I-Org'],
#  ['East', '211', '4', 'I-Org'],
#  ['Asia', '216', '4', 'E-Org'],
#  [',', '220', '1', 'O'],
#  ['управляющим', '222', '11', 'O'],
#  ['13-ю', '234', '4', 'O'],
#  ['филиалами', '239', '9', 'O'],
#  ['в', '249', '1', 'O'],
#  ['Калифорнии', '251', '10', 'S-Location'],
#  ['и', '262', '1', 'O'],
#  ['Нью-Йорке', '264', '9', 'S-Location'],
#  ['.', '273', '1', 'O'],
#  [],
#  ['За', '275', '2', 'O'],
#  ['80', '278', '2', 'O'],
#  ['процентов', '281', '9', 'O'],
#  ['акций', '291', '5', 'O'],
#  ['этой', '297', '4', 'O'],
#  ['финансовой', '302', '10', 'O'],
#  ['структуры', '313', '9', 'O'],
#  [',', '322', '1', 'O'],
#  ['подконтрольный', '324', '14', 'B-Org'],
#  ['китайскому', '339', '10', 'B-Org'],
#  ['правительству', '350', '13', 'E-Org'],
#  ['банк', '364', '4', 'I-Org'],
#  ['заплатит', '369', '8', 'O'],
#  ['около', '378', '5', 'O'],
#  ['100', '384', '3', 'O'],
#  ['млн', '388', '3', 'O'],
#  ['долларов', '392', '8', 'O'],
#  ['.', '400', '1', 'O'],
#  [],
#  ['Соглашение', '403', '10', 'O'],
#  ['было', '414', '4', 'O'],
#  ['подписано', '419', '9', 'O'],
#  ['в', '429', '1', 'O'],
#  ['минувшую', '431', '8', 'O'],
#  ['пятницу', '440', '7', 'O'],
#  ['в', '448', '1', 'O'],
#  ['Чикаго', '450', '6', 'S-Location'],
#  [',', '456', '1', 'O'],
#  ['в', '458', '1', 'O'],
#  ['последний', '460', '9', 'O'],
#  ['день', '470', '4', 'O'],
#  ['визита', '475', '6', 'O'],
#  ['председателя', '482', '12', 'O'],
#  ['КНР', '495', '3', 'S-LocOrg'],
#  ['Ху', '499', '2', 'B-Person'],
#  ['Цзиньтао', '502', '8', 'E-Person'],
#  ['в', '511', '1', 'O'],
#  ['США', '513', '3', 'S-Location'],
#  ['.', '516', '1', 'O'],
#  [],
#  ['Сделка', '518', '6', 'O'],
#  ['ожидает', '525', '7', 'O'],
#  ['утверждения', '533', '11', 'O'],
#  ['американскими', '545', '13', 'O'],
#  ['регулирующими', '559', '13', 'O'],
#  ['органами', '573', '8', 'O'],
#  [',', '581', '1', 'O'],
#  ['что', '583', '3', 'O'],
#  ['может', '587', '5', 'O'],
#  ['задержать', '593', '9', 'O'],
#  ['ее', '603', '2', 'O'],
#  ['завершение', '606', '10', 'O'],
#  ['до', '617', '2', 'O'],
#  ['конца', '620', '5', 'O'],
#  ['этого', '626', '5', 'O'],
#  ['года', '632', '4', 'O'],
#  ['.', '636', '1', 'O'],
#  [],
#  ['Доля', '639', '4', 'O'],
#  ['правительства', '644', '13', 'B-Org'],
#  ['Китая', '658', '5', 'E-Org'],
#  ['в', '664', '1', 'O'],
#  ['Industrial', '666', '10', 'B-Org'],
#  ['and', '677', '3', 'I-Org'],
#  ['Commercial', '681', '10', 'I-Org'],
#  ['Bank', '692', '4', 'I-Org'],
#  ['of', '697', '2', 'I-Org'],
#  ['China', '700', '5', 'E-Org'],
#  ['составляет', '706', '10', 'O'],
#  ['70', '717', '2', 'O'],
#  ['процентов', '720', '9', 'O'],
#  ['.', '729', '1', 'O'],
#  [],
#  ['Если', '731', '4', 'O'],
#  ['сделка', '736', '6', 'O'],
#  ['будет', '743', '5', 'O'],
#  ['утверждена', '749', '10', 'O'],
#  [',', '759', '1', 'O'],
#  ['то', '761', '2', 'O'],
#  ['государственный', '764', '15', 'B-Org'],
#  ['китайский', '780', '9', 'I-Org'],
#  ['банк', '790', '4', 'I-Org'],
#  ['впервые', '795', '7', 'O'],
#  ['в', '803', '1', 'O'],
#  ['истории', '805', '7', 'O'],
#  ['получит', '813', '7', 'O'],
#  ['контроль', '821', '8', 'O'],
#  ['над', '830', '3', 'O'],
#  ['американским', '834', '12', 'O'],
#  ['финансовым', '847', '10', 'O'],
#  ['учреждением', '858', '11', 'O'],
#  ['.', '869', '1', 'O'],
#  [],
#  ['Американцы', '871', '10', 'O'],
#  ['смогут', '882', '6', 'O'],
#  ['делать', '889', '6', 'O'],
#  ['вклады', '896', '6', 'O'],
#  ['в', '903', '1', 'O'],
#  ['его', '905', '3', 'O'],
#  ['филиалах', '909', '8', 'O'],
#  [',', '917', '1', 'O'],
#  ['а', '919', '1', 'O'],
#  ['инвесторы', '921', '9', 'O'],
#  ['смогут', '931', '6', 'O'],
#  ['открывать', '938', '9', 'O'],
#  ['счета', '948', '5', 'O'],
#  ['и', '954', '1', 'O'],
#  ['играть', '956', '6', 'O'],
#  ['на', '963', '2', 'O'],
#  ['курсе', '966', '5', 'O'],
#  ['юаня', '972', '4', 'O'],
#  ['.', '976', '1', 'O'],
#  [],
#  ['За', '979', '2', 'O'],
#  ['последние', '982', '9', 'O'],
#  ['годы', '992', '4', 'O'],
#  ['размеры', '997', '7', 'O'],
#  ['иностранных', '1005', '11', 'O'],
#  ['инвестиций', '1017', '10', 'O'],
#  ['Китая', '1028', '5', 'S-LocOrg'],
#  ['резко', '1034', '5', 'O'],
#  ['увеличились', '1040', '11', 'O'],
#  [',', '1051', '1', 'O'],
#  ['однако', '1053', '6', 'O'],
#  ['расширение', '1060', '10', 'O'],
#  ['китайских', '1071', '9', 'O'],
#  ['финансовых', '1081', '10', 'O'],
#  ['учреждений', '1092', '10', 'O'],
#  ['проходило', '1103', '9', 'O'],
#  ['гораздо', '1113', '7', 'O'],
#  ['медленнее', '1121', '9', 'O'],
#  ['.', '1130', '1', 'O'],
#  [],
#  ['При', '1132', '3', 'O'],
#  ['подписании', '1136', '10', 'O'],
#  ['нового', '1147', '6', 'O'],
#  ['соглашения', '1154', '10', 'O'],
#  ['министр', '1165', '7', 'O'],
#  ['торговли', '1173', '8', 'O'],
#  ['Китая', '1182', '5', 'S-LocOrg'],
#  ['Чэнь', '1188', '4', 'B-Person'],
#  ['Дэмин', '1193', '5', 'E-Person'],
#  ['заявил', '1199', '6', 'O'],
#  [',', '1205', '1', 'O'],
#  ['что', '1207', '3', 'O'],
#  ['одним', '1211', '5', 'O'],
#  ['из', '1217', '2', 'O'],
#  ['приоритетов', '1220', '11', 'O'],
#  ['является', '1232', '8', 'O'],
#  ['перевод', '1241', '7', 'O'],
#  ['огромных', '1249', '8', 'O'],
#  ['резервов', '1258', '8', 'O'],
#  ['иностранной', '1267', '11', 'O'],
#  ['валюты', '1279', '6', 'O'],
#  ['в', '1286', '1', 'O'],
#  ['зарубежные', '1288', '10', 'O'],
#  ['активы', '1299', '6', 'O'],
#  ['.', '1305', '1', 'O'],
#  [],
#  ['Барак', '0', '5', 'B-Person'],
#  ['Обама', '6', '5', 'E-Person'],
#  ['принимает', '12', '9', 'O'],
#  ['в', '22', '1', 'O'],
#  ['Белом', '24', '5', 'B-Location'],
#  ['доме', '30', '4', 'I-Location'],
#  ['своего', '35', '6', 'O'],
#  ['французского', '42', '12', 'O'],
#  ['коллегу', '55', '7', 'O'],
#  ['Николя', '63', '6', 'B-Person'],
#  ['Саркози', '70', '7', 'E-Person'],
#  ['.', '77', '1', 'O'],
#  [],
#  ['Как', '79', '3', 'O'],
#  ['было', '83', '4', 'O'],
#  ['объявлено', '88', '9', 'O'],
#  [',', '97', '1', 'O'],
#  ['президент', '99', '9', 'O'],
#  ['Франции', '109', '7', 'S-LocOrg'],
#  ['прибыл', '117', '6', 'O'],
#  ['в', '124', '1', 'O'],
#  ['Вашингтон', '126', '9', 'S-Location'],
#  [',', '135', '1', 'O'],
#  ['чтобы', '137', '5', 'O'],
#  ['обсудить', '143', '8', 'O'],
#  ['с', '152', '1', 'O'],
#  ['главой', '154', '6', 'O'],
#  ['администрации', '161', '13', 'B-Org'],
#  ['США', '175', '3', 'E-Org'],
#  ['ряд', '179', '3', 'O'],
#  ['насущных', '183', '8', 'O'],
#  ['проблем', '192', '7', 'O'],
#  [',', '199', '1', 'O'],
#  ['главное', '201', '7', 'O'],
#  ['место', '209', '5', 'O'],
#  ['среди', '215', '5', 'O'],
#  ['которых', '221', '7', 'O'],
#  ['занимает', '229', '8', 'O'],
#  ['состояние', '238', '9', 'O'],
#  ['мировой', '248', '7', 'O'],
#  ['экономики', '256', '9', 'O'],
#  ['и', '266', '1', 'O'],
#  ['безопасность', '268', '12', 'O'],
#  ['.', '280', '1', 'O'],
#  [],
#  ['В', '283', '1', 'O'],
#  ['частности', '285', '9', 'O'],
#  [',', '294', '1', 'O'],
#  ['лидеры', '296', '6', 'O'],
#  ['намерены', '303', '8', 'O'],
#  ['обменяться', '312', '10', 'O'],
#  ['мнениями', '323', '8', 'O'],
#  ['о', '332', '1', 'O'],
#  ['перспективах', '334', '12', 'O'],
#  ['военных', '347', '7', 'O'],
#  ['действий', '355', '8', 'O'],
#  ['НАТО', '364', '4', 'S-Org'],
#  ['в', '369', '1', 'O'],
#  ['Афганистане', '371', '11', 'S-Location'],
#  [',', '382', '1', 'O'],
#  ['волнениях', '384', '9', 'O'],
#  ['в', '394', '1', 'O'],
#  ['Пакистане', '396', '9', 'S-Location'],
#  ['и', '406', '1', 'O'],
#  ['угрозах', '408', '7', 'O'],
#  ['экстремистов', '416', '12', 'O'],
#  ['в', '429', '1', 'O'],
#  ['Северной', '431', '8', 'B-Location'],
#  ['Африке', '440', '6', 'E-Location'],
#  ['.', '446', '1', 'O'],
#  [],
#  ['В', '448', '1', 'O'],
#  ['воскресенье', '450', '11', 'O'],
#  ['Николя', '462', '6', 'B-Person'],
#  ['Саркози', '469', '7', 'E-Person'],
#  ['выпустил', '477', '8', 'O'],
#  ['заявление', '486', '9', 'O'],
#  ['с', '496', '1', 'O'],
#  ['осуждением', '498', '10', 'O'],
#  ['убийства', '509', '8', 'O'],
#  ['двух', '518', '4', 'O'],
#  ['французских', '523', '11', 'O'],
#  ['заложников', '535', '10', 'O'],
#  ['в', '546', '1', 'O'],
#  ['Нигере', '548', '6', 'S-Location'],
#  ['.', '554', '1', 'O'],
#  [],
#  ['В', '557', '1', 'O'],
#  ['недавнем', '559', '8', 'O'],
#  ['выступлении', '568', '11', 'O'],
#  ['по', '580', '2', 'O'],
#  ['французскому', '583', '12', 'O'],
#  ['телевидению', '596', '11', 'O'],
#  ['Саркози', '608', '7', 'S-Person'],
#  ['выразил', '616', '7', 'O'],
#  ['мнение', '624', '6', 'O'],
#  ['о', '631', '1', 'O'],
#  ['необходимости', '633', '13', 'O'],
#  ['изменить', '647', '8', 'O'],
#  ['ситуацию', '656', '8', 'O'],
#  ['в', '665', '1', 'O'],
#  ['глобальной', '667', '10', 'O'],
#  ['экономике', '678', '9', 'O'],
#  [',', '687', '1', 'O'],
#  ['при', '689', '3', 'O'],
#  ['которой', '693', '7', 'O'],
#  ['доллар', '701', '6', 'O'],
#  ['остается', '708', '8', 'O'],
#  ['главным', '717', '7', 'O'],
#  ['инструментом', '725', '12', 'O'],
#  ['расчетов', '738', '8', 'O'],
#  ['и', '747', '1', 'O'],
#  ['мировой', '749', '7', 'O'],
#  ['резервной', '757', '9', 'O'],
#  ['валютой', '767', '7', 'O'],
#  ['.', '774', '1', 'O'],
#  [],
#  ['Вашингтонская', '776', '13', 'O'],
#  ['встреча', '790', '7', 'O'],
#  ['проходит', '798', '8', 'O'],
#  ['в', '807', '1', 'O'],
#  ['канун', '809', '5', 'O'],
#  ['передачи', '815', '8', 'O'],
#  ['Франции', '824', '7', 'S-LocOrg'],
#  ['полномочий', '832', '10', 'O'],
#  ['главы', '843', '5', 'O'],
#  ['«', '849', '1', 'O'],
#  ['Большой', '850', '7', 'B-Org'],
#  ['двадцатки', '858', '9', 'E-Org'],
#  ['»', '867', '1', 'O'],
#  ['.', '868', '1', 'O'],
#  [],
#  ['Президент', '870', '9', 'O'],
#  ['Саркози', '880', '7', 'S-Person'],
#  ['выразил', '888', '7', 'O'],
#  ['в', '896', '1', 'O'],
#  ['этой', '898', '4', 'O'],
#  ['связи', '903', '5', 'O'],
#  ['надежду', '909', '7', 'O'],
#  ['на', '917', '2', 'O'],
#  ['то', '920', '2', 'O'],
#  [',', '922', '1', 'O'],
#  ['что', '924', '3', 'O'],
#  ['ему', '928', '3', 'O'],
#  ['удастся', '932', '7', 'O'],
#  ['за', '940', '2', 'O'],
#  ['время', '943', '5', 'O'],
#  ['председательства', '949', '16', 'O'],
#  ['в', '966', '1', 'O'],
#  ['G-20', '968', '4', 'S-Org'],
#  ['провести', '973', '8', 'O'],
#  ['целый', '982', '5', 'O'],
#  ['ряд', '988', '3', 'O'],
#  ['реформ', '992', '6', 'O'],
#  ['.', '998', '1', 'O'],
#  [],
#  ['22-летний', '0', '9', 'O'],
#  ['житель', '10', '6', 'O'],
#  ['Аризоны', '17', '7', 'S-Location'],
#  [',', '24', '1', 'O'],
#  ['открывший', '26', '9', 'O'],
#  ['стрельбу', '36', '8', 'O'],
#  [',', '44', '1', 'O'],
#  ['в', '46', '1', 'O'],
#  ['результате', '48', '10', 'O'],
#  ['которой', '59', '7', 'O'],
#  ['пострадали', '67', '10', 'O'],
#  ['20', '78', '2', 'O'],
#  ['человек', '81', '7', 'O'],
#  [',', '88', '1', 'O'],
#  ['и', '90', '1', 'O'],
#  ['попытавшийся', '92', '12', 'O'],
#  ['убить', '105', '5', 'O'],
#  ['члена', '111', '5', 'O'],
#  ['Конгресса', '117', '9', 'B-Org'],
#  ['США', '127', '3', 'E-Org'],
#  [',', '130', '1', 'O'],
#  ['впервые', '132', '7', 'O'],
#  ['предстал', '140', '8', 'O'],
#  ['перед', '149', '5', 'O'],
#  ['судом', '155', '5', 'O'],
#  ['по', '161', '2', 'O'],
#  ['обвинению', '164', '9', 'O'],
#  ['в', '174', '1', 'O'],
#  ['совершении', '176', '10', 'O'],
#  ['федерального', '187', '12', 'O'],
#  ['преступления', '200', '12', 'O'],
#  ['.', '212', '1', 'O'],
#  [],
#  ['В', '215', '1', 'O'],
#  ['понедельник', '217', '11', 'O'],
#  ['Джаред', '229', '6', 'B-Person'],
#  ['Лофнер', '236', '6', 'E-Person'],
#  ['в', '243', '1', 'O'],
#  ['наручниках', '245', '10', 'O'],
#  ['и', '256', '1', 'O'],
#  ['в', '258', '1', 'O'],
#  ['сопровождении', '260', '13', 'O'],
#  ['нескольких', '274', '10', 'O'],
#  ['охранников', '285', '10', 'O'],
#  ['доставлен', '296', '9', 'O'],
#  ['в', '306', '1', 'O'],
#  ['суд', '308', '3', 'O'],
#  ['в', '312', '1', 'O'],
#  ['города', '314', '6', 'B-Location'],
#  ['Феникс', '321', '6', 'E-Location'],
#  ['.', '327', '1', 'O'],
#  [],
#  ['Побритый', '329', '8', 'O'],
#  ['наголо', '338', '6', 'O'],
#  ['и', '345', '1', 'O'],
#  ['одетый', '347', '6', 'O'],
#  ['в', '354', '1', 'O'],
#  ['тюремную', '356', '8', 'O'],
#  ...]

# %%
testset = prepare('testset')

# %%
testset
# Out:
# [['Александр', '0', '9', 'B-Person'],
#  ['Вертинский', '10', '10', 'E-Person'],
#  ['.', '20', '1', 'O'],
#  ['«', '22', '1', 'O'],
#  ['Я', '23', '1', 'O'],
#  ['не', '25', '2', 'O'],
#  ['знаю', '28', '4', 'O'],
#  [',', '32', '1', 'O'],
#  ['зачем', '34', '5', 'O'],
#  ['и', '40', '1', 'O'],
#  ['кому', '42', '4', 'O'],
#  ['это', '47', '3', 'O'],
#  ['нужно', '51', '5', 'O'],
#  ['…', '56', '1', 'O'],
#  ['»', '57', '1', 'O'],
#  [],
#  ['21', '60', '2', 'O'],
#  ['марта', '63', '5', 'O'],
#  ['1889', '69', '4', 'O'],
#  ['года', '74', '4', 'O'],
#  ['родился', '79', '7', 'O'],
#  ['главный', '87', '7', 'O'],
#  ['русский', '95', '7', 'O'],
#  ['шансонье', '103', '8', 'O'],
#  ['XX', '112', '2', 'O'],
#  ['века', '115', '4', 'O'],
#  [',', '119', '1', 'O'],
#  ['печальный', '121', '9', 'O'],
#  ['Пьеро', '131', '5', 'S-Person'],
#  [',', '136', '1', 'O'],
#  ['вписавший', '138', '9', 'O'],
#  ['свою', '148', '4', 'O'],
#  ['судьбу', '153', '6', 'O'],
#  ['в', '160', '1', 'O'],
#  ['историю', '162', '7', 'O'],
#  ['отечественной', '170', '13', 'O'],
#  ['культуры', '184', '8', 'O'],
#  [],
#  ['Жизнь', '194', '5', 'O'],
#  ['с', '200', '1', 'O'],
#  ['самого', '202', '6', 'O'],
#  ['начала', '209', '6', 'O'],
#  ['оставляла', '216', '9', 'O'],
#  ['для', '226', '3', 'O'],
#  ['Александра', '230', '10', 'B-Person'],
#  ['Вертинского', '241', '11', 'E-Person'],
#  ['слишком', '253', '7', 'O'],
#  ['много', '261', '5', 'O'],
#  ['вопросов', '267', '8', 'O'],
#  ['без', '276', '3', 'O'],
#  ['ответов', '280', '7', 'O'],
#  ['.', '287', '1', 'O'],
#  [],
#  ['Слишком', '289', '7', 'O'],
#  ['много', '297', '5', 'O'],
#  ['«', '303', '1', 'O'],
#  ['пустого', '304', '7', 'O'],
#  ['»', '311', '1', 'O'],
#  ['пространства', '313', '12', 'O'],
#  ['.', '325', '1', 'O'],
#  [],
#  ['И', '327', '1', 'O'],
#  ['он', '329', '2', 'O'],
#  ['научился', '332', '8', 'O'],
#  ['заполнять', '341', '9', 'O'],
#  ['его', '351', '3', 'O'],
#  ['вымыслом', '355', '8', 'O'],
#  ['.', '363', '1', 'O'],
#  [],
#  ['Создал', '365', '6', 'O'],
#  ['собственный', '372', '11', 'O'],
#  ['театр', '384', '5', 'O'],
#  ['с', '390', '1', 'O'],
#  ['безумным', '392', '8', 'O'],
#  ['множеством', '401', '10', 'O'],
#  ['персонажей', '412', '10', 'O'],
#  [',', '422', '1', 'O'],
#  ['каждый', '424', '6', 'O'],
#  ['из', '431', '2', 'O'],
#  ['которых', '434', '7', 'O'],
#  ['—', '442', '1', 'O'],
#  ['от', '444', '2', 'O'],
#  ['сироток', '447', '7', 'O'],
#  ['-', '454', '1', 'O'],
#  ['калек', '455', '5', 'O'],
#  ['и', '461', '1', 'O'],
#  ['безымянных', '463', '10', 'O'],
#  ['кокаинеточек', '474', '12', 'O'],
#  ['до', '487', '2', 'O'],
#  ['гениальных', '490', '10', 'O'],
#  ['скрипачей', '501', '9', 'O'],
#  ['и', '511', '1', 'O'],
#  ['кинодив', '513', '7', 'O'],
#  ['—', '521', '1', 'O'],
#  ['был', '523', '3', 'O'],
#  ['им', '527', '2', 'O'],
#  ['самим', '530', '5', 'O'],
#  ['.', '535', '1', 'O'],
#  [],
#  ['Трехкомнатная', '538', '13', 'O'],
#  ['квартира', '552', '8', 'O'],
#  ['на', '561', '2', 'O'],
#  ['последнем', '564', '9', 'O'],
#  ['этаже', '574', '5', 'O'],
#  ['дома', '580', '4', 'O'],
#  ['на', '585', '2', 'O'],
#  ['углу', '588', '4', 'O'],
#  ['Тверской', '593', '8', 'S-Location'],
#  ['и', '602', '1', 'O'],
#  ['Козицкого', '604', '9', 'B-Location'],
#  ['переулка', '614', '8', 'I-Location'],
#  ['в', '623', '1', 'O'],
#  ['Москве', '625', '6', 'S-Location'],
#  ['и', '632', '1', 'O'],
#  ['сегодня', '634', '7', 'O'],
#  ['выглядит', '642', '8', 'O'],
#  ['так', '651', '3', 'O'],
#  [',', '654', '1', 'O'],
#  ['словно', '656', '6', 'O'],
#  ['ее', '663', '2', 'O'],
#  ['хозяин', '666', '6', 'O'],
#  ['вот-вот', '673', '7', 'O'],
#  ['вернется', '681', '8', 'O'],
#  ['.', '689', '1', 'O'],
#  [],
#  ['В', '691', '1', 'O'],
#  ['просторном', '693', '10', 'O'],
#  ['кабинете', '704', '8', 'O'],
#  ['все', '713', '3', 'O'],
#  ['те', '717', '2', 'O'],
#  ['же', '720', '2', 'O'],
#  ['большие', '723', '7', 'O'],
#  ['книжные', '731', '7', 'O'],
#  ['шкафы', '739', '5', 'O'],
#  [',', '744', '1', 'O'],
#  ['все', '746', '3', 'O'],
#  ['тот', '750', '3', 'O'],
#  ['же', '754', '2', 'O'],
#  ['гигантский', '757', '10', 'O'],
#  ['письменный', '768', '10', 'O'],
#  ['стол', '779', '4', 'O'],
#  ['с', '784', '1', 'O'],
#  ['наполеоновским', '786', '14', 'O'],
#  ['вензелем', '801', '8', 'O'],
#  ['и', '810', '1', 'O'],
#  ['бюстом', '812', '6', 'O'],
#  ['Вольтера', '819', '8', 'S-Person'],
#  ['.', '827', '1', 'O'],
#  [],
#  ['Сейчас', '830', '6', 'O'],
#  ['в', '837', '1', 'O'],
#  ['кабинете', '839', '8', 'O'],
#  ['все', '848', '3', 'O'],
#  ['чаще', '852', '4', 'O'],
#  ['бывает', '857', '6', 'O'],
#  ['лишь', '864', '4', 'O'],
#  ['вдова', '869', '5', 'O'],
#  ['Вертинского', '875', '11', 'S-Person'],
#  ['.', '886', '1', 'O'],
#  [],
#  ['Вновь', '888', '5', 'O'],
#  ['и', '894', '1', 'O'],
#  ['вновь', '896', '5', 'O'],
#  ['перечитывает', '902', '12', 'O'],
#  ['его', '915', '3', 'O'],
#  ['письма', '919', '6', 'O'],
#  [',', '925', '1', 'O'],
#  ['рукописи', '927', '8', 'O'],
#  ['.', '935', '1', 'O'],
#  [],
#  ['Он', '937', '2', 'O'],
#  ['смотрит', '940', '7', 'O'],
#  ['на', '948', '2', 'O'],
#  ['нее', '951', '3', 'O'],
#  ['с', '955', '1', 'O'],
#  ['фотографий', '957', '10', 'O'],
#  [',', '967', '1', 'O'],
#  ['развешанных', '969', '11', 'O'],
#  ['на', '981', '2', 'O'],
#  ['стенах', '984', '6', 'O'],
#  [',', '990', '1', 'O'],
#  ['расставленных', '992', '13', 'O'],
#  ['на', '1006', '2', 'O'],
#  ['столе', '1009', '5', 'O'],
#  [',', '1014', '1', 'O'],
#  ['и', '1016', '1', 'O'],
#  ['словно', '1018', '6', 'O'],
#  ['возвращает', '1025', '10', 'O'],
#  ['в', '1036', '1', 'O'],
#  ['те', '1038', '2', 'O'],
#  ['пятнадцать', '1041', '10', 'O'],
#  ['лет', '1052', '3', 'O'],
#  ['неизбывного', '1056', '11', 'O'],
#  ['счастья', '1068', '7', 'O'],
#  [',', '1075', '1', 'O'],
#  ['когда', '1077', '5', 'O'],
#  ['по', '1083', '2', 'O'],
#  ['квартире', '1086', '8', 'O'],
#  ['витает', '1095', '6', 'O'],
#  ['запах', '1102', '5', 'O'],
#  ['табака', '1108', '6', 'O'],
#  ['и', '1115', '1', 'O'],
#  ['лаванды', '1117', '7', 'O'],
#  [',', '1124', '1', 'O'],
#  ['дом', '1126', '3', 'O'],
#  ['полон', '1130', '5', 'O'],
#  ['гостей', '1136', '6', 'O'],
#  ['и', '1143', '1', 'O'],
#  ['шумные', '1145', '6', 'O'],
#  ['застолья', '1152', '8', 'O'],
#  ['длятся', '1161', '6', 'O'],
#  ['допоздна', '1168', '8', 'O'],
#  ['.', '1176', '1', 'O'],
#  [],
#  ['И', '1178', '1', 'O'],
#  ['все', '1180', '3', 'O'],
#  ['это', '1184', '3', 'O'],
#  ['—', '1188', '1', 'O'],
#  ['будто', '1190', '5', 'O'],
#  ['здесь', '1196', '5', 'O'],
#  ['и', '1202', '1', 'O'],
#  ['сейчас', '1204', '6', 'O'],
#  ['.', '1210', '1', 'O'],
#  [],
#  ['Нет', '1212', '3', 'O'],
#  [',', '1215', '1', 'O'],
#  ['время', '1217', '5', 'O'],
#  ['не', '1223', '2', 'O'],
#  ['остановилось', '1226', '12', 'O'],
#  [',', '1238', '1', 'O'],
#  ['оно', '1240', '3', 'O'],
#  ['сомкнуло', '1244', '8', 'O'],
#  ['объятия', '1253', '7', 'O'],
#  [',', '1260', '1', 'O'],
#  ['чтобы', '1262', '5', 'O'],
#  ['вновь', '1268', '5', 'O'],
#  ['и', '1274', '1', 'O'],
#  ['вновь', '1276', '5', 'O'],
#  ['перечитывать', '1282', '12', 'O'],
#  ['эту', '1295', '3', 'O'],
#  ['странную', '1299', '8', 'O'],
#  [',', '1307', '1', 'O'],
#  ['загадочную', '1309', '10', 'O'],
#  ['судьбу', '1320', '6', 'O'],
#  ['.', '1326', '1', 'O'],
#  [],
#  ['Считается', '1329', '9', 'O'],
#  [',', '1338', '1', 'O'],
#  ['что', '1340', '3', 'O'],
#  ['свой', '1344', '4', 'O'],
#  ['голос', '1349', '5', 'O'],
#  ['Георгий', '1355', '7', 'B-Person'],
#  ['Иванов', '1363', '6', 'E-Person'],
#  ['обрёл', '1370', '5', 'O'],
#  ['в', '1376', '1', 'O'],
#  ['эмиграции', '1378', '9', 'O'],
#  ['и', '1388', '1', 'O'],
#  ['благодаря', '1390', '9', 'O'],
#  ['эмиграции', '1400', '9', 'O'],
#  ['.', '1409', '1', 'O'],
#  [],
#  ['Мол', '1411', '3', 'O'],
#  [',', '1414', '1', 'O'],
#  ['утрата', '1416', '6', 'O'],
#  ['родины', '1423', '6', 'O'],
#  ['стала', '1430', '5', 'O'],
#  ['для', '1436', '3', 'O'],
#  ['него', '1440', '4', 'O'],
#  ['тем', '1445', '3', 'O'],
#  ['«', '1449', '1', 'O'],
#  ['простым', '1450', '7', 'O'],
#  ['человеческим', '1458', '12', 'O'],
#  ['горем', '1471', '5', 'O'],
#  ['»', '1476', '1', 'O'],
#  [',', '1477', '1', 'O'],
#  ['которого', '1479', '8', 'O'],
#  ['так', '1488', '3', 'O'],
#  ['не', '1492', '2', 'O'],
#  ['хватало', '1495', '7', 'O'],
#  ['по', '1503', '2', 'O'],
#  ['форме', '1506', '5', 'O'],
#  ['безупречным', '1512', '11', 'O'],
#  ['его', '1524', '3', 'O'],
#  ['стихам', '1528', '6', 'O'],
#  [',', '1534', '1', 'O'],
#  ['чтобы', '1536', '5', 'O'],
#  ['они', '1542', '3', 'O'],
#  ['наполнились', '1546', '11', 'O'],
#  ['содержанием', '1558', '11', 'O'],
#  ['.', '1569', '1', 'O'],
#  [],
#  ['На', '1571', '2', 'O'],
#  ['самом', '1574', '5', 'O'],
#  ['деле', '1580', '4', 'O'],
#  ['это', '1585', '3', 'O'],
#  ['не', '1589', '2', 'O'],
#  ['совсем', '1592', '6', 'O'],
#  ['так', '1599', '3', 'O'],
#  [',', '1602', '1', 'O'],
#  ['потому', '1604', '6', 'O'],
#  ['что', '1611', '3', 'O'],
#  ['точка', '1615', '5', 'O'],
#  ['сборки', '1621', '6', 'O'],
#  ['Георгия', '1628', '7', 'B-Person'],
#  ['Иванова', '1636', '7', 'E-Person'],
#  ['была', '1644', '4', 'O'],
#  ['смещена', '1649', '7', 'O'],
#  ['ещё', '1657', '3', 'O'],
#  ['в', '1661', '1', 'O'],
#  ['Петербурге', '1663', '10', 'S-Location'],
#  ['.', '1673', '1', 'O'],
#  [],
#  ['Георгий', '1676', '7', 'B-Person'],
#  ['Иванов', '1684', '6', 'E-Person'],
#  ['.', '1690', '1', 'O'],
#  ['На', '1692', '2', 'O'],
#  ['грани', '1695', '5', 'O'],
#  ['музыки', '1701', '6', 'O'],
#  ['и', '1708', '1', 'O'],
#  ['сна', '1710', '3', 'O'],
#  [],
#  ['Первое', '1715', '6', 'O'],
#  ['детское', '1722', '7', 'O'],
#  ['воспоминание', '1730', '12', 'O'],
#  ['Вертинского', '1743', '11', 'S-Person'],
#  ['—', '1755', '1', 'O'],
#  ['о', '1757', '1', 'O'],
#  ['смерти', '1759', '6', 'O'],
#  ['матери', '1766', '6', 'O'],
#  ['.', '1772', '1', 'O'],
#  [],
#  ['Трехлетний', '1774', '10', 'O'],
#  ['Саша', '1785', '4', 'S-Person'],
#  ['сидит', '1790', '5', 'O'],
#  ['на', '1796', '2', 'O'],
#  ['горшке', '1799', '6', 'O'],
#  ['и', '1806', '1', 'O'],
#  ['выковыривает', '1808', '12', 'O'],
#  ['глаза', '1821', '5', 'O'],
#  ['у', '1827', '1', 'O'],
#  ['плюшевого', '1829', '9', 'O'],
#  ['медвежонка', '1839', '10', 'O'],
#  ['.', '1849', '1', 'O'],
#  [],
#  ['Горничная', '1851', '9', 'O'],
#  ['Лизка', '1861', '5', 'S-Person'],
#  ['отрывает', '1867', '8', 'O'],
#  ['мальчика', '1876', '8', 'O'],
#  ['от', '1885', '2', 'O'],
#  ['увлекательного', '1888', '14', 'O'],
#  ['занятия', '1903', '7', 'O'],
#  [':', '1910', '1', 'O'],
#  ['«', '1912', '1', 'O'],
#  ['Вставай', '1913', '7', 'O'],
#  [',', '1920', '1', 'O'],
#  ['твоя', '1922', '4', 'O'],
#  ['мама', '1927', '4', 'O'],
#  ['умерла', '1932', '6', 'O'],
#  ['!', '1938', '1', 'O'],
#  ['»', '1939', '1', 'O'],
#  [],
#  ['Мать', '1941', '4', 'O'],
#  ['лежит', '1946', '5', 'O'],
#  ['в', '1952', '1', 'O'],
#  ['серебристом', '1954', '11', 'O'],
#  ['гробу', '1966', '5', 'O'],
#  ['на', '1972', '2', 'O'],
#  ['столе', '1975', '5', 'O'],
#  [',', '1980', '1', 'O'],
#  ['тело', '1982', '4', 'O'],
#  ['ее', '1987', '2', 'O'],
#  ['скрывают', '1990', '8', 'O'],
#  ['цветы', '1999', '5', 'O'],
#  [';', '2004', '1', 'O'],
#  ['у', '2006', '1', 'O'],
#  ['изголовья', '2008', '9', 'O'],
#  ['стоят', '2018', '5', 'O'],
#  ['серебряные', '2024', '10', 'O'],
#  ['подсвечники', '2035', '11', 'O'],
#  ['и', '2047', '1', 'O'],
#  ['маленькая', '2049', '9', 'O'],
#  ['табуретка', '2059', '9', 'O'],
#  ['.', '2068', '1', 'O'],
#  [],
#  ['В', '2070', '1', 'O'],
#  ['руке', '2072', '4', 'O'],
#  ['Саша', '2077', '4', 'S-Person'],
#  ['сжимает', '2082', '7', 'O'],
#  ['шоколадку', '2090', '9', 'O'],
#  [',', '2099', '1', 'O'],
#  ['он', '2101', '2', 'O'],
#  ['бросается', '2104', '9', 'O'],
#  ['к', '2114', '1', 'O'],
#  ['матери', '2116', '6', 'O'],
#  [',', '2122', '1', 'O'],
#  ['чтобы', '2124', '5', 'O'],
#  ['угостить', '2130', '8', 'O'],
#  ['.', '2138', '1', 'O'],
#  [],
#  ['Но', '2140', '2', 'O'],
#  ['мать', '2143', '4', 'O'],
#  ['не', '2148', '2', 'O'],
#  ['раскрывает', '2151', '10', 'O'],
#  ['рта', '2162', '3', 'O'],
#  ['…', '2165', '1', 'O'],
#  [],
#  ['Через', '2168', '5', 'O'],
#  ['два', '2174', '3', 'O'],
#  ['года', '2178', '4', 'O'],
#  ['от', '2183', '2', 'O'],
#  ['чахотки', '2186', '7', 'O'],
#  ['умер', '2194', '4', 'O'],
#  ['отец', '2199', '4', 'O'],
#  ['.', '2203', '1', 'O'],
#  [],
#  ['Однажды', '2205', '7', 'O'],
#  ['ранней', '2213', '6', 'O'],
#  ['весной', '2220', '6', 'O'],
#  ['его', '2227', '3', 'O'],
#  ['нашли', '2231', '5', 'O'],
#  ['без', '2237', '3', 'O'],
#  ['чувств', '2241', '6', 'O'],
#  ['на', '2248', '2', 'O'],
#  ['могиле', '2251', '6', 'O'],
#  ['супруги', '2258', '7', 'O'],
#  ['.', '2265', '1', 'O'],
#  [],
#  ['Оправиться', '2267', '10', 'O'],
#  ['от', '2278', '2', 'O'],
#  ['болезни', '2281', '7', 'O'],
#  ['он', '2289', '2', 'O'],
#  ['уже', '2292', '3', 'O'],
#  ['не', '2296', '2', 'O'],
#  ['смог', '2299', '4', 'O'],
#  ['.', '2303', '1', 'O'],
#  [],
#  ['Когда', '2305', '5', 'O'],
#  ['кровь', '2311', '5', 'O'],
#  ['хлынула', '2317', '7', 'O'],
#  ['горлом', '2325', '6', 'O'],
#  [',', '2331', '1', 'O'],
#  ['рядом', '2333', '5', 'O'],
#  ['с', '2339', '1', 'O'],
#  ['ним', '2341', '3', 'O'],
#  ['была', '2345', '4', 'O'],
#  ['только', '2350', '6', 'O'],
#  ['десятилетняя', '2357', '12', 'O'],
#  ['дочь', '2370', '4', 'O'],
#  ['Надя', '2375', '4', 'S-Person'],
#  [',', '2379', '1', 'O'],
#  ['не', '2381', '2', 'O'],
#  ['знавшая', '2384', '7', 'O'],
#  [',', '2391', '1', 'O'],
#  ['как', '2393', '3', 'O'],
#  ['помочь', '2397', '6', 'O'],
#  ['.', '2403', '1', 'O'],
#  [],
#  ['Обессиленный', '2405', '12', 'O'],
#  ['отец', '2418', '4', 'O'],
#  ['упал', '2423', '4', 'O'],
#  ['на', '2428', '2', 'O'],
#  ['подушку', '2431', '7', 'O'],
#  ['и', '2439', '1', 'O'],
#  ['захлебнулся', '2441', '11', 'O'],
#  ['кровью', '2453', '6', 'O'],
#  ['.', '2459', '1', 'O'],
#  [],
#  ['Старшая', '2462', '7', 'O'],
#  ['сестра', '2470', '6', 'O'],
#  ['матери', '2477', '6', 'O'],
#  ['забрала', '2484', '7', 'O'],
#  ['Надю', '2492', '4', 'S-Person'],
#  ['к', '2497', '1', 'O'],
#  ['себе', '2499', '4', 'O'],
#  ['в', '2504', '1', 'O'],
#  ['Ковно', '2506', '5', 'S-Location'],
#  ['.', '2511', '1', 'O'],
#  [],
#  ['Саша', '2513', '4', 'S-Person'],
#  ['остался', '2518', '7', 'O'],
#  ['жить', '2526', '4', 'O'],
#  ['в', '2531', '1', 'O'],
#  ['Киеве', '2533', '5', 'S-Location'],
#  ['с', '2539', '1', 'O'],
#  ['другой', '2541', '6', 'O'],
#  ['сестрой', '2548', '7', 'O'],
#  ['матери', '2556', '6', 'O'],
#  [',', '2562', '1', 'O'],
#  ['которая', '2564', '7', 'O'],
#  ['уверила', '2572', '7', 'O'],
#  ['мальчика', '2580', '8', 'O'],
#  ['в', '2589', '1', 'O'],
#  ['том', '2591', '3', 'O'],
#  [',', '2594', '1', 'O'],
#  ['что', '2596', '3', 'O'],
#  ['его', '2600', '3', 'O'],
#  ['сестра', '2604', '6', 'O'],
#  ['умерла', '2611', '6', 'O'],
#  ['.', '2617', '1', 'O'],
#  [],
#  ['То', '2619', '2', 'O'],
#  ['же', '2622', '2', 'O'],
#  ['самое', '2625', '5', 'O'],
#  ['было', '2631', '4', 'O'],
#  ['сказано', '2636', '7', 'O'],
#  ['Наде', '2644', '4', 'S-Person'],
#  ['о', '2649', '1', 'O'],
#  ['брате', '2651', '5', 'O'],
#  ['.', '2656', '1', 'O'],
#  [],
#  ['Спустя', '2658', '6', 'O'],
#  ['годы', '2665', '4', 'O'],
#  ['Александр', '2670', '9', 'S-Person'],
#  ['случайно', '2680', '8', 'O'],
#  ['обнаружит', '2689', '9', 'O'],
#  ['упоминание', '2699', '10', 'O'],
#  ['о', '2710', '1', 'O'],
#  ['Н', '2712', '1', 'S-Person'],
#  ['.', '2713', '1', 'O'],
#  ['Н', '2715', '1', 'S-Person'],
#  ['.', '2716', '1', 'O'],
#  ['Вертинской', '2718', '10', 'S-Person'],
#  ['в', '2729', '1', 'O'],
#  ['журнале', '2731', '7', 'S-Org'],
#  ['«', '2739', '1', 'O'],
#  ['Театр', '2740', '5', 'B-Org'],
#  ['и', '2746', '1', 'I-Org'],
#  ['искусство', '2748', '9', 'E-Org'],
#  ['»', '2757', '1', 'O'],
#  [',', '2758', '1', 'O'],
#  ['напишет', '2760', '7', 'O'],
#  ['ей', '2768', '2', 'O'],
#  [',', '2770', '1', 'O'],
#  ['и', '2772', '1', 'O'],
#  ['выяснится', '2774', '9', 'O'],
#  [',', '2783', '1', 'O'],
#  ['что', '2785', '3', 'O'],
#  ['это', '2789', '3', 'O'],
#  ['его', '2793', '3', 'O'],
#  ['сестра', '2797', '6', 'O'],
#  ['.', '2803', '1', 'O'],
#  [],
#  ['Во', '2805', '2', 'O'],
#  ['время', '2808', '5', 'O'],
#  ['Первой', '2814', '6', 'O'],
#  ['мировой', '2821', '7', 'O'],
#  ['Вертинскому', '2829', '11', 'S-Person'],
#  ['сообщат', '2841', '7', 'O'],
#  [',', '2848', '1', 'O'],
#  ['что', '2850', '3', 'O'],
#  ['Надя', '2854', '4', 'S-Person'],
#  ['покончила', '2859', '9', 'O'],
#  ['с', '2869', '1', 'O'],
#  ['собой', '2871', '5', 'O'],
#  ['.', '2876', '1', 'O'],
#  [],
#  ['Только', '2878', '6', 'O'],
#  ['после', '2885', '5', 'O'],
#  ['смерти', '2891', '6', 'O'],
#  ['Вертинского', '2898', '11', 'S-Person'],
#  ['его', '2910', '3', 'O'],
#  ['вдова', '2914', '5', 'O'],
#  ['выяснит', '2920', '7', 'O'],
#  [',', '2927', '1', 'O'],
#  ['что', '2929', '3', 'O'],
#  ['Надежда', '2933', '7', 'B-Person'],
#  ['Николаевна', '2941', '10', 'E-Person'],
#  ['живет', '2952', '5', 'O'],
#  ['в', '2958', '1', 'O'],
#  ['Ленинграде', '2960', '10', 'S-Location'],
#  ['.', '2970', '1', 'O'],
#  [],
#  ['Смерть', '2973', '6', 'O'],
#  ['причудливо', '2980', '10', 'O'],
#  ['и', '2991', '1', 'O'],
#  ['неотвратимо', '2993', '11', 'O'],
#  ['вписалась', '3005', '9', 'O'],
#  ['в', '3015', '1', 'O'],
#  ['его', '3017', '3', 'O'],
#  ['жизнь', '3021', '5', 'O'],
#  ['.', '3026', '1', 'O'],
#  [],
#  ['Смерть', '3028', '6', 'O'],
#  ['была', '3035', '4', 'O'],
#  ['тем', '3040', '3', 'O'],
#  ['миром', '3044', '5', 'O'],
#  [',', '3049', '1', 'O'],
#  ['где', '3051', '3', 'O'],
#  ['кончались', '3055', '9', 'O'],
#  ['тщета', '3065', '5', 'O'],
#  ['мальчика', '3071', '8', 'O'],
#  ['Мая', '3080', '3', 'S-Person'],
#  ['и', '3084', '1', 'O'],
#  ['тревоги', '3086', '7', 'O'],
#  ['Безноженьки', '3094', '11', 'S-Person'],
#  ['и', '3106', '1', 'O'],
#  ['наступал', '3108', '8', 'O'],
#  ['долгожданный', '3117', '12', 'O'],
#  ['покой', '3130', '5', 'O'],
#  ['.', '3135', '1', 'O'],
#  [],
#  ['Александр', '3138', '9', 'B-Person'],
#  ['Вертинский', '3148', '10', 'E-Person'],
#  ['появился', '3159', '8', 'O'],
#  ['на', '3168', '2', 'O'],
#  ['свет', '3171', '4', 'O'],
#  ['«', '3176', '1', 'O'],
#  ['незаконнорожденным', '3177', '18', 'O'],
#  ['»', '3195', '1', 'O'],
#  ['.', '3196', '1', 'O'],
#  [],
#  ['Родственники', '3198', '12', 'O'],
#  ['отца', '3211', '4', 'O'],
#  ['и', '3216', '1', 'O'],
#  ['матери', '3218', '6', 'O'],
#  ['не', '3225', '2', 'O'],
#  ['одобряли', '3228', '8', 'O'],
#  ['союз', '3237', '4', 'O'],
#  ['Николая', '3242', '7', 'B-Person'],
#  ['Вертинского', '3250', '11', 'E-Person'],
#  ['с', '3262', '1', 'O'],
#  ['Евгенией', '3264', '8', 'B-Person'],
#  ['Скалацкой', '3273', '9', 'E-Person'],
#  ['(', '3283', '1', 'O'],
#  ['Сколацкой', '3284', '9', 'S-Person'],
#  [')', '3293', '1', 'O'],
#  ['даже', '3295', '4', 'O'],
#  ['тогда', '3300', '5', 'O'],
#  [',', '3305', '1', 'O'],
#  ['когда', '3307', '5', 'O'],
#  ['родились', '3313', '8', 'O'],
#  ['Надя', '3322', '4', 'S-Person'],
#  ['и', '3327', '1', 'O'],
#  ['Саша', '3329', '4', 'S-Person'],
#  ['.', '3333', '1', 'O'],
#  [],
#  ['Евгения', '3335', '7', 'B-Person'],
#  ['Степановна', '3343', '10', 'E-Person'],
#  ['происходила', '3354', '11', 'O'],
#  ['из', '3366', '2', 'O'],
#  ['дворянского', '3369', '11', 'O'],
#  ['рода', '3381', '4', 'O'],
#  [',', '3385', '1', 'O'],
#  ['а', '3387', '1', 'O'],
#  ['Николай', '3389', '7', 'B-Person'],
#  ['Петрович', '3397', '8', 'E-Person'],
#  ['был', '3406', '3', 'O'],
#  ['присяжным', '3410', '9', 'O'],
#  ['поверенным', '3420', '10', 'O'],
#  ['.', '3430', '1', 'O'],
#  [],
#  ['Первая', '3432', '6', 'O'],
#  ['жена', '3439', '4', 'O'],
#  ['отца', '3444', '4', 'O'],
#  ['по', '3449', '2', 'O'],
#  ['настоянию', '3452', '9', 'O'],
#  ['родственников', '3462', '13', 'O'],
#  ['Николая', '3476', '7', 'B-Person'],
#  ['Вертинского', '3484', '11', 'E-Person'],
#  ['не', '3496', '2', 'O'],
#  ['давала', '3499', '6', 'O'],
#  ['ему', '3506', '3', 'O'],
#  ['развода', '3510', '7', 'O'],
#  ['.', '3517', '1', 'O'],
#  [],
#  ['Так', '3519', '3', 'O'],
#  ['что', '3523', '3', 'O'],
#  ['пришлось', '3527', '8', 'O'],
#  ['усыновить', '3536', '9', 'O'],
#  ['собственных', '3546', '11', 'O'],
#  ['детей', '3558', '5', 'O'],
#  ['.', '3563', '1', 'O'],
#  [],
#  ['Жизнь', '3566', '5', 'O'],
#  ['с', '3572', '1', 'O'],
#  ['самого', '3574', '6', 'O'],
#  ['начала', '3581', '6', 'O'],
#  ['оставляла', '3588', '9', 'O'],
#  ['для', '3598', '3', 'O'],
#  ['Александра', '3602', '10', 'B-Person'],
#  ['Вертинского', '3613', '11', 'E-Person'],
#  ['слишком', '3625', '7', 'O'],
#  ['много', '3633', '5', 'O'],
#  ['вопросов', '3639', '8', 'O'],
#  ['без', '3648', '3', 'O'],
#  ['ответов', '3652', '7', 'O'],
#  ['.', '3659', '1', 'O'],
#  [],
#  ['Слишком', '3661', '7', 'O'],
#  ['много', '3669', '5', 'O'],
#  ['«', '3675', '1', 'O'],
#  ['пустого', '3676', '7', 'O'],
#  ['»', '3683', '1', 'O'],
#  ['пространства', '3685', '12', 'O'],
#  ['.', '3697', '1', 'O'],
#  [],
#  ['И', '3699', '1', 'O'],
#  ['он', '3701', '2', 'O'],
#  ['научился', '3704', '8', 'O'],
#  ['заполнять', '3713', '9', 'O'],
#  ['его', '3723', '3', 'O'],
#  ['вымыслом', '3727', '8', 'O'],
#  ['.', '3735', '1', 'O'],
#  [],
#  ['Создал', '3737', '6', 'O'],
#  ['собственный', '3744', '11', 'O'],
#  ['театр', '3756', '5', 'O'],
#  ['с', '3762', '1', 'O'],
#  ['безумным', '3764', '8', 'O'],
#  ['множеством', '3773', '10', 'O'],
#  ['персонажей', '3784', '10', 'O'],
#  [',', '3794', '1', 'O'],
#  ['каждый', '3796', '6', 'O'],
#  ['из', '3803', '2', 'O'],
#  ['которых', '3806', '7', 'O'],
#  ['—', '3814', '1', 'O'],
#  ['от', '3816', '2', 'O'],
#  ['сироток', '3819', '7', 'O'],
#  ['-', '3826', '1', 'O'],
#  ['калек', '3827', '5', 'O'],
#  ['и', '3833', '1', 'O'],
#  ['безымянных', '3835', '10', 'O'],
#  ['кокаинеточек', '3846', '12', 'O'],
#  ['до', '3859', '2', 'O'],
#  ['гениальных', '3862', '10', 'O'],
#  ['скрипачей', '3873', '9', 'O'],
#  ['и', '3883', '1', 'O'],
#  ['кинодив', '3885', '7', 'O'],
#  ['—', '3893', '1', 'O'],
#  ['был', '3895', '3', 'O'],
#  ['им', '3899', '2', 'O'],
#  ['самим', '3902', '5', 'O'],
#  ['.', '3907', '1', 'O'],
#  [],
#  ['Театр', '3910', '5', 'O'],
#  ['стал', '3916', '4', 'O'],
#  ['маниакальной', '3921', '12', 'O'],
#  ['страстью', '3934', '8', 'O'],
#  ['Вертинского', '3943', '11', 'S-Person'],
#  ['еще', '3955', '3', 'O'],
#  ['с', '3959', '1', 'O'],
#  ['гимназических', '3961', '13', 'O'],
#  ['лет', '3975', '3', 'O'],
#  ['.', '3978', '1', 'O'],
#  [],
#  ['Он', '3980', '2', 'O'],
#  ['любыми', '3983', '6', 'O'],
#  ['способами', '3990', '9', 'O'],
#  ['проникал', '4000', '8', 'O'],
#  ['на', '4009', '2', 'O'],
#  ['спектакли', '4012', '9', 'O'],
#  [',', '4021', '1', 'O'],
#  ['оперы', '4023', '5', 'O'],
#  [',', '4028', '1', 'O'],
#  ['концерты', '4030', '8', 'O'],
#  [',', '4038', '1', 'O'],
#  ['выступал', '4040', '8', 'O'],
#  ['в', '4049', '1', 'O'],
#  ['любительских', '4051', '12', 'O'],
#  ['постановках', '4064', '11', 'O'],
#  ['в', '4076', '1', 'O'],
#  ['контрактовом', '4078', '12', 'B-Location'],
#  ['зале', '4091', '4', 'I-Location'],
#  ['на', '4096', '2', 'O'],
#  ['киевском', '4099', '8', 'S-Location'],
#  ['Подоле', '4108', '6', 'S-Location'],
#  ['и', '4115', '1', 'O'],
#  ['подвизался', '4117', '10', 'O'],
#  ['статистом', '4128', '9', 'O'],
#  ['в', '4138', '1', 'O'],
#  ['Соловцовском', '4140', '12', 'B-Org'],
#  ['театре', '4153', '6', 'I-Org'],
#  ['—', '4160', '1', 'O'],
#  ['разумеется', '4162', '10', 'O'],
#  [',', '4172', '1', 'O'],
#  ['бесплатно', '4174', '9', 'O'],
#  ['.', '4183', '1', 'O'],
#  [],
#  ['А', '4185', '1', 'O'],
#  ['чтобы', '4187', '5', 'O'],
#  ['не', '4193', '2', 'O'],
#  ['умереть', '4196', '7', 'O'],
#  ['с', '4204', '1', 'O'],
#  ['голоду', '4206', '6', 'O'],
#  [',', '4212', '1', 'O'],
#  ['брался', '4214', '6', 'O'],
#  ['за', '4221', '2', 'O'],
#  ['любую', '4224', '5', 'O'],
#  ['работу', '4230', '6', 'O'],
#  ['—', '4237', '1', 'O'],
#  ['пописывал', '4239', '9', 'O'],
#  ['рецензии', '4249', '8', 'O'],
#  ['на', '4258', '2', 'O'],
#  ['выступления', '4261', '11', 'O'],
#  ['гастролеров', '4273', '11', 'O'],
#  [',', '4284', '1', 'O'],
#  ['служил', '4286', '6', 'O'],
#  ['корректором', '4293', '11', 'O'],
#  ['в', '4305', '1', 'O'],
#  ['типографии', '4307', '10', 'O'],
#  [',', '4317', '1', 'O'],
#  ['нанимался', '4319', '9', 'O'],
#  ['помощником', '4329', '10', 'O'],
#  ['бухгалтера', '4340', '10', 'O'],
#  ['в', '4351', '1', 'O'],
#  ['гостиницу', '4353', '9', 'O'],
#  [',', '4362', '1', 'O'],
#  ['продавал', '4364', '8', 'O'],
#  ['открытки', '4373', '8', 'O'],
#  [',', '4381', '1', 'O'],
#  ['грузил', '4383', '6', 'O'],
#  ['арбузы', '4390', '6', 'O'],
#  ['на', '4397', '2', 'O'],
#  ['барках', '4400', '6', 'O'],
#  ['и', '4407', '1', 'O'],
#  ['даже', '4409', '4', 'O'],
#  ['подворовывал', '4414', '12', 'O'],
#  ['у', '4427', '1', 'O'],
#  ['двоюродной', '4429', '10', 'O'],
#  ['сестры', '4440', '6', 'O'],
#  ['безделушки', '4447', '10', 'O'],
#  [',', '4457', '1', 'O'],
#  ['чтобы', '4459', '5', 'O'],
#  ['сбыть', '4465', '5', 'O'],
#  ['их', '4471', '2', 'O'],
#  ['на', '4474', '2', 'O'],
#  ['толкучке', '4477', '8', 'O'],
#  ['.', '4485', '1', 'O'],
#  [],
#  ['С', '4488', '1', 'O'],
#  ['армией', '4490', '6', 'B-Org'],
#  ['Колчака', '4497', '7', 'S-Person'],
#  ['бежала', '4505', '6', 'O'],
#  ['из', '4512', '2', 'O'],
#  ['Владивостока', '4515', '12', 'S-Location'],
#  ['семья', '4528', '5', 'O'],
#  ['цыган', '4534', '5', 'O'],
#  ['Димитриевичей', '4540', '13', 'O'],
#  [',', '4553', '1', 'O'],
#  ['на', '4555', '2', 'O'],
#  ['пароходах', '4558', '9', 'O'],
#  ['генерала', '4568', '8', 'O'],
#  ['Врангеля', '4577', '8', 'S-Person'],
#  ['спасались', '4586', '9', 'O'],
#  ['Александр', '4596', '9', 'B-Person'],
#  ['Вертинский', '4606', '10', 'E-Person'],
#  ['и', '4617', '1', 'O'],
#  ['Надежда', '4619', '7', 'B-Person'],
#  ['Плевицкая', '4627', '9', 'E-Person'],
#  [',', '4636', '1', 'O'],
#  ['уходили', '4638', '7', 'O'],
#  ['куда', '4646', '4', 'O'],
#  ['угодно', '4651', '6', 'O'],
#  [',', '4657', '1', 'O'],
#  ['лишь', '4659', '4', 'O'],
#  ['бы', '4664', '2', 'O'],
#  ['подальше', '4667', '8', 'O'],
#  ['от', '4676', '2', 'O'],
#  ['Советов', '4679', '7', 'S-LocOrg'],
#  [',', '4686', '1', 'O'],
#  ['многие', '4688', '6', 'O'],
#  ['звёзды', '4695', '6', 'O'],
#  ['и', '4702', '1', 'O'],
#  ['звёздочки', '4704', '9', 'O'],
#  ['...', '4713', '3', 'O'],
#  [],
#  ['Да', '4717', '2', 'O'],
#  [',', '4719', '1', 'O'],
#  ['в', '4721', '1', 'O'],
#  ['первой', '4723', '6', 'O'],
#  ['эмиграции', '4730', '9', 'O'],
#  ['оказалось', '4740', '9', 'O'],
#  ['немало', '4750', '6', 'O'],
#  ['творческих', '4757', '10', 'O'],
#  ['личностей', '4768', '9', 'O'],
#  [',', '4777', '1', 'O'],
#  ['работавших', '4779', '10', 'O'],
#  ['в', '4790', '1', 'O'],
#  ['интересующем', '4792', '12', 'O'],
#  ['нас', '4805', '3', 'O'],
#  ['жанре', '4809', '5', 'O'],
#  ['русской', '4815', '7', 'O'],
#  ['песни', '4823', '5', 'O'],
#  [',', '4828', '1', 'O'],
#  ['но', '4830', '2', 'O'],
#  ['даже', '4833', '4', 'O'],
#  ['самые', '4838', '5', 'O'],
#  ['яркие', '4844', '5', 'O'],
#  ['их', '4850', '2', 'O'],
#  ['имена', '4853', '5', 'O'],
#  ['блекнут', '4859', '7', 'O'],
#  ['рядом', '4867', '5', 'O'],
#  ['со', '4873', '2', 'O'],
#  ['сверкающей', '4876', '10', 'O'],
#  ['снежной', '4887', '7', 'O'],
#  ['шапкой', '4895', '6', 'O'],
#  ['Монблана', '4902', '8', 'S-Location'],
#  ['в', '4911', '1', 'O'],
#  ['лице', '4913', '4', 'O'],
#  ['Фёдора', '4918', '6', 'B-Person'],
#  ['Ивановича', '4925', '9', 'I-Person'],
#  ['Шаляпина', '4935', '8', 'E-Person'],
#  ['.', '4943', '1', 'O'],
#  [],
#  ['Живой', '4946', '5', 'O'],
#  ['бог', '4952', '3', 'O'],
#  ['русской', '4956', '7', 'O'],
#  ['музыки', '4964', '6', 'O'],
#  [],
#  ['В', '4972', '1', 'O'],
#  ['1911', '4974', '4', 'O'],
#  ['–', '4978', '1', 'O'],
#  ['1912', '4979', '4', 'O'],
#  ['годах', '4984', '5', 'O'],
#  ['журналы', '4990', '7', 'S-Org'],
#  ['«', '4998', '1', 'O'],
#  ['Киевская', '4999', '8', 'B-Org'],
#  ['неделя', '5008', '6', 'E-Org'],
#  ['»', '5014', '1', 'O'],
#  ['и', '5016', '1', 'O'],
#  ['«', '5018', '1', 'O'],
#  ['Лукоморье', '5019', '9', 'S-Org'],
#  ['»', '5028', '1', 'O'],
#  ['опубликовали', '5030', '12', 'O'],
#  ['первые', '5043', '6', 'O'],
#  ['рассказы', '5050', '8', 'O'],
#  ['Вертинского', '5059', '11', 'S-Person'],
#  [':', '5070', '1', 'O'],
#  ['«', '5072', '1', 'O'],
#  ['Красные', '5073', '7', 'O'],
#  ['бабочки', '5081', '7', 'O'],
#  ['»', '5088', '1', 'O'],
#  ['и', '5090', '1', 'O'],
#  ['«', '5092', '1', 'O'],
#  ['Моя', '5093', '3', 'O'],
#  ['невеста', '5097', '7', 'O'],
#  ['»', '5104', '1', 'O'],
#  ['—', '5106', '1', 'O'],
#  ['декадентские', '5108', '12', 'O'],
#  [',', '5120', '1', 'O'],
#  ['но', '5122', '2', 'O'],
#  ['с', '5125', '1', 'O'],
#  ['бунинской', '5127', '9', 'O'],
#  ['интонацией', '5137', '10', 'O'],
#  ['.', '5147', '1', 'O'],
#  [],
#  ['«', '5149', '1', 'O'],
#  ['Красные', '5150', '7', 'O'],
#  ['бабочки', '5158', '7', 'O'],
#  ['»', '5165', '1', 'O'],
#  ['—', '5167', '1', 'O'],
#  ['о', '5169', '1', 'O'],
#  ['мальчике', '5171', '8', 'O'],
#  ['-', '5179', '1', 'O'],
#  ['сироте', '5180', '6', 'O'],
#  [',', '5186', '1', 'O'],
#  ['случайно', '5188', '8', 'O'],
#  ['погубившем', '5197', '10', 'O'],
#  ['красных', '5208', '7', 'O'],
#  ['бабочек', '5216', '7', 'O'],
#  [',', '5223', '1', 'O'],
#  ['вышитых', '5225', '7', 'O'],
#  ['на', '5233', '2', 'O'],
#  ['черном', '5236', '6', 'O'],
#  ['платье', '5243', '6', 'O'],
#  ['.', '5249', '1', 'O'],
#  [],
#  ['Мальчик', '5251', '7', 'O'],
#  ['наказан', '5259', '7', 'O'],
#  ['суровой', '5267', '7', 'O'],
#  ['теткой', '5275', '6', 'O'],
#  [',', '5281', '1', 'O'],
#  ['но', '5283', '2', 'O'],
#  ['бабочки', '5286', '7', 'O'],
#  ['являются', '5294', '8', 'O'],
#  ['ему', '5303', '3', 'O'],
#  ['во', '5307', '2', 'O'],
#  ['сне', '5310', '3', 'O'],
#  [',', '5313', '1', 'O'],
#  ['чтобы', '5315', '5', 'O'],
#  ['отомстить', '5321', '9', 'O'],
#  ['за', '5331', '2', 'O'],
#  ['погибших', '5334', '8', 'O'],
#  ['сестер', '5343', '6', 'O'],
#  ['.', '5349', '1', 'O'],
#  [],
#  ['«', '5351', '1', 'O'],
#  ['Моя', '5352', '3', 'O'],
#  ['невеста', '5356', '7', 'O'],
#  ['»', '5363', '1', 'O'],
#  ['—', '5365', '1', 'O'],
#  ['о', '5367', '1', 'O'],
#  ['сумасшедшей', '5369', '11', 'O'],
#  ['бездомной', '5381', '9', 'O'],
#  [',', '5390', '1', 'O'],
#  ['читающей', '5392', '8', 'O'],
#  ['стихи', '5401', '5', 'O'],
#  ['на', '5407', '2', 'O'],
#  ['эстраде', '5410', '7', 'O'],
#  ['опустевшего', '5418', '11', 'O'],
#  ...]

# %%
#Fit_transform для получения матрицы X

# %%
column_types = None
_column_types = column_types if column_types is not None else ["WORD"]

# %%
context_len = 2
_context_len = context_len

# %%
data = []
for el in devset:
    if el:
        data.append(el[0])

# %%
len(data)
# Out:
# 30940

# %%
data
# Out:
# ['В',
#  'понедельник',
#  '28',
#  'июня',
#  'у',
#  'здания',
#  'мэрии',
#  'Москвы',
#  'на',
#  'Тверской',
#  'площади',
#  'состоялась',
#  'очередная',
#  'несанкционированная',
#  'акция',
#  'протеста',
#  '«',
#  'День',
#  'гнева',
#  '»',
#  ',',
#  'в',
#  'этот',
#  'раз',
#  'направленная',
#  ',',
#  'главным',
#  'образом',
#  ',',
#  'против',
#  'политики',
#  'московских',
#  'и',
#  'подмосковных',
#  'властей',
#  '.',
#  'Среди',
#  'требований',
#  ',',
#  'выдвигаемых',
#  'организаторами',
#  'акции',
#  ':',
#  '«',
#  'немедленная',
#  'отставка',
#  'мэра',
#  'Москвы',
#  'Юрия',
#  'Лужкова',
#  ',',
#  'расследование',
#  'итогов',
#  'его',
#  'деятельности',
#  '»',
#  ',',
#  '«',
#  'созыв',
#  'московского',
#  'общественного',
#  'форума',
#  'для',
#  'обсуждения',
#  'путей',
#  'реформирования',
#  'основных',
#  'сфер',
#  'жизнедеятельности',
#  'в',
#  'Москве',
#  '»',
#  ',',
#  '«',
#  'восстановление',
#  'прямых',
#  'выборов',
#  'глав',
#  'регионов',
#  'России',
#  '»',
#  ',',
#  '«',
#  'роспуск',
#  'нелегитимной',
#  'Мосгордумы',
#  '»',
#  ',',
#  'отставка',
#  'подмосковного',
#  'губернатора',
#  'Бориса',
#  'Громова',
#  'и',
#  'др',
#  '.',
#  'Участникам',
#  'акции',
#  'предлагалось',
#  'принести',
#  'с',
#  'собой',
#  'лист',
#  'бумаги',
#  'или',
#  'кусок',
#  'ткани',
#  'чёрного',
#  'цвета',
#  ',',
#  'символизирующие',
#  '«',
#  'чёрную',
#  'метку',
#  '»',
#  'для',
#  'Юрия',
#  'Лужкова',
#  '.',
#  'Начало',
#  'акции',
#  'было',
#  'намечено',
#  'на',
#  '19',
#  'часов',
#  ';',
#  'подчёркивалось',
#  ',',
#  'что',
#  'она',
#  'состоится',
#  'несмотря',
#  'на',
#  'запрет',
#  'властей',
#  '.',
#  'Освещающие',
#  'акцию',
#  'блоггеры',
#  'сообщили',
#  ',',
#  'что',
#  'автобусы',
#  'с',
#  'милицией',
#  'стали',
#  'занимать',
#  'площадь',
#  'у',
#  'памятника',
#  'Юрию',
#  'Долгорукому',
#  'ещё',
#  'с',
#  '15',
#  'часов',
#  'дня',
#  ',',
#  'центральная',
#  'часть',
#  'площади',
#  'была',
#  'огорожена',
#  '.',
#  'Ко',
#  'времени',
#  'начала',
#  'акции',
#  'вокруг',
#  'огороженной',
#  'территории',
#  'собралось',
#  'множество',
#  'журналистов',
#  'и',
#  'прохожих',
#  ',',
#  'по',
#  'мере',
#  'прибытия',
#  'самих',
#  'участников',
#  'акции',
#  'милиция',
#  'начала',
#  'планомерно',
#  'их',
#  'задерживать',
#  'и',
#  'заталкивать',
#  'в',
#  'автобусы',
#  '.',
#  'Всего',
#  ',',
#  'по',
#  'сообщениям',
#  'блоггеров',
#  'и',
#  'СМИ',
#  ',',
#  'было',
#  'задержано',
#  'более',
#  '30',
#  'человек',
#  '.',
#  'Пользователь',
#  'ЖЖ',
#  'zyalt',
#  'сообщает',
#  ',',
#  'что',
#  'среди',
#  'задержанных',
#  'оказался',
#  'депутат',
#  'муниципального',
#  'собрания',
#  'района',
#  'Отрадное',
#  ',',
#  'сопредседатель',
#  'московского',
#  'отделения',
#  'движения',
#  '«',
#  'Солидарность',
#  '»',
#  'Михаил',
#  'Вельмакин',
#  ',',
#  'известный',
#  'правозащитник',
#  'Лев',
#  'Пономарев',
#  ',',
#  'координатор',
#  'движения',
#  '«',
#  'Левый',
#  'фронт',
#  '»',
#  'Сергей',
#  'Удальцов',
#  '.',
#  'Организаторами',
#  'акции',
#  'выступили',
#  'движение',
#  '«',
#  'За',
#  'права',
#  'человека',
#  '»',
#  ',',
#  'Союз',
#  'координационных',
#  'советов',
#  '(',
#  'СКС',
#  ')',
#  ',',
#  'институт',
#  '«',
#  'Коллективное',
#  'действие',
#  '»',
#  ',',
#  '«',
#  'Жилищная',
#  'солидарность',
#  '»',
#  ',',
#  'Движение',
#  'общежитий',
#  'Москвы',
#  ',',
#  'Движение',
#  'в',
#  'защиту',
#  'Химкинского',
#  'леса',
#  ',',
#  'движение',
#  '«',
#  'Московский',
#  'совет',
#  '»',
#  ',',
#  '«',
#  'Координационный',
#  'совет',
#  'пострадавших',
#  'соинвесторов',
#  '»',
#  '.',
#  'Конец',
#  'света',
#  ',',
#  'который',
#  'предрекал',
#  'проповедник',
#  '-',
#  'евангелист',
#  'Герольд',
#  'Кемпинг',
#  'утром',
#  'в',
#  '06.00',
#  'по',
#  'московскому',
#  'времени',
#  '21',
#  'мая',
#  '2011',
#  'года',
#  'так',
#  'и',
#  'не',
#  'наступил',
#  '.',
#  'Это',
#  'далеко',
#  'не',
#  'первое',
#  'несбывшееся',
#  'предсказание',
#  'апокалипсиса',
#  '.',
#  'Поначалу',
#  'на',
#  'него',
#  'практически',
#  'не',
#  'обратили',
#  'внимания',
#  ',',
#  'однако',
#  ',',
#  'с',
#  'приближением',
#  'этой',
#  'даты',
#  ',',
#  'немало',
#  'СМИ',
#  'в',
#  'поисках',
#  'сюжета',
#  ',',
#  'останавливались',
#  'на',
#  'этом',
#  ',',
#  'создавая',
#  'прекрасную',
#  'бесплатную',
#  'PR-компанию',
#  'для',
#  'горе-пророка',
#  '.',
#  'Вполне',
#  'вероятно',
#  ',',
#  'что',
#  'Герольд',
#  'Кемпинг',
#  'объяснит',
#  'это',
#  'какой-либо',
#  'неточностью',
#  'и',
#  'перенесет',
#  'катастрофу',
#  'на',
#  'некоторое',
#  'время',
#  'вперёд',
#  ',',
#  'и',
#  'по',
#  'прежнему',
#  'будет',
#  'оставаться',
#  'в',
#  'центре',
#  'внимания',
#  '.',
#  'Так',
#  ',',
#  'согласно',
#  'его',
#  'пророчествам',
#  ',',
#  '6',
#  'сентября',
#  '1994',
#  'года',
#  'на',
#  'Землю',
#  'должен',
#  'был',
#  'опуститься',
#  'Иисус',
#  'Христос',
#  '.',
#  'Следующее',
#  'подобное',
#  'мероприятие',
#  ',',
#  'по',
#  'прогнозам',
#  'майя',
#  ',',
#  'ожидается',
#  '21',
#  'декабря',
#  '2012',
#  'года',
#  ',',
#  'однако',
#  'не',
#  'следует',
#  'забывать',
#  ',',
#  'что',
#  'конец',
#  'этой',
#  'цивилизации',
#  'наступил',
#  'значительно',
#  'раньше',
#  ',',
#  'и',
#  'это',
#  'отчего-то',
#  'не',
#  'отображено',
#  'в',
#  'их',
#  'наследии',
#  ',',
#  'поэтому',
#  'и',
#  'достоверность',
#  'подобного',
#  'прорицания',
#  'далеко',
#  'не',
#  'очевидна',
#  '.',
#  'Если',
#  '-',
#  'же',
#  'и',
#  'майя',
#  'ошиблись',
#  ',',
#  'то',
#  'расслабляться',
#  'всё-равно',
#  'не',
#  'стоит',
#  '.',
#  'Апокалиптических',
#  'теорий',
#  'ещё',
#  'достаточно',
#  ':',
#  '*',
#  '2021',
#  'год',
#  '—',
#  'инверсия',
#  'магнитного',
#  'поля',
#  'Земли',
#  'уничтожит',
#  'часть',
#  'человечества',
#  '.',
#  '*',
#  '2060',
#  'год',
#  '—',
#  'Согласно',
#  'расчётам',
#  'Исаака',
#  'Ньютона',
#  ',',
#  'сделанным',
#  'в',
#  '1704',
#  'году',
#  'по',
#  'библейской',
#  'книге',
#  'Даниила',
#  'станет',
#  'последним',
#  'для',
#  'людей',
#  '.',
#  '*',
#  '2242',
#  'год',
#  '—',
#  'конец',
#  'эпохи',
#  'Солнца',
#  'согласно',
#  'теории',
#  'смены',
#  'планетных',
#  'эпох',
#  ',',
#  'которая',
#  'была',
#  'изложена',
#  'в',
#  'работах',
#  'ибн',
#  'Эзра',
#  ',',
#  'Авраама',
#  'и',
#  'Абу',
#  'Машара',
#  '.',
#  '*',
#  '2892',
#  'год',
#  '—',
#  'апокалипсис',
#  'обещанный',
#  'Авелем',
#  '.',
#  '*',
#  '3797',
#  'год',
#  '—',
#  'кончину',
#  'миру',
#  'предрёк',
#  'сам',
#  'Нострадамус',
#  '.',
#  '*',
#  '5079',
#  'год',
#  '—',
#  'сочла',
#  'последним',
#  'всемирно',
#  'известная',
#  'Ванга',
#  '…',
#  'Промышленный',
#  'и',
#  'коммерческий',
#  'банк',
#  'Китая',
#  '(',
#  'Industrial',
#  'and',
#  'Commercial',
#  'Bank',
#  'of',
#  'China',
#  ')',
#  ',',
#  'по',
#  'некоторым',
#  'показателям',
#  '—',
#  'крупнейший',
#  'банк',
#  'мира',
#  ',',
#  'подписал',
#  'соглашение',
#  'о',
#  'покупке',
#  'контрольной',
#  'доли',
#  'в',
#  'американском',
#  'отделении',
#  'Bank',
#  'of',
#  'East',
#  'Asia',
#  ',',
#  'управляющим',
#  '13-ю',
#  'филиалами',
#  'в',
#  'Калифорнии',
#  'и',
#  'Нью-Йорке',
#  '.',
#  'За',
#  '80',
#  'процентов',
#  'акций',
#  'этой',
#  'финансовой',
#  'структуры',
#  ',',
#  'подконтрольный',
#  'китайскому',
#  'правительству',
#  'банк',
#  'заплатит',
#  'около',
#  '100',
#  'млн',
#  'долларов',
#  '.',
#  'Соглашение',
#  'было',
#  'подписано',
#  'в',
#  'минувшую',
#  'пятницу',
#  'в',
#  'Чикаго',
#  ',',
#  'в',
#  'последний',
#  'день',
#  'визита',
#  'председателя',
#  'КНР',
#  'Ху',
#  'Цзиньтао',
#  'в',
#  'США',
#  '.',
#  'Сделка',
#  'ожидает',
#  'утверждения',
#  'американскими',
#  'регулирующими',
#  'органами',
#  ',',
#  'что',
#  'может',
#  'задержать',
#  'ее',
#  'завершение',
#  'до',
#  'конца',
#  'этого',
#  'года',
#  '.',
#  'Доля',
#  'правительства',
#  'Китая',
#  'в',
#  'Industrial',
#  'and',
#  'Commercial',
#  'Bank',
#  'of',
#  'China',
#  'составляет',
#  '70',
#  'процентов',
#  '.',
#  'Если',
#  'сделка',
#  'будет',
#  'утверждена',
#  ',',
#  'то',
#  'государственный',
#  'китайский',
#  'банк',
#  'впервые',
#  'в',
#  'истории',
#  'получит',
#  'контроль',
#  'над',
#  'американским',
#  'финансовым',
#  'учреждением',
#  '.',
#  'Американцы',
#  'смогут',
#  'делать',
#  'вклады',
#  'в',
#  'его',
#  'филиалах',
#  ',',
#  'а',
#  'инвесторы',
#  'смогут',
#  'открывать',
#  'счета',
#  'и',
#  'играть',
#  'на',
#  'курсе',
#  'юаня',
#  '.',
#  'За',
#  'последние',
#  'годы',
#  'размеры',
#  'иностранных',
#  'инвестиций',
#  'Китая',
#  'резко',
#  'увеличились',
#  ',',
#  'однако',
#  'расширение',
#  'китайских',
#  'финансовых',
#  'учреждений',
#  'проходило',
#  'гораздо',
#  'медленнее',
#  '.',
#  'При',
#  'подписании',
#  'нового',
#  'соглашения',
#  'министр',
#  'торговли',
#  'Китая',
#  'Чэнь',
#  'Дэмин',
#  'заявил',
#  ',',
#  'что',
#  'одним',
#  'из',
#  'приоритетов',
#  'является',
#  'перевод',
#  'огромных',
#  'резервов',
#  'иностранной',
#  'валюты',
#  'в',
#  'зарубежные',
#  'активы',
#  '.',
#  'Барак',
#  'Обама',
#  'принимает',
#  'в',
#  'Белом',
#  'доме',
#  'своего',
#  'французского',
#  'коллегу',
#  'Николя',
#  'Саркози',
#  '.',
#  'Как',
#  'было',
#  'объявлено',
#  ',',
#  'президент',
#  'Франции',
#  'прибыл',
#  'в',
#  'Вашингтон',
#  ',',
#  'чтобы',
#  'обсудить',
#  'с',
#  'главой',
#  'администрации',
#  'США',
#  'ряд',
#  'насущных',
#  'проблем',
#  ',',
#  'главное',
#  'место',
#  'среди',
#  'которых',
#  'занимает',
#  'состояние',
#  'мировой',
#  'экономики',
#  'и',
#  'безопасность',
#  '.',
#  'В',
#  'частности',
#  ',',
#  'лидеры',
#  'намерены',
#  'обменяться',
#  'мнениями',
#  'о',
#  'перспективах',
#  'военных',
#  'действий',
#  'НАТО',
#  'в',
#  'Афганистане',
#  ',',
#  'волнениях',
#  'в',
#  'Пакистане',
#  'и',
#  'угрозах',
#  'экстремистов',
#  'в',
#  'Северной',
#  'Африке',
#  '.',
#  'В',
#  'воскресенье',
#  'Николя',
#  'Саркози',
#  'выпустил',
#  'заявление',
#  'с',
#  'осуждением',
#  'убийства',
#  'двух',
#  'французских',
#  'заложников',
#  'в',
#  'Нигере',
#  '.',
#  'В',
#  'недавнем',
#  'выступлении',
#  'по',
#  'французскому',
#  'телевидению',
#  'Саркози',
#  'выразил',
#  'мнение',
#  'о',
#  'необходимости',
#  'изменить',
#  'ситуацию',
#  'в',
#  'глобальной',
#  'экономике',
#  ',',
#  'при',
#  'которой',
#  'доллар',
#  'остается',
#  'главным',
#  'инструментом',
#  'расчетов',
#  'и',
#  'мировой',
#  'резервной',
#  'валютой',
#  '.',
#  'Вашингтонская',
#  'встреча',
#  'проходит',
#  'в',
#  'канун',
#  'передачи',
#  'Франции',
#  'полномочий',
#  'главы',
#  '«',
#  'Большой',
#  'двадцатки',
#  '»',
#  '.',
#  'Президент',
#  'Саркози',
#  'выразил',
#  'в',
#  'этой',
#  'связи',
#  'надежду',
#  'на',
#  'то',
#  ',',
#  'что',
#  'ему',
#  'удастся',
#  'за',
#  'время',
#  'председательства',
#  'в',
#  'G-20',
#  'провести',
#  'целый',
#  'ряд',
#  'реформ',
#  '.',
#  '22-летний',
#  'житель',
#  'Аризоны',
#  ',',
#  'открывший',
#  'стрельбу',
#  ',',
#  'в',
#  'результате',
#  'которой',
#  'пострадали',
#  '20',
#  'человек',
#  ',',
#  'и',
#  'попытавшийся',
#  'убить',
#  'члена',
#  'Конгресса',
#  'США',
#  ',',
#  'впервые',
#  'предстал',
#  'перед',
#  'судом',
#  'по',
#  'обвинению',
#  'в',
#  'совершении',
#  'федерального',
#  'преступления',
#  '.',
#  'В',
#  'понедельник',
#  'Джаред',
#  'Лофнер',
#  'в',
#  'наручниках',
#  'и',
#  'в',
#  'сопровождении',
#  'нескольких',
#  'охранников',
#  'доставлен',
#  'в',
#  'суд',
#  'в',
#  'города',
#  'Феникс',
#  '.',
#  'Побритый',
#  'наголо',
#  'и',
#  'одетый',
#  'в',
#  'тюремную',
#  'форму',
#  ',',
#  'он',
#  'сказал',
#  ',',
#  'что',
#  'знает',
#  'свои',
#  'права',
#  '.',
#  'Лофнер',
#  'предстал',
#  'перед',
#  'судом',
#  'через',
#  'два',
#  'дня',
#  'после',
#  'стрельбы',
#  'в',
#  'Тусоне',
#  '.',
#  'Тогда',
#  'были',
#  'убиты',
#  'шесть',
#  'человек',
#  ',',
#  'а',
#  'член',
#  'Палаты',
#  'представителей',
#  'Конгресса',
#  'США',
#  'от',
#  'штата',
#  'Аризона',
#  'Гэбриэль',
#  'Гиффордс',
#  'получила',
#  'ранение',
#  ...]

# %%
# ЗАЧЕМ?
# Добавляем пустые "слова" в начало и конец (для контекста) #
data = [["" for i in range(len(_column_types))] for i in range(_context_len)] + data
data = data + [["" for i in range(len(_column_types))] for i in range(_context_len)]

# %%
len(data)
# Out:
# 30944

# %%
data
# Out:
# [[''],
#  [''],
#  'В',
#  'понедельник',
#  '28',
#  'июня',
#  'у',
#  'здания',
#  'мэрии',
#  'Москвы',
#  'на',
#  'Тверской',
#  'площади',
#  'состоялась',
#  'очередная',
#  'несанкционированная',
#  'акция',
#  'протеста',
#  '«',
#  'День',
#  'гнева',
#  '»',
#  ',',
#  'в',
#  'этот',
#  'раз',
#  'направленная',
#  ',',
#  'главным',
#  'образом',
#  ',',
#  'против',
#  'политики',
#  'московских',
#  'и',
#  'подмосковных',
#  'властей',
#  '.',
#  'Среди',
#  'требований',
#  ',',
#  'выдвигаемых',
#  'организаторами',
#  'акции',
#  ':',
#  '«',
#  'немедленная',
#  'отставка',
#  'мэра',
#  'Москвы',
#  'Юрия',
#  'Лужкова',
#  ',',
#  'расследование',
#  'итогов',
#  'его',
#  'деятельности',
#  '»',
#  ',',
#  '«',
#  'созыв',
#  'московского',
#  'общественного',
#  'форума',
#  'для',
#  'обсуждения',
#  'путей',
#  'реформирования',
#  'основных',
#  'сфер',
#  'жизнедеятельности',
#  'в',
#  'Москве',
#  '»',
#  ',',
#  '«',
#  'восстановление',
#  'прямых',
#  'выборов',
#  'глав',
#  'регионов',
#  'России',
#  '»',
#  ',',
#  '«',
#  'роспуск',
#  'нелегитимной',
#  'Мосгордумы',
#  '»',
#  ',',
#  'отставка',
#  'подмосковного',
#  'губернатора',
#  'Бориса',
#  'Громова',
#  'и',
#  'др',
#  '.',
#  'Участникам',
#  'акции',
#  'предлагалось',
#  'принести',
#  'с',
#  'собой',
#  'лист',
#  'бумаги',
#  'или',
#  'кусок',
#  'ткани',
#  'чёрного',
#  'цвета',
#  ',',
#  'символизирующие',
#  '«',
#  'чёрную',
#  'метку',
#  '»',
#  'для',
#  'Юрия',
#  'Лужкова',
#  '.',
#  'Начало',
#  'акции',
#  'было',
#  'намечено',
#  'на',
#  '19',
#  'часов',
#  ';',
#  'подчёркивалось',
#  ',',
#  'что',
#  'она',
#  'состоится',
#  'несмотря',
#  'на',
#  'запрет',
#  'властей',
#  '.',
#  'Освещающие',
#  'акцию',
#  'блоггеры',
#  'сообщили',
#  ',',
#  'что',
#  'автобусы',
#  'с',
#  'милицией',
#  'стали',
#  'занимать',
#  'площадь',
#  'у',
#  'памятника',
#  'Юрию',
#  'Долгорукому',
#  'ещё',
#  'с',
#  '15',
#  'часов',
#  'дня',
#  ',',
#  'центральная',
#  'часть',
#  'площади',
#  'была',
#  'огорожена',
#  '.',
#  'Ко',
#  'времени',
#  'начала',
#  'акции',
#  'вокруг',
#  'огороженной',
#  'территории',
#  'собралось',
#  'множество',
#  'журналистов',
#  'и',
#  'прохожих',
#  ',',
#  'по',
#  'мере',
#  'прибытия',
#  'самих',
#  'участников',
#  'акции',
#  'милиция',
#  'начала',
#  'планомерно',
#  'их',
#  'задерживать',
#  'и',
#  'заталкивать',
#  'в',
#  'автобусы',
#  '.',
#  'Всего',
#  ',',
#  'по',
#  'сообщениям',
#  'блоггеров',
#  'и',
#  'СМИ',
#  ',',
#  'было',
#  'задержано',
#  'более',
#  '30',
#  'человек',
#  '.',
#  'Пользователь',
#  'ЖЖ',
#  'zyalt',
#  'сообщает',
#  ',',
#  'что',
#  'среди',
#  'задержанных',
#  'оказался',
#  'депутат',
#  'муниципального',
#  'собрания',
#  'района',
#  'Отрадное',
#  ',',
#  'сопредседатель',
#  'московского',
#  'отделения',
#  'движения',
#  '«',
#  'Солидарность',
#  '»',
#  'Михаил',
#  'Вельмакин',
#  ',',
#  'известный',
#  'правозащитник',
#  'Лев',
#  'Пономарев',
#  ',',
#  'координатор',
#  'движения',
#  '«',
#  'Левый',
#  'фронт',
#  '»',
#  'Сергей',
#  'Удальцов',
#  '.',
#  'Организаторами',
#  'акции',
#  'выступили',
#  'движение',
#  '«',
#  'За',
#  'права',
#  'человека',
#  '»',
#  ',',
#  'Союз',
#  'координационных',
#  'советов',
#  '(',
#  'СКС',
#  ')',
#  ',',
#  'институт',
#  '«',
#  'Коллективное',
#  'действие',
#  '»',
#  ',',
#  '«',
#  'Жилищная',
#  'солидарность',
#  '»',
#  ',',
#  'Движение',
#  'общежитий',
#  'Москвы',
#  ',',
#  'Движение',
#  'в',
#  'защиту',
#  'Химкинского',
#  'леса',
#  ',',
#  'движение',
#  '«',
#  'Московский',
#  'совет',
#  '»',
#  ',',
#  '«',
#  'Координационный',
#  'совет',
#  'пострадавших',
#  'соинвесторов',
#  '»',
#  '.',
#  'Конец',
#  'света',
#  ',',
#  'который',
#  'предрекал',
#  'проповедник',
#  '-',
#  'евангелист',
#  'Герольд',
#  'Кемпинг',
#  'утром',
#  'в',
#  '06.00',
#  'по',
#  'московскому',
#  'времени',
#  '21',
#  'мая',
#  '2011',
#  'года',
#  'так',
#  'и',
#  'не',
#  'наступил',
#  '.',
#  'Это',
#  'далеко',
#  'не',
#  'первое',
#  'несбывшееся',
#  'предсказание',
#  'апокалипсиса',
#  '.',
#  'Поначалу',
#  'на',
#  'него',
#  'практически',
#  'не',
#  'обратили',
#  'внимания',
#  ',',
#  'однако',
#  ',',
#  'с',
#  'приближением',
#  'этой',
#  'даты',
#  ',',
#  'немало',
#  'СМИ',
#  'в',
#  'поисках',
#  'сюжета',
#  ',',
#  'останавливались',
#  'на',
#  'этом',
#  ',',
#  'создавая',
#  'прекрасную',
#  'бесплатную',
#  'PR-компанию',
#  'для',
#  'горе-пророка',
#  '.',
#  'Вполне',
#  'вероятно',
#  ',',
#  'что',
#  'Герольд',
#  'Кемпинг',
#  'объяснит',
#  'это',
#  'какой-либо',
#  'неточностью',
#  'и',
#  'перенесет',
#  'катастрофу',
#  'на',
#  'некоторое',
#  'время',
#  'вперёд',
#  ',',
#  'и',
#  'по',
#  'прежнему',
#  'будет',
#  'оставаться',
#  'в',
#  'центре',
#  'внимания',
#  '.',
#  'Так',
#  ',',
#  'согласно',
#  'его',
#  'пророчествам',
#  ',',
#  '6',
#  'сентября',
#  '1994',
#  'года',
#  'на',
#  'Землю',
#  'должен',
#  'был',
#  'опуститься',
#  'Иисус',
#  'Христос',
#  '.',
#  'Следующее',
#  'подобное',
#  'мероприятие',
#  ',',
#  'по',
#  'прогнозам',
#  'майя',
#  ',',
#  'ожидается',
#  '21',
#  'декабря',
#  '2012',
#  'года',
#  ',',
#  'однако',
#  'не',
#  'следует',
#  'забывать',
#  ',',
#  'что',
#  'конец',
#  'этой',
#  'цивилизации',
#  'наступил',
#  'значительно',
#  'раньше',
#  ',',
#  'и',
#  'это',
#  'отчего-то',
#  'не',
#  'отображено',
#  'в',
#  'их',
#  'наследии',
#  ',',
#  'поэтому',
#  'и',
#  'достоверность',
#  'подобного',
#  'прорицания',
#  'далеко',
#  'не',
#  'очевидна',
#  '.',
#  'Если',
#  '-',
#  'же',
#  'и',
#  'майя',
#  'ошиблись',
#  ',',
#  'то',
#  'расслабляться',
#  'всё-равно',
#  'не',
#  'стоит',
#  '.',
#  'Апокалиптических',
#  'теорий',
#  'ещё',
#  'достаточно',
#  ':',
#  '*',
#  '2021',
#  'год',
#  '—',
#  'инверсия',
#  'магнитного',
#  'поля',
#  'Земли',
#  'уничтожит',
#  'часть',
#  'человечества',
#  '.',
#  '*',
#  '2060',
#  'год',
#  '—',
#  'Согласно',
#  'расчётам',
#  'Исаака',
#  'Ньютона',
#  ',',
#  'сделанным',
#  'в',
#  '1704',
#  'году',
#  'по',
#  'библейской',
#  'книге',
#  'Даниила',
#  'станет',
#  'последним',
#  'для',
#  'людей',
#  '.',
#  '*',
#  '2242',
#  'год',
#  '—',
#  'конец',
#  'эпохи',
#  'Солнца',
#  'согласно',
#  'теории',
#  'смены',
#  'планетных',
#  'эпох',
#  ',',
#  'которая',
#  'была',
#  'изложена',
#  'в',
#  'работах',
#  'ибн',
#  'Эзра',
#  ',',
#  'Авраама',
#  'и',
#  'Абу',
#  'Машара',
#  '.',
#  '*',
#  '2892',
#  'год',
#  '—',
#  'апокалипсис',
#  'обещанный',
#  'Авелем',
#  '.',
#  '*',
#  '3797',
#  'год',
#  '—',
#  'кончину',
#  'миру',
#  'предрёк',
#  'сам',
#  'Нострадамус',
#  '.',
#  '*',
#  '5079',
#  'год',
#  '—',
#  'сочла',
#  'последним',
#  'всемирно',
#  'известная',
#  'Ванга',
#  '…',
#  'Промышленный',
#  'и',
#  'коммерческий',
#  'банк',
#  'Китая',
#  '(',
#  'Industrial',
#  'and',
#  'Commercial',
#  'Bank',
#  'of',
#  'China',
#  ')',
#  ',',
#  'по',
#  'некоторым',
#  'показателям',
#  '—',
#  'крупнейший',
#  'банк',
#  'мира',
#  ',',
#  'подписал',
#  'соглашение',
#  'о',
#  'покупке',
#  'контрольной',
#  'доли',
#  'в',
#  'американском',
#  'отделении',
#  'Bank',
#  'of',
#  'East',
#  'Asia',
#  ',',
#  'управляющим',
#  '13-ю',
#  'филиалами',
#  'в',
#  'Калифорнии',
#  'и',
#  'Нью-Йорке',
#  '.',
#  'За',
#  '80',
#  'процентов',
#  'акций',
#  'этой',
#  'финансовой',
#  'структуры',
#  ',',
#  'подконтрольный',
#  'китайскому',
#  'правительству',
#  'банк',
#  'заплатит',
#  'около',
#  '100',
#  'млн',
#  'долларов',
#  '.',
#  'Соглашение',
#  'было',
#  'подписано',
#  'в',
#  'минувшую',
#  'пятницу',
#  'в',
#  'Чикаго',
#  ',',
#  'в',
#  'последний',
#  'день',
#  'визита',
#  'председателя',
#  'КНР',
#  'Ху',
#  'Цзиньтао',
#  'в',
#  'США',
#  '.',
#  'Сделка',
#  'ожидает',
#  'утверждения',
#  'американскими',
#  'регулирующими',
#  'органами',
#  ',',
#  'что',
#  'может',
#  'задержать',
#  'ее',
#  'завершение',
#  'до',
#  'конца',
#  'этого',
#  'года',
#  '.',
#  'Доля',
#  'правительства',
#  'Китая',
#  'в',
#  'Industrial',
#  'and',
#  'Commercial',
#  'Bank',
#  'of',
#  'China',
#  'составляет',
#  '70',
#  'процентов',
#  '.',
#  'Если',
#  'сделка',
#  'будет',
#  'утверждена',
#  ',',
#  'то',
#  'государственный',
#  'китайский',
#  'банк',
#  'впервые',
#  'в',
#  'истории',
#  'получит',
#  'контроль',
#  'над',
#  'американским',
#  'финансовым',
#  'учреждением',
#  '.',
#  'Американцы',
#  'смогут',
#  'делать',
#  'вклады',
#  'в',
#  'его',
#  'филиалах',
#  ',',
#  'а',
#  'инвесторы',
#  'смогут',
#  'открывать',
#  'счета',
#  'и',
#  'играть',
#  'на',
#  'курсе',
#  'юаня',
#  '.',
#  'За',
#  'последние',
#  'годы',
#  'размеры',
#  'иностранных',
#  'инвестиций',
#  'Китая',
#  'резко',
#  'увеличились',
#  ',',
#  'однако',
#  'расширение',
#  'китайских',
#  'финансовых',
#  'учреждений',
#  'проходило',
#  'гораздо',
#  'медленнее',
#  '.',
#  'При',
#  'подписании',
#  'нового',
#  'соглашения',
#  'министр',
#  'торговли',
#  'Китая',
#  'Чэнь',
#  'Дэмин',
#  'заявил',
#  ',',
#  'что',
#  'одним',
#  'из',
#  'приоритетов',
#  'является',
#  'перевод',
#  'огромных',
#  'резервов',
#  'иностранной',
#  'валюты',
#  'в',
#  'зарубежные',
#  'активы',
#  '.',
#  'Барак',
#  'Обама',
#  'принимает',
#  'в',
#  'Белом',
#  'доме',
#  'своего',
#  'французского',
#  'коллегу',
#  'Николя',
#  'Саркози',
#  '.',
#  'Как',
#  'было',
#  'объявлено',
#  ',',
#  'президент',
#  'Франции',
#  'прибыл',
#  'в',
#  'Вашингтон',
#  ',',
#  'чтобы',
#  'обсудить',
#  'с',
#  'главой',
#  'администрации',
#  'США',
#  'ряд',
#  'насущных',
#  'проблем',
#  ',',
#  'главное',
#  'место',
#  'среди',
#  'которых',
#  'занимает',
#  'состояние',
#  'мировой',
#  'экономики',
#  'и',
#  'безопасность',
#  '.',
#  'В',
#  'частности',
#  ',',
#  'лидеры',
#  'намерены',
#  'обменяться',
#  'мнениями',
#  'о',
#  'перспективах',
#  'военных',
#  'действий',
#  'НАТО',
#  'в',
#  'Афганистане',
#  ',',
#  'волнениях',
#  'в',
#  'Пакистане',
#  'и',
#  'угрозах',
#  'экстремистов',
#  'в',
#  'Северной',
#  'Африке',
#  '.',
#  'В',
#  'воскресенье',
#  'Николя',
#  'Саркози',
#  'выпустил',
#  'заявление',
#  'с',
#  'осуждением',
#  'убийства',
#  'двух',
#  'французских',
#  'заложников',
#  'в',
#  'Нигере',
#  '.',
#  'В',
#  'недавнем',
#  'выступлении',
#  'по',
#  'французскому',
#  'телевидению',
#  'Саркози',
#  'выразил',
#  'мнение',
#  'о',
#  'необходимости',
#  'изменить',
#  'ситуацию',
#  'в',
#  'глобальной',
#  'экономике',
#  ',',
#  'при',
#  'которой',
#  'доллар',
#  'остается',
#  'главным',
#  'инструментом',
#  'расчетов',
#  'и',
#  'мировой',
#  'резервной',
#  'валютой',
#  '.',
#  'Вашингтонская',
#  'встреча',
#  'проходит',
#  'в',
#  'канун',
#  'передачи',
#  'Франции',
#  'полномочий',
#  'главы',
#  '«',
#  'Большой',
#  'двадцатки',
#  '»',
#  '.',
#  'Президент',
#  'Саркози',
#  'выразил',
#  'в',
#  'этой',
#  'связи',
#  'надежду',
#  'на',
#  'то',
#  ',',
#  'что',
#  'ему',
#  'удастся',
#  'за',
#  'время',
#  'председательства',
#  'в',
#  'G-20',
#  'провести',
#  'целый',
#  'ряд',
#  'реформ',
#  '.',
#  '22-летний',
#  'житель',
#  'Аризоны',
#  ',',
#  'открывший',
#  'стрельбу',
#  ',',
#  'в',
#  'результате',
#  'которой',
#  'пострадали',
#  '20',
#  'человек',
#  ',',
#  'и',
#  'попытавшийся',
#  'убить',
#  'члена',
#  'Конгресса',
#  'США',
#  ',',
#  'впервые',
#  'предстал',
#  'перед',
#  'судом',
#  'по',
#  'обвинению',
#  'в',
#  'совершении',
#  'федерального',
#  'преступления',
#  '.',
#  'В',
#  'понедельник',
#  'Джаред',
#  'Лофнер',
#  'в',
#  'наручниках',
#  'и',
#  'в',
#  'сопровождении',
#  'нескольких',
#  'охранников',
#  'доставлен',
#  'в',
#  'суд',
#  'в',
#  'города',
#  'Феникс',
#  '.',
#  'Побритый',
#  'наголо',
#  'и',
#  'одетый',
#  'в',
#  'тюремную',
#  'форму',
#  ',',
#  'он',
#  'сказал',
#  ',',
#  'что',
#  'знает',
#  'свои',
#  'права',
#  '.',
#  'Лофнер',
#  'предстал',
#  'перед',
#  'судом',
#  'через',
#  'два',
#  'дня',
#  'после',
#  'стрельбы',
#  'в',
#  'Тусоне',
#  '.',
#  'Тогда',
#  'были',
#  'убиты',
#  'шесть',
#  'человек',
#  ',',
#  'а',
#  'член',
#  'Палаты',
#  'представителей',
#  'Конгресса',
#  'США',
#  'от',
#  'штата',
#  'Аризона',
#  'Гэбриэль',
#  'Гиффордс',
#  ...]

# %%
# Находим индексы столбцов в переданных данных #
word_index = _column_types.index("WORD")
if "POS" in _column_types:
    pos_index = _column_types.index("POS")
else:
    pos_index = None
if "CHUNK" in _column_types:
    chunk_index = _column_types.index("CHUNK")
else:
    chunk_index = None

# %%
word_index
# Out:
# 0

# %%
# Список признаков (строка == набор признаков для слова из массива data) #
features_list = []

# %%
_morph = pymorphy2.MorphAnalyzer()

# %%
_morph.parse('Открой')[0].tag.POS
# Out:
# 'VERB'

# %%
# Возвращает POS-тег слова #
def get_pos_tag(token):
    return _morph.parse(token)[0].tag.POS

# %%
def get_capital(token):
    pattern = re.compile("[{}]+$".format(re.escape(string.punctuation)))
    if pattern.match(token):
        return "none"
    if len(token) == 0:
        return "none"
    if token.islower():
        return "lower"
    elif token.isupper():
        return "upper"
    elif token[0].isupper() and len(token) == 1:
        return "proper"
    elif token[0].isupper() and token[1:].islower():
        return "proper"
    else:
        return "camel"

# %%
# Признак того, является ли слово пунктуацией #
def get_is_punct(token):
    pattern = re.compile("[{}]+$".format(re.escape(string.punctuation)))
    if pattern.match(token):
        return "yes"
    else:
        return "no"

# %%
# Заполнение массива features_list "сырыми" данными (без отсева) #
for k in range(len(data) - 2 * _context_len):
    arr = []
    i = k + _context_len

    if pos_index is not None:
        pos_arr = [data[i][pos_index]]
        for j in range(1, _context_len + 1):
            pos_arr.append(data[i - j][pos_index])
            pos_arr.append(data[i + j][pos_index])
    else:
        pos_arr = [get_pos_tag(data[i][word_index])]
        for j in range(1, _context_len + 1):
            pos_arr.append(get_pos_tag(data[i - j][word_index]))
            pos_arr.append(get_pos_tag(data[i + j][word_index]))
    arr += pos_arr

    if chunk_index is not None:
        chunk_arr = [data[i][chunk_index]]
        for j in range(1, _context_len + 1):
            chunk_arr.append(data[i - j][chunk_index])
            chunk_arr.append(data[i + j][chunk_index])
        arr += chunk_arr

    capital_arr = [get_capital(data[i][word_index])]
    for j in range(1, _context_len + 1):
        capital_arr.append(get_capital(data[i - j][word_index]))
        capital_arr.append(get_capital(data[i + j][word_index]))
    arr += capital_arr

    is_punct_arr = [get_is_punct(data[i][word_index])]
    for j in range(1, _context_len + 1):
        is_punct_arr.append(get_is_punct(data[i - j][word_index]))
        is_punct_arr.append(get_is_punct(data[i + j][word_index]))
    arr += is_punct_arr

    is_number_arr = [get_is_number(data[i][word_index])]
    for j in range(1, _context_len + 1):
        is_number_arr.append(get_is_number(data[i - j][word_index]))
        is_number_arr.append(get_is_number(data[i + j][word_index]))
    arr += is_number_arr

    initial_arr = [get_initial(data[i][word_index])]
    for j in range(1, _context_len + 1):
        initial_arr.append(get_initial(data[i - j][word_index]))
        initial_arr.append(get_initial(data[i + j][word_index]))
    arr += initial_arr

    features_list.append(arr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-d615e99e858a> in <module>()
#      29     arr += capital_arr
#      30
# ---> 31     is_punct_arr = [get_is_punct(data[i][word_index])]
#      32     for j in range(1, _context_len + 1):
#      33         is_punct_arr.append(get_is_punct(data[i - j][word_index]))
#
# TypeError: get_is_punct() missing 1 required positional argument: 'token'

# %%
X_train = gen.fit_transform([[el] for el in factrueval_devset.words()], 
                            Y_train, 
                            path=TRAINSET_PATH)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-4e78e9d30223> in <module>()
# ----> 1 X_train = gen.fit_transform([[el] for el in factrueval_devset.words()],
#       2                             Y_train,
#       3                             path=TRAINSET_PATH)
#
# NameError: name 'gen' is not defined
